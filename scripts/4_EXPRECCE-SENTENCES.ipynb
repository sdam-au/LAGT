# %%
#import pandas as pd
import spacy
import pandas as pd
from spacy.tokens import Doc
import sddk
import re
import regex
import unicodedata
from greek_accentuation.characters import strip_accents
from greek_accentuation.syllabify import *
from greek_accentuation.accentuation import *
import nltk
import os
import pickle
import json

# %%
#!sudo pip install https://huggingface.co/Jacobo/grc_proiel_trf/resolve/main/grc_proiel_trf-3.7.5-py3-none-any.whl
nlp = spacy.load('grc_proiel_trf')

# %%
spacy.__version__
# Out:
# '3.8.4'

# %%
doc = nlp('δοκῶ μοι περὶ ὧν πυνθάνεσθε οὐκ ἀμελέτητος εἶναι, δοκῶ μοι περὶ ὧν πυνθάνεσθε οὐκ ἀμελέτητος εἶναι.')

# %%
for t in doc:
    print(t.text, t.lemma_, t.pos_)
# Out:
# δοκῶ δοκέω VERB
# μοι ἐγώ PRON
# περὶ περί ADP
# ὧν ὅς PRON
# πυνθάνεσθε πυνθάνομαι VERB
# οὐκ οὐ ADV
# ἀμελέτητος ἀμελέτητος ADJ
# εἶναι εἰμί AUX
# , , PUNCT
# δοκῶ δοκέω VERB
# μοι ἐγώ PRON
# περὶ περί ADP
# ὧν ὅς PRON
# πυνθάνεσθε πυνθάνομαι VERB
# οὐκ οὐ ADV
# ἀμελέτητος ἀμελέτητος ADJ
# εἶναι εἰμί AUX
# . . PUNCT

# %% [markdown]
# xLet's improve it: preclean the string and make it suitable to work with large documents

# %% [markdown]
# # Text preprocessing & function developement

# %%
# functioms for cleaning the string

def grave_to_acute(string):
    GRAVE = "\u0300"
    ACUTE = "\u0301"
    return unicodedata.normalize("NFC", "".join(unicodedata.normalize("NFD", string).replace(GRAVE, ACUTE)))

def possible_accentuation(morph):
    try:
        if isinstance(morph, str):
            morph = strip_accents(morph)
            morph = rebreath(morph)
            s = syllabify(morph)
            for accentuation in possible_accentuations(s, default_short=True):
                pos, accent = accentuation
                final = s[1 - pos:] if pos > 1 else [""]
                morph_acc_var = "".join(s[:-pos] + [syllable_add_accent(s[-pos], accent)] + final)
                return morph_acc_var  # Return the first accentuation immediately
        return morph  # If no accentuation is available, return the original morph
    except:
        return morph

def decap(token):
    if len(token) > 1:
        if token[1].isupper():
            token = token[0] + token[1:].lower()
            token = possible_accentuation(token)
    return token

def clean_string(string):
    string = re.sub("ϲ(\W)", r"ς\1", string) # if "ϲ" is last letter of a word
    string = re.sub("ϲ(\w)", r"σ\1", string)
    string = grave_to_acute(string)
    string = string.replace("—", " — ")
    cleaned_string = regex.sub(r'[^\p{Greek}\p{P}]', ' ', string)
    cleaned_string = " ".join([decap(token) for token in cleaned_string.split()])
    cleaned_string = regex.sub(' +', ' ', cleaned_string)
    cleaned_string = cleaned_string.replace("·", ".")
    return cleaned_string

# %%
def get_doc(string, segment_len=100000):
    if len(string) > segment_len:
        segment = string[:segment_len]
        matches = [(m.start(0), m.end(0)) for m in re.finditer('(\.\s|·\s)', segment)]
        if matches:
            split_at = matches[-1][1]  # taking the end index of last match
            current_segment = segment[:split_at]
            next_segment_beginning = segment[split_at:]
        else:
            current_segment = segment
            next_segment_beginning = ""

        segment_doc = nlp(current_segment)
        segment_docs = [segment_doc]

        for n in range(segment_len, len(string), segment_len):
            segment = string[n:n+segment_len]
            if len(segment) == segment_len:
                matches = [(m.start(0), m.end(0)) for m in re.finditer('(\.\s|·\s)', segment)]
                if matches:
                    split_at = matches[-1][1]
                    current_segment = next_segment_beginning + segment[:split_at]
                    next_segment_beginning = segment[split_at:]
                else:
                    current_segment = next_segment_beginning + segment
                    next_segment_beginning = ""
            else:
                current_segment = next_segment_beginning + segment

            segment_doc = nlp(current_segment)
            segment_docs.append(segment_doc)

        doc = Doc.from_docs(segment_docs)
    else:
        doc = nlp(string)
    return doc

# %%
# extract lemmata from the sentences
# target_path = "../data/large_files/sents_data/"
target_path = "/srv/data/greek/exprecce_sentences/"
try:
    os.mkdir(target_path)
except:
    pass

sents_data_ready = os.listdir(target_path)


#pos_dict = {"VERB" : "v", "ADJ" : "a", "PROPN" : "n", "NOUN" : "n"}
reformat_tags_dict = {
    "NOUN": "n",
    "VERB": "v",
    "ADJ": "a",
    "ADV": "r",
    "PRON": "p",
    "DET": "l",
    "ADP": "r",
    "CCONJ": "c",
    "SCONJ": "c",
    "PROPN": "n",
    "PUNCT": "u",
    "n": "n",
    "v": "v",
    "a": "a",
    "r": "r",
    "p": "p",
    "l": "l",
    "c": "c",
    "u": "u"  # Assuming punctuation remains "u"
}


def reformat_tags(tag):
    try:
        return reformat_tags_dict[tag]
    except:
        return "x"


def get_sents_data(doc, doc_id):
    sentences = []
    lemmatized_sentences = []
    doc_sentdata = []
    for n, sent in enumerate(doc.sents):
        sentences.append(sent.text)
    
        # Extract lemmata for specific POS tags
        sentence_lemmata = [regex.sub(r'[^\p{Greek}]', "", t.lemma_) for t in sent if
                            t.pos_ in ["NOUN", "VERB", "ADJ", "PROPN"]]
        lemmatized_sentences.append(sentence_lemmata)
    
        # Extract token data including text, lemma, POS, and position indices
        token_data = [
            (t.text,
             t.lemma_.lower(),
             reformat_tags(t.pos_),
             (t.idx - sent[0].idx, t.idx - sent[0].idx + len(t))
             )
            for t in sent
        ]
    
        doc_sentdata.append((doc_id, n, sent.text, token_data))
    return doc_sentdata, lemmatized_sentences, sentences

# %%
exprecce = pd.read_json("../data/exprecce.json")
exprecce.head()
# Out:
#                                                title          doc_id  \
# 0     The Letter of the Churches of Vienne and Lyons  tlg1352.tlg001
# 1            Martyrium Pionii presbyteri et sodalium  tlg2005.tlg001
# 2      Martyrium Agapae, Irenae, Chionae et sodalium  tlg2011.tlg001
# 3                            Testamentum xl martyrum  tlg2015.tlg001
# 4  Passio sancti Sabae Gothi (sub auctore Athanar...  tlg5451.tlg001
#
#   author_id     raw_date  not_before  not_after     genre author provenience  \
# 0   tlg1352       A.D. 2         101      200.0  Hagiogr.   None   christian
# 1   tlg2005       A.D. 4         301      400.0  Hagiogr.   None   christian
# 2   tlg2011       A.D. 4         301      400.0  Hagiogr.   None   christian
# 3   tlg2015  post A.D. 4         401        NaN  Hagiogr.   None   christian
# 4   tlg5451       A.D. 4         301      400.0  Hagiogr.   None   christian
#
#      source                                             string
# 0  exprecce  οἱ ἐν Βιέννῃ καὶ Λουγδούνῳ τῆς Γαλλίας παροικο...
# 1  exprecce  Μαρτύριον τοῦ ἁγίου Πιονίου τοῦ πρεσβυτέρου κα...
# 2  exprecce  Μαρτύριον τῶν ἁγίων Ἀγάπης, Εἰρήνης καὶ Χιόνης...
# 3  exprecce  ΔΙΑΘΗΚΗ τῶν ἁγίων καὶ ἐνδόξων τοῦ Χριστοῦ τεσσ...
# 4  exprecce  Μαρτύριον τοῦ ἁγίου Σάβα τοῦ Γότθου. Ἡ ἐκκλησί...

# %% [markdown]
# ## Get exprecce sentence data

# %%
def get_row_data(row):
    doc_id = row["doc_id"]
    string = row["string"]
    doc = get_doc(string)
    tokencount = len(doc)
    sents_data, sentences, lemmatized_sentences = get_sents_data(doc, doc_id)
    with open(target_path + doc_id + ".pickle", "wb") as f:
       pickle.dump(sents_data, f)
    return tokencount #sentences, lemmatized_sentences # , source, lemmata_source

# Apply function
tokencount = exprecce.apply(lambda row: get_row_data(row), axis=1)

# Assign the results to separate columns in your DataFrame
#exprecce["sentences"] = result[0]  # Assign sentences
#exprecce["lemmatized_sentences"] = result[1]  # Assign lemmatized_sentences

# %%
exprecce["tokencount"] = tokencount

# %%
exprecce.drop("string", axis=1, inplace=True)

# %%
exprecce.to_json("../data/exprecce_sentences.json", orient="records")

# %%
os.listdir(target_path)[:10]
# Out:
# ['tlg0389.tlg001.pickle',
#  'tlg2062.tlg050.pickle',
#  'tlg2017.tlg065.pickle',
#  'tlg2012.tlg001.pickle',
#  'tlg0304.tlg001.pickle',
#  'tlg2798.tlg005.pickle',
#  'tlg0388.tlg002.pickle',
#  'tlg2062.tlg043.pickle',
#  'tlg2010.tlg001.pickle',
#  'tlg2008.tlg001.pickle']

# %%
with open(target_path + os.listdir(target_path)[0], "rb") as f:
    doc_sentdata = pickle.load(f)
doc_sentdata[:3]
# Out:
# [('tlg0389.tlg001',
#   0,
#   'Μαρτύριον τοῦ ἁγίου ἀποστόλου Πέτρου.',
#   [('Μαρτύριον', 'μαρτύριος', 'NOUN', (0, 9)),
#    ('τοῦ', 'ὁ', 'DET', (10, 13)),
#    ('ἁγίου', 'ἅγιος', 'ADJ', (14, 19)),
#    ('ἀποστόλου', 'ἀποστόλου', 'NOUN', (20, 29)),
#    ('Πέτρου', 'πέτρος', 'PROPN', (30, 36)),
#    ('.', '.', 'PUNCT', (36, 37))]),
#  ('tlg0389.tlg001',
#   1,
#   'Κυριακῆς οὔσης, ὁμιλοῦντος τοῦ Πέτρου τοῖς ἀδελφοῖς, καὶ προτρέποντος εἰς τὴν τοῦ Χριστοῦ πίστιν, παρόντων πολλῶν συγκλητικῶν καὶ ἱππικῶν πλειόνων καὶ γυναικῶν πλουσίων καὶ ματρωνῶν καὶ στηριζομένων τῇ πίστει,',
#   [('Κυριακῆς', 'κυριακός', 'ADJ', (0, 8)),
#    ('οὔσης', 'εἰμί', 'AUX', (9, 14)),
#    (',', ',', 'PUNCT', (14, 15)),
#    ('ὁμιλοῦντος', 'ὁμιλοῦντος', 'VERB', (16, 26)),
#    ('τοῦ', 'ὁ', 'DET', (27, 30)),
#    ('Πέτρου', 'πέτρος', 'PROPN', (31, 37)),
#    ('τοῖς', 'ὁ', 'DET', (38, 42)),
#    ('ἀδελφοῖς', 'ἀδελφός', 'NOUN', (43, 51)),
#    (',', ',', 'PUNCT', (51, 52)),
#    ('καὶ', 'καί', 'CCONJ', (53, 56)),
#    ('προτρέποντος', 'προτρέπω', 'VERB', (57, 69)),
#    ('εἰς', 'εἰς', 'ADP', (70, 73)),
#    ('τὴν', 'ὁ', 'DET', (74, 77)),
#    ('τοῦ', 'ὁ', 'DET', (78, 81)),
#    ('Χριστοῦ', 'χριστός', 'PROPN', (82, 89)),
#    ('πίστιν', 'πίστις', 'NOUN', (90, 96)),
#    (',', ',', 'PUNCT', (96, 97)),
#    ('παρόντων', 'πάρειμι', 'VERB', (98, 106)),
#    ('πολλῶν', 'πολύς', 'ADJ', (107, 113)),
#    ('συγκλητικῶν', 'συγκλητικός', 'ADJ', (114, 125)),
#    ('καὶ', 'καί', 'CCONJ', (126, 129)),
#    ('ἱππικῶν', 'ἱππικός', 'ADJ', (130, 137)),
#    ('πλειόνων', 'πολύς', 'ADJ', (138, 146)),
#    ('καὶ', 'καί', 'CCONJ', (147, 150)),
#    ('γυναικῶν', 'γυνή', 'NOUN', (151, 159)),
#    ('πλουσίων', 'πλούσιος', 'ADJ', (160, 168)),
#    ('καὶ', 'καί', 'CCONJ', (169, 172)),
#    ('ματρωνῶν', 'ματρωνός', 'NOUN', (173, 181)),
#    ('καὶ', 'καί', 'CCONJ', (182, 185)),
#    ('στηριζομένων', 'στηριζομένω', 'VERB', (186, 198)),
#    ('τῇ', 'ὁ', 'DET', (199, 201)),
#    ('πίστει', 'πίστις', 'NOUN', (202, 208)),
#    (',', ',', 'PUNCT', (208, 209))]),
#  ('tlg0389.tlg001',
#   2,
#   'μία τις ἔνθα οὖσα γυνὴ πάνυ πλουσία, ἥτις τὴν ἐπίκλησιν τοὔνομα Χρυσὴ εἶχεν, διὰ τὸ πᾶν αὐτῆς σκεῦος χρύσεον ὑπάρχειν ἥτις γεννηθεῖσα οὔτε ἀργυρέῳ ποτὲ σκεύει ἐχρήσατο οὔτε ὑελῷ, εἰ μὴ μόνοις χρυσέοις εἶπεν τῷ Πέτρῳ· Πέτρε, θεοῦ δοῦλε·',
#   [('μία', 'εἷς', 'NUM', (0, 3)),
#    ('τις', 'τίς', 'DET', (4, 7)),
#    ('ἔνθα', 'ἔνθα', 'ADV', (8, 12)),
#    ('οὖσα', 'εἰμί', 'AUX', (13, 17)),
#    ('γυνὴ', 'γυνή', 'NOUN', (18, 22)),
#    ('πάνυ', 'πάνυ', 'ADV', (23, 27)),
#    ('πλουσία', 'πλούσιος', 'ADJ', (28, 35)),
#    (',', ',', 'PUNCT', (35, 36)),
#    ('ἥτις', 'ὅστις', 'PRON', (37, 41)),
#    ('τὴν', 'ὁ', 'DET', (42, 45)),
#    ('ἐπίκλησιν', 'ἐπίκλησις', 'NOUN', (46, 55)),
#    ('τοὔ', 'τοὔ', 'NOUN', (56, 59)),
#    ('νομα', 'νομα', 'NOUN', (59, 63)),
#    ('Χρυσὴ', 'χρυσὴ', 'ADJ', (64, 69)),
#    ('εἶχεν', 'ἔχω', 'VERB', (70, 75)),
#    (',', ',', 'PUNCT', (75, 76)),
#    ('διὰ', 'διά', 'ADP', (77, 80)),
#    ('τὸ', 'ὁ', 'DET', (81, 83)),
#    ('πᾶν', 'πᾶς', 'DET', (84, 87)),
#    ('αὐτῆς', 'αὐτός', 'PRON', (88, 93)),
#    ('σκεῦος', 'σκεῦος', 'NOUN', (94, 100)),
#    ('χρύσεον', 'χρύσεος', 'ADJ', (101, 108)),
#    ('ὑπάρχειν', 'ὑπάρχω', 'VERB', (109, 117)),
#    ('ἥτις', 'ὅστις', 'PRON', (118, 122)),
#    ('γεννηθεῖσα', 'γεννάω', 'VERB', (123, 133)),
#    ('οὔτε', 'οὔτε', 'CCONJ', (134, 138)),
#    ('ἀργυρέῳ', 'ἀργύρεος', 'ADJ', (139, 146)),
#    ('ποτὲ', 'ποτε', 'ADV', (147, 151)),
#    ('σκεύει', 'σκεύει', 'NOUN', (152, 158)),
#    ('ἐχρήσατο', 'χράω', 'VERB', (159, 167)),
#    ('οὔτε', 'οὔτε', 'CCONJ', (168, 172)),
#    ('ὑελῷ', 'ὑελῷς', 'NOUN', (173, 177)),
#    (',', ',', 'PUNCT', (177, 178)),
#    ('εἰ', 'εἰ', 'ADV', (179, 181)),
#    ('μὴ', 'μή', 'ADV', (182, 184)),
#    ('μόνοις', 'μόνος', 'ADJ', (185, 191)),
#    ('χρυσέοις', 'χρύσεος', 'ADJ', (192, 200)),
#    ('εἶπεν', 'λέγω', 'VERB', (201, 206)),
#    ('τῷ', 'ὁ', 'DET', (207, 209)),
#    ('Πέτρῳ', 'πέτρος', 'PROPN', (210, 215)),
#    ('·', '·', 'PUNCT', (215, 216)),
#    ('Πέτρε', 'πέτρος', 'PROPN', (217, 222)),
#    (',', ',', 'PUNCT', (222, 223)),
#    ('θεοῦ', 'θεός', 'NOUN', (224, 228)),
#    ('δοῦλε', 'δοῦλος', 'NOUN', (229, 234)),
#    ('·', '·', 'PUNCT', (234, 235))])]

# %%
LAGT[LAGT["lemmatized_sentences"].isnull()].sample(10)
# Out:
#      author_id            doc_id                         filename  \
# 684    tlg2035    tlg2035.tlg132    tlg2035.tlg132.1st1K-grc1.xml
# 844    tlg2200  tlg2200.tlg00543    tlg2200.tlg00543.opp-grc1.xml
# 793    tlg2200  tlg2200.tlg00456    tlg2200.tlg00456.opp-grc1.xml
# 942    tlg4102    tlg4102.tlg043    tlg4102.tlg043.1st1K-grc1.xml
# 705    tlg2042    tlg2042.tlg019    tlg2042.tlg019.1st1K-grc1.xml
# 836    tlg2200  tlg2200.tlg00535    tlg2200.tlg00535.opp-grc1.xml
# 1698   tlg2003    tlg2003.tlg007  tlg2003.tlg007.perseus-grc1.xml
# 862    tlg2655    tlg2655.tlg002    tlg2655.tlg002.1st1K-grc1.xml
# 756    tlg2200  tlg2200.tlg00405    tlg2200.tlg00405.opp-grc1.xml
# 764    tlg2200  tlg2200.tlg00427    tlg2200.tlg00427.opp-grc1.xml
#
#                            author                          title  \
# 684                    Athanasius      Oratio III contra Arianos
# 844                      Libanius                  Declamatio 43
# 793                      Libanius                      Oratio 56
# 942   Catenae (Novum Testamentum)  Catena In Epistulam Joannis I
# 705                        Origen                     Philocalia
# 836                      Libanius                  Declamatio 35
# 1698           Julian the Emperor        To the Cynic Heracleios
# 862                     Damigeron                   De lapidibus
# 756                      Libanius                       Oratio V
# 764                      Libanius                      Oratio 27
#
#                                                  string  wordcount   source  \
# 684   1. ΟΙ Ἀρειομανῖται, ὡς ἔοικε, κρίναντες ἅπαξ ἀ...    26026.0     1Kgr
# 844   καὶ ἡ γυνὴ φιλόπολις καὶ ὁ δῆμος φιλε- R IV 79...    11263.0     1Kgr
# 793   εἰμὶ μὲν τῶν ἀπηντηκότων Λουκιανῷ οὐ\n\nδιὰ τὸ...     4417.0     1Kgr
# 942   ΥΠΟΘΕΣΙΣ. Ἐπειδη αὐτὸς ὁ Ἰωάννης τὸ Εὐαγγέλιον...    11904.0     1Kgr
# 705   Ἐκλογὴν ἡ παροῦσα περιέχει βίβλος γραφικῶν ζητ...    74499.0     1Kgr
# 836   τῷ μὲν δήμῳ πολλὴ χάρις, ὦ βουλή, μηδ’ RIV 227...     4805.0     1Kgr
# 1698  \n*)=h polla\ gi/netai e)n makrw=| xro/nw|: to...     8829.0  perseus
# 862   1] Τηρήσει τὰς κριθὰς ἀβλαβεῖς δάφνης καρποφόρ...     2657.0     1Kgr
# 756   Αὐτὸ τοῦτο τὸ νῦν ἐμὲ καὶ ζῆν καὶ λέγειν καὶ R...     4703.0     1Kgr
# 764   ἐπαινῶν ἠξιωκὼς ἃ τῆς βελτίονος ἦν μοί- R II ...     5965.0     1Kgr
#
#      lemmatized_sentences lemmata_source   tlg_date  not_before  not_after  \
# 684                  None          grecy     A.D. 4       301.0      400.0
# 844                  None          grecy     A.D. 4       301.0      400.0
# 793                  None          grecy     A.D. 4       301.0      400.0
# 942                  None          grecy  p. A.D. 5       501.0        NaN
# 705                  None          grecy   A.D. 2-3       101.0      300.0
# 836                  None          grecy     A.D. 4       301.0      400.0
# 1698                 None          grecy     A.D. 4       301.0      400.0
# 862                  None          grecy   Incertum      -200.0        NaN
# 756                  None          grecy     A.D. 4       301.0      400.0
# 764                  None          grecy     A.D. 4       301.0      400.0
#
#      date_uncertain             tlg_epithet provenience  lemmatacount  \
# 684           False            [Theologici]   christian       10132.0
# 844           False  [Rhetorici, Sophistae]       pagan        3489.0
# 793           False  [Rhetorici, Sophistae]       pagan        1298.0
# 942           False                      []   christian        5206.0
# 705           False            [Theologici]   christian       30547.0
# 836           False  [Rhetorici, Sophistae]       pagan        1636.0
# 1698          False      [Philosophici/-ae]       pagan           0.0
# 862           False                      []       pagan        1277.0
# 756           False  [Rhetorici, Sophistae]       pagan        1612.0
# 764           False  [Rhetorici, Sophistae]       pagan        1961.0
#
#      sentences raw_date genre
# 684       None     None  None
# 844       None     None  None
# 793       None     None  None
# 942       None     None  None
# 705       None     None  None
# 836       None     None  None
# 1698      None     None  None
# 862       None     None  None
# 756       None     None  None
# 764       None     None  None

# %%
# there is an invalid document:
row_index = LAGT[LAGT["doc_id"] == "tlg0530.tlg006"].index[0]
LAGT = LAGT.drop(row_index)

# %%
def get_row_data(row):
    doc_id = row["doc_id"]
    # source = row["source"]
    # lemmata_source = row["lemmata_source"]
    try:
        file_path = target_path + doc_id + ".pickle"
        with open(file_path, "rb") as f:
            sentences_data = pickle.load(f)
        sentences = [sent[2] for sent in sentences_data]
        lemmatized_sentences = [[t[1] for t in sent[3] if t[2] in ["n", "a", "v", "NOUN", "PROPN", "ADJ", "VERB"]] for sent in sentences_data]
        #source = "glaux1"
        #lemmata_source = "glaux1"
    except:
        sentences = None
        lemmatized_sentences = None
    return sentences, lemmatized_sentences # , source, lemmata_source

# %%
result = LAGT.apply(lambda row: pd.Series(get_row_data(row)), axis=1)

# %%
result.sample(10)
# Out:
#                                                       0  \
# 192   [περὶ μὲν οὖν τῶν πρώτων αἰτίων τῆς φύσεως καὶ...
# 401   [πᾶν μέρος λόγου εὕρηται μὲν ἐπὶ μηνύσει πράγμ...
# 1474  [ἡγεῖσθαι μὲν τῆς πάσης στρατιᾶς τοὺς κατασκόπ...
# 1094  [εἰς τοῦτο δὴ τὸ δικαστήριον καὶ αὐτὸς εἰσάγων...
# 551   [ὁδοὶ δύο εἰσί, μία τῆς ζωῆς καὶ μία τοῦ θανάτ...
# 1099  [διὰ τί τὸ θαλάττιον ὕδωρ οὐ τρέφει τὰ δένδρα;...
# 177   [περὶ δὲ τῆς μαντικῆς τῆς ἐν τοῖς ὕπνοις γινομ...
# 1763  [τὰς δὲ βροτοὶ καλέουσι Πελειάδας., χειμέριαι ...
# 1314  [Παῦλος ἀπόστολος Χριστοῦ Ἰησοῦ διὰ θελήματος ...
# 572   [Μισθοφόροι τόν ποταμόν τοῖς πολεμίοις ἐπήγαγο...
#
#                                                       1
# 192   [[πρῶτος, αἴτιος, φύσις, κίνησις, φυσικός, φορ...
# 401   [[μέρος, λόγος, εὑρίσκω, μήνυσις, πρᾶγμα, καιρ...
# 1474  [[ἡγέομαι, στρατιά, κατάσκοπος, ἱππεύς, τάσσω,...
# 1094  [[δικαστήριον, εἰσάγω, γίγνομαι, διάλεξις, οἴο...
# 551   [[ὁδός, εἰμί, ζωή, θάνατος, διαφορά, πολύς, ὁδ...
# 1099  [[θαλάσσιος, ὕδωρ, τρέφω, δένδρον], [αἰτία, ζῷ...
# 177   [[μαντικός, ὕπνος, γίγνομαι, λέγω, συμβαίνω, ἐ...
# 1763  [[βροτός, καλέω, Πελειάς], [χειμέριος, δύω, Πε...
# 1314  [[Παῦλος, ἀπόστολος, Χριστός, Ἰησοῦς, θέλημα, ...
# 572   [[μισθοφόρος, ποταμός, πολέμιος, ἐπήγαγος], []...

# %%
LAGT["sentences"] = result[0]  # Extract sentences
LAGT["lemmatized_sentences"] = result[1]

# %%
LAGT.loc[1963]
# Out:
# author_id                                                         tlg2798
# doc_id                                                     tlg2798.tlg005
# filename                                                             None
# author                                        Pseudo-Dionysius Areopagita
# title                                                De mystica theologia
# string                  Τριὰς ὑπερούσιε, καὶ ὑπέρθεε, καὶ ὑπεράγαθε, τ...
# wordcount                                                             NaN
# source                                                           exprecce
# lemmatized_sentences    [[τριάς, ὑπερούσιε, ὑπέρθεε, ὑπεράγαθε, χριστι...
# lemmata_source                                                       None
# tlg_date                                                             None
# not_before                                                          401.0
# not_after                                                           600.0
# date_uncertain                                                       None
# tlg_epithet                                                          None
# provenience                                                     christian
# lemmatacount                                                          NaN
# sentences               [Τριάς ὑπερούσιε, καί ὑπέρθεε, καί ὑπεράγαθε, ...
# raw_date                                                         A.D. 5-6
# genre                                                              Theol.
# Name: 1963, dtype: object

# %%
LAGT["lemmatized_sentences"].isnull().sum()
# Out:
# 0

# %%
len(LAGT)
# Out:
# 1963

# %%
LAGT = LAGT.drop_duplicates(subset="doc_id", keep="first")
len(LAGT)
# Out:
# 1958

# %% [markdown]
# ### Checking what is in what shape

# %%
LAGT[LAGT["source"]=="exprecce"]
# Out:
#      author_id          doc_id filename                       author  \
# 1939   tlg1352  tlg1352.tlg001     None                         None
# 1940   tlg2005  tlg2005.tlg001     None                         None
# 1941   tlg2011  tlg2011.tlg001     None                         None
# 1942   tlg2015  tlg2015.tlg001     None                         None
# 1943   tlg5451  tlg5451.tlg001     None                         None
# 1945   tlg2010  tlg2010.tlg001     None                         None
# 1946   tlg2008  tlg2008.tlg001     None                         None
# 1948   tlg2012  tlg2012.tlg001     None                         None
# 1949   tlg0390  tlg0390.tlg001     None                         None
# 1950   tlg0304  tlg0304.tlg001     None                         None
# 1953   tlg0389  tlg0389.tlg001     None                         None
# 1955   tlg3150  tlg3150.tlg002     None                         None
# 1956   tlg2017  tlg2017.tlg065     None           Gregorius Nyssenus
# 1957   tlg2040  tlg2040.tlg034     None        Basilius Caesariensis
# 1958   tlg2040  tlg2040.tlg035     None        Basilius Caesariensis
# 1959   tlg2062  tlg2062.tlg041     None         Joannes Chrysostomus
# 1960   tlg2062  tlg2062.tlg043     None         Joannes Chrysostomus
# 1961   tlg2062  tlg2062.tlg050     None         Joannes Chrysostomus
# 1962   tlg2062  tlg2062.tlg511     None         Joannes Chrysostomus
# 1963   tlg2798  tlg2798.tlg005     None  Pseudo-Dionysius Areopagita
#
#                                                   title  \
# 1939     The Letter of the Churches of Vienne and Lyons
# 1940            Martyrium Pionii presbyteri et sodalium
# 1941      Martyrium Agapae, Irenae, Chionae et sodalium
# 1942                            Testamentum xl martyrum
# 1943  Passio sancti Sabae Gothi (sub auctore Athanar...
# 1945                                    Martyrium Dasii
# 1946                                  Martyrium Cononis
#
#                                    lemmatized_sentences lemmata_source  \
# 1939  [[βιέννῃ, λουγδούνῳς, γαλλία, παροικέω, δοῦλος...           None
# 1940  [[μαρτύριος, ἅγιος, πιονίας, πρέσβυς], [μνεία,...           None
# 1941  [[μαρτύριος, ἅγιος, ἀγάπη, εἰρήνης, χιόνης, μα...           None
# 1942  [[διαθηκή, ἅγιος, ἔνδοξος, χριστός, μάρτυς, σε...           None
# 1943  [[μαρτύριος, ἅγιος, σάβας, γότθης], [ἐκκλησία,...           None
# 1945  [[μαρτύριος, ἅγιος, δασῖος], [κύριος, εὐλόγησο...           None
# 1946  [[δυσσεβής, κρίσις], [τελειόω, ἅγιος, χριστός,...           None
# 1948  [[κύριος, διοκλιτιανῷ, ἔννατος, μαξιμιανός, ὀγ...           None
# 1949  [[μαρτύριος, ἅγιος, κάρπος, παπύλας, ἀγαθονίκη...           None
# 1950  [[μαρτύριος, ἅγιος, πανευφήμος, ἀποστόλου, ἀπο...           None
# 1953  [[μαρτύριος, ἅγιος, ἀποστόλου, πέτρος], [κυρια...           None
# 1955  [[μαρτύριος, ἅγιος, ἀνδρέας, ἀποστόλος], [μακά...           None
# 1956  [[χριστός, λαός, ἅγιος, ποίμνη, βασίλειος, ἱερ...           None
# 1957  [[νόμος, φύσις, μελίσση, ἀπαίρω, σίμβλος, βασι...           None
# 1958  [[μαρτύρων, μνήμη, γίγνομαι, κόρος, φιλομάρτυρ...           None
# 1959  [[βούλομαι, ἀποδίδωμι, χρέος], [γίγνομαι, ὑπισ...           None
# 1960  [[εὐλογητος, θεός], [γυνή, θάνατος, λοιπός, κα...           None
# 1961  [[μάρτυς, ἡμέρα], [μάρτυς, ἡμέρα], [μάρτυς, ἡμ...           None
# 1962  [[γῆ, τοιοῦτος, μάρτυς, τιμή], [ἀποδημία, πλέκ...           None
# 1963  [[τριάς, ὑπερούσιε, ὑπέρθεε, ὑπεράγαθε, χριστι...           None
#
#      tlg_date  not_before  not_after date_uncertain tlg_epithet provenience  \
# 1939     None       101.0      200.0           None        None   christian
# 1940     None       301.0      400.0           None        None   christian
# 1941     None       301.0      400.0           None        None   christian
# 1942     None       401.0        NaN           None        None   christian
# 1943     None       301.0      400.0           None        None   christian
# 1945     None       401.0        NaN           None        None   christian
# 1946     None       401.0        NaN           None        None   christian
# 1948     None       401.0        NaN           None        None   christian
# 1949     None       101.0      200.0           None        None   christian
# 1950     None       101.0      400.0           None        None   christian
# 1953     None       101.0      200.0           None        None   christian
# 1955     None       101.0      200.0           None        None   christian
# 1956     None       301.0      400.0           None        None   christian
# 1957     None       301.0      400.0           None        None   christian
# 1958     None       301.0      400.0           None        None   christian
# 1959     None       301.0      500.0           None        None   christian
# 1960     None       301.0      500.0           None        None   christian
# 1961     None       301.0      500.0           None        None   christian
# 1962     None       301.0      500.0           None        None   christian
# 1963     None       401.0      600.0           None        None   christian
#
#       lemmatacount                                          sentences  \
# 1939           NaN  [οἱ ἐν Βιέννῃ καί Λουγδούνῳ τῆς Γαλλίας παροικ...
# %%
def get_wordcout(doc_id):
    try:
        file_path = target_path + doc_id + ".pickle"
        with open(file_path, "rb") as f:
            sentences_data = pickle.load(f)
        wordcount = sum([len(sent_data[3]) for sent_data in sentences_data])
    except:
        wordcount = 0
    return wordcount

# %%
LAGT["wordcount"] = LAGT["doc_id"].apply(get_wordcout)

# %%
LAGT["wordcount"].sum()
# Out:
# 35809325

# %%
lemmatized_sentences = [s for work in LAGT["lemmatized_sentences"] for s in work]
lemmatized_sentences[:10]
# Out:
# [[],
#  [],
#  [],
#  [],
#  ['πινυτός', 'ἀντιγράφω'],
#  ['θαυμάζω', 'ἀποδέχω', 'διονύσιος'],
#  ['ἀντιπαρακαλέω', 'στεῤῥοτέρας', 'μεταδίδωμι', 'τροφή'],
#  ['τελειοτέρω',
#   'γράμμα',
#   'λαός',
#   'ὑποθρέψαντα',
#   'διατέλος',
#   'γαλακτώδεμι',
#   'ἐνδιατρίβω',
#   'λόγος',
#   'νηπιώδης',
#   'ἀγωγή',
#   'λανθάνω',
#   'καταγηράζω'],
#  ['ἐπιστολή',
#   'πινυτός',
#   'πίστις',
#   'ὀρθοδοξία',
#   'φροντίς',
#   'ὑπήκοος',
#   'ὡφελεία',
#   'λόγιον',
#   'θεῖος',
#   'σύνεσις'],
#  ['ἀκριβεστάτης', 'ἀναδείκνυται', 'εἰκών']]

# %%
# update lemmatacount
LAGT["lemmatacount"] = LAGT["lemmatized_sentences"].apply(lambda x: len([l for s in x for l in s]))

# %%
LAGT["lemmatacount"]
# Out:
# 0          34
# 1          59
# 2       10315
# 3        1496
# 4         125
#         ...
# 1959     1011
# 1960     1227
# 1961     1505
# 1962     1893
# 1963      578
# Name: lemmatacount, Length: 1958, dtype: int64

# %%
LAGT['lemmata_source'] = LAGT['lemmata_source'].fillna("grecy")

# %%
placeholder = "glaux_tmp"
LAGT['lemmata_source'] = LAGT['lemmata_source'].replace("glaux", placeholder)
LAGT['lemmata_source'] = LAGT['lemmata_source'].replace(placeholder, "glaux1")

# %%
LAGT.groupby("lemmata_source").size() #.isnull().sum()
# Out:
# lemmata_source
# glaux1    1698
# grecy      260
# dtype: int64

# %%
LAGT.groupby("source").size() #.isnull().sum()
# Out:
# source
# 1Kgr         218
# exprecce      20
# glaux1      1696
# perseus       24
# dtype: int64

# %%
LAGT.columns
# Out:
# Index(['author_id', 'doc_id', 'filename', 'author', 'title', 'string',
#        'wordcount', 'source', 'lemmatized_sentences', 'lemmata_source',
#        'tlg_date', 'not_before', 'not_after', 'date_uncertain', 'tlg_epithet',
#        'provenience', 'lemmatacount', 'sentences', 'raw_date', 'genre'],
#       dtype='object')

# %%
LAGT = LAGT[['author_id', 'doc_id', 'filename', 'author', 'title',  'sentences', 'lemmatized_sentences', 'source', 'lemmata_source', 'not_before', 'not_after', 'tlg_epithet', 'genre', 'provenience', 'wordcount', 'lemmatacount', ]]

# %%
LAGT["title"].fillna("", inplace=True)
LAGT["author"].fillna("", inplace=True)

# %%
LAGT[LAGT["author"].str.contains("Septuagint")]
# 309      -300.0     -101.0          []  None      jewish      16297
# 310      -300.0     -101.0          []  None      jewish       8029
# 311      -300.0     -101.0          []  None      jewish      22565
# 312      -300.0     -101.0          []  None      jewish       5798
# 313      -300.0     -101.0          []  None      jewish       4639
# 314      -300.0     -101.0          []  None      jewish       3749
# 315      -300.0     -101.0          []  None      jewish       2725
# 316      -300.0     -101.0          []  None      jewish       1838
# 317      -300.0     -101.0          []  None      jewish        541
# 318      -300.0     -101.0          []  None      jewish       1253
# 319      -300.0     -101.0          []  None      jewish       1110
# 320      -300.0     -101.0          []  None      jewish       1308
# 321      -300.0     -101.0          []  None      jewish       1427
# 322      -300.0     -101.0          []  None      jewish       1087
# 323      -300.0     -101.0          []  None      jewish       5701
# 324      -300.0     -101.0          []  None      jewish       1658
# 325      -300.0     -101.0          []  None      jewish      31993
# 326      -300.0     -101.0          []  None      jewish      33480
# 327      -300.0     -101.0          []  None      jewish       3002
# 328      -300.0     -101.0          []  None      jewish       2951
# 329      -300.0     -101.0          []  None      jewish       1517
# 330      -300.0     -101.0          []  None      jewish      33929
# 331      -300.0     -101.0          []  None      jewish        902
# 332      -300.0     -101.0          []  None      jewish       1308
# 333      -300.0     -101.0          []  None      jewish      12172
# 334      -300.0     -101.0          []  None      jewish      12021
# 335      -300.0     -101.0          []  None      jewish       1013
# 336      -300.0     -101.0          []  None      jewish       1031
#
#      lemmatacount
# 282         14951
# 283         11279
# 284          8479
# 285         11768
# 286          9749
# 287          6854
# 288         10764
# 289           908
# 290          9549
# 291          8185
# 292         10102
# 293          8841
# 294          8348
# 295          9940
# 296          4204
# 297          6436
# 298          2763
# 299          3970
# 300          2475
# 301          8303
# 302          5908
# 303          2560
# 304          3873
# 305         16227
# 306          2103
# 307          6708
# 308           998
# 309          6553
# 310          3727
# 311          9963
# 312          2385
# 313          1817
# 314          1521
# 315          1112
# 316           751
# 317           226
# 318           492
# 319           462
# 320           541
# 321           575
# 322           455
# 323          2284
# 324           650
# 325         13030
# 326         13310
# 327          1206
# 328          1280
# 329           595
# 330         12866
# 331           367
# 332           518
# 333          4876
# 334          4711
# 335           438
# 336           416

# %%
LAGT[LAGT["lemmata_source"]=="grecy"].sample(10)
# Out:
#      author_id            doc_id                         filename  \
# 813    tlg2200  tlg2200.tlg00512    tlg2200.tlg00512.opp-grc1.xml
# 891    tlg4016    tlg4016.tlg003    tlg4016.tlg003.1st1K-grc1.xml
# 740    tlg2057    tlg2057.tlg002    tlg2057.tlg002.1st1K-grc1.xml
# 760    tlg2200  tlg2200.tlg00409    tlg2200.tlg00409.opp-grc1.xml
# 750    tlg2189    tlg2189.tlg003    tlg2189.tlg003.1st1K-grc1.xml
# 680    tlg2035    tlg2035.tlg003    tlg2035.tlg003.1st1K-grc1.xml
# 1693   tlg2003    tlg2003.tlg002  tlg2003.tlg002.perseus-grc1.xml
# 836    tlg2200  tlg2200.tlg00535    tlg2200.tlg00535.opp-grc1.xml
# 913    tlg4089    tlg4089.tlg003      tlg4089.tlg003.opp-grc1.xml
# 898    tlg4019    tlg4019.tlg003    tlg4019.tlg003.1st1K-grc1.xml
#
#                         author  \
# 813                   Libanius
# 891                   Ammonius
# 740     Socrates, Scholasticus
# 760                   Libanius
# 750                 Callinicus
# 680   Athanasius of Alexandria
# 1693        Julian the Emperor
# 836                   Libanius
# 913                Theodoretus
# 898               Olympiodorus
#
#                                                   title  \
# 813                                       Declamatio 12
# 891   In Aristotelis Librum De Interpretatione Comme...
# 740                              Historia Ecclesiastica
# 760                                            Oratio 9
# 750                                           Fragmenta
# 680    De decretis Nicaenae synodi (Chapters 41 and 42)
# 1693                   Panegyric on the Empress Eusebia
# 836                                       Declamatio 35
# 913                             Historia ecclesiastica
# 898                  In Aristotelis meteora commentaria
#
#                                               sentences  \
# 813   [Χαλεπόν τό ζήτημα., δύο γάρ ἐναντία ἀλλή- λοι...
# 891   [Α, ,, , Πολύ μέν ἐν σοφοῖσι κοὐκ ἀνώνυμον τό ...
# 740   [Τό τοῦ βιβλίου προοίμιον., Εὐσέβιος ὁ Παμφίλο...
# 760   [Ἡ μέν οὖν ἑορτή καί αὐτή προσάγει τό αὑτῆς εὖ...
# 750   [Οὔτε ἡ καθ’ ὑμᾶς γῆ πρός ἕτερον οὐδέν εὐαρμόσ...
# 680   [Κατά Εὐσεβίου καί Θεογνίου, ., », κωνσταντινό...
# 1693  [* / )/ \ \ ) / / \ / / ,, ), / \ / ) \ ) / , ...
# 836   [τῷ μέν δήμῳ πολλή χάρις,, ὦ βουλή, μηδ’ ὑπό τ...
# 913   [Τάδε ἔνεστιν ἐν τῷ πρώτῳ τόμῳ τῆς Θεοδωρήτου ...
# 898   [Πρᾶξις α . ., Περί μέν οὖν τῶν πρώτων αἰτίων ...
#
#                                    lemmatized_sentences   source  \
# 813   [[χαλεπός, ζήτημα], [ἐναντίος, ἀλλή, λος, ἦθος...     1Kgr
# 891   [[], [], [πολύς, σοφός, ἀνώνυμος, ἑρμηνεία, ἀρ...     1Kgr
# 740   [[βιβλίον, προοίμιον], [εὐσέβιος, παίφμλος, ὅλ...     1Kgr
# 760   [[ἑορτή, αὐτός, προσάγω, ποιήσω], [πρότερος, π...     1Kgr
# 750   [[γῆ, ἕτερος, ἔχω, βασιλεία, βασιλεία, χωρίον,...     1Kgr
# 680   [[εὐσεβῖος, θεογνῖος], [], [], [κωνσταντινός, ...     1Kgr
# 1693  [[/, \, \, \, /, /], [], [\, /, \, /, \, /, \,...  perseus
# 836   [[δῆμος, πολύς, χάρις], [βουλή, πάρειμι, συμφο...     1Kgr
# 913   [[ὅδε, ἔνειμι, πρῶτος, τόμος, θεοδωρήτης, ἐκκλ...     1Kgr
# 898   [[πρᾶξις], [πρῶτος, αἰτέω, φύσις], [προοίμιον,...     1Kgr
#
#      lemmata_source  not_before  not_after  \
# 813           grecy       301.0      400.0
# 891           grecy       401.0      500.0
# 740           grecy       301.0      500.0
# 760           grecy       301.0      400.0
# 750           grecy       201.0      300.0
# 680           grecy       301.0      400.0
# 1693          grecy       301.0      400.0
# 836           grecy       301.0      400.0
# 913           grecy       301.0      500.0
# 898           grecy       501.0      600.0
#
#                                  tlg_epithet genre provenience  wordcount  \
# 813                   [Rhetorici, Sophistae]  None       pagan       7265
# 891                       [Philosophici/-ae]  None       pagan     154056
# 740                          [Historici/-ae]  None   christian     120491
# 760                   [Rhetorici, Sophistae]  None       pagan       1236
# 750                              [Sophistae]  None       pagan        185
# 680                             [Theologici]  None   christian       1485
# 1693                      [Philosophici/-ae]  None       pagan       8697
# 836                   [Rhetorici, Sophistae]  None       pagan       4204
# 913   [Scriptores Ecclesiastici, Theologici]  None   christian     119273
# 898                       [Philosophici/-ae]  None       pagan     145277
#
#       lemmatacount
# 813           2875
# 891          53815
# 740          51190
# 760            498
# 750             86
# 680            615
# 1693          3972
# 836           1699
# 913          44883
# 898          53704

# %%
LAGT.to_parquet("../data/large_files/LAGT_grecy.parquet")

# %%
# save metadata for future usage
LAGT[['author_id', 'doc_id', 'filename', 'author', 'title', 'source', 'lemmata_source', 'not_before',
       'not_after', 'tlg_epithet', 'genre', 'provenience', 'wordcount',
       'lemmatacount']].to_csv("../data/LAGT_v4-0_metadata.csv", index=False)

# %% [markdown]
# ### From sents_data pickles to jsons

# %%
source_path = "../data/large_files/sents_data/"
target_path = "../data/large_files/sents_data_jsons/"
try:
    os.mkdir(target_path)
except:
    pass

# %%
fn = "tlg0527.tlg048.pickle"
with open(source_path + fn, "rb") as f:
    sents_data = pickle.load(f)
sents_data[:10]
# Out:
# [('0527-048',
#   0,
#   'ὅρασις, ἣν εἶδεν Ἡσαΐας υἱὸς Ἀμώς, ἣν εἶδε κατὰ τῆς Ἰουδαίας καὶ κατὰ Ἱερουσαλὴμ ἐν βασιλεία Ὀζίου καὶ Ἰωάθαμ καὶ Ἄχαζ καὶ Ἐζεκίου, οἵ ἐβασίλευσαν τῆς Ἰουδαίας. E',
#   [('ὅρασις', 'ὅρασις', 'n', (0, 6)),
#    (',', ',', 'u', (6, 7)),
#    ('ἣν', 'ὅς', 'p', (8, 10)),
#    ('εἶδεν', 'ὁράω', 'v', (11, 16)),
#    ('Ἡσαΐας', 'Ἡσαΐας', 'n', (17, 23)),
#    ('υἱὸς', 'υἱός', 'n', (24, 28)),
#    ('Ἀμώς', 'Ἀμώς', 'n', (29, 33)),
#    (',', ',', 'u', (33, 34)),
#    ('ἣν', 'ὅς', 'p', (35, 37)),
#    ('εἶδε', 'ὁράω', 'v', (38, 42)),
#    ('κατὰ', 'κατά', 'r', (43, 47)),
#    ('τῆς', 'ὁ', 'l', (48, 51)),
#    ('Ἰουδαίας', 'Ἰουδαία', 'n', (52, 60)),
#    ('καὶ', 'καί', 'c', (61, 64)),
#    ('κατὰ', 'κατά', 'r', (65, 69)),
#    ('Ἱερουσαλὴμ', 'Ἱεροσόλυμα', 'n', (70, 80)),
#    ('ἐν', 'ἐν', 'r', (81, 83)),
#    ('βασιλεία', 'βασιλεία', 'n', (84, 92)),
#    ('Ὀζίου', 'Ὄζιος', 'n', (93, 98)),
#    ('καὶ', 'καί', 'c', (99, 102)),
#    ('Ἰωάθαμ', 'Ἰωάθαμ', 'n', (103, 109)),
#    ('καὶ', 'καί', 'c', (110, 113)),
#    ('Ἄχαζ', 'Ἄχαζ', 'n', (114, 118)),
#    ('καὶ', 'καί', 'c', (119, 122)),
#    ('Ἐζεκίου', 'Ἐζεκίας', 'n', (123, 130)),
#    (',', ',', 'u', (130, 131)),
#    ('οἵ', 'ὅς', 'p', (132, 134)),
#    ('ἐβασίλευσαν', 'βασιλεύω', 'v', (135, 146)),
#    ('τῆς', 'ὁ', 'l', (147, 150)),
#    ('Ἰουδαίας', 'Ἰουδαία', 'n', (151, 159)),
#    ('.', '.', 'u', (159, 160)),
#    ('E', 'E', 'z', (161, 162))]),
#  ('0527-048',
#   1,
#   'ἄκουε οὐρανὲ καὶ ἐνωτίζου γῆ, ὅτι Κύριος ἐλάλησεν·',
#   [('ἄκουε', 'ἀκούω', 'v', (0, 5)),
#    ('οὐρανὲ', 'οὐρανός', 'n', (6, 12)),
#    ('καὶ', 'καί', 'c', (13, 16)),
#    ('ἐνωτίζου', 'ἐνωτίζομαι', 'v', (17, 25)),
#    ('γῆ', 'γῆ', 'n', (26, 28)),
#    (',', ',', 'u', (28, 29)),
#    ('ὅτι', 'ὅτι', 'c', (30, 33)),
#    ('Κύριος', 'κύριος', 'n', (34, 40)),
#    ('ἐλάλησεν', 'λαλέω', 'v', (41, 49)),
#    ('·', '·', 'u', (49, 50))]),
#  ('0527-048',
#   2,
#   'υἱοὺς ἐγέννησα καὶ ὕψωσα, αὐτοὶ δέ με ἠθέτησαν.',
#   [('υἱοὺς', 'υἱός', 'n', (0, 5)),
#    ('ἐγέννησα', 'γεννάω', 'v', (6, 14)),
#    ('καὶ', 'καί', 'c', (15, 18)),
#    ('ὕψωσα', 'ὑψόω', 'v', (19, 24)),
#    (',', ',', 'u', (24, 25)),
#    ('αὐτοὶ', 'αὐτός', 'p', (26, 31)),
#    ('δέ', 'δέ', 'c', (32, 34)),
#    ('με', 'ἐγώ', 'p', (35, 37)),
#    ('ἠθέτησαν', 'ἀθετέω', 'v', (38, 46)),
#    ('.', '.', 'u', (46, 47))]),
#  ('0527-048',
#   3,
#   'ἔγνω βοῦς τὸν κτησάμενον καὶ ὄνος τὴν φάτνην τοῦ κυρίου αὐτοῦ·',
#   [('ἔγνω', 'γιγνώσκω', 'v', (0, 4)),
#    ('βοῦς', 'βοῦς', 'n', (5, 9)),
#    ('τὸν', 'ὁ', 'l', (10, 13)),
#    ('κτησάμενον', 'κτάομαι', 'v', (14, 24)),
#    ('καὶ', 'καί', 'c', (25, 28)),
#    ('ὄνος', 'ὄνος', 'n', (29, 33)),
#    ('τὴν', 'ὁ', 'l', (34, 37)),
#    ('φάτνην', 'φάτνη', 'n', (38, 44)),
#    ('τοῦ', 'ὁ', 'l', (45, 48)),
#    ('κυρίου', 'κύριος', 'n', (49, 55)),
#    ('αὐτοῦ', 'αὐτός', 'p', (56, 61)),
#    ('·', '·', 'u', (61, 62))]),
#  ('0527-048',
#   4,
#   'Ἰσραὴλ δέ με οὐκ ἔγνω καὶ ὁ λαός με οὐ συνῆκεν.',
#   [('Ἰσραὴλ', 'Ἰσραήλ', 'n', (0, 6)),
#    ('δέ', 'δέ', 'c', (7, 9)),
#    ('με', 'ἐγώ', 'p', (10, 12)),
#    ('οὐκ', 'οὐ', 'd', (13, 16)),
#    ('ἔγνω', 'γιγνώσκω', 'v', (17, 21)),
#    ('καὶ', 'καί', 'c', (22, 25)),
#    ('ὁ', 'ὁ', 'l', (26, 27)),
#    ('λαός', 'λαός', 'n', (28, 32)),
#    ('με', 'ἐγώ', 'p', (33, 35)),
#    ('οὐ', 'οὐ', 'd', (36, 38)),
#    ('συνῆκεν', 'συνίημι', 'v', (39, 46)),
#    ('.', '.', 'u', (46, 47))]),
#  ('0527-048',
#   5,
#   'οὐαὶ ἔθνος ἁμαρτωλόν, λαὸς πλήρης ἁμαρτιῶν, σπέρμα πονηρόν, υἱοὶ ἄνομοι· E',
#   [('οὐαὶ', 'οὐαί', 'i', (0, 4)),
#    ('ἔθνος', 'ἔθνος', 'n', (5, 10)),
#    ('ἁμαρτωλόν', 'ἁμαρτωλός', 'a', (11, 20)),
#    (',', ',', 'u', (20, 21)),
#    ('λαὸς', 'λαός', 'n', (22, 26)),
#    ('πλήρης', 'πλήρης', 'a', (27, 33)),
#    ('ἁμαρτιῶν', 'ἁμαρτία', 'n', (34, 42)),
#    (',', ',', 'u', (42, 43)),
#    ('σπέρμα', 'σπέρμα', 'n', (44, 50)),
#    ('πονηρόν', 'πονηρός', 'a', (51, 58)),
#    (',', ',', 'u', (58, 59)),
#    ('υἱοὶ', 'υἱός', 'n', (60, 64)),
#    ('ἄνομοι', 'ἄνομος', 'a', (65, 71)),
#    ('·', '·', 'u', (71, 72)),
#    ('E', 'E', 'z', (73, 74))]),
#  ('0527-048',
#   6,
#   'ἐγκατελίπατε τὸν Κύριον καὶ παρωργίσατε τὸν ἅγιον τοῦ Ἰσραήλ.',
#   [('ἐγκατελίπατε', 'ἐγκατελλ́γω', 'v', (0, 12)),
#    ('τὸν', 'ὁ', 'l', (13, 16)),
#    ('Κύριον', 'κύριος', 'n', (17, 23)),
#    ('καὶ', 'καί', 'c', (24, 27)),
#    ('παρωργίσατε', 'παροργίζω', 'v', (28, 39)),
#    ('τὸν', 'ὁ', 'l', (40, 43)),
#    ('ἅγιον', 'ἅγιος', 'a', (44, 49)),
#    ('τοῦ', 'ὁ', 'l', (50, 53)),
#    ('Ἰσραήλ', 'Ἰσραήλ', 'n', (54, 60)),
#    ('.', '.', 'u', (60, 61))]),
#  ('0527-048',
#   7,
#   'τί ἔτι πληγῆτε προστιθέντες ἀνομίαν;',
#   [('τί', 'τίς', 'p', (0, 2)),
#    ('ἔτι', 'ἔτι', 'd', (3, 6)),
#    ('πληγῆτε', 'πλήσσω', 'v', (7, 14)),
#    ('προστιθέντες', 'προστίθημι', 'v', (15, 27)),
#    ('ἀνομίαν', 'ἀνομία', 'n', (28, 35)),
#    (';', ';', 'u', (35, 36))]),
#  ('0527-048',
#   8,
#   'πᾶσα κεφαλὴ εἰς πόνον καὶ πᾶσα καρδία εἰς λύπην. E',
#   [('πᾶσα', 'πᾶς', 'p', (0, 4)),
#    ('κεφαλὴ', 'κεφαλή', 'n', (5, 11)),
#    ('εἰς', 'εἰς', 'r', (12, 15)),
#    ('πόνον', 'πόνος', 'n', (16, 21)),
#    ('καὶ', 'καί', 'c', (22, 25)),
#    ('πᾶσα', 'πᾶς', 'p', (26, 30)),
#    ('καρδία', 'καρδία', 'n', (31, 37)),
#    ('εἰς', 'εἰς', 'r', (38, 41)),
#    ('λύπην', 'λύπη', 'n', (42, 47)),
#    ('.', '.', 'u', (47, 48)),
#    ('E', 'E', 'z', (49, 50))]),
#  ('0527-048',
#   9,
#   'ἀπὸ ποδῶν ἕως κεφαλῆς οὐκ ἔστιν ἐν αὐτῷ ὁλοκληρία, οὔ -τε τραῦμα οὔ -τε μώλωψ οὔ -τε πληγὴ φλεγμαίνουσα·',
#   [('ἀπὸ', 'ἀπό', 'r', (0, 3)),
#    ('ποδῶν', 'πούς', 'n', (4, 9)),
#    ('ἕως', 'ἕως', 'r', (10, 13)),
#    ('κεφαλῆς', 'κεφαλή', 'n', (14, 21)),
#    ('οὐκ', 'οὐ', 'd', (22, 25)),
#    ('ἔστιν', 'εἰμί', 'v', (26, 31)),
#    ('ἐν', 'ἐν', 'r', (32, 34)),
#    ('αὐτῷ', 'αὐτός', 'p', (35, 39)),
#    ('ὁλοκληρία', 'ὁλοκληρία', 'n', (40, 49)),
#    (',', ',', 'u', (49, 50)),
#    ('οὔ', 'οὐ', 'd', (51, 53)),
#    ('-τε', 'τε', 'c', (54, 57)),
#    ('τραῦμα', 'τραῦμα', 'n', (58, 64)),
#    ('οὔ', 'οὐ', 'd', (65, 67)),
#    ('-τε', 'τε', 'c', (68, 71)),
#    ('μώλωψ', 'μώλωψ', 'n', (72, 77)),
#    ('οὔ', 'οὐ', 'd', (78, 80)),
#    ('-τε', 'τε', 'c', (81, 84)),
#    ('πληγὴ', 'πληγή', 'n', (85, 90)),
#    ('φλεγμαίνουσα', 'φλεγμαίνω', 'v', (91, 103)),
#    ('·', '·', 'u', (103, 104))])]

# %%
reformat_tags_dict = {
    "NOUN": "n",
    "VERB": "v",
    "ADJ": "a",
    "ADV": "r",
    "PRON": "p",
    "DET": "l",
    "ADP": "r",
    "CCONJ": "c",
    "SCONJ": "c",
    "PROPN": "n",
    "PUNCT": "u",
    "n" : "n",
    "v": "v",
    "a": "a",
    "r": "r",
    "p": "p",
    "l": "l",
    "c": "c",
    "u": "u" # Assuming punctuation remains "u"
}

def reformat_tags(tag):
    try:
        return reformat_tags_dict[tag]
    except:
        return "x"
    
for fn in os.listdir(source_path):
    doc_id =  fn.rpartition(".")[0]
    with open(source_path + fn, "rb") as f:
        sents_data = pickle.load(f)
    sents_data_updated = []
    for id, sent_n, sent_text, sent_data in sents_data:
        sent_data_updated = [(t[0], t[1], reformat_tags(t[2]), t[3]) for t in sent_data]
        sents_data_updated.append((doc_id, sent_n, sent_text, sent_data_updated))
    with open(target_path + doc_id + ".json", "w") as f:
        json.dump(sents_data_updated, f)

# %%
fn = "tlg2640.tlg001.json"
with open(target_path + fn, "rb") as f:
    sents_data = json.load(f)
sents_data[:10]
# Out:
# [['tlg2640.tlg001', 0, '.', [['.', '.', 'u', [0, 1]]]],
#  ['tlg2640.tlg001',
#   1,
#   'Ἐχθρός γενοίμην μηδενός, φίλος δέ τοῦ αἰεί καί παραμενέοντος·',
#   [['Ἐχθρός', 'ἐχθρός', 'a', [0, 6]],
#    ['γενοίμην', 'γίγνομαι', 'v', [7, 15]],
#    ['μηδενός', 'μηδείς', 'a', [16, 23]],
#    [',', ',', 'u', [23, 24]],
#    ['φίλος', 'φίλος', 'n', [25, 30]],
#    ['δέ', 'δέ', 'r', [31, 33]],
#    ['τοῦ', 'ὁ', 'l', [34, 37]],
#    ['αἰεί', 'ἀεί', 'r', [38, 42]],
#    ['καί', 'καί', 'c', [43, 46]],
#    ['παραμενέοντος', 'παραμενέω', 'v', [47, 60]],
#    ['·', '·', 'u', [60, 61]]]],
#  ['tlg2640.tlg001',
#   2,
#   'καί μήκοτε μέν διενεχθείην πρός τούς οἰκειοτάτους,',
#   [['καί', 'καί', 'c', [0, 3]],
#    ['μήκοτε', 'μήκοτε', 'r', [4, 10]],
#    ['μέν', 'μέν', 'r', [11, 14]],
#    ['διενεχθείην', 'διενεχθείην', 'v', [15, 26]],
#    ['πρός', 'πρός', 'r', [27, 31]],
#    ['τούς', 'ὁ', 'l', [32, 36]],
#    ['οἰκειοτάτους', 'οἰκεῖος', 'a', [37, 49]],
#    [',', ',', 'u', [49, 50]]]],
#  ['tlg2640.tlg001',
#   3,
#   'διενεχθείς δέ διαλλαχθείην ὡς τάχιστα.',
#   [['διενεχθείς', 'διενεχθείς', 'v', [0, 10]],
#    ['δέ', 'δέ', 'r', [11, 13]],
#    ['διαλλαχθείην', 'διαλλαχθεία', 'v', [14, 26]],
#    ['ὡς', 'ὡς', 'r', [27, 29]],
#    ['τάχιστα', 'ταχύς', 'r', [30, 37]],
#    ['.', '.', 'u', [37, 38]]]],
#  ['tlg2640.tlg001',
#   4,
#   'Μηδενί ἐπιβουλεύσαιμι,',
#   [['Μηδενί', 'μηδενί', 'a', [0, 6]],
#    ['ἐπιβουλεύσαιμι', 'ἐπιβουλεύσαιμι', 'v', [7, 21]],
#    [',', ',', 'u', [21, 22]]]],
#  ['tlg2640.tlg001',
#   5,
#   'ἐπιβουλευόμενος δέ ἄνευ ἀνάγκης τοῦ τι ἀντιδρᾶσαι ἀνήκεστον ἀπαθής διαφύγοιμι.',
#   [['ἐπιβουλευόμενος', 'ἐπιβουλεύω', 'v', [0, 15]],
#    ['δέ', 'δέ', 'r', [16, 18]],
#    ['ἄνευ', 'ἄνευ', 'r', [19, 23]],
#    ['ἀνάγκης', 'ἀνάγκη', 'n', [24, 31]],
#    ['τοῦ', 'ὁ', 'l', [32, 35]],
#    ['τι', 'τίς', 'a', [36, 38]],
#    ['ἀντιδρᾶσαι', 'ἀντιδρᾶσαι', 'v', [39, 49]],
#    ['ἀνήκεστον', 'ἀνήκεστος', 'a', [50, 59]],
#    ['ἀπαθής', 'ἀπαθής', 'a', [60, 66]],
#    ['διαφύγοιμι', 'διαφύγω', 'v', [67, 77]],
#    ['.', '.', 'u', [77, 78]]]],
#  ['tlg2640.tlg001',
#   6,
#   'Ὀργῆς κρατοίην.',
#   [['Ὀργῆς', 'ὀργή', 'n', [0, 5]],
#    ['κρατοίην', 'κρατοία', 'v', [6, 14]],
#    ['.', '.', 'u', [14, 15]]]],
#  ['tlg2640.tlg001',
#   7,
#   'Ἐρῴην καί ἐπιθυμέοιμι καί τυγχάνοιμι μούνων τῶν καλῶν,',
#   [['Ἐρῴην', 'ἐρῴης', 'v', [0, 5]],
#    ['καί', 'καί', 'c', [6, 9]],
#    ['ἐπιθυμέοιμι', 'ἐπιθυμέω', 'v', [10, 21]],
#    ['καί', 'καί', 'c', [22, 25]],
#    ['τυγχάνοιμι', 'τυγχάνω', 'v', [26, 36]],
#    ['μούνων', 'μόνος', 'a', [37, 43]],
#    ['τῶν', 'ὁ', 'l', [44, 47]],
#    ['καλῶν', 'καλός', 'a', [48, 53]],
#    [',', ',', 'u', [53, 54]]]],
#  ['tlg2640.tlg001',
#   8,
#   'τῶν δέ ἀπ’ ἐναντίης τῆς ἐπιθυμίης',
#   [['τῶν', 'ὁ', 'l', [0, 3]],
#    ['δέ', 'δέ', 'r', [4, 6]],
#    ['ἀπ', 'ἀπ', 'r', [7, 9]],
#    ['’', '’', 'c', [9, 10]],
#    ['ἐναντίης', 'ἐναντίνω', 'a', [11, 19]],
#    ['τῆς', 'ὁ', 'l', [20, 23]],
#    ['ἐπιθυμίης', 'ἐπιθυμίνω', 'n', [24, 33]]]],
#  ['tlg2640.tlg001',
#   9,
#   ', μηδέ ἁμαρτών κοτε ὥστε εὔξασθαι, τύχοιμι.',
#   [[',', ',', 'u', [0, 1]],
#    ['μηδέ', 'μηδέ', 'c', [2, 6]],
#    ['ἁμαρτών', 'ἁμαρτάνω', 'v', [7, 14]],
#    ['κοτε', 'ποτε', 'r', [15, 19]],
#    ['ὥστε', 'ὥστε', 'c', [20, 24]],
#    ['εὔξασθαι', 'εὔχομαι', 'v', [25, 33]],
#    [',', ',', 'u', [33, 34]],
#    ['τύχοιμι', 'τυγχάνω', 'v', [35, 42]],
#    ['.', '.', 'u', [42, 43]]]]]

# %%
LAGT = pd.read_parquet("../data/large_files/LAGT_v4-0.parquet")
LAGT.head()
# Out:
#   author_id          doc_id                       filename      author  \
# 0   ogl0001  ogl0001.ogl001  ogl0001.ogl001.1st1K-grc1.xml     Pinytus
# 1   tlg0005  tlg0005.tlg003  tlg0005.tlg003.1st1K-grc1.xml  Theocritus
# 2   tlg0006  tlg0006.tlg020  tlg0006.tlg020.1st1K-grc1.xml   Euripides
# 3   tlg0007  tlg0007.tlg146  tlg0007.tlg146.1st1K-grc1.xml    Plutarch
# 4   tlg0007  tlg0007.tlg147  tlg0007.tlg147.1st1K-grc1.xml    Plutarch
#
#                                title  \
# 0    De Epistola Pinyti ad Dionysium
# 1                             Syrinx
# 2                          Fragmenta
# 3  Παροιμίαι αἷς Ἀλεξανδρεῖς ἐχρῶντο
# 4           Ἐκλογὴ περὶ τῶν ἀδυνάτων
#
#                                            sentences  \
# 0  [, , ., . . . . ., — πρός ἥν ( ,, ), ὁ Πινυτός...
# 1  [Οὐδενός εὐνάτειρα Μακροπτολέμοιο δέ μάτηρ μαί...
# 2  [ποίαν σε φῶμεν γαῖαν ἐκλελοιπότα πόλει ξενοῦσ...
# 3  [Οἴκοι τά Μιλήσια: ἐπί τῶν ὅποι μή προςήκει τή...
# 4  [Κατά πετρῶν σπείρεις., Πλίνθον πλύνεις., Δικτ...
#
#                                 lemmatized_sentences  source lemmata_source  \
# 0  [[], [], [], [], [πινυτός, ἀντιγράφω], [θαυμάζ...  glaux1         glaux1
# 1  [[εὐνητήρ, μακροπτολέμον, μήτηρ, μαῖα, ἀντιπέτ...  glaux1         glaux1
# 2  [[φημί, γῆ, ἐκλείπω, πόλις, ξενοῦσθαι], [πάτρα...  glaux1         glaux1
# 3  [[μιλήσιος, πργοςήκω, τρυφή, ἐπιδείκνυμι], [ἀρ...  glaux1         glaux1
# 4  [[πέτρα, σπείρω], [πλίνθος, πλύνω], [δίκτυον, ...  glaux1         glaux1
#
#    not_before  not_after                    tlg_epithet genre provenience  \
# 0       101.0      200.0                             []  None   christian
# 1      -400.0     -201.0                     [Bucolici]  None       pagan
# 2      -500.0     -401.0                      [Tragici]  None       pagan
# 3         1.0      200.0  [Biographi, Philosophici/-ae]  None       pagan
# 4         1.0      200.0  [Biographi, Philosophici/-ae]  None       pagan
#
#    wordcount  lemmatacount
# 0        109            34
# 1         95            59
# 2      21516         10315
# 3       3206          1496
# 4        195           125

# %%
path = "../data/large_files/sents_data/"
LAGT[LAGT["doc_id"].apply(lambda x: f"{x}.pickle" not in os.listdir(path))]
# Out:
#     author_id          doc_id                       filename        author  \
# 339   tlg0530  tlg0530.tlg006  tlg0530.tlg006.1st1K-grc1.xml  Pseudo-Galen
#
#                                 title sentences lemmatized_sentences source  \
# 339  Ad Gaurum quomodo animetur fetus        []                   []   1Kgr
#
#     lemmata_source  not_before  not_after tlg_epithet genre provenience  \
# 339          grecy       201.0        NaN    [Medici]  None       pagan
#
#      wordcount  lemmatacount
# 339          0             0

# %%
len(set(LAGT["doc_id"]))
# Out:
# 1959

# %% [markdown]
# ### Backup of an old approach...

# %%
# put the string cleaning, doc creation and lemmata together into one function
def from_string_to_lemsents(string):
    try:    
        doc = get_doc(clean_string(string), segment_len=50000)
        lemmatized_sentences = get_lemmatized_sentences(doc)
    except:
        lemmatized_sentences = None
    return lemmatized_sentences

# %%
grecy_lemmatized_list = []
def get_grecy_lemmata(string, lemmatized_sentences, doc_id):
    if lemmatized_sentences == None:
        lemmatized_sentences = from_string_to_lemsents(string)
        grecy_lemmatized_list.append(doc_id)
        print(len(grecy_lemmatized_list), doc_id, len(string))
    return lemmatized_sentences

#sample_lemmatized_sentences = LAGT.sample(10, random_state=1).apply(lambda row: get_grecy_lemmata(row["string"], row["lemmatized_sentences"], row["doc_id"]), axis=1)

# %%
#sample_lemmatized_sentences

# %%
#LAGT.loc[sample_lemmatized_sentences.index]

# %%
#grecy_lemmatized_list

# %% [markdown]
# # Applying the main funtion

# %%
# %%time
### will be time consuming...
LAGT["lemmatized_sentences"] = LAGT.apply(lambda row: get_grecy_lemmata(row["string"], row["lemmatized_sentences"], row["doc_id"]), axis=1)
# Out:
# 1 ggm0001.ggm001 3857
# 2 ogl0001.ogl001 1257
# 3 stoa0033a.tlg028 41978
# 4 stoa0033a.tlg043 20816
# 5 stoa0121.stoa001 171855
# 6 stoa0146d.stoa001 27696
# 7 tlg0005.tlg003 572
# 8 tlg0006.tlg020 108623
# 9 tlg0007.tlg146 18130
# 10 tlg0007.tlg147 1069
# 11 tlg0018.tlg001 143932
# 12 tlg0018.tlg002 260468
# 13 tlg0018.tlg003 76774
# 14 tlg0018.tlg004 141567
# 15 tlg0018.tlg005 96145
# 16 tlg0018.tlg006 97880
# 17 tlg0018.tlg007 32667
# 18 tlg0018.tlg008 94218
# 19 tlg0018.tlg009 92533
# 20 tlg0018.tlg010 89337
# 21 tlg0018.tlg011 108351
# 22 tlg0018.tlg012 33173
# 23 tlg0018.tlg013 93899
# 24 tlg0018.tlg014 110248
# 25 tlg0018.tlg015 172311
# 26 tlg0018.tlg016 90855
# 27 tlg0018.tlg017 114022
# 28 tlg0018.tlg018 114895
# 29 tlg0018.tlg019 246616
# 30 tlg0018.tlg020 151034
# 31 tlg0018.tlg021 139575
# 32 tlg0018.tlg022 365437
# 33 tlg0018.tlg023 95569
# 34 tlg0018.tlg024 642298
# 35 tlg0018.tlg025 173969
# 36 tlg0018.tlg026 99048
# 37 tlg0018.tlg027 107520
# 38 tlg0018.tlg028 66001
# 39 tlg0018.tlg029 118642
# 40 tlg0018.tlg030 91632
# 41 tlg0018.tlg031 186072
# 42 tlg0022.tlg001 42279
# 43 tlg0022.tlg002 27630
# 44 tlg0026.tlg004 27172
# 45 tlg0037.tlg001 8718
# 46 tlg0039.tlg001 2170
# 47 tlg0044.tlg001 3116
# 48 tlg0045.tlg001 4229
# 49 tlg0046.tlg001 4698
# 50 tlg0048.tlg001 15540
# 51 tlg0053.tlg001 114143
# 52 tlg0055.tlg001 54245
# 53 tlg0057.tlg033 86209
# 54 tlg0057.tlg037 320258
# 55 tlg0061.tlg001 59143
# 56 tlg0061.tlg002 49844
# 57 tlg0061.tlg003 32620
# 58 tlg0061.tlg004 5672
# 59 tlg0061.tlg005 7158
# 60 tlg0061.tlg006 14667
# 61 tlg0061.tlg007 20676
# 62 tlg0061.tlg008 21856
# 63 tlg0065.tlg001 74605
# 232 tlg0646.tlg004 17788
# 233 tlg0649.tlg002 9456
# 234 tlg0649.tlg003 6136
# 235 tlg0656.tlg001 2332559
# 236 tlg0656.tlg002 251615
# 237 tlg0657.tlg001 6808
# 238 tlg0658.tlg001 493050
# 239 tlg0666.tlg001 1661
# 240 tlg0676.tlg001 1187
# 241 tlg0693.tlg001 91621
# 242 tlg0693.tlg002 9910
# 243 tlg0731.tlg001 81692
# 244 tlg0731.tlg003 34087
# 245 tlg0732.tlg003 48580
# 246 tlg0732.tlg004 3037859
# 247 tlg0732.tlg005 1218218
# 248 tlg0732.tlg006 1570669
# 249 tlg0732.tlg007 489124
# 250 tlg0732.tlg008 613933
# 251 tlg0732.tlg010 445688
# 252 tlg0732.tlg013 203102
# 253 tlg0732.tlg014 195877
# 254 tlg0732.tlgX01 573522
# 255 tlg0733.tlg001 43978
# 256 tlg0751.tlg005 11919
# 257 tlg1118.tlg003 7413
# 258 tlg1129.tlg001 8615
# 259 tlg1131.tlg001 8135
# 260 tlg1134.tlg001 11333
# 261 tlg1146.tlg001 29958
# 262 tlg1147.tlg003 26261
# 263 tlg1188.tlg002 35189
# 264 tlg1193.tlg001 32825
# 265 tlg1194.tlg001 198987
# 266 tlg1247.tlg001 29014
# 267 tlg1264.tlg001 811279
# 268 tlg1264.tlg002 447955
# 269 tlg1264.tlg003 1934
# 270 tlg1264.tlg004 23289
# 271 tlg1269.tlg002 73317
# 272 tlg1271.tlg003 2970
# 273 tlg1271.tlg004 4677
# 274 tlg1271.tlg005 16394
# 275 tlg1271.tlg006 406824
# 276 tlg1271.tlg010 13415
# 277 tlg1271.tlg011 159361
# 278 tlg1271.tlg012 165129
# 279 tlg1272.tlg001 166915
# 280 tlg1286.tlg001 15207
# 281 tlg1286.tlg002 8122
# 282 tlg1286.tlg003 2736
# 283 tlg1286.tlg004 6233
# 284 tlg1286.tlg005 6781
# 285 tlg1286.tlg006 4742
# 286 tlg1286.tlg007 1623
# 287 tlg1286.tlg008 2910
# 288 tlg1286.tlg009 6282
# 289 tlg1286.tlg010 15538
# 290 tlg1286.tlg011 14191
# 291 tlg1286.tlg012 12418
# 292 tlg1286.tlg013 13126
# 293 tlg1286.tlg014 5027
# 294 tlg1286.tlg016 8528
# 295 tlg1286.tlg017 785
# 296 tlg1286.tlg018 9427
# 297 tlg1286.tlg020 117899
# 298 tlg1287.tlg001 10061
# 299 tlg1304.tlg002 114131
# 300 tlg1309.tlg001 21760
# 301 tlg1319.tlg002 7830
# 302 tlg1320.tlg001 75012
# 303 tlg1325.tlg001 54958
# 304 tlg1329.tlg001 5270
# 305 tlg1347.tlg004 8549
# 306 tlg1367.tlg001 11063
# 307 tlg1383.tlg001 128253
# 308 tlg1390.tlg004 14325
# 309 tlg1402.tlg001 52031
# 310 tlg1402.tlg002 3832
# 311 tlg1402.tlg003 10569
# 312 tlg1402.tlg004 3505
# 313 tlg1402.tlg005 2028
# 314 tlg1409.opp003 2968
# 315 tlg1414.tlg001 93581
# 316 tlg1416.tlg007 14123
# 317 tlg1419.tlg001 209522
# 318 tlg1434.tlg004 5076
# 319 tlg1441.tlg001 7694
# 320 tlg1443.tlg001 73227
# 321 tlg1443.tlg002 123035
# 322 tlg1447.tlg001 213761
# 323 tlg1447.tlg009 2314
# 324 tlg1463.tlg001 101536
# 325 tlg1482.tlg001 172124
# 326 tlg1484.tlg001 26046
# 327 tlg1486.tlg001 44586
# 328 tlg1486.tlg002 5489
# 329 tlg1542.tlg001 43303
# 330 tlg1548.tlg001 52231
# 331 tlg1551.tlg001 490884
# 332 tlg1551.tlg002 13590
# 333 tlg1553.tlg001 45981
# 334 tlg1562.tlg002 18742
# 335 tlg1595.tlg221 84424
# 336 tlg1595.tlg370 63568
# 337 tlg1596.tlg002 13566
# 338 tlg1602.tlg001 2815
# 339 tlg1617.tlg001 38273
# 340 tlg1626.tlg001 2010
# 341 tlg1634.tlg002 11524
# 342 tlg1664.tlg001 10155
# 343 tlg1669.tlg004 11941
# 344 tlg1681.tlg001 2717
# 345 tlg1692.tlg005 35780
# 346 tlg1699.tlg001 1856
# 347 tlg1699.tlg002 8927
# 348 tlg1699.tlg003 7572
# 349 tlg1699.tlg004 7502
# 350 tlg1699.tlg005 2753
# 351 tlg1699.tlg006 1470
# 352 tlg1699.tlg007 1283
# 353 tlg1699.tlg008 5928
# 354 tlg1701.tlg001 83421
# 355 tlg1701.tlg002 44151
# 356 tlg1705.tlg001 1167
# 357 tlg1719.tlg001 142479
# 358 tlg1724.tlg001 305587
# 359 tlg1725.tlg001 133494
# 360 tlg1749.tlg001 2896
# 361 tlg1750.tlg001 32680
# 362 tlg1750.tlg002 25131
# 363 tlg1750.tlg003 7126
# 364 tlg1750.tlg004 23624
# 365 tlg1763.tlg001 16936
# 366 tlg1764.tlg001 1121485
# 367 tlg1799.tlg007 118804
# 368 tlg1799.tlg009 102687
# 369 tlg1799.tlg016 77697
# 370 tlg1801.tlg001 23162
# 371 tlg1802.tlg001 6179
# 372 tlg1803.tlg001 23683
# 373 tlg1805.tlg001 27521
# 374 tlg1805.tlg002 6142
# 375 tlg1805.tlg003 3795
# 376 tlg1805.tlg004 1151
# 377 tlg1805.tlg005 2498
# 378 tlg1805.tlg006 3398
# 379 tlg1805.tlg007 840
# 380 tlg1805.tlg008 1823
# 381 tlg1805.tlg009 640
# 382 tlg1805.tlg010 14236
# 383 tlg2000.tlg001 1780323
# 384 tlg2001.tlg038 242896
# 385 tlg2001.tlg039 709341
# 386 tlg2001.tlg040 361845
# 387 tlg2001.tlg041 120208
# 388 tlg2001.tlg042 702053
# 389 tlg2016.tlg001 26637
# 390 tlg2018.tlg001 1462122
# 391 tlg2018.tlg003 52665
# 392 tlg2018.tlg005 998726
# 393 tlg2018.tlg007 113346
# 394 tlg2018.tlg008 1102
# 395 tlg2018.tlg009 107910
# 396 tlg2018.tlg010 73253
# 397 tlg2018.tlg011 112485
# 398 tlg2018.tlg020 328878
# 399 tlg2018.tlg021 99087
# 400 tlg2018.tlg022 144840
# 401 tlg2018.tlg023 322598
# 402 tlg2021.tlg001 349688
# 403 tlg2021.tlg002 1848112
# 404 tlg2021.tlg003 33083
# 405 tlg2022.tlg003 203370
# 406 tlg2022.tlg007 51598
# 407 tlg2022.tlg008 116499
# 408 tlg2022.tlg009 80018
# 409 tlg2022.tlg010 86347
# 410 tlg2022.tlg011 101829
# 411 tlg2022.tlg060 918
# 412 tlg2023.tlg001 196177
# 413 tlg2023.tlg002 248786
# 414 tlg2023.tlg003 124697
# 415 tlg2023.tlg004 163232
# 416 tlg2023.tlg006 257199
# 417 tlg2027.tlg001 163954
# 418 tlg2027.tlg002 15921
# 419 tlg2029.tlg001 11225
# 420 tlg2032.tlg001 502968
# 421 tlg2034.tlg002 39078
# 422 tlg2034.tlg003 221031
# 423 tlg2034.tlg005 29155
# 424 tlg2034.tlg006 62563
# 425 tlg2034.tlg007 206689
# 426 tlg2034.tlg014 968429
# 427 tlg2034.tlg015 199552
# 428 tlg2034.tlg027 14020
# 429 tlg2035.tlg002 121529
# 430 tlg2035.tlg003 8744
# 431 tlg2035.tlg117 65544
# 432 tlg2035.tlg130 146276
# 433 tlg2035.tlg131 186363
# 434 tlg2035.tlg132 149550
# 435 tlg2036.tlg001 184834
# 436 tlg2038.tlg001 177300
# 437 tlg2039.tlg003 566
# 438 tlg2039.tlg004 15566
# 439 tlg2039.tlg005 21685
# 440 tlg2041.tlg001 84757
# 441 tlg2042.tlg005 1613774
# 442 tlg2042.tlg006 251875
# 443 tlg2042.tlg009 298099
# 444 tlg2042.tlg010 73327
# 445 tlg2042.tlg011 84829
# 446 tlg2042.tlg013 30818
# 447 tlg2042.tlg014 18071
# 448 tlg2042.tlg015 691
# 449 tlg2042.tlg016 390083
# 450 tlg2042.tlg017 133262
# 451 tlg2042.tlg019 449020
# 452 tlg2042.tlg021 393792
# 453 tlg2042.tlg029 242851
# 454 tlg2042.tlg030 734223
# 455 tlg2042.tlg044 50751
# 456 tlg2042.tlg045 43064
# 457 tlg2042.tlg048 86701
# 458 tlg2042.tlg050 28635
# 459 tlg2042.tlg051 12454
# 460 tlg2042.tlg052 14294
# 461 tlg2042.tlg053 20113
# 462 tlg2042.tlg054 8005
# 463 tlg2042.tlg055 2183
# 464 tlg2042.tlg057 28348
# 465 tlg2042.tlg058 646010
# 466 tlg2042.tlg061 2037
# 467 tlg2042.tlg066 4100
# 468 tlg2042.tlg067 1554
# 469 tlg2042.tlg068 3626
# 470 tlg2042.tlg069 2511
# 471 tlg2042.tlg070 12551
# 472 tlg2042.tlg071 1342
# 473 tlg2042.tlg072 898
# 474 tlg2042.tlg073 56955
# 475 tlg2042.tlg074 56041
# 476 tlg2042.tlg075 112945
# 477 tlg2042.tlg076 44028
# 478 tlg2042.tlg077 27646
# 479 tlg2042.tlg078 69046
# 480 tlg2042.tlg079 358885
# 481 tlg2042.tlg084 8832
# 482 tlg2042.tlg086 39489
# 483 tlg2048.tlg001 1093504
# 484 tlg2049.tlg001 29831
# 485 tlg2050.tlg001 8061
# 817 tlg0007.tlg128 9963
# 818 tlg0007.tlg129 79227
# 819 tlg0007.tlg130 22312
# 820 tlg0007.tlg131 10381
# 821 tlg0007.tlg132 8174
# 822 tlg0007.tlg133 39004
# 823 tlg0007.tlg134 58062
# 824 tlg0007.tlg135 7295
# 825 tlg0007.tlg136 76856
# 826 tlg0007.tlg137 3331
# 827 tlg0007.tlg138 87471
# 828 tlg0007.tlg139 62837
# 829 tlg0007.tlg140 63485
# 830 tlg0007.tlg141 8062
# 831 tlg0013.tlg008 775
# 832 tlg0014.tlg062 59923
# 833 tlg0014.tlg063 38588
# 834 tlg0081.tlg007 1473
# 835 tlg0094.tlg003 99016
# 836 tlg0363.tlg007 243516
# 837 tlg0555.tlg004 849920
# 838 tlg0557.tlg004 1741
# 839 tlg0557.tlg005 11957
# 840 tlg0612.tlg001 1124459
# 841 tlg0647.tlg001 29917
# 842 tlg0652.tlg001 43202
# 843 tlg2003.tlg002 53312
# 844 tlg2003.tlg003 101300
# 845 tlg2003.tlg004 23061
# 846 tlg2003.tlg005 36385
# 847 tlg2003.tlg006 25544
# 848 tlg2003.tlg007 66734
# 849 tlg2003.tlg008 43025
# 850 tlg2003.tlg009 43696
# 851 tlg2003.tlg010 52005
# 852 tlg2003.tlg011 55631
# 853 tlg2003.tlg012 66962
# 854 tlg2003.tlg013 171136
# 855 tlg2003.tlg017 66408
# 856 tlg2018.tlg002 692543
# 857 tlg2040.tlg002 38430
# 858 tlg2040.tlg004 916516
# 859 tlg2045.tlg001 934506
# 860 tlg2046.tlg001 395355
# 861 tlg2934.tlg066 430237
# 862 tlg4029.tlg002 210702
# 863 tlg4081.tlg001 16905
# 864 tlg4091.tlg001 24761
# 865 tlg7000.tlg001 132782
# CPU times: user 16h 57min 22s, sys: 4h 21min 57s, total: 21h 19min 20s
# Wall time: 11h 42min 42s

# %%
LAGT[LAGT["lemmatized_sentences"].isnull()]
# Out:
#     author_id          doc_id                       filename        author  \
# 411   tlg0530  tlg0530.tlg006  tlg0530.tlg006.1st1K-grc1.xml  Pseudo-Galen
# 824   tlg2042  tlg2042.tlg009    tlg2042.tlg009.opp-grc1.xml      Origenes
# 834   tlg2042  tlg2042.tlg021    tlg2042.tlg021.opp-grc1.xml      Origenes
#
#                                 title  \
# 411  Ad Gaurum quomodo animetur fetus
# 824       In Jeremiam (Homiliae 1-11)
# 834      In Jeremiam (Homiliae 12-20)
#
#                                                 string  wordcount source  \
# 411  Τὸ περὶ τῆς εἰς τὰ σώματα τῶν ψυχῶν εἰσκρίσεως...       9595   1Kgr
# 824  \n Ὁ θεὸς εἰς ἀγαθοποιίαν πρόχειρός\n         ...      36685   1Kgr
# 834  Ὃ προστάσσεται ὁ προφήτης λέγειν ὑπὸ θεοῦ, ὀφε...      48360   1Kgr
#
#     lemmatized_sentences lemmata_source
# 411                 None           None
# 824                 None           None
# 834                 None           None

# %%
missing_i = LAGT[LAGT["lemmatized_sentences"].isnull()].index

# %%
string = LAGT[LAGT["lemmatized_sentences"].isnull()]["string"].tolist()[1]

# %%
type(string)
# Out:
# str

# %%
cleaned_string = clean_string(string)

# %%
cleaned_string = re.sub("\.{3}\.*", "...", cleaned_string)

# %%
doc = nlp(cleaned_string)

# %%
def dealing_with_missing(string):
    string = str(string)
    cleaned_string = clean_string(string)
    cleaned_string = re.sub("\.{3}\.*", "...", cleaned_string)
    doc = nlp(cleaned_string)
    lemmatized_sentences = get_lemmatized_sentences(doc)
    return lemmatized_sentences

lemmatized_missing = LAGT[LAGT["lemmatized_sentences"].isnull()]["string"].apply(dealing_with_missing)

# %%
lemmatized_missing
# Out:
# 411    [[σῶμα, ψυχή, εἰσκρίσις, ζῳογονία, δόγμα, πολύ...
# 824    [[θεός, ἀγαθοποιία, πρόχειρος, κολάζω, ἄξιος, ...
# 834    [[προστάσσω, προφήτης, λέγω, θεός], [ὀφείλω, ἄ...
# Name: string, dtype: object

# %%
LAGT.loc[missing_i, "lemmatized_sentences"] = lemmatized_missing

# %%
LAGT.sample(10, random_state=1)
# Out:
#      author_id            doc_id                         filename  \
# 1532   tlg0031    tlg0031.tlg008  tlg0031.tlg008.perseus-grc2.xml
# 1619   tlg0060    tlg0060.tlg001  tlg0060.tlg001.perseus-grc6.xml
# 581    tlg0732    tlg0732.tlg013    tlg0732.tlg013.1st1K-grc1.xml
# 474    tlg0591  tlg0591.1st1K001  tlg0591.1st1K001.1st1K-grc1.xml
# 704    tlg1699    tlg1699.tlg004    tlg1699.tlg004.1st1K-grc1.xml
# 274    tlg0087    tlg0087.tlg013    tlg0087.tlg013.1st1K-grc1.xml
# 200    tlg0066    tlg0066.tlg001    tlg0066.tlg001.1st1K-grc1.xml
# 652    tlg1383    tlg1383.tlg001    tlg1383.tlg001.1st1K-grc1.xml
# 1107   tlg4102    tlg4102.tlg037    tlg4102.tlg037.1st1K-grc1.xml
# 1283   tlg0007    tlg0007.tlg089  tlg0007.tlg089.perseus-grc2.xml
#
#                            author  \
# 1532                         None
# 1619             Diodorus Siculus
# 581      Alexander of Aphrodisias
# 474                   Antisthenes
# 704             Teles Megarenesis
# 274                    Herodianus
# 200               Ps. Dicaearchus
# 652                       Geminus
# 1107  Catenae (Novum Testamentum)
# 1283                     Plutarch
#
#                                                   title  \
# 1532                      New Testament - 2 Corinthians
# 1619                  Βιβλιοθήκη Ἱστορική (Books 18-20)
# 581                              Ἠθικὰ προβλήματα [Sp.]
# 474                                                Αἴας
# 704                  Περὶ συγκρίσεως πενίας καὶ πλούτου
# 274                               Περὶ κλίσεως ὀνομάτων
# 200   Dicaearchi, ut fertur, potius vero Athenaei De...
# 652                                 Elementa astronomia
# 1107                  Catena In Epistulam Ad Philemonem
# 1283                           Περὶ Ἴσιδος και Ὀσίριδος
#
#                                                  string  wordcount   source  \
# 1532  \n\n                    ΠΑΥΛΟΣ ἀπόστολος Χριστ...       4470  perseus
# 1619   τάδε ἔνεστιν ἐν τῇ ὀκτωκαιδεκάτῃ τῶν Διοδώρου...      79283  perseus
# 581   α. Ἀπορίαι πρὸς τοὺς τὸ ζῆν οὐκ ἀγαθὸν\n      ...      23343     1Kgr
# 474   Ἐβουλόμην ἂν τοὺς αὐτοὺς ἡμῖν δικάζειν οἵπερ \...        502     1Kgr
# 704   Δοκεῖ μοι ἡ τῶν χρημάτων κτῆσις σπάνεως καὶ ἐν...       1195     1Kgr
# 274   1. Anecd.Ox.IV 333, 6: Ἐπιτομὴ τῶν ὀνοματικῶν ...      59506     1Kgr
# 200   Ἐντεῦθεν εἰς τὸ Ἀθηναίων ἔπεισιν \n\n         ...       2757     1Kgr
# 652    Ὁ τῶν ζῳδίων κύκλος διαιρεῖται εἰς μέρη ιβ′, ...      20574     1Kgr
# 1107  ΑΝΗΡ τις ἦν Φιλήμων τῶν πιστῶν καὶ γενναίων ἀν...       2185     1Kgr
# 1283  πάντα μέν, ὦ Κλέα, δεῖ τἀγαθὰ τοὺς νοῦν ἔχοντα...      18332  perseus
#
#                                    lemmatized_sentences lemmata_source
# 1532  [[Παῦλος, ἀπόστολος, Χριστός, Ἰησοῦς, θέλημα, ...       morphgnt
# 1619  [[θεός, δισσός, παλαιός, ἄνθρωπος, μεταγενής, ...          glaux
# 581   [[Ἀπορίαις, ζῶ, ἀγαθός, λέγω], [ὁμοειδέω, ἡδον...           None
# 474   [[Ἐβουλόμης, αὐτός, δικάζω, πρᾶγμα, πάρειμι], ...           None
# 704   [[δοκέω, χρῆμα, κτῆσις, σπάνις, ἔνδεια, ἀπολύω...           None
# 274   [[Ἐπιτομή, ὀνοματικός, κανών, Ἡρωδιανός], [ὅμο...           None
# 200   [[Ἀθηναῖος, ἔπειμι, ἄστυ], [ὁδός, ἡδύς, γεωργο...           None
# 652   [[ζωίδιον, κύκλος, διαιρέω, μέρος, καλέω, ἕκασ...           None
# 1107  [[Ἀνήρ, Φιλήμων, πιστός, γενναῖος, ἀνήρ], [οὗτ...           None
# 1283  [[Κλέα, δεῖ, ἀγαθός, νόος, ἔχω, αἰτέω, θεός], ...           None

# %%
LAGT["lemmata_source"] = LAGT["lemmata_source"].apply(lambda x: "grecy" if x is None else x)

# %% [markdown]
# # Simple explorations of what is in the lemmata

# %%
lemmata_series = LAGT["lemmatized_sentences"].apply(lambda x: [l for s in x for l in s])
lemmata_all = [l for lemmata in lemmata_series for l in lemmata]
nltk.FreqDist(lemmata_all).most_common()[:100]
# Out:
# [('οὗτος', 364348),
#  ('λέγω', 273729),
#  ('εἰμί', 229129),
#  ('αὐτός', 219506),
#  ('γίγνομαι', 173868),
#  ('ἔχω', 166248),
#  ('πολύς', 135222),
#  ('φημί', 116779),
#  ('πᾶς', 111288),
#  ('ἄλλος', 106778),
#  ('ποιέω', 97082),
#  ('λόγος', 93057),
#  ('τις', 92160),
#  ('τίς', 89570),
#  ('θεός', 67982),
#  ('μέγας', 62129),
#  ('ἐκεῖνος', 59461),
#  ('ἄνθρωπος', 58719),
#  ('πρῶτος', 55821),
#  ('ἕτερος', 52649),
#  ('οὐδείς', 49900),
#  ('πόλις', 49567),
#  ('σῶμα', 48549),
#  ('τοιοῦτος', 48415),
#  ('λαμβάνω', 48313),
#  ('ἀγαθός', 47307),
#  ('ὁράω', 47064),
#  ('φύσις', 45476),
#  ('μόνος', 44592),
#  ('ἀρχή', 42234),
#  ('δοκέω', 41371),
#  ('ἀνήρ', 41105),
#  ('δύναμαι', 38233),
#  ('ἕκαστος', 37620),
#  ('δύναμις', 37101),
#  ('δίδωμι', 36702),
#  ('καλέω', 36355),
#  ('ψυχή', 35405),
#  ('γῆ', 35381),
#  ('χρόνος', 34719),
#  ('μέρος', 34201),
#  ('ὑπάρχω', 33759),
#  ('κινέω', 32630),
#  ('δέω', 32382),
#  ('ἅπας', 31728),
#  ('βασιλεύς', 31257),
#  ('οἶδα', 29574),
#  ('ὅλος', 28608),
#  ('τόπος', 28354),
#  ('βούλομαι', 28263),
#  ('χράω', 27548),
#  ('ἡμέρα', 27231),
#  ('δείκνυμι', 27183),
#  ('δεῖ', 26970),
#  ('εἶδος', 26910),
#  ('πατήρ', 26624),
#  ('φέρω', 26601),
#  ('ὄνομα', 26597),
#  ('συμβαίνω', 25785),
#  ('γένος', 25711),
#  ('ἔρχομαι', 25673),
#  ('κύριος', 25184),
#  ('φαίνω', 24561),
#  ('κακός', 24555),
#  ('ἀκούω', 24224),
#  ('ὅδε', 23763),
#  ('ἴσος', 23675),
#  ('τρόπος', 23283),
#  ('πρᾶγμα', 23224),
#  ('υἱός', 23166),
#  ('οὐσία', 22905),
#  ('γυνή', 22705),
#  ('ὕδωρ', 22557),
#  ('γράφω', 22557),
#  ('μέσος', 22518),
#  ('καλός', 22108),
#  ('παῖς', 22057),
#  ('μηδείς', 21908),
#  ('ἴδιος', 21881),
#  ('ζῷον', 21391),
#  ('νόμος', 21075),
#  ('ἔργον', 20474),
#  ('κίνησις', 20307),
#  ('πρότερος', 20054),
#  ('εἷς', 19835),
#  ('εὑρίσκω', 19754),
#  ('ς', 19642),
#  ('ἐναντίος', 19429),
#  ('χείρ', 19394),
#  ('πάσχω', 19388),
#  ('ἀνάγκη', 18849),
#  ('μικρός', 18832),
#  ('κοινός', 18743),
#  ('ἄρχω', 18694),
#  ('μέλλω', 18641),
#  ('τίθημι', 18570),
#  ('αἰτία', 18568),
#  ('πράσσω', 18371),
#  ('τυγχάνω', 18331),
#  ('δεύτερος', 18295)]

# %%
lemmata_series = LAGT[LAGT["lemmata_source"]=="grecy"]["lemmatized_sentences"].apply(lambda x: [l for s in x for l in s])
lemmata_all = [l for lemmata in lemmata_series for l in lemmata]
nltk.FreqDist(lemmata_all).most_common()[:100]
# Out:
# [('οὗτος', 203072),
#  ('λέγω', 191259),
#  ('γίγνομαι', 105697),
#  ('ἔχω', 103927),
#  ('φημί', 81432),
#  ('πολύς', 70140),
#  ('τίς', 66012),
#  ('λόγος', 62317),
#  ('ἄλλος', 57911),
#  ('ποιέω', 56310),
#  ('πᾶς', 48551),
#  ('θεός', 43913),
#  ('ἄνθρωπος', 39751),
#  ('αὐτός', 37861),
#  ('μόνος', 35407),
#  ('πρῶτος', 34811),
#  ('μέγας', 33667),
#  ('ἕτερος', 33187),
#  ('σῶμα', 32234),
#  ('φύσις', 31748),
#  ('ἐκεῖνος', 31561),
#  ('λαμβάνω', 29963),
#  ('ὁράω', 28237),
#  ('ψυχή', 27962),
#  ('κινέω', 27778),
#  ('ἀγαθός', 27685),
#  ('ἀρχή', 27153),
#  ('δεῖ', 26878),
#  ('δύναμαι', 24669),
#  ('τοιοῦτος', 23815),
#  ('οὐδείς', 23610),
#  ('ὑπάρχω', 23510),
#  ('γῆ', 22548),
#  ('δοκέω', 22514),
#  ('ἕκαστος', 22488),
#  ('εἶδος', 22412),
#  ('πόλις', 22142),
#  ('χρόνος', 22057),
#  ('μέρος', 21609),
#  ('δύναμις', 21541),
#  ('δείκνυμι', 21349),
#  ('τόπος', 21248),
#  ('καλέω', 21223),
#  ('δίδωμι', 20088),
#  ('ς', 19563),
#  ('ἀνήρ', 19097),
#  ('ὅλος', 19077),
#  ('οὐσία', 18602),
#  ('γένος', 18407),
#  ('συμβαίνω', 17823),
#  ('πατήρ', 17081),
#  ('ὄνομα', 17048),
#  ('οἶδα', 17000),
#  ('Θεός', 16779),
#  ('πρότερος', 16366),
#  ('βασιλεύς', 16204),
#  ('φέρω', 15968),
#  ('κίνησις', 15912),
#  ('βούλομαι', 15592),
#  ('ζῷον', 15298),
#  ('τρόπος', 14889),
#  ('χράω', 14739),
#  ('μέσος', 14631),
#  ('πρᾶγμα', 14481),
#  ('ὕδωρ', 14349),
#  ('κακός', 14306),
#  ('ἴδιος', 14193),
#  ('ἴσος', 13769),
#  ('ἀκούω', 13573),
#  ('ἡμέρα', 13344),
#  ('υἱός', 13320),
#  ('Χριστός', 13290),
#  ('ἀνάγκη', 13156),
#  ('ἔρχομαι', 13000),
#  ('φαίνω', 12984),
#  ('αἰτία', 12761),
#  ('ἐναντίος', 12729),
#  ('δεύτερος', 12592),
#  ('ἅπας', 12570),
#  ('ὕλη', 12564),
#  ('κύριος', 12551),
#  ('νόος', 12489),
#  ('καλός', 12466),
#  ('νόμος', 12465),
#  ('αἴτιος', 12342),
#  ('γυνή', 12260),
#  ('ἀληθής', 12095),
#  ('γράφω', 12021),
#  ('κοινός', 11981),
#  ('λοιπός', 11839),
#  ('εὑρίσκω', 11617),
#  ('πάσχω', 11468),
#  ('τίθημι', 11390),
#  ('πῦρ', 11329),
#  ('μέλλω', 11264),
#  ('δῆλος', 11154),
#  ('παῖς', 11133),
#  ('ἔργον', 10978),
#  ('μηδείς', 10597),
#  ('ἀριθμός', 10569)]

# %%
LAGT.to_json("../data/large_files/LAGT_grecy_20240116.json")

# %%
#s = sddk.cloudSession("sciencedata.dk", "SDAM_root", "648597@au.dk")
s.write_file("SDAM_data/AGT/LAGT_grecy_20240116.json", LAGT)
# Out:
# A file with the same name ("LAGT_grecy_20240116.json") already exists in this location.
# Your <class 'pandas.core.frame.DataFrame'> object has been succesfully written as "https://sciencedata.dk/sharingout/648597%40au.dk/SDAM_root/SDAM_data/AGT/LAGT_grecy_20240116.json"
