# %%
import spacy
import pyconll
import json
import re
import unicodedata

import plac
import random
from pathlib import Path
from spacy.util import minibatch, compounding

import sddk

# %%
# for data exchange with sciencedata.dk (skip if not needed)
conf = sddk.configure("SDAM_root", "648597@au.dk")
# Out:
# sciencedata.dk username (format '123456@au.dk'): 648597@au.dk
# sciencedata.dk password: ········
# connection with shared folder established with you as its owner
# endpoint variable has been configured to: https://sciencedata.dk/files/SDAM_root/

# %% [markdown]
# # Initialize the model

# %%
# using priviously generated word2vec vectors
# !python3 -m spacy init-model el ../models/spacy_grc_model_7_vectors --vectors-loc ../data/word2vec_win2.txt
# Out:
# ✔ Successfully created model
# 132846it [00:06, 20486.41it/s]/word2vec_win2.txt
# ✔ Loaded vectors from ../data/word2vec_win2.txt
# ✔ Sucessfully compiled vocab
# 133518 entries, 132846 vectors

# %%
# load it into our envoronment
nlp = spacy.load("../models/spacy_grc_model_7_vectors")
tagger = nlp.create_pipe("tagger")
nlp.add_pipe(tagger)
optimizer = nlp.begin_training()
# Out:
# /home/kasev/.local/lib/python3.6/site-packages/spacy/language.py:639: UserWarning:
#
# [W022] Training a new part-of-speech tagger using a model with no lemmatization rules or data. This means that the trained model may not be able to lemmatize correctly. If this is intentional or the language you're using doesn't have lemmatization data, please ignore this warning. If this is surprising, make sure you have the spacy-lookups-data package installed.
#
# /home/kasev/.local/lib/python3.6/site-packages/spacy/language.py:639: UserWarning:
#
# [W033] Training a new part-of-speech tagger using a model with no lexeme normalization table. This may degrade the performance of the model to some degree. If this is intentional or the language you're using doesn't have a normalization table, please ignore this warning. If this is surprising, make sure you have the spacy-lookups-data package installed. The languages with lexeme normalization tables are currently: da, de, el, en, id, lb, pt, ru, sr, ta, th.

# %% [markdown]
# # Add lookup tables

# %%
ag_lemma_lookup = json.load(open("../data/ag_lemma_lookup.json"))
ag_lemma_lookup_merged = json.load(open("../data/ag_lemma_lookup_merged.json"))

# %%
len(ag_lemma_lookup["VERB"].values())
# Out:
# 172980

# %%
ag_lemma_lookup["VERB"]
# Out:
# {'ἀάατον': 'ἀάω',
#  'ἄτᾳ': 'ἀτάομαι',
#  'ἀτᾷ': 'ἀτάομαι',
#  'ἆτʼ': 'ἀτάομαι',
#  'κἄτʼ': 'ἐτάζω',
#  'κἆτʼ': 'ἐτάζω',
#  'κᾆτʼ': 'εἰμί',
#  'κἆθʼ': 'ἔθω',
#  'κᾆθʼ': 'εἰμί',
#  'κἆτα': 'ἐτάζω',
#  'ἄατον': 'ἀάω',
#  'ʼτῷ': 'ἐτάζω',
#  'τὦ': 'εἰμί',
#  'ἀτοῦ': 'ἀτάομαι',
#  'ἄατε': 'ἀάω',
#  'ἄασα': 'ἀάω',
#  'ἄᾰσα': 'ἀάω',
#  'ᾱ̓́ασα': 'ἀάω',
#  'ἄασας': 'ἀάω',
#  'ἄᾰσας': 'ἀάω',
#  'ἄασαν': 'ἀάω',
#  'ἄᾱσαν': 'ἀάω',
#  'ᾱ̓́ασαν': 'ἀάω',
#  'ἄαςʼ': 'ἀάω',
#  'ἄας': 'ἀάω',
#  'ἀάσαι': 'ἀάω',
#  'ὤασιν': 'ἀάω',
#  'ἄαν': 'ἀάω',
#  'ἄων': 'ἀάω',
#  'ἀών': 'ἀάω',
#  'ἄωον': 'ἀάω',
#  'ἀασθῆναι': 'ἀάω',
#  'ἐπάην': 'ἄημι',
#  'ἄσαμεν': 'ἄω',
#  'ἄσα': 'ἀάω',
#  'ἆσα': 'ἀάω',
#  'ἄσᾳ': 'ἀσάομαι',
#  'ᾱ̓́ᾱσα': 'ἀάω',
#  'ἀασάμην': 'ἀάω',
#  'ἀᾰσάμην': 'ἀάω',
#  'ἀᾱσάμην': 'ἀάω',
#  'ἀσάμην': 'ἀσάομαι',
#  'ἀ̄ασάμην': 'ἀάω',
#  'ᾱ̓ασάμην': 'ἀάω',
#  'ᾱ̓σάμην': 'ἀσάομαι',
#  'ἀάσθην': 'ἀάω',
#  'ʼα': 'ἐάω',
#  'ʼω': 'ἐάω',
#  'ὤ': 'εἰμί',
#  'ὦ': 'εἰμί',
#  'ὥ': 'ἵημι',
#  'ὧ': 'ἵημι',
#  'ἄα': 'ἀάω',
#  'ἀᾶ': 'ἀάω',
#  'ἄω': 'ἀάω',
#  'ἀῶ': 'ἀάω',
#  'ἀάω': 'ἀάω',
#  'παράα': 'ἀάω',
#  'παρᾱά': 'ἀάω',
#  'ἄητον': 'ἄημι',
#  'ἀντιάητον': 'ἄημι',
#  'ἄσατε': 'ἀάω',
#  'ἄσασθε': 'ἀσάομαι',
#  'ἄηθʼ': 'ἄημι',
#  'ἄσας': 'ἀάω',
#  'ἆσας': 'ἀάω',
#  'ᾄσας': 'ἀείδω',
#  'ᾆσας': 'ἀείδω',
#  'ἄσω': 'ἄω',
#  'ἀσῶ': 'ἄω',
#  'ᾄσω': 'ἀείδω',
#  'ᾀσῶ': 'ἀείδω',
#  'ᾱ̓́σω': 'ἄω',
#  'ἀάσθης': 'ἀάω',
#  'ἄᾱς': 'ἀάω',
#  'ἀμφαής': 'ἄημι',
#  'ἀπο-ήω': 'ἀάω',
#  'ἠῶ': 'ἀάω',
#  'ʼη': 'ἐάω',
#  'ἤ': 'ἠμί',
#  'ἤʼ': 'εἰμί',
#  'ἤ͂': 'ἠμί',
#  'ἦ': 'ἠμί',
#  'ᾖ': 'εἰμί',
#  'ᾗ': 'ἵημι',
#  'ἄη': 'ἄημι',
#  'ἀή': 'ἄημι',
#  'ἀναπάη': 'ἄημι',
#  'ἀάτην': 'ἀάω',
#  'ἀήτην': 'ἄημι',
#  'ἄασε': 'ἀάω',
#  'ἄασεν': 'ἀάω',
#  'ἄᾰσεν': 'ἀάω',
#  'ἆσε': 'ἀάω',
#  'ᾆσε': 'ἀείδω',
#  'ἄσατο': 'ἀάω',
#  'ἀάσατο': 'ἀάω',
#  'ἀᾱ́σατο': 'ἀάω',
#  'ᾱ̓́σατο': 'ἀσάομαι',
#  'ᾱ̓άσατο': 'ἀάω',
#  'ἀάσθη': 'ἀάω',
#  'ἀασθῇ': 'ἀάω',
#  'ἦα': 'εἰμί',
#  'ᾖα': 'εἶμι',
#  'ἄητο': 'ἄημι',
#  'ἄαται': 'ἄω',
#  'ἀᾶται': 'ἀάω',
#  'ἄᾰται': 'ἀάω',
#  'ἄηται': 'ἄημι',
#  'ἀῆται': 'ἄημι',
#  'ἀήτω': 'ἄημι',
#  'ἀβάκησαν': 'ἀβακέω',
#  'ἀβουλῆσαι': 'ἀβουλέω',
#  'ἀβουλεῖν': 'ἀβουλέω',
#  'ἠβουλήθην': 'βούλομαι',
#  'ἀβουλ-έω': 'ἀβουλέω',
#  'ἀβουλέω': 'ἀβουλέω',
#  'ἀβούλητον': 'ἀβουλέω',
#  'κἀβουλήθης': 'βούλομαι',
#  'ἀβούλου': 'ἀβουλέω',
#  'ἠβούλου': 'βούλομαι',
#  'ἀβουλ-εί': 'ἀβουλέω',
#  'ἀβουλεί': 'ἀβουλέω',
#  'ἀβουλήτων': 'ἀβουλέω',
#  'ἠβουλήθησαν': 'βούλομαι',
#  'ἠβουλήθη': 'βούλομαι',
#  'διαβούλ-οι': 'ἀβουλέω',
#  'διαβούλοι': 'ἀβουλέω',
#  'ἀβροτάξομεν': 'ἀβροτάζω',
#  'ἄβροτα': 'ἀβροτάζω',
#  'ἀβροτάζω': 'ἀβροτάζω',
#  'ἁβρῦναι': 'ἁβρύνω',
#  'ἁβρύνεσθαι': 'ἁβρύνω',
#  'ἅβρυνα': 'ἁβρύνω',
#  'ἁβρ-ύνω': 'ἁβρύνω',
#  'ἁβρύνω': 'ἁβρύνω',
#  'ἁβρύνομαι': 'ἁβρύνω',
#  'ἡβρυνόμην': 'ἁβρύνω',
#  'ἅβρυνε': 'ἁβρύνω',
#  'ἁβρύνεται': 'ἁβρύνω',
#  'ἡβρύνετο': 'ἁβρύνω',
#  'ἀγαθοεργεῖν': 'ἀγαθοεργέω',
#  'ἀγαθο-εργέω': 'ἀγαθοεργέω',
#  'ἀγαθοεργέω': 'ἀγαθοεργέω',
#  'ἀγαθουργέω': 'ἀγαθοεργέω',
#  'ἀγαθοεργοί': 'ἀγαθοεργέω',
#  'ἀγαθοποιῆσαι': 'ἀγαθοποιέω',
#  'ἀγαθο-ποιέω': 'ἀγαθοποιέω',
#  'ἀγαθοποιέω': 'ἀγαθοποιέω',
#  'ἀγαθοποιεῖτε': 'ἀγαθοποιέω',
#  'ἀγαθοποιῆτε': 'ἀγαθοποιέω',
#  'ἀγάθʼ': 'ἄγαμαι',
#  'κἀγάθʼ': 'ἄγαμαι',
#  'τἀγάθʼ': 'ἄγαμαι',
#  'ὦγαθʼ': 'ἄγαμαι',
#  'ἁγαθή': 'γηθέω',
#  'κἀγαθῆς': 'γηθέω',
#  'κἀγαθή': 'γηθέω',
#  'κἀγαθοῦ': 'γηθέω',
#  'τἀγαθοῦ': 'γηθέω',
#  'τὠγαθοῦ': 'γηθέω',
#  'ἀγαίομαι': 'ἀγαίομαι',
#  'ἐπαγαίομαι': 'ἀγαίομαι',
#  'ἐπᾰγαίομαι': 'ἀγαίομαι',
#  'ἀγαίου': 'ἀγαίομαι',
#  'ἀγαίετο': 'ἀγαίομαι',
#  'ἐπαγαίετο': 'ἀγαίομαι',
#  'ἀγαίεται': 'ἀγαίομαι',
#  'ἀγαλλιάσει': 'ἀγαλλιάω',
#  'ἀγαλλιαθῆναι': 'ἀγαλλιάω',
#  'ἠγαλλίασεν': 'ἀγαλλιάω',
#  'ἀγαλλιῶμεν': 'ἀγαλλιάω',
#  'ἀγαλλιώμεθα': 'ἀγαλλιάω',
#  'ἠγαλλίᾱσα': 'ἀγαλλιάω',
#  'ἠγαλλιᾱσάμην': 'ἀγαλλιάω',
#  'ἠγαλλιάσθην': 'ἀγαλλιάω',
#  'ἀγαλλι-άω': 'ἀγαλλιάω',
#  'ἀγαλλιάω': 'ἀγαλλιάω',
#  'ἀγαλλιάομαι': 'ἀγαλλιάω',
#  'ἀγαλλιᾶτε': 'ἀγαλλιάω',
#  'ἀγαλλιᾶσθε': 'ἀγαλλιάω',
#  'ἀγαλλίας': 'ἀγαλλιάω',
#  'ἀγαλλιάς': 'ἀγαλλιάω',
#  'ἀγαλλιάζει': 'ἀγαλλιάω',
#  'ἠγαλλιάσατο': 'ἀγαλλιάω',
#  'ἀγάλλουσι': 'ἀγάλλω',
#  'ἀγῆλαι': 'ἀγάλλω',
#  'ἀγαλθῆναι': 'ἀγάλλω',
#  'ἀγάλλειν': 'ἀγάλλω',
#  'ἀγάλλεσθαι': 'ἀγάλλω',
#  'ἀγαλοῦμεν': 'ἀγάλλω',
#  'ἀγαλλόμεθα': 'ἀγάλλω',
#  'ἤγηλα': 'ἀγάλλω',
#  'ἀγαλῶ': 'ἀγάλλω',
#  'ἀγᾰλῶ': 'ἀγάλλω',
#  'ἀγήλω': 'ἀγάλλω',
#  'ἠγαλλόμην': 'ἀγάλλω',
#  'ἀγάλλω': 'ἀγάλλω',
#  'ᾰ̓γάλλω': 'ἀγάλλω',
#  'προσαγάλλω': 'ἀγάλλω',
#  'προσᾰγάλλω': 'ἀγάλλω',
#  'ἀγάλλομαι': 'ἀγάλλω',
#  'συναγάλλομαι': 'ἀγάλλω',
#  'ἄγαλμʼ': 'ἀγάλλω',
#  'τἄγαλμʼ': 'ἀγάλλω',
#  'ἀγάλλεσθε': 'ἀγάλλω',
#  'ἠγάλλεσθε': 'ἀγάλλω',
#  'ἀγάλλευ': 'ἀγάλλω',
#  'ἠγάλλου': 'ἀγάλλω',
#  'ἀγάλλει': 'ἀγάλλω',
#  'ἀγάλλῃ': 'ἀγάλλω',
#  'ἄγαλλε': 'ἀγάλλω',
#  'ἠγάλλοντο': 'ἀγάλλω',
#  'ἀγάλλονται': 'ἀγάλλω',
#  'ἀγάλλοιντο': 'ἀγάλλω',
#  'ἀγάλλετο': 'ἀγάλλω',
#  'ἠγάλλετο': 'ἀγάλλω',
#  'ἀγάλλεται': 'ἀγάλλω',
#  'ἀγάλλοιτο': 'ἀγάλλω',
#  'ἀγασθέν': 'ἄγαμαι',
#  'ἀγάσασθαι': 'ἄγαμαι',
#  'ἀγάσσασθαι': 'ἄγαμαι',
#  'ἀγασθῆναι': 'ἄγαμαι',
#  'ἀναγασθῆναι': 'ἄγαμαι',
#  'ἀγάσεσθαι': 'ἄγαμαι',
#  'ἀγάσσεσθαι': 'ἄγαμαι',
#  'ἄγασθαι': 'ἄγαμαι',
#  'ἀγάασθαι': 'ἄγαμαι',
#  'ἀγασσάμεθʼ': 'ἄγαμαι',
#  'ἠγάσθημεν': 'ἄγαμαι',
#  'ἀγασθῶμεν': 'ἄγαμαι',
#  'ἀγάμεθʼ': 'ἄγαμαι',
#  'ἀγάμεθα': 'ἄγαμαι',
#  'ἠγασάμην': 'ἄγαμαι',
#  'ἠγασσάμην': 'ἄγαμαι',
#  'ἠγάσθην': 'ἄγαμαι',
#  'ἀγασθείην': 'ἄγαμαι',
#  'ἀγάσσομαι': 'ἄγαμαι',
#  'ἀγασθῶ': 'ἄγαμαι',
#  'ἀγασθήσομαι': 'ἄγαμαι',
#  'ἠγάμην': 'ἄγαμαι',
#  'ἅγαμαι': 'ἄγαμαι',
#  'ἄγαμαι': 'ἄγαμαι',
#  'ἄγᾰμαι': 'ἄγαμαι',
#  'ἀγάζομαι': 'ἄγαμαι',
#  'ἀμφάγαμαι': 'ἄγαμαι',
#  'ᾰ̓́γαμαι': 'ἄγαμαι',
#  'ᾰ̓γάζομαι': 'ἄγαμαι',
#  'ἐνάγαμαι': 'ἄγαμαι',
#  'ἐνάγᾰμαι': 'ἄγαμαι',
#  'προσάγαμαι': 'ἄγαμαι',
#  'προσάγᾰμαι': 'ἄγαμαι',
#  'ἀγαίμην': 'ἄγαμαι',
#  'ἄγωμαι': 'ἄγω',
#  'ἀγάσησθε': 'ἄγαμαι',
#  'ἄγασθε': 'ἄγαμαι',
#  'ἀγάασθε': 'ἄγαμαι',
#  'ἠγάασθε': 'ἄγαμαι',
#  'ἄγησθε': 'ἄγω',
#  'ἄγασαι': 'ἄγαμαι',
#  'ʼγώ': 'ἄγω',
#  'ἁγώ': 'ἄγω',
#  'ἄγω': 'ἄγω',
#  'ἁ̄γώ': 'ἄγω',
#  'ἄγα': 'ἄγαμαι',
#  'ἀγα': 'ἄγαμαι',
#  'ἀγά': 'ἄγαμαι',
#  'ἄγᾱ': 'ἄγαμαι',
#  'ἀγα-': 'ἄγαμαι',
#  'ἀντικατάγω': 'κατάγω',
#  'ἀντιμετάγω': 'μετάγω',
#  'ἀντιπροσάγω': 'προσάγω',
#  'ἀποκατάγω': 'κατάγω',
#  'ἀποσυνάγω': 'συνάγω',
#  'ᾰ̓́γω': 'ἄγω',
#  'διεξάγω': 'ἐξάγω',
#  'ἐξυπάγω': 'ὑπάγω',
#  'ἐνδιάγω': 'διάγω',
#  'ἐπιπαράγω': 'παράγω',
#  'κἀγώ': 'ἄγω',
#  'κἀ̄γώ': 'ἄγω',
#  'παρανάγω': 'ἀνάγω',
#  'παρεξάγω': 'ἐξάγω',
#  'περισυνάγω': 'συνάγω',
#  'προσαπάγω': 'ἀπάγω',
#  'προσεισάγω': 'εἰσάγω',
#  'προσεπάγω': 'ἐπάγω',
#  'προσκατάγω': 'κατάγω',
#  'προσσυνάγω': 'συνάγω',
#  'προσυνάγω': 'συνάγω',
#  'συμμετάγω': 'μετάγω',
#  'συμπαράγω': 'παράγω',
#  'συμπροσάγω': 'προσάγω',
#  'συνυπάγω': 'ὑπάγω',
#  'ὑπανάγω': 'ἀνάγω',
#  'ἄγηι': 'ἄγω',
#  'ἀγῆι': 'ἄγω',
#  'ἄγησι': 'ἄγω',
#  'ἄγῃσι': 'ἄγω',
#  'ἄγῃ': 'ἄγω',
#  'ἀγῇ': 'ἄγω',
#  'ἄγη': 'ἄγνυμι',
#  'ἀγή': 'ἄγνυμι',
#  'ἀγάσαντο': 'ἄγαμαι',
#  'ἠγάσαντο': 'ἄγαμαι',
#  'ἠγάσθησαν': 'ἄγαμαι',
#  'προσηγάσθησαν': 'ἄγαμαι',
#  'ἀγασθῶσι': 'ἄγαμαι',
#  'ἄγανται': 'ἄγαμαι',
#  'ἄγαιντο': 'ἄγαμαι',
#  'ἄγωνται': 'ἄγω',
#  'ἀγάσσατο': 'ἄγαμαι',
#  'ἐπαγάσσατο': 'ἄγαμαι',
#  'ἠγάσατο': 'ἄγαμαι',
#  'ἠγάσσατο': 'ἄγαμαι',
#  'ἠγάσθη': 'ἄγαμαι',
#  'ἀγάσαιτο': 'ἄγαμαι',
#  'ἀγασθείη': 'ἄγαμαι',
#  'ἄγαται': 'ἄγαμαι',
#  'ἄγηθʼ': 'ἄγω',
#  'ἄγηται': 'ἄγω',
#  'ἁγῆται': 'ἡγέομαι',
#  'ἀγανακτησάντων': 'ἀγανακτέω',
#  'ἀγανακτήσοντας': 'ἀγανακτέω',
#  'ἀγανακτοῦςʼ': 'ἀγανακτέω',
#  'ἀγανακτοῦσι': 'ἀγανακτέω',
#  'ἀγανακτοῦσιν': 'ἀγανακτέω',
#  'ἀγανακτούντων': 'ἀγανακτέω',
#  'ἀγανακτήσας': 'ἀγανακτέω',
#  'ἀγανακτοῦν': 'ἀγανακτέω',
#  'ἀγανακτῆσαι': 'ἀγανακτέω',
#  'ἀγανακτήσειν': 'ἀγανακτέω',
#  'ἀγανακτεῖν': 'ἀγανακτέω',
#  'ἠγανάκτησεν': 'ἀγανακτέω',
#  'ἀγανακτοῦμεν': 'ἀγανακτέω',
#  'ἠγανακτοῦμεν': 'ἀγανακτέω',
#  'κἀγανακτοῦμεν': 'ἀγανακτέω',
#  'ἠγανάκτησα': 'ἀγανακτέω',
#  'ἀγανακτήσαιμʼ': 'ἀγανακτέω',
#  'ἐξηγανάκτουν': 'ἀγανακτέω',
#  'ἠγανάκτουν': 'ἀγανακτέω',
#  'ἀγανακτέω': 'ἀγανακτέω',
#  'ἀγανακτῶ': 'ἀγανακτέω',
#  'ἀγᾰνακτ-έω': 'ἀγανακτέω',
#  'ἀγᾰνακτέω': 'ἀγανακτέω',
#  'ἀγανακτοίην': 'ἀγανακτέω',
#  'ἠγανάκτηκα': 'ἀγανακτέω',
#  'ἀγανακτητόν': 'ἀγανακτέω',
#  'ἠγανακτήσατε': 'ἀγανακτέω',
#  'ἀγανακτήσαιτʼ': 'ἀγανακτέω',
#  'ἀγανακτήσετε': 'ἀγανακτέω',
#  'ἀγανακτεῖτε': 'ἀγανακτέω',
#  'ἠγανακτεῖτʼ': 'ἀγανακτέω',
#  'ἠγανακτεῖτε': 'ἀγανακτέω',
#  'ἠγανάκτησας': 'ἀγανακτέω',
#  'ἀγανακτήσει': 'ἀγανακτέω',
#  'ἀγανακτεῖς': 'ἀγανακτέω',
#  'ἠγανάκτεις': 'ἀγανακτέω',
#  'ἀγανάκτει': 'ἀγανακτέω',
#  'ἀγανακτεῖ': 'ἀγανακτέω',
#  'ἀγανακτῇ': 'ἀγανακτέω',
#  'ἀγανάκτησιν': 'ἀγανακτέω',
#  'ἠγανάκτησαν': 'ἀγανακτέω',
#  'ἀγανακτήσειαν': 'ἀγανακτέω',
#  'ἀγανακτοῖεν': 'ἀγανακτέω',
#  'ἠγανάκτηνται': 'ἀγανακτέω',
#  'ἠγανάκτησε': 'ἀγανακτέω',
#  'ἀγανακτήσειε': 'ἀγανακτέω',
#  'ἀγανακτήσειεν': 'ἀγανακτέω',
#  'ἠγανάκτει': 'ἀγανακτέω',
#  'ἀγανακτοίη': 'ἀγανακτέω',
#  'ἁγάνα': 'γανάω',
#  'ἀγαπάζοντʼ': 'ἀγαπάζω',
#  'ἀγαπῶςʼ': 'ἀγαπάω',
#  'ἀγαπῶσι': 'ἀγαπάω',
#  'ἀγαπῶσιν': 'ἀγαπάω',
#  'ἀγαπώντων': 'ἀγαπάω',
#  'ἀγαπῶντι': 'ἀγαπάω',
#  'ἀγαπᾶν': 'ἀγαπάω',
#  'ἀγαπᾷν': 'ἀγαπάω',
#  'ἀγαπῶν': 'ἀγαπάω',
#  'ἀγαπάζοντι': 'ἀγαπάζω',
#  'ἀγάπαζον': 'ἀγαπάζω',
#  'ἀγαπάξαι': 'ἀγαπάζω',
#  'ἀγαπᾶσθαι': 'ἀγαπάω',
#  'ἀγαπάζειν': 'ἀγαπάζω',
#  'ἀγαπαζέμεν': 'ἀγαπάζω',
#  'ἀγαπῶμεν': 'ἀγαπάω',
#  'ἀγαπῷμεν': 'ἀγαπάω',
#  'ἀγάπα': 'ἀγαπάω',
#  'ἀγαπᾶ': 'ἀγαπάω',
#  'ἀγαπᾷ': 'ἀγαπάω',
#  'ἀγαπῶ': 'ἀγαπάω',
#  'ἀγαπῶμαι': 'ἀγαπάω',
#  'ἀγαπῴην': 'ἀγαπάω',
#  'ἀγαπάζω': 'ἀγαπάζω',
#  'ᾰ̓γᾰπάζω': 'ἀγαπάζω',
#  'ἀγαπητόν': 'ἀγαπάω',
#  'ἀγαπᾶθʼ': 'ἀγαπάω',
#  'ἀγαπᾶτε': 'ἀγαπάω',
#  'ἀγαπητέ': 'ἀγαπάω',
#  'ἀγάπαις': 'ἀγαπάω',
#  'ἀγάπης': 'ἀγαπάω',
#  'ἀγαπᾶς': 'ἀγαπάω',
#  'ἀγαπᾷς': 'ἀγαπάω',
#  'ἀγάπῃ': 'ἀγαπάω',
#  'ἀγαπῇ': 'ἀγαπάω',
#  'ἀγάπη': 'ἀγαπάω',
#  'ἀγαπάζεο': 'ἀγαπάζω',
#  'ἀγαπάζει': 'ἀγαπάζω',
#  'ἀγαπάζῃ': 'ἀγαπάζω',
#  'ἀγαπῶνται': 'ἀγαπάω',
#  'ἀγαπῷεν': 'ἀγαπάω',
#  'ἀ̄γαπάζοντο': 'ἀγαπάζω',
#  'ἀγαπᾶται': 'ἀγαπάω',
#  'ἀγαπῴη': 'ἀγαπάω',
#  'ἀγαπησάντων': 'ἀγαπάω',
#  'ἀγαπήσοντας': 'ἀγαπάω',
#  'ἀγαπήσουσι': 'ἀγαπάω',
#  'ἀγαπήσουσιν': 'ἀγαπάω',
#  'ἀγαπήσαις': 'ἀγαπάω',
#  'ἀγαπήσας': 'ἀγαπάω',
#  'ἀγαπήσων': 'ἀγαπάω',
#  'ἀγαπῆσαι': 'ἀγαπάω',
#  'ἀγαπηθῆναι': 'ἀγαπάω',
#  'ἀγαπήσειν': 'ἀγαπάω',
#  'ἀγάπην': 'ἀγαπάω',
#  'ἠγαπηκέναι': 'ἀγαπάω',
#  'ἠγαπῆσθαι': 'ἀγαπάω',
#  'ἠγάπησεν': 'ἀγαπάω',
#  'ἀγαπήσομεν': 'ἀγαπάω',
#  'ἠγαπῶμεν': 'ἀγαπάω',
#  'ἠγαπήκαμεν': 'ἀγαπάω',
#  'ἀγάπησα': 'ἀγαπάω',
#  'ἠγάπησα': 'ἀγαπάω',
#  'ἀγαπήσαιμʼ': 'ἀγαπάω',
#  'ἀγαπήσω': 'ἀγαπάω',
#  'ἠγάπευν': 'ἀγαπάω',
#  'ἠγάπων': 'ἀγαπάω',
#  'ἀγαπάω': 'ἀγαπάω',
#  'ἀγαπέω': 'ἀγαπάω',
#  'ᾰ̓γᾰπάω': 'ἀγαπάω',
#  'ἠγάπηκα': 'ἀγαπάω',
#  'ἀγαπήσατε': 'ἀγαπάω',
#  'ἀγαπήσητε': 'ἀγαπάω',
#  'ἠγαπᾶτε': 'ἀγαπάω',
#  'ἠγάπησας': 'ἀγαπάω',
#  'ἀγαπήσειας': 'ἀγαπάω',
#  'ἀγαπήσεις': 'ἀγαπάω',
#  'ἀγαπήσῃ': 'ἀγαπάω',
#  'ἀγαπήσει': 'ἀγαπάω',
#  'ἀγάπ-η': 'ἀγαπάω',
#  'ἀγαπῷο': 'ἀγαπάω',
#  'ἀγαπητήν': 'ἀγαπάω',
#  'κἀγαπητήν': 'ἀγαπάω',
#  'ἠγάπησαν': 'ἀγαπάω',
#  'ἠγαπήθησαν': 'ἀγαπάω',
#  'ἠγαπήκασι': 'ἀγαπάω',
#  'ἠγάπησε': 'ἀγαπάω',
#  'ἠγαπήθη': 'ἀγαπάω',
#  'ἀγαπήσειε': 'ἀγαπάω',
#  'ἀγαπήσειεν': 'ἀγαπάω',
#  'ἀγαπηθείη': 'ἀγαπάω',
#  'ἀγαπηθήσεται': 'ἀγαπάω',
#  'ἠγάπα': 'ἀγαπάω',
#  'ἠγαπᾶτο': 'ἀγαπάω',
#  'ἀγαπάτω': 'ἀγαπάω',
#  'ἀγαπῷτο': 'ἀγαπάω',
#  'ἀγγαρεύουσιν': 'ἀγγαρεύω',
#  'ἀγγαρεύειν': 'ἀγγαρεύω',
#  'ἀγγαρεύεσθαι': 'ἀγγαρεύω',
#  'ἀγγαρεύω': 'ἀγγαρεύω',
#  'ἀγγᾰρ-εύω': 'ἀγγαρεύω',
#  'ἀγγᾰρεύω': 'ἀγγαρεύω',
#  'ἀγγαρεύσει': 'ἀγγαρεύω',
#  'ἠγγάρευσαν': 'ἀγγαρεύω',
#  'παρηγγάρευσε': 'ἀγγαρεύω',
#  'ἀγγαρεύεται': 'ἀγγαρεύω',
#  'ἀγγέλλουςʼ': 'ἀγγέλλω',
#  'ἀγγέλλουσι': 'ἀγγέλλω',
#  'ἀγγέλλουσιν': 'ἀγγέλλω',
#  'ἀγγειλάντων': 'ἀγγέλλω',
#  'ἀγγελλόντων': 'ἀγγέλλω',
#  'ἀγγελέουσι': 'ἀγγέλλω',
#  'ἀγγελέουσιν': 'ἀγγέλλω',
#  'ἀγγείλας': 'ἀγγέλλω',
#  'ἀγγελθέν': 'ἀγγέλλω',
#  'ἀγγέλων': 'ἀναγελάω',
#  'ἀγγελῶν': 'ἀναγελάω',
#  'ἀγγέλλειν': 'ἀγγέλλω',
#  'ἀγγείλαι': 'ἀγγέλλω',
#  'ἀγγεῖλαι': 'ἀγγέλλω',
#  'ἀγγέλλεσθαι': 'ἀγγέλλω',
#  'ἀγγείλασθαι': 'ἀγγέλλω',
#  'ἀγγελεῖν': 'ἀγγέλλω',
#  'ἠγγέλθαι': 'ἀγγέλλω',
#  'ἀγγέλλομεν': 'ἀγγέλλω',
#  'ἀγγείλαιμεν': 'ἀγγέλλω',
#  'ἀγγελλοίμεθα': 'ἀγγέλλω',
#  'ἀγγέλλωμεν': 'ἀγγέλλω',
#  'ἀγγελοῦμεν': 'ἀγγέλλω',
#  'ἠγγέλμεθα': 'ἀγγέλλω',
#  'ἄγγειλα': 'ἀγγέλλω',
#  'ἀγγέλλεσκον': 'ἀγγέλλω',
#  'ἤγγειλʼ': 'ἀγγέλλω',
#  'ἤγγειλα': 'ἀγγέλλω',
#  'ἤγγελλον': 'ἀγγέλλω',
#  'ἤγγελσα': 'ἀγγέλλω',
#  'ἠγγέλθην': 'ἀγγέλλω',
#  'ἀγγείλαιμι': 'ἀγγέλλω',
#  'ἀγγέλλω': 'ἀγγέλλω',
#  'συναγγέλλω': 'ἀγγέλλω',
#  'ἀγγέλω': 'ἀναγελάω',
#  'ἀγγελῶ': 'ἀναγελάω',
#  'ἀγγέλῳ': 'ἀναγελάω',
#  'ἀγγελέω': 'ἀγγέλλω',
#  'ἀγγελθήσομαι': 'ἀγγέλλω',
#  'ἠγγέλμην': 'ἀγγέλλω',
#  'ἀγγέλλομαι': 'ἀγγέλλω',
#  'ἤγγελκα': 'ἀγγέλλω',
#  'ἄγγελμʼ': 'ἀγγέλλω',
#  'ἤγγελμαι': 'ἀγγέλλω',
#  'ἀγγέλλετε': 'ἀγγέλλω',
#  'ἀγγείλατʼ': 'ἀγγέλλω',
#  'ἤγγειλας': 'ἀγγέλλω',
#  'ἠγγέλθης': 'ἀγγέλλω',
#  'ἄγγειλον': 'ἀγγέλλω',
#  'ἄγγελλʼ': 'ἀγγέλλω',
#  'ἄγγελλε': 'ἀγγέλλω',
#  'ἀγγέλλοις': 'ἀγγέλλω',
#  'ἀγγείλῃς': 'ἀγγέλλω',
#  'ἀγγείλῃ': 'ἀγγέλλω',
#  'ἀγγελεῖς': 'ἀγγέλλω',
#  'ἀγγελεῖ': 'ἀγγέλλω',
#  'ἀγγέλοις': 'ἀγγέλλω',
#  'ἤγγελσο': 'ἀγγέλλω',
#  'ἀγγέλλεις': 'ἀγγέλλω',
#  'ἀγγέλλει': 'ἀγγέλλω',
#  'ἤγγελσαι': 'ἀγγέλλω',
#  'ἤγγειλαν': 'ἀγγέλλω',
#  'ἠγγέλλοντο': 'ἀγγέλλω',
#  'ἠγγέλθησαν': 'ἀγγέλλω',
#  'ἀγγείλωσι': 'ἀγγέλλω',
#  'ἀγγέλλονται': 'ἀγγέλλω',
#  'ἄγγειλε': 'ἀγγέλλω',
#  'ἤγγειλε': 'ἀγγέλλω',
#  'ἤγγειλεν': 'ἀγγέλλω',
#  'ἤγγελλε': 'ἀγγέλλω',
#  'ἤγγελλεν': 'ἀγγέλλω',
#  'ἀγγέλλετο': 'ἀγγέλλω',
#  'ἠγγέλλετο': 'ἀγγέλλω',
#  'ἠγγέλθη': 'ἀγγέλλω',
#  'ἀγγελλέτω': 'ἀγγέλλω',
#  'ἀγγέλλοι': 'ἀγγέλλω',
#  'ἀγγείλειε': 'ἀγγέλλω',
#  'ἀγγείλειεν': 'ἀγγέλλω',
#  'ἀγγέλλοιτο': 'ἀγγέλλω',
#  'ἄγγελοι': 'ἀγγέλλω',
#  'ἄγγελτο': 'ἀγγέλλω',
#  'ἤγγελτο': 'ἀγγέλλω',
#  'ἀγγέλλεται': 'ἀγγέλλω',
#  'ἤγγελται': 'ἀγγέλλω',
#  'ἀγγέλωι': 'ἀναγελάω',
#  'ἀγείρας': 'ἀγείρω',
#  'ἀγειράντων': 'ἀγείρω',
#  'ἀγείρουσι': 'ἀγείρω',
#  'ἀγειρόντων': 'ἀγείρω',
#  'ἀγείραις': 'ἀγείρω',
#  'ἄγειραν': 'ἀγείρω',
#  'ἄγερθεν': 'ἀγείρω',
#  'ἀγείροντι': 'ἀγείρω',
#  'ἄγειρον': 'ἀγείρω',
#  'ἀγεῖραι': 'ἀγείρω',
#  'ἀγερέσθαι': 'ἀγείρω',
#  'ἀγερθῆναι': 'ἀγείρω',
#  'ἄγειρεν': 'ἀγείρω',
#  'ἀγείρειν': 'ἀγείρω',
#  'ἠγείραμεν': 'ἐγείρω',
#  'ἀγείρομεν': 'ἀγείρω',
#  'ἄγειρα': 'ἀγείρω',
#  'ἤγειρα': 'ἀγείρω',
#  'ἠγειράμην': 'ἐγείρω',
#  'ἠγέρθην': 'ἐγείρω',
#  'ἀγείρω': 'ἀγείρω',
#  'ἀναγείρω': 'ἀγείρω',
#  'ἀνταγείρω': 'ἀγείρω',
#  'ἀντᾰγείρω': 'ἀγείρω',
#  'ἀπαγείρω': 'ἀγείρω',
#  'ἐναγείρω': 'ἀγείρω',
#  'ἐνᾰγείρω': 'ἀγείρω',
#  'καταγείρω': 'ἀγείρω',
#  'ἀγείρομαι': 'ἀγείρω',
#  'διήγειρον': 'ἐγείρω',
#  'ἤγειρον': 'ἀγείρω',
#  'ἀγήγερμαι': 'ἀγείρω',
#  'ἠγείρατε': 'ἐγείρω',
#  'ἤγειρας': 'ἐγείρω',
#  'ἀγείρει': 'ἀγείρω',
#  'ἀντήγειραν': 'ἐγείρω',
#  'διήγειραν': 'διεγείρω',
#  'ἤγειραν': 'ἐγείρω',
#  'ἀγέροντʼ': 'ἀγείρω',
#  'ἀγέροντο': 'ἀγείρω',
#  'ἤγερθεν': 'ἀγείρω',
#  'ἠγέρθησαν': 'ἐγείρω',
#  'ἀγείρειαν': 'ἀγείρω',
#  'ἀγείρωσιν': 'ἀγείρω',
#  'ἀγείροντο': 'ἀγείρω',
#  'διηγείροντο': 'ἐγείρω',
#  'ἠγείροντο': 'ἀγείρω',
#  'ἀγηγέραθʼ': 'ἀγείρω',
#  'ἀγηγέρατʼ': 'ἀγείρω',
#  'ἀγηγέρατο': 'ἀγείρω',
#  'ἀγείρονται': 'ἀγείρω',
#  'ἀγείροιεν': 'ἀγείρω',
#  'διήγειρε': 'ἐγείρω',
#  'διήγειρεν': 'ἐγείρω',
#  'ἤγειρε': 'ἀγείρω',
#  'ἤγειρεν': 'ἐγείρω',
#  'ἀγέρθη': 'ἀγείρω',
#  'ἠγέρθη': 'ἐγείρω',
#  'ἀγείρετο': 'ἀγείρω',
#  'ἠγείρετο': 'ἀγείρω',
#  'ἀγήγερτο': 'ἀγείρω',
#  'ἀγειρέσθω': 'ἀγείρω',
#  'ἀγείροι': 'ἀγείρω',
#  'ἀγελ-αρχέω': 'ἀγελαρχέω',
#  'ἀγελαρχέω': 'ἀγελαρχέω',
#  'ἀγελ-άρχης': 'ἀγελαρχέω',
#  'ἀγελάρχης': 'ἀγελαρχέω',
#  'ἅγε': 'ἄγω',
#  'ἄγε': 'ἄγω',
#  'ἄγε͂': 'ἄγω',
#  'ἆγε': 'ἄγω',
#  'ἀγέ': 'ἄγω',
#  'ἄγʼ': 'ἄγω',
#  'ἄγεθʼ': 'ἄγω',
#  'ἄγετʼ': 'ἄγω',
#  'ἄγετε': 'ἄγω',
#  'ᾰ̓́γε': 'ἄγω',
#  'ἁγηλατήσειν': 'ἁγηλατέω',
#  'ἀγηλατήσειν': 'ἁγηλατέω',
#  'ἀγηλατεῖν': 'ἁγηλατέω',
#  'ἁγηλατέω': 'ἁγηλατέω',
#  'ἀγηλατέω': 'ἁγηλατέω',
#  'ἀγηλᾰτ-έω': 'ἁγηλατέω',
#  'ἀγηλᾰτέω': 'ἁγηλατέω',
#  'ἀγηλατέει': 'ἁγηλατέω',
#  'ἡγηλάτει': 'ἁγηλατέω',
#  'ἄγῃς': 'ἄγω',
#  'ἀγῆς': 'ἄγνυμι',
#  'ἀγῇσιν': 'ἄγω',
#  'ἄγην': 'ἄγω',
#  'ἀγήν': 'ἄγω',
#  'ᾰ̓́γην': 'ἄγω',
#  'ἄγητον': 'ἄγω',
#  'ἀγητόν': 'ἄγω',
#  'ἁγίζω': 'ἁγίζω',
#  'ᾰ̔γίζω': 'ἁγίζω',
#  'ἁγίοις': 'ἁγίζω',
#  'ἅγιοι': 'ἁγίζω',
#  'ἥγιζεν': 'ἁγίζω',
#  'ἀγινήσουςʼ': 'ἀγινέω',
#  'ἀγινήσουσι': 'ἀγινέω',
#  'ἀγινέουσι': 'ἀγινέω',
#  'ἀγινεῦσι': 'ἀγινέω',
#  'ἀγίνεον': 'ἀγινέω',
#  'ἀγινέμεναι': 'ἀγινέω',
#  'ἀγινεῖν': 'ἀγινέω',
#  'ἀγῑνέμεναι': 'ἀγινέω',
#  'ἀγινήσω': 'ἀγινέω',
#  'ἀγίνεσκον': 'ἀγινέω',
#  'ἠγίνεον': 'ἀγινέω',
#  'ἀγινέω': 'ἀγινέω',
#  'ἀγινῶ': 'ἀγινέω',
#  'ἀγῑνέω': 'ἀγινέω',
#  'ἀγινεῖς': 'ἀγινέω',
#  'ἀγινεῖ': 'ἀγινέω',
#  'ἀγινῆται': 'ἀγινέω',
#  'ἁγιστεύσουσι': 'ἁγιστεύω',
#  'ἀφαγιστεύσας': 'ἁγιστεύω',
#  'ἁγιστεύσειν': 'ἁγιστεύω',
#  'ἁγιστεύειν': 'ἁγιστεύω',
#  'ἁγ-ιστεύω': 'ἁγιστεύω',
#  'ἁγιστεύω': 'ἁγιστεύω',
#  'ἁγιστεύει': 'ἁγιστεύω',
#  'ἀγκάσσασθαι': 'ἀγκάζομαι',
#  'ἀγκάζομαι': 'ἀγκάζομαι',
#  'ἄγχʼ': 'ἄγχω',
#  'ἀγκάζοντο': 'ἀγκάζομαι',
#  'ἀπηναγκάσθη': 'ἀναγκάζω',
#  'ἀγκάλῃς': 'ἀνακαλέω',
#  'ἀγκάλης': 'ἀνακαλέω',
#  'ἀγκάλην': 'ἀνακαλέω',
#  'ʼγκαλῇ': 'ἐγκαλέω',
#  'ἀγκάλῃ': 'ἀνακαλέω',
#  'ἀγκάλη': 'ἀνακαλέω',
#  'ἀγκαλίζω': 'ἀγκαλίζομαι',
#  'ἀγκαλίζομαι': 'ἀγκαλίζομαι',
#  'ἀγκᾰλ-ίζομαι': 'ἀγκαλίζομαι',
#  'ἀγκᾰλίζομαι': 'ἀγκαλίζομαι',
#  'ἠγκαλίσασθε': 'ἀγκαλίζομαι',
#  'προσηγκαλίζοντο': 'ἀγκαλίζομαι',
#  'ἀγκαλίζεται': 'ἀγκαλίζομαι',
#  'ἀγκίστρου': 'ἀγκιστρόομαι',
#  'ἀγκιστρόομαι': 'ἀγκιστρόομαι',
#  'ἄγκοινα': 'ἀνακοινόω',
#  'ἀγκοίνα': 'ἀνακοινόω',
#  'ἀγκοίναις': 'ἀνακοινόω',
#  'ἀγκοίναισιν': 'ἀνακοινόω',
#  'ἀγκοίνησιν': 'ἀνακοινόω',
#  'ἀγκοίνη': 'ἀνακοινόω',
#  'ἀγκύλων': 'ἀγκυλόω',
#  'ἀγκυλῶν': 'ἀγκυλόω',
#  'ἀγκύλοι': 'ἀγκυλόω',
#  'ἀγκυλ-όω': 'ἀγκυλόω',
#  'ἀγκυλόω': 'ἀγκυλόω',
#  'ἀγκυρίσας': 'ἀγκυρίζω',
#  'ἀγκυρίζω': 'ἀγκυρίζω',
#  'ἀγκῡρίζω': 'ἀγκυρίζω',
#  'ἀγλαΐης': 'ἀγλαίζω',
#  'ἀγλαί̈ης': 'ἀγλαίζω',
#  'ἀγλαΐην': 'ἀγλαίζω',
#  'ἀγλαί̈ην': 'ἀγλαίζω',
#  'ἀγλαΐῃ': 'ἀγλαίζω',
#  'ἀγλαί̈ῃ': 'ἀγλαίζω',
#  'ἀγλαίσας': 'ἀγλαίζω',
#  'ἀγλαϊεῖσθαι': 'ἀγλαίζω',
#  'ἀγλαΐζεσθαι': 'ἀγλαίζω',
#  'ἀγλαί̈ζομεν': 'ἀγλαίζω',
#  'ἠγλάϊσα': 'ἀγλαίζω',
#  'ἀγλαϊῶ': 'ἀγλαίζω',
#  'ἀγλα-ί̈ζω': 'ἀγλαίζω',
#  'ἀγλαί̈ζω': 'ἀγλαίζω',
#  'ἀγλαίζω': 'ἀγλαίζω',
#  'ἀγλαΐζομαι': 'ἀγλαίζω',
#  'ἀγλάισμʼ': 'ἀγλαίζω',
#  'ἀγλαί̈ζει': 'ἀγλαίζω',
#  'ἀγλάισε': 'ἀγλαίζω',
#  'ἠγλάϊσεν': 'ἀγλαίζω',
#  'ἀγλαί̈ζεται': 'ἀγλαίζω',
#  'ἀγλαίζεται': 'ἀγλαίζω',
#  'ἀγλαϊζέτω': 'ἀγλαίζω',
#  'ἅγνευμʼ': 'ἁγνεύω',
#  'ἁγνεύουσι': 'ἁγνεύω',
#  'ἁγνεύσας': 'ἁγνεύω',
#  'ἁγνεύειν': 'ἁγνεύω',
#  'ἡγνευκέναι': 'ἁγνεύω',
#  'ἁγν-εύω': 'ἁγνεύω',
#  'ἁγνεύω': 'ἁγνεύω',
#  'ἥγνευκα': 'ἁγνεύω',
#  'ἁγνεύσετε': 'ἁγνεύω',
#  'ἁγνεύετε': 'ἁγνεύω',
#  'ἁγνεύει': 'ἁγνεύω',
#  'ἁγνεύοι': 'ἁγνεύω',
#  'ἁγνίσας': 'ἁγνίζω',
#  'ἅγνισον': 'ἁγνίζω',
#  'ἁγνίσαι': 'ἁγνίζω',
#  'ἁγνίζειν': 'ἁγνίζω',
#  'ἡγνίσμεθα': 'ἁγνίζω',
#  'ἥγνισα': 'ἁγνίζω',
#  'ἁγνιῶ': 'ἁγνίζω',
#  'ἥγνιζον': 'ἁγνίζω',
#  'ἁγνίζω': 'ἁγνίζω',
#  'ἥγνικα': 'ἁγνίζω',
#  'ἁγνίσατε': 'ἁγνίζω',
#  'ἁγνίσθητι': 'ἁγνίζω',
#  'ἁγνίσῃ': 'ἁγνίζω',
#  'ἡγνίζου': 'ἁγνίζω',
#  'ἁγνίζει': 'ἁγνίζω',
#  'ἥγνισαι': 'ἁγνίζω',
#  'ἥγνισαν': 'ἁγνίζω',
#  'ἁγνίσωσιν': 'ἁγνίζω',
#  'ἥγνισε': 'ἁγνίζω',
#  'ἡγνίσθη': 'ἁγνίζω',
#  'ἁγνίσειεν': 'ἁγνίζω',
#  'ἥγνιζε': 'ἁγνίζω',
#  'ἀγνοησάντων': 'ἀγνοέω',
#  'ἀγνοήσοντας': 'ἀγνοέω',
#  'ἀγνοοῦσι': 'ἀγνοέω',
#  'ἀγνοοῦσιν': 'ἀγνοέω',
#  'ἀγνοούντων': 'ἀγνοέω',
#  'ἀγνοήσαις': 'ἀγνοέω',
#  'ἀγνοήσας': 'ἀγνοέω',
#  'ἀγνοοῦντι': 'ἀγνοέω',
#  'ἀγνοοῦν': 'ἀγνοέω',
#  'ἀγνοῆσαι': 'ἀγνοέω',
#  'ἀγνοήσειν': 'ἀγνοέω',
#  'ἀγνοήσεσθαι': 'ἀγνοέω',
#  'ἀγνοέειν': 'ἀγνοέω',
#  'ἀγνοεῖν': 'ἀγνοέω',
#  'ἀγνοεῖσθαι': 'ἀγνοέω',
#  'ἠγνόηκεν': 'ἀγνοέω',
#  'ἠγνοηκέναι': 'ἀγνοέω',
#  'ἠγνοῆσθαι': 'ἀγνοέω',
#  'ἠγνόησεν': 'ἀγνοέω',
#  'ἠγνοίησεν': 'ἀγνοέω',
#  'ἀγνοοῦμεν': 'ἀγνοέω',
#  'ἠγνοοῦμεν': 'ἀγνοέω',
#  'ἀγνοοῖμεν': 'ἀγνοέω',
#  'ἠγνοήκαμεν': 'ἀγνοέω',
#  'ἠγνόησα': 'ἀγνοέω',
#  'ἠγνοίησα': 'ἀγνοέω',
#  'ἠγνοήθην': 'ἀγνοέω',
#  'ἀγνοήσω': 'ἀγνοέω',
#  'ἀγνοήσομαι': 'ἀγνοέω',
#  'ἀγνοηθήσομαι': 'ἀγνοέω',
#  'ἠγνόουν': 'ἀγνοέω',
#  'ἠμφηγνόουν': 'ἀγνοέω',
#  'ἀγνο-έω': 'ἀγνοέω',
#  'ἀγνοέω': 'ἀγνοέω',
#  'ἀγνοιέω': 'ἀγνοέω',
#  'ἀγνοῶ': 'ἀγνοέω',
#  'ἀμφαγνοέω': 'ἀγνοέω',
#  'ἠγνόηκα': 'ἀγνοέω',
#  'ἠγνόημαι': 'ἀγνοέω',
#  'ἀγνοήσαιτε': 'ἀγνοέω',
#  'ἀγνοήσετʼ': 'ἀγνοέω',
#  'ἀγνοεῖθʼ': 'ἀγνοέω',
#  'ἀγνοεῖτʼ': 'ἀγνοέω',
#  'ἀγνοεῖτε': 'ἀγνοέω',
#  'ἀγνοῆτʼ': 'ἀγνοέω',
#  'ἀγνοῆτε': 'ἀγνοέω',
#  'ἠγνοήκατε': 'ἀγνοέω',
#  'ἀγνοήσειας': 'ἀγνοέω',
#  'ἀγνοήσῃς': 'ἀγνοέω',
#  'ἀγνοήσῃ': 'ἀγνοέω',
#  'ἀγνοήσει': 'ἀγνοέω',
#  'ἀγνοεῖς': 'ἀγνοέω',
#  'ἠγνόεις': 'ἀγνοέω',
#  'ἀγνόει': 'ἀγνοέω',
#  'ἀγνοεῖ': 'ἀγνοέω',
#  'ἀγνοῇ': 'ἀγνοέω',
#  'ἀγνοίη': 'ἀγνοέω',
#  'ἀγνοοῖς': 'ἀγνοέω',
#  'ἀγνοιῆσι': 'ἀγνοέω',
#  'ἀγνοιῇσι': 'ἀγνοέω',
#  'ἠγνόησαν': 'ἀγνοέω',
#  'ἠγνοίησαν': 'ἀγνοέω',
#  'ἠγνοήθησαν': 'ἀγνοέω',
#  'ἀγνοήσωσι': 'ἀγνοέω',
#  'ἠγνοήκεσαν': 'ἀγνοέω',
#  'ἀγνοοῖεν': 'ἀγνοέω',
#  'ἠγνοήκασιν': 'ἀγνοέω',
#  'ἀγνοήσασκε': 'ἀγνοέω',
#  'ἀγνώσασκε': 'ἀγνοέω',
#  'ἠγνόησε': 'ἀγνοέω',
#  'ἠγνοίησε': 'ἀγνοέω',
#  'ἀγνοήσειε': 'ἀγνοέω',
#  'ἀγνοήσειεν': 'ἀγνοέω',
#  'ἀγνοηθῇ': 'ἀγνοέω',
#  'ἠγνόει': 'ἀγνοέω',
#  'ἠγνοεῖτο': 'ἀγνοέω',
#  'ἀγνοεῖται': 'ἀγνοέω',
#  'ἀγνοείτω': 'ἀγνοέω',
#  'ἀγνοοίη': 'ἀγνοέω',
#  'ἀγνοοῖ': 'ἀγνοέω',
#  'ἀγνοοῖτο': 'ἀγνοέω',
#  'ἠγνόηται': 'ἀγνοέω',
#  'κἄγνων': 'γιγνώσκω',
#  'ἄξαντʼ': 'ἄγω',
#  'ἄξονθʼ': 'ἄγω',
#  'ἄξοντʼ': 'ἄγω',
#  'ἄξοισι': 'ἄγω',
#  'ἄξουσι': 'ἄγω',
#  'ἄξουσιν': 'ἄγω',
#  'ἀξίοισι': 'ἀξιόω',
#  'ἄγνυσι': 'ἄγνυμι',
#  'ἀγνύμεναι': 'ἄγνυμι',
#  'ἄξαις': 'ἄγνυμι',
#  'ἄξας': 'ἄγω',
#  'ᾄξας': 'ἀίσσω',
#  'ἄγεις': 'ἄγω',
#  'ἄγεν': 'ἄγω',
#  'ἆγεν': 'ἄγω',
#  'ᾰ̓́γεν': 'ἄγω',
#  'ἀξίων': 'ἀξιόω',
#  'ἀξιῶν': 'ἀξιόω',
#  'ἆξον': 'ἄγω',
#  'κἀξόν': 'ἄγω',
#  'ἀγνύς': 'ἄγνυμι',
#  'ἄξαι': 'ἄγω',
#  'ἆξαι': 'ἄγνυμι',
#  'ἀγέμεν': 'ἄγω',
#  'ἀγῆναι': 'ἄγνυμι',
#  'ἄξειν': 'ἄγω',
#  'ἆξεν': 'ἄγω',
#  'ἀξ-έμεν': 'ἄγω',
#  'ἀξέμεν': 'ἄγω',
#  'ἀξέμεναι': 'ἄγω',
#  'ἄξεσθαι': 'ἄγω',
#  'ἀγνύναι': 'ἄγνυμι',
#  'ἄξομεν': 'ἄγω',
#  'ἄγωμεν': 'ἄγω',
#  'ἀξιοῖμεν': 'ἀξιόω',
#  'ἔαξα': 'ἄγνυμι',
#  'ἔᾱξα': 'ἄγνυμι',
#  'ἦξα': 'ἄγω',
#  'ᾖξα': 'ἀίσσω',
#  'ἀξάμην': 'ἄγω',
#  'ἠξάμην': 'ἐξαμάω',
#  'ἐάγην': 'ἄγνυμι',
#  'ἐά̄γην': 'ἄγνυμι',
#  'ἐᾰ́γην': 'ἄγνυμι',
#  'ʼξω': 'ἐξίημι',
#  'ξῶ': 'ξέω',
#  'ἄξω': 'ἄγω',
#  'ἀξῶ': 'ἄγω',
#  'ᾄξω': 'ἀίσσω',
#  'κἄξω': 'ἐξίημι',
#  'τἄξω': 'ἐξίημι',
#  'τάξω': 'τάσσω',
#  'ἅξομαι': 'ἄγω',
#  'ἄξομαι': 'ἄγω',
#  'ἀξίω': 'ἀξιόω',
#  'ἀξιῶ': 'ἀξιόω',
#  'ἄγνυον': 'ἄγνυμι',
#  'ἄγνῦμι': 'ἄγνυμι',
#  'ἄγνυμι': 'ἄγνυμι',
#  'ἄγνῡμι': 'ἄγνυμι',
#  'παρ-άγνυμι': 'ἄγνυμι',
#  'παράγνυμι': 'ἄγνυμι',
#  'ὑπάγνυμι': 'ἄγνυμι',
#  'ὑπάγνῡμι': 'ἄγνυμι',
#  'ἀμφάγνυμαι': 'ἄγνυμι',
#  'ἀπάγνυμαι': 'ἄγνυμι',
#  'ἀπάγνῠμαι': 'ἄγνυμι',
#  'προσάγνυμαι': 'ἄγνυμι',
#  'ἔᾶγα': 'ἄγνυμι',
#  'ἔαγα': 'ἄγνυμι',
#  'ἔᾱγα': 'ἄγνυμι',
#  'ἔηγα': 'ἄγνυμι',
#  'παρέᾱγα': 'ἄγνυμι',
#  'ἄγνυτον': 'ἄγνυμι',
#  'ἄγνῠτον': 'ἄγνυμι',
#  'ἄξεθʼ': 'ἄγω',
#  'ἄξετʼ': 'ἄγω',
#  'ἄξετε': 'ἄγω',
#  'ἄξεσθε': 'ἄγω',
#  'ἄξεις': 'ἄγω',
#  'ᾄξεις': 'ἀίσσω',
#  'ἄξῃς': 'ἄγνυμι',
#  'ἄξῃ': 'ἄγνυμι',
#  'ἀξῇ': 'ἄγω',
#  'ἄξει': 'ἄγω',
#  'ἀξεῖ': 'ἄγνυμι',
#  'ἀξίοις': 'ἀξιόω',
#  'ἀξιοῖς': 'ἀξιόω',
#  'ἔαγε': 'ἄγνυμι',
#  'ἔᾱγε': 'ἄγνυμι',
#  'ἔαξαν': 'ἄγνυμι',
#  'ἦξαν': 'ἄγω',
#  'ᾖξαν': 'ἀίσσω',
#  'ἄξαντο': 'ἄγω',
#  'ἐάγησαν': 'ἄγνυμι',
#  'ἄξειαν': 'ἄγνυμι',
#  'ἄγουςʼ': 'ἄγω',
#  'ἄγουσι': 'ἄγω',
#  'ἄγουσιν': 'ἄγω',
#  'ἄγωσι': 'ἄγω',
#  'ἀγῶσι': 'ἄγω',
#  'ἄγωσιν': 'ἄγω',
#  'ἀγῶσιν': 'ἄγω',
#  'ἄξονται': 'ἄγω',
#  'ἀξιοῖεν': 'ἀξιόω',
#  'ἄξοιντο': 'ἄγω',
#  'ἀξιοῖντο': 'ἀξιόω',
#  'ἔαξε': 'ἄγνυμι',
#  'ἔαξεν': 'ἄγνυμι',
#  'ἦξε': 'ἄγνυμι',
#  'ᾖξε': 'ἀίσσω',
#  'ἐάγη': 'ἄγνυμι',
#  'ἐάγῃ': 'ἄγνυμι',
#  'ἐά̄γη': 'ἄγνυμι',
#  'ἄξεται': 'ἄγω',
#  'ἄγει': 'ἄγω',
#  'ἄγεϊ': 'ἄγω',
#  'ἅγει': 'ἡγέομαι',
#  'ἁγεῖ': 'ἡγέομαι',
#  'ὑπεράγει': 'ἄγω',
#  'ἁξιοῖ': 'ἀξιόω',
#  'ἄξιοι': 'ἀξιόω',
#  'ἀξιοῖ': 'ἀξιόω',
#  'ἄξοι': 'ἄγω',
#  'ἄγνυτο': 'ἄγνυμι',
#  'ἄγνυται': 'ἄγνυμι',
#  'ἀγνωμονοῦσιν': 'ἀγνωμονέω',
#  'ἀγνωμονῆσαι': 'ἀγνωμονέω',
#  'ἀγνωμονεῖν': 'ἀγνωμονέω',
#  'ἀγνωμ-ονέω': 'ἀγνωμονέω',
#  'ἀγνωμονέω': 'ἀγνωμονέω',
#  'ἀγνωμονήσει': 'ἀγνωμονέω',
#  'ἀγνωμόνει': 'ἀγνωμονέω',
#  'ἀγνωμονῇ': 'ἀγνωμονέω',
#  'ἠγνωμόνησαν': 'ἀγνωμονέω',
#  'ἠγνωμονήκεσαν': 'ἀγνωμονέω',
#  'ἀγνωμονοῖτο': 'ἀγνωμονέω',
#  'ἀγοράσας': 'ἀγοράζω',
#  'ἀγοράσαι': 'ἀγοράζω',
#  'ἀγοράζουσι': 'ἀγοράζω',
#  ...}

# %%
len(set(ag_lemma_lookup["VERB"].values()))
# Out:
# 11099

# %%
print(list(ag_lemma_lookup.keys()))
# Out:
# ['ADJ', 'PRON', 'ADP', 'PUNCT', 'DET', 'CCONJ', 'INTJ', 'PART', 'PROPN', 'AUX', 'SCONJ', 'ADV', 'NOUN', 'X', 'NUM', 'VERB']

# %%
ag_lemma_lookup["NOUN"]["ἐνεργειῶν"]
# Out:
# 'ἐνέργεια'

# %% [markdown]
# ok, this works but there is a substantial number of cases in which there is a wrong tag, e.g. "VERB" - in this case the lemmatization is unsuccessful

# %%
ag_lemma_lookup_merged["ἐνεργειῶν"]
# Out:
# 'ἐνέργεια'

# %%
try:
    nlp.vocab.lookups.remove_table("lemma_lookup")
    nlp.vocab.lookups.remove_table("lemma_lookup_merged")
except:
    pass

# %%
# let add our table to our model
table = nlp.vocab.lookups.add_table("lemma_lookup", ag_lemma_lookup)
table = nlp.vocab.lookups.add_table("lemma_lookup_merged", ag_lemma_lookup_merged)
# nlp.vocab.lookups.remove_table("lemma_exc")

# %%
# load it back from the model (to check functionality for future usage)
ag_lemma_lookup = nlp.vocab.lookups.get_table("lemma_lookup")
ag_lemma_lookup_merged = nlp.vocab.lookups.get_table("lemma_lookup_merged")


ag_lemma_lookup["VERB"]["μνήσομαι"]
# Out:
# 'μιμνήσκω'

# %% [markdown]
# # Lemmatization functions

# %%
# !pip install greek-accentuation
from greek_accentuation.characters import strip_accents
from greek_accentuation.syllabify import *
from greek_accentuation.accentuation import *



def grave_to_acute(string):
    GRAVE = "\u0300"
    ACUTE = "\u0301"
    return unicodedata.normalize("NFC", "".join(unicodedata.normalize("NFD", string).replace(GRAVE, ACUTE)))


def list_of_possible_accentuations(morph):
    try:
        if isinstance(morph, str):
            morph = strip_accents(morph)
            morph = rebreath(morph.lower())
            s = syllabify(morph)
            morph_vars = []
            for accentuation in possible_accentuations(s, default_short=True):
                pos, accent = accentuation #add_accentuation(s, accentuation))
                final = s[1 - pos:] if pos > 1 else [""]
                morph_acc_var = "".join(s[:-pos] + [syllable_add_accent(s[-pos], accent)] + final)
                morph_vars.append(morph_acc_var)
                morph_vars.append(morph_acc_var.capitalize())
            return morph_vars
        else:
            return []
    except:
        return []


def grc_doc_lemmatizer(doc):
    for token in doc:
        token.lemma_, token.pos_ = lemmatizer(token.text, token.pos_, token.lemma_)
    return doc   

def apply_nlp(sentences_list):
    spacy_docs = []
    for sentence in sentences_list:
        doc = nlp(sentence)
        spacy_docs.append(doc)
    return spacy_docs

def check_char_validity(token_text, tag):
    if re.search("\W", token_text):
        if re.match("\W+$", token_text):
            tag = "PUNCT"
        else:
            if "’" not in token_text:
                token_text = re.sub("\W", "", token_text)
    return token_text, tag

# for new tags in specific order...

keys = ['PRON', 'ADP', 'PUNCT', 'DET', 'CCONJ', 'INTJ', 'PART', 'ADJ', 'AUX', 'SCONJ', 'ADV', 'NOUN','PROPN', 'VERB','X', 'NUM']
 
def check_other_tags(token_text, tag):
    lemma = token_text
    match = False
    # for new tags in specific order...
    for new_tag in keys:
        try:
            lemma = ag_lemma_lookup[new_tag][token_text]
            tag = new_tag
            match = True
            break
        except:
            pass
    return lemma, tag, match
    
def lemmatizer(token_text, tag, old_lemma=None):
    if (old_lemma==None) or (token_text == old_lemma):
        token_text, tag = check_char_validity(token_text, tag)
        lemma = token_text.lower() # start with assigning the word as it stands
        try:
            lemma = ag_lemma_lookup[tag][token_text]
        except:
            try:
                lemma = ag_lemma_lookup[tag][grave_to_acute(token_text)]
            except:
                if check_other_tags(token_text, tag)[2] == True:
                    lemma, tag, match = check_other_tags(token_text, tag)
                else:
                        morph_vars = list_of_possible_accentuations(token_text)
                        for var in morph_vars:
                            try:
                                try:
                                    lemma = ag_lemma_lookup[tag][var] 
                                    break
                                except:
                                    a, b, match = check_other_tags(var, tag)
                                    if match ==True:
                                        lemma, tag, match = check_other_tags(var, tag)
                                        break
                            except:
                                pass

        return lemma, tag
    else:
        return old_lemma, tag

# %%
lemmatizer('ἀπʼ', 'PUNCT')
# Out:
# ('ἀπό', 'ADP')

# %%
lemmatizer("δι’", "ADP")
# Out:
# ('δι’', 'ADP')

# %%
lemmatizer("ΠΑΥΛΟΣ", "VERB")
# Out:
# ('Παῦλος', 'NOUN')

# %%
lemmatizer("ΒΙΒΛΟΣ", "ADJ")
# Out:
# ('βίβλος', 'NOUN')

# %%
lemmatizer("Ἰησοῦ", "NOUN")
# Out:
# ('Ἰησοῦς', 'NOUN')

# %%
# nonexistent word
lemmatizer("ΒΙΒΒΙΒΛΟΣ", "NOUN")
# Out:
# ('βιββιβλος', 'NOUN')

# %%
# it works even with wrong POS-tag
lemmatizer("ἐνεργειῶν", "VERB")
# Out:
# ('ἐνέργεια', 'NOUN')

# %%
lemmatizer("θεοῦ.", "PUNCT")
# Out:
# ('θεός', 'NOUN')

# %%
# Out:
# True

# %% [markdown]
# # Training our own model with gold-parse

# %%
urls = [
    "https://raw.githubusercontent.com/UniversalDependencies/UD_Ancient_Greek-Perseus/master/grc_perseus-ud-train.conllu",
    "https://raw.githubusercontent.com/UniversalDependencies/UD_Ancient_Greek-Perseus/master/grc_perseus-ud-dev.conllu",
    "https://raw.githubusercontent.com/UniversalDependencies/UD_Ancient_Greek-PROIEL/master/grc_proiel-ud-train.conllu",
    "https://raw.githubusercontent.com/UniversalDependencies/UD_Ancient_Greek-PROIEL/master/grc_proiel-ud-dev.conllu"]

# %%
v_ud = "’"
v_agt = "ʼ"

print(v_ud == v_agt)# because of that, we will everywhere use the agt version, since it does not confuse the word tokenizer
# Out:
# False

# %%
def normalize_encoding(string):
    return unicodedata.normalize("NFC", string)

def tagged_data_from_url(url):
    corpus = pyconll.load.iter_from_url(url)
    tagged_data = []
    for sentence in corpus:
        words, tags, lemmata = [], [], []
        for token in sentence:
            words.append(normalize_encoding(re.sub(v_ud, v_agt, token.form)))
            tags.append(token.upos)
            lemmata.append(normalize_encoding(token.lemma))
        if "-dev." in url:
            tagged_data.append((normalize_encoding(re.sub(v_ud, v_agt, sentence.text)), {"words" : words, "tags" : tags, "lemmata" : lemmata}))
        else:
            tagged_data.append((normalize_encoding(re.sub(v_ud, v_agt, sentence.text)), {"words" : words, "tags" : tags}))
    print("File name: {0}; number of sentences: {1}".format(url.rpartition("/")[2], len(tagged_data)))
    return tagged_data

# %%
perseus_train = tagged_data_from_url(urls[0])
perseus_dev = tagged_data_from_url(urls[1])
proiel_train = tagged_data_from_url(urls[2])
proiel_dev = tagged_data_from_url(urls[3])
# Out:
# File name: grc_perseus-ud-train.conllu; number of sentences: 11476
# File name: grc_perseus-ud-dev.conllu; number of sentences: 1137
# File name: grc_proiel-ud-train.conllu; number of sentences: 15014
# File name: grc_proiel-ud-dev.conllu; number of sentences: 1019

# %%
print(perseus_train[0])
# Out:
# ('ἐρᾷ μὲν ἁγνὸς οὐρανὸς τρῶσαι χθόνα, ἔρως δὲ γαῖαν λαμβάνει γάμου τυχεῖν·', {'words': ['ἐρᾷ', 'μὲν', 'ἁγνὸς', 'οὐρανὸς', 'τρῶσαι', 'χθόνα', ',', 'ἔρως', 'δὲ', 'γαῖαν', 'λαμβάνει', 'γάμου', 'τυχεῖν', '·'], 'tags': ['VERB', 'ADV', 'ADJ', 'NOUN', 'VERB', 'NOUN', 'PUNCT', 'NOUN', 'CCONJ', 'NOUN', 'VERB', 'NOUN', 'VERB', 'PUNCT']})

# %%
train_data = perseus_train + proiel_train

# %%
len(train_data)
# Out:
# 26490

# %%
proiel_dev_len = sum([len(sent[1]["tags"]) for sent in proiel_dev])
print("tokens in proiel_dev: " + str(proiel_dev_len))

perseus_dev_len = sum([len(sent[1]["tags"]) for sent in perseus_dev])
print("tokens in perseus_dev: " + str(perseus_dev_len))
total_len = proiel_dev_len + perseus_dev_len
# Out:
# tokens in proiel_dev: 13652
# tokens in perseus_dev: 22135

# %%
model_tests = []

# %%
# add lemmatizer to the pipeline
#nlp.remove_pipe("grc_doc_lemmatizer")
nlp.add_pipe(grc_doc_lemmatizer, "grc_doc_lemmatizer", after="tagger") # grc_doc_lemmatizer

# %%
n_iter = 25

model_tests = []
for i in range(n_iter):
    
    ### TRAIN THE MODEL
    random.shuffle(train_data)
    losses = {}
        # batch up the examples using spaCy's minibatch
    batches = minibatch(train_data, size=compounding(4.0, 32.0, 1.001))
    for batch in batches:
        texts, annotations = zip(*batch)
        nlp.update(texts, annotations, drop=0.3, sgd=optimizer, losses=losses)
    
    ### TEST THE MODEL
    
    model_test = {}
    model_test["Losses"] = losses
    
    proiel_tags_correct = 0
    proiel_lemmata_correct = 0
    for sent in proiel_dev:
        doc = nlp(sent[0])
        predicted_tags = [token.pos_ for token in doc]
        predicted_lemmata = [token.lemma_ for token in doc]
        #predicted_lemmata = [lemmatizer(token.text, token.pos_) for token in doc]
        given_tags = sent[1]["tags"]
        given_lemmata = sent[1]["lemmata"]
        proiel_tags_correct += len([p for p, g in zip(predicted_tags, given_tags) if p ==g])
        proiel_lemmata_correct += len([p for p, g in zip(predicted_lemmata, given_lemmata) if p ==g])
    model_test["proiel_tags_correct%"] = (proiel_tags_correct / proiel_dev_len) * 100
    model_test["proiel_lemmata_correct%"] = (proiel_lemmata_correct / proiel_dev_len) * 100

    perseus_tags_correct = 0
    perseus_lemmata_correct = 0
    for sent in perseus_dev:
        doc = nlp(sent[0])
        predicted_tags = [token.pos_ for token in doc]
        predicted_lemmata = [token.lemma_ for token in doc]
        #predicted_lemmata = [lemmatizer(token.text, token.pos_) for token in doc]
        given_tags = sent[1]["tags"]
        given_lemmata = sent[1]["lemmata"]
        perseus_tags_correct += len([p for p, g in zip(predicted_tags, given_tags) if p ==g])
        perseus_lemmata_correct += len([p for p, g in zip(predicted_lemmata, given_lemmata) if p ==g])
    model_test["perseus_tags_correct%"] = (perseus_tags_correct / perseus_dev_len) * 100
    model_test["perseus_lemmata_correct%"] = (perseus_lemmata_correct / perseus_dev_len) * 100
    print(model_test)
    model_tests.append(model_test)
# Out:
# {'Losses': {'tagger': 56364.95995467901}, 'proiel_tags_correct%': 95.01171989452095, 'proiel_lemmata_correct%': 95.29739232346908, 'perseus_tags_correct%': 87.53557714027558, 'perseus_lemmata_correct%': 87.06573300203297}
# {'Losses': {'tagger': 46929.60791128874}, 'proiel_tags_correct%': 95.89071198359214, 'proiel_lemmata_correct%': 95.35599179607384, 'perseus_tags_correct%': 87.88344251185904, 'perseus_lemmata_correct%': 87.04766207363903}
# {'Losses': {'tagger': 41977.65289503336}, 'proiel_tags_correct%': 95.407266334603, 'proiel_lemmata_correct%': 95.45121593905654, 'perseus_tags_correct%': 88.44364129207139, 'perseus_lemmata_correct%': 87.21933589338153}
# {'Losses': {'tagger': 38295.55491784215}, 'proiel_tags_correct%': 96.08848520363317, 'proiel_lemmata_correct%': 95.43656607090536, 'perseus_tags_correct%': 88.00090354641969, 'perseus_lemmata_correct%': 87.03410887734357}
# {'Losses': {'tagger': 35758.74683788419}, 'proiel_tags_correct%': 95.64166422502197, 'proiel_lemmata_correct%': 95.49516554351011, 'perseus_tags_correct%': 88.48430088095776, 'perseus_lemmata_correct%': 87.22385362548}
# {'Losses': {'tagger': 33840.40595907532}, 'proiel_tags_correct%': 96.22033401699385, 'proiel_lemmata_correct%': 95.49516554351011, 'perseus_tags_correct%': 88.28552066862436, 'perseus_lemmata_correct%': 87.1606053761012}
# {'Losses': {'tagger': 32095.809285717492}, 'proiel_tags_correct%': 96.31555815997656, 'proiel_lemmata_correct%': 95.44389100498096, 'perseus_tags_correct%': 88.35328665010165, 'perseus_lemmata_correct%': 87.1922295007906}
# {'Losses': {'tagger': 30854.25888666138}, 'proiel_tags_correct%': 95.9419865221213, 'proiel_lemmata_correct%': 95.48784060943451, 'perseus_tags_correct%': 88.96318048339734, 'perseus_lemmata_correct%': 87.25547775016942}
# {'Losses': {'tagger': 29489.01731290482}, 'proiel_tags_correct%': 96.42543217111046, 'proiel_lemmata_correct%': 95.51714034573689, 'perseus_tags_correct%': 88.42557036367744, 'perseus_lemmata_correct%': 87.1606053761012}
# {'Losses': {'tagger': 28476.38776820898}, 'proiel_tags_correct%': 96.15440961031351, 'proiel_lemmata_correct%': 95.49516554351011, 'perseus_tags_correct%': 88.59724418341992, 'perseus_lemmata_correct%': 87.1244635193133}
# {'Losses': {'tagger': 27686.765684477054}, 'proiel_tags_correct%': 96.3741576325813, 'proiel_lemmata_correct%': 95.49516554351011, 'perseus_tags_correct%': 88.99480460808674, 'perseus_lemmata_correct%': 87.21481816128303}
# {'Losses': {'tagger': 26702.884508642368}, 'proiel_tags_correct%': 96.23498388514503, 'proiel_lemmata_correct%': 95.53179021388807, 'perseus_tags_correct%': 88.44364129207139, 'perseus_lemmata_correct%': 87.11091032301785}
# {'Losses': {'tagger': 26114.314855716657}, 'proiel_tags_correct%': 96.35950776443012, 'proiel_lemmata_correct%': 95.49516554351011, 'perseus_tags_correct%': 88.95866275129885, 'perseus_lemmata_correct%': 87.23740682177547}
# {'Losses': {'tagger': 25574.5498828087}, 'proiel_tags_correct%': 96.13975974216233, 'proiel_lemmata_correct%': 95.51714034573689, 'perseus_tags_correct%': 88.74632934266998, 'perseus_lemmata_correct%': 87.1922295007906}
# {'Losses': {'tagger': 24738.726235747337}, 'proiel_tags_correct%': 96.47670670963961, 'proiel_lemmata_correct%': 95.52446527981249, 'perseus_tags_correct%': 88.99480460808674, 'perseus_lemmata_correct%': 87.18771176869211}
# {'Losses': {'tagger': 24307.362325702794}, 'proiel_tags_correct%': 96.43275710518606, 'proiel_lemmata_correct%': 95.52446527981249, 'perseus_tags_correct%': 88.48881861305624, 'perseus_lemmata_correct%': 87.14705217980574}
# {'Losses': {'tagger': 23920.308644185774}, 'proiel_tags_correct%': 96.17638441254029, 'proiel_lemmata_correct%': 95.5098154116613, 'perseus_tags_correct%': 89.29297492658685, 'perseus_lemmata_correct%': 87.17867630449514}
# {'Losses': {'tagger': 23543.56598253781}, 'proiel_tags_correct%': 96.57193085262233, 'proiel_lemmata_correct%': 95.48784060943451, 'perseus_tags_correct%': 88.73729387847301, 'perseus_lemmata_correct%': 87.15608764400271}
# {'Losses': {'tagger': 23017.382916590548}, 'proiel_tags_correct%': 96.40345736888368, 'proiel_lemmata_correct%': 95.55376501611485, 'perseus_tags_correct%': 89.25231533770047, 'perseus_lemmata_correct%': 87.1922295007906}
# {'Losses': {'tagger': 22533.66998050129}, 'proiel_tags_correct%': 96.42543217111046, 'proiel_lemmata_correct%': 95.53179021388807, 'perseus_tags_correct%': 89.39688276485205, 'perseus_lemmata_correct%': 87.16964084029817}
# {'Losses': {'tagger': 22403.837807178497}, 'proiel_tags_correct%': 96.43275710518606, 'proiel_lemmata_correct%': 95.49516554351011, 'perseus_tags_correct%': 89.01287553648068, 'perseus_lemmata_correct%': 87.10187485882088}
# {'Losses': {'tagger': 22105.197869144846}, 'proiel_tags_correct%': 96.44740697333724, 'proiel_lemmata_correct%': 95.48051567535893, 'perseus_tags_correct%': 88.94962728710188, 'perseus_lemmata_correct%': 87.1606053761012}
# {'Losses': {'tagger': 21756.431068399645}, 'proiel_tags_correct%': 96.34485789627894, 'proiel_lemmata_correct%': 95.56841488426603, 'perseus_tags_correct%': 89.36074090806414, 'perseus_lemmata_correct%': 87.1967472328891}
# {'Losses': {'tagger': 21313.53678219393}, 'proiel_tags_correct%': 96.3888075007325, 'proiel_lemmata_correct%': 95.54644008203927, 'perseus_tags_correct%': 89.7131240117461, 'perseus_lemmata_correct%': 87.17867630449514}
# {'Losses': {'tagger': 20961.601952746452}, 'proiel_tags_correct%': 96.60123058892471, 'proiel_lemmata_correct%': 95.51714034573689, 'perseus_tags_correct%': 88.9405918229049, 'perseus_lemmata_correct%': 87.15608764400271}

# %%
# The reason why the performance on perseus is not so good is actually caused by inperfect tokenization 
# -> implying that our sentences are of different length than the sentences in the test data

all_tags_len = 0
inconsistencies = []
perseus_tags_correct = 0
perseus_lemmata_correct = 0
for sent in perseus_dev:
        doc = nlp(sent[0])
        predicted_tags = [token.pos_ for token in doc]
        all_tags_len = all_tags_len + len(predicted_tags)
        predicted_lemmata = [token.lemma_ for token in doc]
        #predicted_lemmata = [lemmatizer(token.text, token.pos_) for token in doc]
        given_tags = sent[1]["tags"]
        given_lemmata = sent[1]["lemmata"]
        if len(predicted_lemmata) != len(given_lemmata):
            inconsistencies.append((sent[1]["words"], [(token.text, token.lemma_) for token in doc]))
        perseus_tags_correct += len([p for p, g in zip(predicted_tags, given_tags) if p ==g])
        perseus_lemmata_correct += len([p for p, g in zip(predicted_lemmata, given_lemmata) if p ==g])
model_test["perseus_tags_correct%"] = (perseus_tags_correct / perseus_dev_len) * 100
model_test["perseus_lemmata_correct%"] = (perseus_lemmata_correct / perseus_dev_len) * 100
print(inconsistencies[:3])
# Out:
# [(['πολλῷ', 'γὰρ', 'ὕστερον', 'ἔτι', 'καὶ', 'τῶν', 'Τρωικῶν', 'γενόμενος', 'οὐδαμοῦ', 'τοὺς', 'ξύμπαντας', 'ὠνόμασεν', ',', 'οὐδ̓', 'ἄλλους', 'ἢ', 'τοὺς', 'μετ̓', 'Ἀχιλλέως', 'ἐκ', 'τῆς', 'Φθιώτιδος', ',', 'οἵπερ', 'καὶ', 'πρῶτοι', 'Ἕλληνες', 'ἦσαν', ',', 'Δαναοὺς', 'δὲ', 'ἐν', 'τοῖς', 'ἔπεσι', 'καὶ', 'Ἀργείους', 'καὶ', 'Ἀχαιοὺς', 'ἀνακαλεῖ', '.'], [('πολλῷ', 'πολύς'), ('γὰρ', 'γάρ'), ('ὕστερον', 'ὕστερος'), ('ἔτι', 'ἔτι'), ('καὶ', 'καί'), ('τῶν', 'ὁ'), ('Τρωικῶν', 'Τρωικός'), ('γενόμενος', 'γίγνομαι'), ('οὐδαμοῦ', 'οὐδαμοῦ'), ('τοὺς', 'ὁ'), ('ξύμπαντας', 'σύμπας'), ('ὠνόμασεν', 'ὀνομάζω'), (',', ','), ('οὐδ̓', 'οὐδ'), ('ἄλλους', 'ἄλλος'), ('ἢ', 'ἤ'), ('τοὺς', 'ὁ'), ('μετ̓', 'μετ'), ('Ἀχιλλέως', 'Ἀχιλλεύς'), ('ἐκ', 'ἐκ'), ('τῆς', 'ὁ'), ('Φθιώτιδος', 'Φθιῶτις'), (',', ','), ('οἵπερ', 'ὅσπερ'), ('καὶ', 'καί'), ('πρῶτοι', 'πρῶτος'), ('Ἕλληνες', 'Ἕλλην'), ('ἦσαν', 'εἰμί'), (',', ','), ('Δαναοὺς', 'Δαναοί'), ('δὲ', 'δέ'), ('ἐν', 'ἐν'), ('τοῖς', 'ὁ'), ('ἔπεσι', 'ἔπος'), ('καὶ', 'καί'), ('Ἀργείους', 'Ἀργεῖος'), ('καὶ', 'καί'), ('Ἀχαιοὺς', 'Ἀχαιός'), ('ἀνακαλεῖ.', 'ἀνακαλέω')]), (['καὶ', 'Πολυκράτης', 'Σάμου', 'τυραννῶν', 'ἐπὶ', 'Καμβύσου', 'ναυτικῷ', 'ἰσχύων', 'ἄλλας', 'τε', 'τῶν', 'νήσων', 'ὑπηκόους', 'ἐποιήσατο', 'καὶ', 'Ῥήνειαν', 'ἑλὼν', 'ἀνέθηκε', 'τῷ', 'Ἀπόλλωνι', 'τῷ', 'Δηλίῳ', '.'], [('καὶ', 'καί'), ('Πολυκράτης', 'Πολυκράτης'), ('Σάμου', 'Σάμος'), ('τυραννῶν', 'τύραννος'), ('ἐπὶ', 'ἐπί'), ('Καμβύσου', 'καμβύσου'), ('ναυτικῷ', 'ναυτικός'), ('ἰσχύων', 'ἰσχύω'), ('ἄλλας', 'ἄλλος'), ('τε', 'τε'), ('τῶν', 'ὁ'), ('νήσων', 'νῆσος'), ('ὑπηκόους', 'ὑπήκοος'), ('ἐποιήσατο', 'ποιέω'), ('καὶ', 'καί'), ('Ῥήνειαν', 'ῥαίνω'), ('ἑλὼν', 'αἱρέω'), ('ἀνέθηκε', 'ἀνατίθημι'), ('τῷ', 'ὁ'), ('Ἀπόλλωνι', 'Ἀπόλλων'), ('τῷ', 'ὁ'), ('Δηλίῳ.', 'Δήλιος')]), (['τῇ', 'δὲ', 'αὐτῇ', 'ἡμέρᾳ', 'αὐτοῖς', 'ξυνέβη', 'καὶ', 'τοὺς', 'τὴν', 'Ἐπίδαμνον', 'πολιορκοῦντας', 'παραστήσασθαι', 'ὁμολογίᾳ', 'ὥστε', 'τοὺς', 'μὲν', 'ἐπήλυδας', 'ἀποδόσθαι', ',', 'Κορινθίους', 'δὲ', 'δήσαντας', 'ἔχειν', 'ἕως', 'ἂν', 'ἄλλο', 'τι', 'δόξῃ', '.'], [('τῇ', 'ὁ'), ('δὲ', 'δέ'), ('αὐτῇ', 'αὐτός'), ('ἡμέρᾳ', 'ἡμέρα'), ('αὐτοῖς', 'αὐτός'), ('ξυνέβη', 'συμβαίνω'), ('καὶ', 'καί'), ('τοὺς', 'ὁ'), ('τὴν', 'ὁ'), ('Ἐπίδαμνον', 'ἐπίδαμνον'), ('πολιορκοῦντας', 'πολιορκοῦντας'), ('παραστήσασθαι', 'παρίστημι'), ('ὁμολογίᾳ', 'ὁμολογία'), ('ὥστε', 'ὥστε'), ('τοὺς', 'ὁ'), ('μὲν', 'μέν'), ('ἐπήλυδας', 'ἔπηλυς'), ('ἀποδόσθαι', 'ἀποδίδωμι'), (',', ','), ('Κορινθίους', 'Κορίνθιος'), ('δὲ', 'δέ'), ('δήσαντας', 'δήσαντας'), ('ἔχειν', 'ἔχω'), ('ἕως', 'ἕως'), ('ἂν', 'ἄν'), ('ἄλλο', 'ἄλλος'), ('τι', 'τίς'), ('δόξῃ.', 'δοκέω')])]

# %%
all_tags_len
# Out:
# 22107

# %%
# COMPARE WITH OUR FIRST MODEL
nlp_1 = spacy.load("../models/spacy_grc_model_1")

model_test = {}
proiel_tags_correct = 0
proiel_lemmata_correct = 0
for sent in proiel_dev:
    doc = nlp(sent[0])
    predicted_tags = [token.pos_ for token in doc]
    all_tags_len = all_tags_len + len(predicted_tags)
    predicted_lemmata = [token.lemma_ for token in doc]
    given_tags = sent[1]["tags"]
    given_lemmata = sent[1]["lemmata"]
    proiel_tags_correct += len([p for p, g in zip(predicted_tags, given_tags) if p ==g])
    proiel_lemmata_correct += len([p for p, g in zip(predicted_lemmata, given_lemmata) if p ==g])
model_test["proiel_tags_correct%"] = (proiel_tags_correct / proiel_dev_len) * 100
model_test["proiel_lemmata_correct%"] = (proiel_lemmata_correct / proiel_dev_len) * 100

perseus_tags_correct = 0
perseus_lemmata_correct = 0
for sent in perseus_dev:
    doc = nlp(sent[0])
    predicted_tags = [token.pos_ for token in doc]
    all_tags_len = all_tags_len + len(predicted_tags)
    predicted_lemmata = [token.lemma_ for token in doc]
    given_tags = sent[1]["tags"]
    given_lemmata = sent[1]["lemmata"]
    perseus_tags_correct += len([p for p, g in zip(predicted_tags, given_tags) if p ==g])
    perseus_lemmata_correct += len([p for p, g in zip(predicted_lemmata, given_lemmata) if p ==g])
model_test["perseus_tags_correct%"] = (perseus_tags_correct / perseus_dev_len) * 100
model_test["perseus_lemmata_correct%"] = (perseus_lemmata_correct / perseus_dev_len) * 100

model_test
# Out:
# {'proiel_tags_correct%': 96.60123058892471,
#  'proiel_lemmata_correct%': 95.51714034573689,
#  'perseus_tags_correct%': 88.9405918229049,
#  'perseus_lemmata_correct%': 87.15608764400271}

# %% [markdown]
# our results with first model:
# ```
# {'proiel_tags_correct%': 87.90653384119544,
#  'proiel_lemmata_correct%': 85.62115440961031,
#  'perseus_tags_correct%': 85.05534221820646,
#  'perseus_lemmata_correct%': 82.66997967020556}
#  ```

# %%
nlp.remove_pipe('grc_doc_lemmatizer')
nlp.to_disk("../models/spacy_grc_model_7")

# %% [markdown]
# # Testing with real data

# %%
AGT = sddk.read_file("SDAM_data/AGT/AGT_preprocessed_20201209.json", "df", conf)

# %%
nlp = spacy.load("../models/spacy_grc_model_7")

# %%
nlp.add_pipe(grc_doc_lemmatizer, "grc_doc_lemmatizer", after="tagger") # grc_doc_lemmatizer

# %%
doc = nlp(AGT[AGT["author_id"]=="tlg0031paul"].iloc[3]["sentences"][0])
print([(token.text, token.pos_, token.lemma_) for token in doc])
# Out:
# [('ΠΑΥΛΟΣ', 'NOUN', 'Παῦλος'), ('ἀπόστολος', 'NOUN', 'ἀπόστολος'), (',', 'PUNCT', ','), ('οὐκ', 'ADV', 'οὐ'), ('ἀπʼ', 'ADP', 'ἀπό'), ('ἀνθρώπων', 'NOUN', 'ἄνθρωπος'), ('οὐδὲ', 'CCONJ', 'οὐδέ'), ('διʼ', 'ADP', 'διά'), ('ἀνθρώπου', 'NOUN', 'ἄνθρωπος'), ('ἀλλὰ', 'CCONJ', 'ἀλλά'), ('διὰ', 'ADP', 'διά'), ('Ἰησοῦ', 'PROPN', 'Ἰησοῦς'), ('Χριστοῦ', 'PROPN', 'Χριστός'), ('καὶ', 'CCONJ', 'καί'), ('θεοῦ', 'NOUN', 'θεός'), ('πατρὸς', 'NOUN', 'πατήρ'), ('τοῦ', 'DET', 'ὁ'), ('ἐγείραντος', 'VERB', 'ἐγείρω'), ('αὐτὸν', 'PRON', 'αὐτός'), ('ἐκ', 'ADP', 'ἐκ'), ('νεκρῶν', 'NOUN', 'νεκρός'), (',', 'PUNCT', ','), ('καὶ', 'CCONJ', 'καί'), ('οἱ', 'DET', 'ὁ'), ('σὺν', 'ADP', 'σύν'), ('ἐμοὶ', 'PRON', 'ἐγώ'), ('πάντες', 'ADJ', 'πᾶς'), ('ἀδελφοί', 'NOUN', 'ἀδελφός'), (',', 'PUNCT', ','), ('ταῖς', 'DET', 'ὁ'), ('ἐκκλησίαις', 'NOUN', 'ἐκκλησία'), ('τῆς', 'DET', 'ὁ'), ('Γαλατίας', 'NOUN', 'Γαλατία'), ('·', 'PUNCT', '·')]

# %%
doc = nlp(AGT[AGT["author_id"]=="tlg0031paul"].iloc[3]["sentences"][0])
print([(token.text, token.pos_, token.lemma_) for token in doc])
# Out:
# [('ΠΑΥΛΟΣ', 'NOUN', 'Παῦλος'), ('ἀπόστολος', 'NOUN', 'ἀπόστολος'), (',', 'PUNCT', ','), ('οὐκ', 'ADV', 'οὐ'), ('ἀπʼ', 'ADP', 'ἀπό'), ('ἀνθρώπων', 'NOUN', 'ἄνθρωπος'), ('οὐδὲ', 'CCONJ', 'οὐδέ'), ('διʼ', 'ADP', 'διά'), ('ἀνθρώπου', 'NOUN', 'ἄνθρωπος'), ('ἀλλὰ', 'CCONJ', 'ἀλλά'), ('διὰ', 'ADP', 'διά'), ('Ἰησοῦ', 'PROPN', 'Ἰησοῦς'), ('Χριστοῦ', 'PROPN', 'Χριστός'), ('καὶ', 'CCONJ', 'καί'), ('θεοῦ', 'NOUN', 'θεός'), ('πατρὸς', 'NOUN', 'πατήρ'), ('τοῦ', 'DET', 'ὁ'), ('ἐγείραντος', 'VERB', 'ἐγείρω'), ('αὐτὸν', 'PRON', 'αὐτός'), ('ἐκ', 'ADP', 'ἐκ'), ('νεκρῶν', 'NOUN', 'νεκρός'), (',', 'PUNCT', ','), ('καὶ', 'CCONJ', 'καί'), ('οἱ', 'DET', 'ὁ'), ('σὺν', 'ADP', 'σύν'), ('ἐμοὶ', 'PRON', 'ἐγώ'), ('πάντες', 'ADJ', 'πᾶς'), ('ἀδελφοί', 'NOUN', 'ἀδελφός'), (',', 'PUNCT', ','), ('ταῖς', 'DET', 'ὁ'), ('ἐκκλησίαις', 'NOUN', 'ἐκκλησία'), ('τῆς', 'DET', 'ὁ'), ('Γαλατίας', 'NOUN', 'Γαλατία'), ('·', 'PUNCT', '·')]

# %%
arist_test = apply_nlp(AGT[AGT["doc_id"]=="tlg0086.tlg010"]["sentences"].tolist()[0])
for doc in arist_test[:10]:
    print([(token.text, token.pos_, token.lemma_) for token in doc])
# Out:
# [('πᾶσα', 'DET', 'πᾶς'), ('τέχνη', 'NOUN', 'τέχνη'), ('καὶ', 'CCONJ', 'καί'), ('πᾶσα', 'ADJ', 'πᾶς'), ('μέθοδος', 'NOUN', 'μέθοδος'), (',', 'PUNCT', ','), ('ὁμοίως', 'ADV', 'ὁμοίως'), ('δὲ', 'CCONJ', 'δέ'), ('πρᾶξίς', 'NOUN', 'πρᾶξις'), ('τε', 'PART', 'τε'), ('καὶ', 'CCONJ', 'καί'), ('προαίρεσις', 'NOUN', 'προαίρεσις'), (',', 'PUNCT', ','), ('ἀγαθοῦ', 'ADJ', 'ἀγαθός'), ('τινὸς', 'PRON', 'τίς'), ('ἐφίεσθαι', 'VERB', 'ἐφίημι'), ('δοκεῖ', 'VERB', 'δοκέω'), ('·', 'PUNCT', '·')]
# [('διὸ', 'ADV', 'διό'), ('καλῶς', 'ADV', 'καλῶς'), ('ἀπεφήναντο', 'VERB', 'ἀποφαίνω'), ('τἀγαθόν', 'ADJ', 'ἀγαθός'), (',', 'PUNCT', ','), ('οὗ', 'ADV', 'οὗ'), ('πάντʼ', 'ADJ', 'πᾶς'), ('ἐφίεται', 'VERB', 'ἐφίημι'), ('.', 'PUNCT', '.')]
# [('διαφορὰ', 'NOUN', 'διαφορά'), ('δέ', 'ADV', 'δέ'), ('τις', 'PRON', 'τίς'), ('φαίνεται', 'VERB', 'φαίνω'), ('τῶν', 'DET', 'ὁ'), ('τελῶν', 'NOUN', 'τέλος'), ('·', 'PUNCT', '·')]
# [('τὰ', 'PRON', 'ὁ'), ('μὲν', 'PART', 'μέν'), ('γάρ', 'PART', 'γάρ'), ('εἰσιν', 'VERB', 'εἰμί'), ('ἐνέργειαι', 'NOUN', 'ἐνέργεια'), (',', 'PUNCT', ','), ('τὰ', 'DET', 'ὁ'), ('δὲ', 'CCONJ', 'δέ'), ('παρʼ', 'ADP', 'παρά'), ('αὐτὰς', 'ADJ', 'αὐτός'), ('ἔργα', 'NOUN', 'ἔργον'), ('τινά', 'PRON', 'τις'), ('.', 'PUNCT', '.')]
# [('ὧν', 'PRON', 'ὅς'), ('δʼ', 'ADV', 'δέ'), ('εἰσὶ', 'AUX', 'εἰμί'), ('τέλη', 'NOUN', 'τέλος'), ('τινὰ', 'DET', 'τὶς'), ('παρὰ', 'ADP', 'παρά'), ('τὰς', 'DET', 'ὁ'), ('πράξεις', 'NOUN', 'πρᾶξις'), (',', 'PUNCT', ','), ('ἐν', 'ADP', 'ἐν'), ('τούτοις', 'PRON', 'οὗτος'), ('βελτίω', 'ADJ', 'βελτίων'), ('πέφυκε', 'VERB', 'φύω'), ('τῶν', 'DET', 'ὁ'), ('ἐνεργειῶν', 'NOUN', 'ἐνέργεια'), ('τὰ', 'DET', 'ὁ'), ('ἔργα', 'NOUN', 'ἔργον'), ('.', 'PUNCT', '.')]
# [('πολλῶν', 'ADJ', 'πολύς'), ('δὲ', 'ADV', 'δέ'), ('πράξεων', 'NOUN', 'πρᾶξις'), ('οὐσῶν', 'AUX', 'εἰμί'), ('καὶ', 'CCONJ', 'καί'), ('τεχνῶν', 'NOUN', 'τέχνη'), ('καὶ', 'CCONJ', 'καί'), ('ἐπιστημῶν', 'NOUN', 'ἐπιστήμη'), ('πολλὰ', 'ADJ', 'πολύς'), ('γίνεται', 'VERB', 'γίγνομαι'), ('καὶ', 'ADV', 'καί'), ('τὰ', 'DET', 'ὁ'), ('τέλη', 'NOUN', 'τέλος'), ('·', 'PUNCT', '·')]
# [('ἰατρικῆς', 'ADJ', 'ἰατρικός'), ('μὲν', 'PART', 'μέν'), ('γὰρ', 'PART', 'γάρ'), ('ὑγίεια', 'NOUN', 'ὑγίεια'), (',', 'PUNCT', ','), ('ναυπηγικῆς', 'ADJ', 'ναυπηγικός'), ('δὲ', 'CCONJ', 'δέ'), ('πλοῖον', 'NOUN', 'πλοῖον'), (',', 'PUNCT', ','), ('στρατηγικῆς', 'ADJ', 'στρατηγικός'), ('δὲ', 'PART', 'δέ'), ('νίκη', 'NOUN', 'νίκη'), (',', 'PUNCT', ','), ('οἰκονομικῆς', 'ADJ', 'οἰκονομικός'), ('δὲ', 'PART', 'δέ'), ('πλοῦτος', 'NOUN', 'πλοῦτος'), ('.', 'PUNCT', '.')]
# [('ὅσαι', 'PRON', 'ὅσος'), ('δʼ', 'ADV', 'δέ'), ('εἰσὶ', 'AUX', 'εἰμί'), ('τῶν', 'DET', 'ὁ'), ('τοιούτων', 'ADJ', 'τοιοῦτος'), ('ὑπὸ', 'ADP', 'ὑπό'), ('μίαν', 'ADJ', 'εἷς'), ('τινὰ', 'PRON', 'τίς'), ('δύναμιν', 'NOUN', 'δύναμις'), (',', 'PUNCT', ','), ('καθάπερ', 'SCONJ', 'καθά'), ('ὑπὸ', 'ADP', 'ὑπό'), ('τὴν', 'DET', 'ὁ'), ('ἱππικὴν', 'ADJ', 'ἱππικός'), ('χαλινοποιικὴ', 'NOUN', 'χαλινοποιική'), ('καὶ', 'CCONJ', 'καί'), ('ὅσαι', 'PRON', 'ὅσος'), ('ἄλλαι', 'DET', 'ἄλλος'), ('τῶν', 'DET', 'ὁ'), ('ἱππικῶν', 'ADJ', 'ἱππικός'), ('ὀργάνων', 'NOUN', 'ὄργανον'), ('εἰσίν', 'VERB', 'εἰμί'), (',', 'PUNCT', ','), ('αὕτη', 'PRON', 'αὐτός'), ('δὲ', 'CCONJ', 'δέ'), ('καὶ', 'ADV', 'καί'), ('πᾶσα', 'DET', 'πᾶς'), ('πολεμικὴ', 'ADJ', 'πολεμικός'), ('πρᾶξις', 'NOUN', 'πρᾶξις'), ('ὑπὸ', 'ADP', 'ὑπό'), ('τὴν', 'DET', 'ὁ'), ('στρατηγικήν', 'ADJ', 'στρατηγικός'), (',', 'PUNCT', ','), ('κατὰ', 'ADP', 'κατά'), ('τὸν', 'DET', 'ὁ'), ('αὐτὸν', 'ADJ', 'αὐτός'), ('δὴ', 'ADV', 'δή'), ('τρόπον', 'NOUN', 'τρόπος'), ('ἄλλαι', 'ADJ', 'ἄλλος'), ('ὑφʼ', 'ADP', 'ὑπό'), ('ἑτέρας', 'ADJ', 'ἕτερος'), ('·', 'PUNCT', '·')]
# [('ἐν', 'ADP', 'ἐν'), ('ἁπάσαις', 'ADJ', 'ἅπας'), ('δὲ', 'ADV', 'δέ'), ('τὰ', 'DET', 'ὁ'), ('τῶν', 'DET', 'ὁ'), ('ἀρχιτεκτονικῶν', 'ADJ', 'ἀρχιτεκτονικῶν'), ('τέλη', 'NOUN', 'τέλος'), ('πάντων', 'DET', 'πᾶς'), ('ἐστὶν', 'AUX', 'εἰμί'), ('αἱρετώτερα', 'ADJ', 'αἱρετός'), ('τῶν', 'DET', 'ὁ'), ('ὑπʼ', 'ADP', 'ὑπό'), ('αὐτά', 'PRON', 'αὐτός'), ('·', 'PUNCT', '·')]
# [('τούτων', 'ADJ', 'οὗτος'), ('γὰρ', 'PART', 'γάρ'), ('χάριν', 'NOUN', 'χάρις'), ('κἀκεῖνα', 'ADJ', 'ἐκεῖνος'), ('διώκεται', 'VERB', 'διώκω'), ('.', 'PUNCT', '.')]

# %% [markdown]
# # Zip the model and upload it to sciencedata.dk

# %%
# zip the model to our models folder
! zip ../models/spacy_grc_model_7.zip -r ../models/spacy_grc_model_7
# Out:
# updating: ../models/spacy_grc_model_7/ (stored 0%)
# updating: ../models/spacy_grc_model_7/meta.json (deflated 57%)
# updating: ../models/spacy_grc_model_7/grc_lemmatization.py (deflated 75%)
# updating: ../models/spacy_grc_model_7/tokenizer (deflated 73%)
# updating: ../models/spacy_grc_model_7/tagger/ (stored 0%)
# updating: ../models/spacy_grc_model_7/tagger/cfg (deflated 11%)
# updating: ../models/spacy_grc_model_7/tagger/model (deflated 10%)
# updating: ../models/spacy_grc_model_7/tagger/tag_map (deflated 19%)
# updating: ../models/spacy_grc_model_7/vocab/ (stored 0%)
# updating: ../models/spacy_grc_model_7/vocab/strings.json (deflated 86%)
# updating: ../models/spacy_grc_model_7/vocab/vectors (deflated 7%)
# updating: ../models/spacy_grc_model_7/vocab/lookups.bin (deflated 73%)
# updating: ../models/spacy_grc_model_7/vocab/key2row (deflated 13%)
# updating: ../models/spacy_grc_model_7/vocab/lookups_extra.bin (deflated 10%)
# updating: ../models/spacy_grc_model_7/.ipynb_checkpoints/ (stored 0%)

# %%
from getpass import getpass
from webdav3.client import Client

options = {
 'webdav_hostname': "https://sciencedata.dk/files/",
 'webdav_login':    "648597@au.dk",
 'webdav_password': getpass("sciencedata password: ")
}
client = Client(options)
# Out:
# sciencedata password: ········

# %%
client.upload_sync(remote_path="SDAM_root/SDAM_data/AGT/spacy_grc_model_7.zip", local_path="../models/spacy_grc_model_7.zip")
