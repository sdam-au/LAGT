# %% [markdown]
# # Requirements

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup
import re
import pickle
from collections import defaultdict
import requests
import unicodedata

# %%
# load LAGT v 3.0, as we will use it as a source for metadata
#LAGT = pd.read_parquet("../data/large_files/LAGT_v3-0.parquet")
#len(LAGT)

# %%
# LAGT.head(5)

# %%
# currently from Glaux:
#sum(LAGT["lemmata_source"] == "glaux")

# %% [markdown]
# ### Load newest local Glaux

# %%
greek_data_dir = "/srv/data/greek/"

# %%
source_dir = os.path.join(greek_data_dir, "glaux/xml/")
glaux_filenames = os.listdir(source_dir)
glaux_filenames[:10]
# Out:
# ['0018-016.xml',
#  '0007-131.xml',
#  '0057-002.xml',
#  '0032-013.xml',
#  '0062-022.xml',
#  '0284-024.xml',
#  '0592-003.xml',
#  '1157-001.xml',
#  '1183-001.xml',
#  '0014-022.xml']

# %%
len(glaux_filenames)
# Out:
# 1421

# %%
with open(source_dir  + glaux_filenames[0], "r") as f:
    soup = BeautifulSoup(f.read())
print(soup.prettify()[:5000])
# Out:
# <html>
#  <body>
#   <treebank version="2" xml:lang="grc">
#    <sentence analysis="auto" document_id="0018-016" id="1" struct_id="349278">
#     <word div_section="1" form='"' head="0" id="106302716" lemma='"' postag="u--------" relation="AuxG">
#     </word>
#     <word div_section="1" form="Σάρα" head="106302723" id="106302717" lemma="Σάρα" postag="n-s---fn-" relation="SBJ">
#     </word>
#     <word div_section="1" form="δὲ" head="106302723" id="106302718" lemma="δέ" postag="c--------" relation="AuxY">
#     </word>
#     <word div_section="1" form="ἡ" head="106302720" id="106302719" lemma="ὁ" postag="l-s---fn-" relation="ATR">
#     </word>
#     <word div_section="1" form="γυνὴ" head="106302717" id="106302720" lemma="γυνή" postag="n-s---fn-" relation="APOS">
#     </word>
#     <word div_section="1" form="Ἀβραὰμ" head="106302720" id="106302721" lemma="Ἀβραάμ" postag="n--------" relation="ATR">
#     </word>
#     <word div_section="1" form="οὐκ" head="106302723" id="106302722" lemma="οὐ" postag="d--------" relation="AuxZ">
#     </word>
#     <word div_section="1" form="ἔτικτεν" head="0" id="106302723" lemma="τίκτω" postag="v3siia---" relation="PRED">
#     </word>
#     <word div_section="1" form="αὐτῷ" head="106302723" id="106302724" lemma="αὐτός" postag="p-s---md-" relation="OBJ">
#     </word>
#     <word div_section="1" form="." head="0" id="106302725" lemma="." postag="u--------" relation="AuxK">
#     </word>
#    </sentence>
#    <sentence analysis="auto" document_id="0018-016" id="2" struct_id="349279">
#     <word div_section="1" form="ἦν" head="0" id="106302726" lemma="εἰμί" postag="v3siia---" relation="PRED">
#     </word>
#     <word div_section="1" form="δὲ" head="106302726" id="106302727" lemma="δέ" postag="c--------" relation="AuxY">
#     </word>
#     <word div_section="1" form="αὐτῇ" head="106302726" id="106302728" lemma="αὐτός" postag="p-s---fd-" relation="OBJ">
#     </word>
#     <word div_section="1" form="παιδίσκη" head="106302726" id="106302729" lemma="παιδίσκη" postag="n-s---fn-" relation="SBJ">
#     </word>
#     <word div_section="1" form="Αἰγυπτία" head="106302729" id="106302730" lemma="Αἰγύπτιος" postag="a-s---fn-" relation="ATR">
#     </word>
#     <word div_section="1" form="," head="0" id="106302731" lemma="," postag="u--------" relation="AuxX">
#     </word>
#     <word div_section="1" form="ᾗ" head="1000062440" id="106302732" lemma="ὅς" postag="p-s---fd-" relation="ADV">
#     </word>
#     <word div_section="1" form="ὄνομα" head="1000062440" id="106302733" lemma="ὄνομα" postag="n-s---nn-" relation="SBJ">
#     </word>
#     <word div_section="1" form="Ἄγαρ" head="1000062440" id="106302734" lemma="Ἄγαρ" postag="n-s---fn-" relation="SBJ">
#     </word>
#     <word div_section="1" form="." head="0" id="106302735" lemma="." postag="u--------" relation="AuxK">
#     </word>
#     <word artificial="elliptic" div_section="1" form="E" head="106302729" id="1000062440" lemma="E" postag="z--------" relation="ATR">
#     </word>
#    </sentence>
#    <sentence analysis="auto" document_id="0018-016" id="3" struct_id="349280">
#     <word div_section="1" form="εἶπε" head="0" id="106302736" lemma="λέγω" postag="v3saia---" relation="PRED">
#     </word>
#     <word div_section="1" form="δὲ" head="106302736" id="106302737" lemma="δέ" postag="c--------" relation="AuxY">
#     </word>
#     <word div_section="1" form="Σάρα" head="106302736" id="106302738" lemma="Σάρα" postag="n-s---fn-" relation="SBJ">
#     </word>
#     <word div_section="1" form="πρὸς" head="106302736" id="106302739" lemma="πρός" postag="r--------" relation="AuxP">
#     </word>
#     <word div_section="1" form="Ἀβραάμ" head="106302739" id="106302740" lemma="Ἀβραάμ" postag="n--------" relation="OBJ">
#     </word>
#     <word div_section="1" form="·" head="0" id="106302741" lemma="·" postag="u--------" relation="AuxK">
#     </word>
#    </sentence>
#    <sentence analysis="auto" document_id="0018-016" id="4" struct_id="349281">
#     <word div_section="1" form="ἰδού" head="106302744" id="106302742" lemma="ἰδού" postag="i--------" relation="ExD">
#     </word>
#     <word div_section="1" form="," head="0" id="106302743" lemma="," postag="u--------" relation="AuxX">
#     </word>
#     <word div_section="1" form="συνέκλεισέ" head="0" id="106302744" lemma="συγκλείω" postag="v3saia---" relation="PRED">
#     </word>
#     <word div_section="1" form="με" head="106302744" id="106302745" lemma="ἐγώ" postag="p-s---ca-" relation="OBJ">
#     </word>
#     <word div_section="1" form="κύριος" head="106302744" id="106302746" lemma="κύριος" postag="n-s---mn-" relation="SBJ">
#     </word>
#     <word div_section="1" form="τοῦ" head="106302749" id="106302747" lemma="ὁ" postag="l-s---ng-" relation="ATR">
#     </word>
#     <word div_section="1" form="μὴ" head="106302749" id="106302748" lemma="μή" postag="d--------" relation="AuxZ">
#     </word>
#     <word div_section="1" form="τίκτειν" head="106302746" id="106302749" lemma="τίκτω" postag="v--pna---" relation="ATR">
#     </word>
#     <word div_secti

# %%
glaux_tlgs = [re.sub(r'(\d{4})-(\d{3}).xml', r'tlg\1.tlg\2', fn) for fn in glaux_filenames]
glaux_tlgs[:10]
# Out:
# ['tlg0018.tlg016',
#  'tlg0007.tlg131',
#  'tlg0057.tlg002',
#  'tlg0032.tlg013',
#  'tlg0062.tlg022',
#  'tlg0284.tlg024',
#  'tlg0592.tlg003',
#  'tlg1157.tlg001',
#  'tlg1183.tlg001',
#  'tlg0014.tlg022']

# %%
#LAGT["doc_id"].isin(glaux_tlgs).sum()

# %%
#not_lagt = [glaux_fn for glaux_fn in glaux_filenames if re.sub(r'(\d{4})-(\d{3}).xml', r'tlg\1.tlg\2', glaux_fn) not in list(LAGT["doc_id"])]
#not_lagt[:10]

# %%
#len(not_lagt)

# %%
with open(source_dir  + glaux_filenames[0], "r") as f:
    soup = BeautifulSoup(f.read())

# %%
print(soup.prettify()[:20000])
# Out:
# <html>
#  <body>
#   <treebank version="2" xml:lang="grc">
#    <sentence analysis="auto" document_id="0018-016" id="1" struct_id="349278">
#     <word div_section="1" form='"' head="0" id="106302716" lemma='"' postag="u--------" relation="AuxG">
#     </word>
#     <word div_section="1" form="Σάρα" head="106302723" id="106302717" lemma="Σάρα" postag="n-s---fn-" relation="SBJ">
#     </word>
#     <word div_section="1" form="δὲ" head="106302723" id="106302718" lemma="δέ" postag="c--------" relation="AuxY">
#     </word>
#     <word div_section="1" form="ἡ" head="106302720" id="106302719" lemma="ὁ" postag="l-s---fn-" relation="ATR">
#     </word>
#     <word div_section="1" form="γυνὴ" head="106302717" id="106302720" lemma="γυνή" postag="n-s---fn-" relation="APOS">
#     </word>
#     <word div_section="1" form="Ἀβραὰμ" head="106302720" id="106302721" lemma="Ἀβραάμ" postag="n--------" relation="ATR">
#     </word>
#     <word div_section="1" form="οὐκ" head="106302723" id="106302722" lemma="οὐ" postag="d--------" relation="AuxZ">
#     </word>
#     <word div_section="1" form="ἔτικτεν" head="0" id="106302723" lemma="τίκτω" postag="v3siia---" relation="PRED">
#     </word>
#     <word div_section="1" form="αὐτῷ" head="106302723" id="106302724" lemma="αὐτός" postag="p-s---md-" relation="OBJ">
#     </word>
#     <word div_section="1" form="." head="0" id="106302725" lemma="." postag="u--------" relation="AuxK">
#     </word>
#    </sentence>
#    <sentence analysis="auto" document_id="0018-016" id="2" struct_id="349279">
#     <word div_section="1" form="ἦν" head="0" id="106302726" lemma="εἰμί" postag="v3siia---" relation="PRED">
#     </word>
#     <word div_section="1" form="δὲ" head="106302726" id="106302727" lemma="δέ" postag="c--------" relation="AuxY">
#     </word>
#     <word div_section="1" form="αὐτῇ" head="106302726" id="106302728" lemma="αὐτός" postag="p-s---fd-" relation="OBJ">
#     </word>
#     <word div_section="1" form="παιδίσκη" head="106302726" id="106302729" lemma="παιδίσκη" postag="n-s---fn-" relation="SBJ">
#     </word>
#     <word div_section="1" form="Αἰγυπτία" head="106302729" id="106302730" lemma="Αἰγύπτιος" postag="a-s---fn-" relation="ATR">
#     </word>
#     <word div_section="1" form="," head="0" id="106302731" lemma="," postag="u--------" relation="AuxX">
#     </word>
#     <word div_section="1" form="ᾗ" head="1000062440" id="106302732" lemma="ὅς" postag="p-s---fd-" relation="ADV">
#     </word>
#     <word div_section="1" form="ὄνομα" head="1000062440" id="106302733" lemma="ὄνομα" postag="n-s---nn-" relation="SBJ">
#     </word>
#     <word div_section="1" form="Ἄγαρ" head="1000062440" id="106302734" lemma="Ἄγαρ" postag="n-s---fn-" relation="SBJ">
#     </word>
#     <word div_section="1" form="." head="0" id="106302735" lemma="." postag="u--------" relation="AuxK">
#     </word>
#     <word artificial="elliptic" div_section="1" form="E" head="106302729" id="1000062440" lemma="E" postag="z--------" relation="ATR">
#     </word>
#    </sentence>
#    <sentence analysis="auto" document_id="0018-016" id="3" struct_id="349280">
#     <word div_section="1" form="εἶπε" head="0" id="106302736" lemma="λέγω" postag="v3saia---" relation="PRED">
#     </word>
#     <word div_section="1" form="δὲ" head="106302736" id="106302737" lemma="δέ" postag="c--------" relation="AuxY">
#     </word>
#     <word div_section="1" form="Σάρα" head="106302736" id="106302738" lemma="Σάρα" postag="n-s---fn-" relation="SBJ">
#     </word>
#     <word div_section="1" form="πρὸς" head="106302736" id="106302739" lemma="πρός" postag="r--------" relation="AuxP">
#     </word>
#     <word div_section="1" form="Ἀβραάμ" head="106302739" id="106302740" lemma="Ἀβραάμ" postag="n--------" relation="OBJ">
#     </word>
#     <word div_section="1" form="·" head="0" id="106302741" lemma="·" postag="u--------" relation="AuxK">
#     </word>
#    </sentence>
#    <sentence analysis="auto" document_id="0018-016" id="4" struct_id="349281">
#     <word div_section="1" form="ἰδού" head="106302744" id="106302742" lemma="ἰδού" postag="i--------" relation="ExD">
#     </word>
#     <word div_section="1" form="," head="0" id="106302743" lemma="," postag="u--------" relation="AuxX">
#     </word>
#     <word div_section="1" form="συνέκλεισέ" head="0" id="106302744" lemma="συγκλείω" postag="v3saia---" relation="PRED">
#     </word>
#     <word div_section="1" form="με" head="106302744" id="106302745" lemma="ἐγώ" postag="p-s---ca-" relation="OBJ">
#     </word>
#     <word div_section="1" form="κύριος" head="106302744" id="106302746" lemma="κύριος" postag="n-s---mn-" relation="SBJ">
#     </word>
#     <word div_section="1" form="τοῦ" head="106302749" id="106302747" lemma="ὁ" postag="l-s---ng-" relation="ATR">
#     </word>
#     <word div_section="1" form="μὴ" head="106302749" id="106302748" lemma="μή" postag="d--------" relation="AuxZ">
#     </word>
#     <word div_section="1" form="τίκτειν" head="106302746" id="106302749" lemma="τίκτω" postag="v--pna---" relation="ATR">
#     </word>
#     <word div_section="1" form="," head="0" id="106302750" lemma="," postag="u--------" relation="AuxX">
#     </word>
#     <word div_section="1" form="εἴσελθε" head="106302744" id="106302751" lemma="εἰσέρχομαι" postag="v2sama---" relation="CO">
#     </word>
#     <word div_section="1" form="πρὸς" head="106302751" id="106302752" lemma="πρός" postag="r--------" relation="AuxP">
#     </word>
#     <word div_section="1" form="τὴν" head="106302754" id="106302753" lemma="ὁ" postag="l-s---fa-" relation="ATR">
#     </word>
#     <word div_section="1" form="παιδίσκην" head="106302752" id="106302754" lemma="παιδίσκη" postag="n-s---fa-" relation="OBJ">
#     </word>
#     <word div_section="1" form="μου" head="106302754" id="106302755" lemma="ἐγώ" postag="p-s---cg-" relation="ATR">
#     </word>
#     <word div_section="1" form="," head="0" id="106302756" lemma="," postag="u--------" relation="AuxX">
#     </word>
#     <word div_section="1" form="ἵνα" head="106302751" id="106302757" lemma="ἵνα" postag="c--------" relation="AuxC">
#     </word>
#     <word div_section="1" form="τεκνοποιήσῃς" head="106302757" id="106302758" lemma="τεκνοποιέω" postag="v2sasa---" relation="ADV">
#     </word>
#     <word div_section="1" form="ἐξ" head="106302758" id="106302759" lemma="ἐκ" postag="r--------" relation="AuxP">
#     </word>
#     <word div_section="1" form="αὐτῆς" head="106302759" id="106302760" lemma="αὐτός" postag="p-s---fg-" relation="OBJ">
#     </word>
#     <word div_section="1" form='"' head="0" id="106302761" lemma='"' postag="u--------" relation="AuxG">
#     </word>
#     <word div_section="1" form="." head="0" id="106302762" lemma="." postag="u--------" relation="AuxK">
#     </word>
#    </sentence>
#    <sentence analysis="auto" document_id="0018-016" id="5" struct_id="349282">
#     <word div_section="2" form="τὸ" head="106302765" id="106302763" lemma="ὁ" postag="l-s---nn-" relation="ATR">
#     </word>
#     <word div_section="2" form="Σάρας" head="106302765" id="106302764" lemma="Σάρα" postag="n-s---fg-" relation="ATR">
#     </word>
#     <word div_section="2" form="ὄνομα" head="106302767" id="106302765" lemma="ὄνομα" postag="n-s---nn-" relation="SBJ">
#     </word>
#     <word div_section="2" form="μεταληφθέν" head="106302767" id="106302766" lemma="μεταλαμβάνω" postag="v-sappnn-" relation="PNOM">
#     </word>
#     <word div_section="2" form="ἐστιν" head="0" id="106302767" lemma="εἰμί" postag="v3spia---" relation="PRED">
#     </word>
#     <word div_section="2" form='"' head="0" id="106302768" lemma='"' postag="u--------" relation="AuxG">
#     </word>
#     <word div_section="2" form="ἀρχή" head="1000062441" id="106302769" lemma="ἀρχή" postag="n-s---fn-" relation="PNOM">
#     </word>
#     <word div_section="2" form="μου" head="106302769" id="106302770" lemma="ἐγώ" postag="p-s---cg-" relation="ATR">
#     </word>
#     <word div_section="2" form='"' head="0" id="106302771" lemma='"' postag="u--------" relation="AuxG">
#     </word>
#     <word div_section="2" form="·" head="0" id="106302772" lemma="·" postag="u--------" relation="AuxK">
#     </word>
#     <word artificial="elliptic" div_section="2" form="E" head="106302767" id="1000062441" lemma="E" postag="z--------" relation="CO">
#     </word>
#    </sentence>
#    <sentence analysis="auto" document_id="0018-016" id="6" struct_id="349283">
#     <word div_section="2" form="φρόνησις" head="106302788" id="106302773" lemma="φρόνησις" postag="n-s---fn-" relation="SBJ_CO">
#     </word>
#     <word div_section="2" form="δὲ" head="106302802" id="106302774" lemma="δέ" postag="c--------" relation="AuxY">
#     </word>
#     <word div_section="2" form="ἡ" head="106302773" id="106302775" lemma="ὁ" postag="l-s---fn-" relation="ATR">
#     </word>
#     <word div_section="2" form="ἐν" head="106302773" id="106302776" lemma="ἐν" postag="r--------" relation="AuxP">
#     </word>
#     <word div_section="2" form="ἐμοὶ" head="106302776" id="106302777" lemma="ἐγώ" postag="p-s---cd-" relation="ATR">
#     </word>
#     <word div_section="2" form="καὶ" head="106302788" id="106302778" lemma="καί" postag="c--------" relation="AuxY">
#     </word>
#     <word div_section="2" form="σωφροσύνη" head="106302788" id="106302779" lemma="σωφροσύνη" postag="n-s---fn-" relation="SBJ_CO">
#     </word>
#     <word div_section="2" form="ἡ" head="106302779" id="106302780" lemma="ὁ" postag="l-s---fn-" relation="ATR">
#     </word>
#     <word div_section="2" form="ἐν" head="106302779" id="106302781" lemma="ἐν" postag="r--------" relation="AuxP">
#     </word>
#     <word div_section="2" form="ἐμοὶ" head="106302781" id="106302782" lemma="ἐγώ" postag="p-s---cd-" relation="ATR">
#     </word>
#     <word div_section="2" form="καὶ" head="106302788" id="106302783" lemma="καί" postag="c--------" relation="AuxY">
#     </word>
#     <word div_section="2" form="ἡ" head="106302787" id="106302784" lemma="ὁ" postag="l-s---fn-" relation="ATR">
#     </word>
#     <word div_section="2" form="ἐπὶ" head="106302787" id="106302785" lemma="ἐπί" postag="r--------" relation="AuxP">
#     </word>
#     <word div_section="2" form="μέρους" head="106302785" id="106302786" lemma="μέρος" postag="n-s---ng-" relation="ATR">
#     </word>
#     <word div_section="2" form="δικαιοσύνη" head="106302788" id="106302787" lemma="δικαιοσύνη" postag="n-s---fn-" relation="SBJ_CO">
#     </word>
#     <word div_section="2" form="καὶ" head="106302802" id="106302788" lemma="καί" postag="c--------" relation="COORD">
#     </word>
#     <word div_section="2" form="ἑκάστη" head="106302788" id="106302789" lemma="ἕκαστος" postag="p-s---fn-" relation="SBJ_CO">
#     </word>
#     <word div_section="2" form="τῶν" head="106302792" id="106302790" lemma="ὁ" postag="l-p---fg-" relation="ATR">
#     </word>
#     <word div_section="2" form="ἄλλων" head="106302792" id="106302791" lemma="ἄλλος" postag="p-p---fg-" relation="ATR">
#     </word>
#     <word div_section="2" form="ἀρετῶν" head="106302789" id="106302792" lemma="ἀρετή" postag="n-p---fg-" relation="ATR">
#     </word>
#     <word div_section="2" form="," head="0" id="106302793" lemma="," postag="u--------" relation="AuxX">
#     </word>
#     <word div_section="2" form="ἣν" head="106302798" id="106302794" lemma="ὅς" postag="p-s---fa-" relation="SBJ">
#     </word>
#     <word div_section="2" form="περὶ" head="106302798" id="106302795" lemma="περί" postag="r--------" relation="AuxP">
#     </word>
#     <word div_section="2" form="ἐμὲ" head="106302795" id="106302796" lemma="ἐγώ" postag="p-s---ca-" relation="ADV">
#     </word>
#     <word div_section="2" form="μόνον" head="106302798" id="106302797" lemma="μόνος" postag="a-s---ma-" relation="PNOM">
#     </word>
#     <word div_section="2" form="εἶναι" head="106302799" id="106302798" lemma="εἰμί" postag="v--pna---" relation="SBJ">
#     </word>
#     <word div_section="2" form="συμβέβηκεν" head="106302792" id="106302799" lemma="συμβαίνω" postag="v3sria---" relation="ATR">
#     </word>
#     <word div_section="2" form="," head="0" id="106302800" lemma="," postag="u--------" relation="AuxX">
#     </word>
#     <word div_section="2" form="ἀρχή" head="106302802" id="106302801" lemma="ἀρχή" postag="n-s---fn-" relation="PNOM">
#     </word>
#     <word div_section="2" form="ἐστιν" head="0" id="106302802" lemma="εἰμί" postag="v3spia---" relation="PRED">
#     </word>
#     <word div_section="2" form="ἐμοῦ" head="106302801" id="106302803" lemma="ἐγώ" postag="p-s---cg-" relation="ATR">
#     </word>
#     <word div_section="2" form="μόνου" head="106302803" id="106302804" lemma="μόνος" postag="a-s---mg-" relation="ATR">
#     </word>
#     <word div_section="2" form="·" head="0" id="106302805" lemma="·" postag="u--------" relation="AuxK">
#     </word>
#    </sentence>
#    <sentence analysis="auto" document_id="0018-016" id="7" struct_id="349284">
#     <word div_section="2" form="ἐπιστατεῖ" head="106302809" id="106302806" lemma="ἐπιστατέω" postag="v3spia---" relation="PRED_CO">
#     </word>
#     <word div_section="2" form="γάρ" head="106302809" id="106302807" lemma="γάρ" postag="g--------" relation="AuxY">
#     </word>
#     <word div_section="2" form="μου" head="106302806" id="106302808" lemma="ἐγώ" postag="p-s---cg-" relation="OBJ">
#     </word>
#     <word div_section="2" form="καὶ" head="0" id="106302809" lemma="καί" postag="c--------" relation="COORD">
#     </word>
#     <word div_section="2" form="ἡγεμονεύει" head="106302809" id="106302810" lemma="ἡγεμονεύω" postag="v3spia---" relation="PRED_CO">
#     </word>
#     <word div_section="2" form="πειθαρχεῖν" head="106302810" id="106302811" lemma="πειθαρχέω" postag="v--pna---" relation="OBJ">
#     </word>
#     <word div_section="2" form="ἐγνωκότος" head="106302810" id="106302812" lemma="γιγνώσκω" postag="v-srpamg-" relation="ADV">
#     </word>
#     <word div_section="2" form="," head="0" id="106302813" lemma="," postag="u--------" relation="AuxX">
#     </word>
#     <word div_section="2" form="βασιλὶς" head="106302817" id="106302814" lemma="βασιλίς" postag="n-s---fn-" relation="PNOM">
#     </word>
#     <word div_section="2" form="ἐκ" head="106302817" id="106302815" lemma="ἐκ" postag="r--------" relation="AuxP">
#     </word>
#     <word div_section="2" form="φύσεως" head="106302815" id="106302816" lemma="φύσις" postag="n-s---fg-" relation="ADV">
#     </word>
#     <word div_section="2" form="ὑπάρχουσα" head="106302810" id="106302817" lemma="ὑπάρχω" postag="v-sppafn-" relation="ADV">
#     </word>
#     <word div_section="2" form="." head="0" id="106302818" lemma="." postag="u--------" relation="AuxK">
#     </word>
#    </sentence>
#    <sentence analysis="auto" document_id="0018-016" id="8" struct_id="349285">
#     <word div_section="3" form="ταύτην" head="106302827" id="106302819" lemma="οὗτος" postag="p-s---fa-" relation="OBJ">
#     </word>
#     <word div_section="3" form="Μωυσῆς" head="106302827" id="106302820" lemma="Μωϋσῆς" postag="n-s---mn-" relation="SBJ">
#     </word>
#     <word div_section="3" form="," head="0" id="106302821" lemma="," postag="u--------" relation="AuxX">
#     </word>
#     <word div_section="3" form="τὸ" head="106302823" id="106302822" lemma="ὁ" postag="l-s---nn-" relation="ATR">
#     </word>
#     <word div_section="3" form="παραδοξότατον" head="106302827" id="106302823" lemma="παράδοξος" postag="a-s---nas" relation="OBJ">
#     </word>
#     <word div_section="3" form="," head="0" id="106302824" lemma="," postag="u--------" relation="AuxX">
#     </word>
#     <word div_section="3" form="καὶ" head="106302828" id="106302825" lemma="καί" postag="c--------" relation="AuxY">
#     </word>
#     <word div_section="3" form="στεῖραν" head="106302828" id="106302826" lemma="στεῖρα" postag="n-s---fa-" relation="OBJ_CO">
#     </word>
#     <word div_section="3" form="ἀποφαίνει" head="0" id="106302827" lemma="ἀποφαίνω" postag="v3spia---" relation="PRED">
#     </word>
#     <word div_section="3" form="καὶ" head="106302827" id="106302828" lemma="καί" postag="c--------" relation="COORD">
#     </word>
#     <word div_section="3" form="πολυγονωτάτην" head="106302828" id="106302829" lemma="πολύγονος" postag="a-s---fas" relation="OBJ_CO">
#     </word>
#     <word div_section="3" form="," head="0" id="106302830" lemma="," postag="u--------" relation="AuxX">
#     </word>
#     <word div_section="3" form="εἴ" head="106302827" id="106302831" lemma="εἰ" postag="c--------" relation="AuxC">
#     </word>
#     <word div_section="3" form="γε" head="106302839" id="106302832" lemma="γε" postag="g--------" relation="AuxZ">
#     </word>
#     <word div_section="3" form="τὸ" head="106302834" id="106302833" lemma="ὁ" postag="l-s---na-" relation="ATR">
#     </word>
#     <word div_section="3" form="πολυανθρωπότατον" head="106302840" id="106302834" lemma="πολυάνθρωπος" postag="a-s---nas" relation="SBJ">
#     </word>
#     <word div_section="3" form="τῶν" head="106302836" id="106302835" lemma="ὁ" postag="l-p---ng-" relation="ATR">
#     </word>
#     <word div_section="3" form="ἐθνῶν" head="106302834" id="106302836" lemma="ἔθνος" postag="n-p---ng-" relation="ATR">
#     </word>
#     <word div_section="3" form="ἐξ" head="106302840" id="106302837" lemma="ἐκ" postag="r--------" relation="AuxP">
#     </word>
#     <word div_section="3" form="αὐτῆς" head="106302837" id="106302838" lemma="αὐτός" postag="p-s---fg-" relation="ADV">
#     </word>
#     <word div_section="3" form="ὁμολογεῖ" head="106302831" id="106302839" lemma="ὁμολογέω" postag="v3spia---" relation="ADV">
#     </word>
#     <word div_section="3" form="γενέσθαι" head="106302839" id="106302840" lemma="γίγνομαι" postag="v--anm---" relation="OBJ">
#     </word>
#     <word div_section="3" form="." head="0" id="106302841" lemma="." postag="u--------" relation="AuxK">
#     </word>
#    </sentence>
#    <sentence analysis="auto" document_id="0018-016" id="9" struct_id="349286">
#     <word div_section="3" form="τῷ" head="106302844" id="106302842" lemma="ὁ" postag="l-s---nd-" relation="ATR">
#     </word>
#     <word div_section="3" form="γὰρ" head="106302855" id="106302843" lemma="γάρ" postag="g--------" relation="AuxY">
#     </word>
#     <word div_section="3" form="ὄντι" head="106302852" id="106302844" lemma="εἰμί" postag="v-sppand-" relation="ADV">
#     </word>
#     <word div_section="3" form="ἡ" head="106302846" id="106302845" lemma="ὁ" postag="l-s---fn-" relation="ATR">
#     </word>
#     <word div_section="3" form="ἀρετὴ" head="106302855" id="106302846" lemma="ἀρετή" postag="n-s---fn-" relation="SBJ">
#     </word>
#     <word div_section="3" form="πρὸς" head="106302852" id="106302847" lemma="πρός" postag="r--------" relation="AuxP">
#     </word>
#     <word div_section="3" form="μὲν" head="106302855" id="106302848" lemma="μέν" postag="g--------" relation="AuxY">
#     </word>
#     <word div_section="3" form="τὰ" head="106302850" id="106302849" lemma="ὁ" postag="l-p---na-" relation="ATR">
#     </word>
#     <word div_section="3" form="φαῦλα" head="106302847" id="106302850" lemma="φαῦλος" postag="a-p---na-" relation="ADV">
#     </word>
#     <word div_section="3" form="πάντα" head="106302850" id="106302851" lemma="πᾶς" postag="p-p---na-" relation="ATR">
#     </word>
#     <word div_section="3" form="ἐστείρωται" head="106302855" id="106302852" lemma="στειρόω" postag="v3srim---" relation="PRED_CO">
#     </word>
#     <word div_section="3" form="," head="0" id="106302853" lemma="," postag="u--------" relation="AuxX">
#     </word>
#     <word div_section="3" form="τῶν" head="106302856" id="106302854" lemma="ὁ" postag="l-p---ng-" relation="ATR">
#     </word>
#     <word div_section="3" form="δὲ" head="0" id="106302855" lemma="δέ" postag="c--------" relation="COORD">
#     </word>
#     <word div_section="3" form="ἀγαθῶν" head="106302857" id="106302856" lemma="ἀγαθός" postag="a-p---ng-" relation="ATR">
#     </word>
#     <word div_section="3" form="εὐτοκίᾳ" head="106302858" id="106302857" lemma="εὐτοκία" postag="n-s---fd-" relation="OBJ">
#     </word>
#     <word div_section="3" form="χρῆται" head="106302855" id="106302858" lemma="χράω" postag="v3spim---" relation="PRED_CO">
#     </word>
#     <word div_section="3" form="τοι

# %%
#glaux_metadata = pd.read_csv("../../glaux/metadata.txt", sep="\t")
#glaux_metadata.head(5)

# %% [markdown]
# ### Extract Glaux sentence level data

# %%
target_path = os.path.join(greek_data_dir, "glaux_sentences_2025-08/")
try:
    os.mkdir(target_path)
except:
    pass

# %%
os.listdir(target_path)
# Out:
# []

# %%
# Normalize a string to a specified Unicode form
def norm(text):
    return unicodedata.normalize('NFC', text)

# %%
def from_filename_to_sentence_data(fn):
    with open(source_dir + fn, "r") as f:
        soup = BeautifulSoup(f.read(), "xml")
    sentences_data = []
    tlg_doc_id = re.sub(r'(\d{4})-(\d{3})\w?\.xml', r'tlg\1.tlg\2', fn)
    for sent_n, sent in enumerate(soup.find_all("sentence")):
        sentence = ""
        sent_data = []
        start_index = 0
        for n, w in enumerate(sent.find_all("word")):
            token = norm(w["form"])
            ref = {}
            for attr in ["div_book", "div_section", "line", "stephanus_page", "div_fragment", "div_jebb_page", "div_ed2page", "div_bekker_page"]:
                try:
                    ref[attr] = w[attr]
                except KeyError:
                    pass

            if n == 0 or w.get("relation") in ["AuxX", "AuxK", "PUNCT"]:
                start_index = len(sentence)
                sentence += token
            else:
                start_index = len(sentence) + 1
                sentence += " " + token

            end_index = start_index + len(token)

            try:
                sent_data.append((token, norm(w["lemma"]), w["postag"][0], start_index, end_index))
            except (KeyError, IndexError):
                sent_data.append((token, token, None, start_index, end_index))
            if w.get("relation") == "AuxK":
                break
        sentences_data.append((tlg_doc_id, sent_n, sentence, sent_data))
    target_fn = tlg_doc_id + ".pickle"
    with open(target_path + target_fn, "wb") as f:
        pickle.dump(sentences_data, f)

# %%
# %%time
for fn in glaux_filenames:
    from_filename_to_sentence_data(fn)

# %%
# ok, this approach does not work for all the files....
files_to_merge = [fn for fn in os.listdir(target_path) if "xml" in fn]
files_to_merge[:10]
# Out:
# ['0627-024b.xml.pickle',
#  '0007-082a.xml.pickle',
#  '0007-052b.xml.pickle',
#  '0007-052a.xml.pickle',
#  '0541-042c.xml.pickle',
#  '0007-084b.xml.pickle',
#  '4150-001a.xml.pickle',
#  '0541-042a.xml.pickle',
#  '0632-002d.xml.pickle',
#  '0007-082b.xml.pickle']

# %%
# let's rename and merge these files now.
file_groups = defaultdict(list)
pattern = re.compile(r'(\d{4})-(\d{3})[a-z]')

for fn in files_to_merge:
    match = pattern.match(fn)
    if match:
        doc_id = f'tlg{match.group(1)}.tlg{match.group(2)}'
        file_groups[doc_id].append(fn)

# Step 3: Iterate over groups and merge files
for doc_id, files in file_groups.items():
    files.sort()
    merged_list = []
    for fn in files:
        file_path = os.path.join(target_path, fn)
        with open(file_path, "rb") as f:
            data = pickle.load(f)
            merged_list.extend(data)

    # Step 4: Save the merged list
    target_fn = os.path.join(target_path, doc_id + ".pickle")
    with open(target_fn, "wb") as f:
        pickle.dump(merged_list, f)

# %%
for fn in files_to_merge:
    os.remove(os.path.join(target_path, fn))

# %% [markdown]
# ### BACKUP: Add current glaux data to LAGT

# %%
os.listdir(target_path)[:10]
# Out:
# ['tlg0007.tlg121.pickle',
#  'tlg0527.tlg020.pickle',
#  'tlg0540.tlg019.pickle',
#  'tlg0026.tlg004.pickle',
#  'tlg0018.tlg020.pickle',
#  'tlg0540.tlg015.pickle',
#  'tlg2042.tlg086.pickle',
#  'tlg0057.tlg078.pickle',
#  'tlg0062.tlg023.pickle',
#  'tlg0284.tlg001.pickle']

# %%
# open a test file to explore its structure
file_path = target_path + "tlg0007.tlg121.pickle"
with open(file_path, "rb") as f:
    sentences_data = pickle.load(f)
sentences_data[:5]
# Out:
# [('0007-121',
#   0,
#   'Ἀντιφῶν Σοφίλου μὲν ἦν πατρὸς τῶν δὲ δήμων Ῥαμνούσιος·',
#   [('Ἀντιφῶν', 'Ἀντιφῶν', 'n', (0, 7)),
#    ('Σοφίλου', 'Σόφιλος', 'n', (8, 15)),
#    ('μὲν', 'μέν', 'g', (16, 19)),
#    ('ἦν', 'εἰμί', 'v', (20, 22)),
#    ('πατρὸς', 'πατήρ', 'n', (23, 29)),
#    ('τῶν', 'ὁ', 'l', (30, 33)),
#    ('δὲ', 'δέ', 'c', (34, 36)),
#    ('δήμων', 'δῆμος', 'n', (37, 42)),
#    ('Ῥαμνούσιος', 'Ῥαμνούσιος', 'a', (43, 53)),
#    ('·', '·', 'u', (53, 54))]),
#  ('0007-121',
#   1,
#   'μαθητεύσας δὲ τῷ πατρὶ ( ἦν γὰρ σοφιστής, † ὧ καὶ Ἀλκιβιάδης † παρ’ αὐτὸν ἔτι παῖδα ὄντα φοιτῆσαι ) καὶ δύναμιν λόγων κτησάμενος, ὥς τινες νομίζουσιν, ἀπ’ οἰκείας φύσεως, παρέπεμψε μὲν πολιτεύεσθαι, διατριβὴν δὲ συνέστησε καὶ Σωκράτει τῷ φιλοσόφῳ διεφέρετο τὴν ὑπὲρ τῶν λόγων διαφορὰν οὐ φιλονείκως ἀλλ’ ἐλεγκτικῶς, ὡς Ξενοφῶν ἱστόρηκεν ἐν τοῖς Ἀπομνημονεύμασι. E',
#   [('μαθητεύσας', 'μαθητεύω', 'v', (0, 10)),
#    ('δὲ', 'δέ', 'c', (11, 13)),
#    ('τῷ', 'ὁ', 'l', (14, 16)),
#    ('πατρὶ', 'πατήρ', 'n', (17, 22)),
#    ('(', '(', 'u', (23, 24)),
#    ('ἦν', 'εἰμί', 'v', (25, 27)),
#    ('γὰρ', 'γάρ', 'g', (28, 31)),
#    ('σοφιστής', 'σοφιστής', 'n', (32, 40)),
#    (',', ',', 'u', (40, 41)),
#    ('†', '†', 'u', (42, 43)),
#    ('ὧ', 'ὧ', 'd', (44, 45)),
#    ('καὶ', 'καί', 'c', (46, 49)),
#    ('Ἀλκιβιάδης', 'Ἀλκιβιάδης', 'n', (50, 60)),
#    ('†', '†', 'u', (61, 62)),
#    ('παρ’', 'παρά', 'r', (63, 67)),
#    ('αὐτὸν', 'αὐτός', 'p', (68, 73)),
#    ('ἔτι', 'ἔτι', 'd', (74, 77)),
#    ('παῖδα', 'παῖς', 'n', (78, 83)),
#    ('ὄντα', 'εἰμί', 'v', (84, 88)),
#    ('φοιτῆσαι', 'φοιτάω', 'v', (89, 97)),
#    (')', ')', 'u', (98, 99)),
#    ('καὶ', 'καί', 'c', (100, 103)),
#    ('δύναμιν', 'δύναμις', 'n', (104, 111)),
#    ('λόγων', 'λόγος', 'n', (112, 117)),
#    ('κτησάμενος', 'κτάομαι', 'v', (118, 128)),
#    (',', ',', 'u', (128, 129)),
#    ('ὥς', 'ὡς', 'c', (130, 132)),
#    ('τινες', 'τις', 'p', (133, 138)),
#    ('νομίζουσιν', 'νομίζω', 'v', (139, 149)),
#    (',', ',', 'u', (149, 150)),
#    ('ἀπ’', 'ἀπό', 'r', (151, 154)),
#    ('οἰκείας', 'οἰκεῖος', 'a', (155, 162)),
#    ('φύσεως', 'φύσις', 'n', (163, 169)),
#    (',', ',', 'u', (169, 170)),
#    ('παρέπεμψε', 'παραπέμπω', 'v', (171, 180)),
#    ('μὲν', 'μέν', 'g', (181, 184)),
#    ('πολιτεύεσθαι', 'πολιτεύω', 'v', (185, 197)),
#    (',', ',', 'u', (197, 198)),
#    ('διατριβὴν', 'διατριβή', 'n', (199, 208)),
#    ('δὲ', 'δέ', 'c', (209, 211)),
#    ('συνέστησε', 'συνίστημι', 'v', (212, 221)),
#    ('καὶ', 'καί', 'c', (222, 225)),
#    ('Σωκράτει', 'Σωκράτης', 'n', (226, 234)),
#    ('τῷ', 'ὁ', 'l', (235, 237)),
#    ('φιλοσόφῳ', 'φιλόσοφος', 'n', (238, 246)),
#    ('διεφέρετο', 'διαφέρω', 'v', (247, 256)),
#    ('τὴν', 'ὁ', 'l', (257, 260)),
#    ('ὑπὲρ', 'ὑπέρ', 'r', (261, 265)),
#    ('τῶν', 'ὁ', 'l', (266, 269)),
#    ('λόγων', 'λόγος', 'n', (270, 275)),
#    ('διαφορὰν', 'διαφορά', 'n', (276, 284)),
#    ('οὐ', 'οὐ', 'd', (285, 287)),
#    ('φιλονείκως', 'φιλόνεικος', 'd', (288, 298)),
#    ('ἀλλ’', 'ἀλλά', 'c', (299, 303)),
#    ('ἐλεγκτικῶς', 'ἐλεγκτικός', 'd', (304, 314)),
#    (',', ',', 'u', (314, 315)),
#    ('ὡς', 'ὡς', 'c', (316, 318)),
#    ('Ξενοφῶν', 'Ξενοφῶν', 'n', (319, 326)),
#    ('ἱστόρηκεν', 'ἱστορέω', 'v', (327, 336)),
#    ('ἐν', 'ἐν', 'r', (337, 339)),
#    ('τοῖς', 'ὁ', 'l', (340, 344)),
#    ('Ἀπομνημονεύμασι', 'Ἀπομνημόνευμα', 'n', (345, 360)),
#    ('.', '.', 'u', (360, 361)),
#    ('E', 'E', 'z', (362, 363))]),
#  ('0007-121',
#   2,
#   'καί τινας λόγους τοῖς δεομένοις τῶν πολιτῶν συνέγραφεν εἰς τοὺς ἐν τοῖς δικαστηρίοις ἀγῶνας πρῶτος ἐπὶ τοῦτο τραπείς, ὥσπερ τινές φασι·',
#   [('καί', 'καί', 'c', (0, 3)),
#    ('τινας', 'τις', 'p', (4, 9)),
#    ('λόγους', 'λόγος', 'n', (10, 16)),
#    ('τοῖς', 'ὁ', 'l', (17, 21)),
#    ('δεομένοις', 'δέω', 'v', (22, 31)),
#    ('τῶν', 'ὁ', 'l', (32, 35)),
#    ('πολιτῶν', 'πολίτης', 'n', (36, 43)),
#    ('συνέγραφεν', 'συγγράφω', 'v', (44, 54)),
#    ('εἰς', 'εἰς', 'r', (55, 58)),
#    ('τοὺς', 'ὁ', 'l', (59, 63)),
#    ('ἐν', 'ἐν', 'r', (64, 66)),
#    ('τοῖς', 'ὁ', 'l', (67, 71)),
#    ('δικαστηρίοις', 'δικαστήριον', 'n', (72, 84)),
#    ('ἀγῶνας', 'ἀγών', 'n', (85, 91)),
#    ('πρῶτος', 'πρῶτος', 'a', (92, 98)),
#    ('ἐπὶ', 'ἐπί', 'r', (99, 102)),
#    ('τοῦτο', 'οὗτος', 'p', (103, 108)),
#    ('τραπείς', 'τρέπω', 'v', (109, 116)),
#    (',', ',', 'u', (116, 117)),
#    ('ὥσπερ', 'ὥσπερ', 'c', (118, 123)),
#    ('τινές', 'τις', 'p', (124, 129)),
#    ('φασι', 'φημί', 'v', (130, 134)),
#    ('·', '·', 'u', (134, 135))]),
#  ('0007-121',
#   3,
#   'τῶν γοῦν πρὸ αὐτοῦ γενομένων οὐδενὸς φέρεται δικανικὸς λόγος, ἀλλ’ οὐ -δὲ τῶν κατ’ αὐτόν, διὰ τὸ μηδέπω ἐν ἔθει τοῦ συγγράφειν εἶναι, οὐ Θεμιστοκλέους οὐκ Ἀριστείδου οὐ Περικλέους, καίτοι πολλὰς ἀφορμὰς καὶ ἀνάγκας παρασχόντων αὐτοῖς τῶν καιρῶν·',
#   [('τῶν', 'ὁ', 'l', (0, 3)),
#    ('γοῦν', 'γοῦν', 'g', (4, 8)),
#    ('πρὸ', 'πρό', 'r', (9, 12)),
#    ('αὐτοῦ', 'αὐτός', 'p', (13, 18)),
#    ('γενομένων', 'γίγνομαι', 'v', (19, 28)),
#    ('οὐδενὸς', 'οὐδείς', 'p', (29, 36)),
#    ('φέρεται', 'φέρω', 'v', (37, 44)),
#    ('δικανικὸς', 'δικανικός', 'a', (45, 54)),
#    ('λόγος', 'λόγος', 'n', (55, 60)),
#    (',', ',', 'u', (60, 61)),
#    ('ἀλλ’', 'ἀλλά', 'c', (62, 66)),
#    ('οὐ', 'οὐ', 'd', (67, 69)),
#    ('-δὲ', 'δέ', 'c', (70, 73)),
#    ('τῶν', 'ὁ', 'l', (74, 77)),
#    ('κατ’', 'κατά', 'r', (78, 82)),
#    ('αὐτόν', 'αὐτός', 'p', (83, 88)),
#    (',', ',', 'u', (88, 89)),
#    ('διὰ', 'διά', 'r', (90, 93)),
#    ('τὸ', 'ὁ', 'l', (94, 96)),
#    ('μηδέπω', 'μηδέπω', 'd', (97, 103)),
#    ('ἐν', 'ἐν', 'r', (104, 106)),
#    ('ἔθει', 'ἔθος', 'n', (107, 111)),
#    ('τοῦ', 'ὁ', 'l', (112, 115)),
#    ('συγγράφειν', 'συγγράφω', 'v', (116, 126)),
#    ('εἶναι', 'εἰμί', 'v', (127, 132)),
#    (',', ',', 'u', (132, 133)),
#    ('οὐ', 'οὐ', 'd', (134, 136)),
#    ('Θεμιστοκλέους', 'Θεμιστοκλῆς', 'n', (137, 150)),
#    ('οὐκ', 'οὐ', 'd', (151, 154)),
#    ('Ἀριστείδου', 'Ἀριστείδης', 'n', (155, 165)),
#    ('οὐ', 'οὐ', 'd', (166, 168)),
#    ('Περικλέους', 'Περικλῆς', 'n', (169, 179)),
#    (',', ',', 'u', (179, 180)),
#    ('καίτοι', 'καίτοι', 'g', (181, 187)),
#    ('πολλὰς', 'πολύς', 'a', (188, 194)),
#    ('ἀφορμὰς', 'ἀφορμή', 'n', (195, 202)),
#    ('καὶ', 'καί', 'c', (203, 206)),
#    ('ἀνάγκας', 'ἀνάγκη', 'n', (207, 214)),
#    ('παρασχόντων', 'παρέχω', 'v', (215, 226)),
#    ('αὐτοῖς', 'αὐτός', 'p', (227, 233)),
#    ('τῶν', 'ὁ', 'l', (234, 237)),
#    ('καιρῶν', 'καιρός', 'n', (238, 244)),
#    ('·', '·', 'u', (244, 245))]),
#  ('0007-121',
#   4,
#   'καὶ γὰρ οὐ δι’ ἀσθένειαν ἀπελείποντο τοῦ συγγράφειν, ὡς δῆλον ἐκ τῶν εἰρημένων παρὰ τοῖς συγγραφεῦσι περὶ ἑνὸς ἑκάστου τῶν προειρημένων ἀνδρῶν. E',
#   [('καὶ', 'καί', 'c', (0, 3)),
#    ('γὰρ', 'γάρ', 'g', (4, 7)),
#    ('οὐ', 'οὐ', 'd', (8, 10)),
#    ('δι’', 'διά', 'r', (11, 14)),
#    ('ἀσθένειαν', 'ἀσθένεια', 'n', (15, 24)),
#    ('ἀπελείποντο', 'ἀπολείπω', 'v', (25, 36)),
#    ('τοῦ', 'ὁ', 'l', (37, 40)),
#    ('συγγράφειν', 'συγγράφω', 'v', (41, 51)),
#    (',', ',', 'u', (51, 52)),
#    ('ὡς', 'ὡς', 'c', (53, 55)),
#    ('δῆλον', 'δῆλος', 'a', (56, 61)),
#    ('ἐκ', 'ἐκ', 'r', (62, 64)),
#    ('τῶν', 'ὁ', 'l', (65, 68)),
#    ('εἰρημένων', 'λέγω', 'v', (69, 78)),
#    ('παρὰ', 'παρά', 'r', (79, 83)),
#    ('τοῖς', 'ὁ', 'l', (84, 88)),
#    ('συγγραφεῦσι', 'συγγραφεύς', 'n', (89, 100)),
#    ('περὶ', 'περί', 'r', (101, 105)),
#    ('ἑνὸς', 'εἷς', 'm', (106, 110)),
#    ('ἑκάστου', 'ἕκαστος', 'p', (111, 118)),
#    ('τῶν', 'ὁ', 'l', (119, 122)),
#    ('προειρημένων', 'προλέγω', 'v', (123, 135)),
#    ('ἀνδρῶν', 'ἀνήρ', 'n', (136, 142)),
#    ('.', '.', 'u', (142, 143)),
#    ('E', 'E', 'z', (144, 145))])]

# %%
lemmatized_sentences = [[t[1] for t in sent[3] if t[2] in ["n", "a", "v", "NOUN", "PROPN", "ADJ", "VERB"]] for sent in sentences_data]
lemmatized_sentences
# Out:
# [['Ἀντιφῶν', 'Σόφιλος', 'εἰμί', 'πατήρ', 'δῆμος', 'Ῥαμνούσιος'],
#  ['μαθητεύω',
#   'πατήρ',
#   'εἰμί',
#   'σοφιστής',
#   'Ἀλκιβιάδης',
#   'παῖς',
#   'εἰμί',
#   'φοιτάω',
#   'δύναμις',
#   'λόγος',
#   'κτάομαι',
#   'νομίζω',
#   'οἰκεῖος',
#   'φύσις',
#   'παραπέμπω',
#   'πολιτεύω',
#   'διατριβή',
#   'συνίστημι',
#   'Σωκράτης',
#   'φιλόσοφος',
#   'διαφέρω',
#   'λόγος',
#   'διαφορά',
#   'Ξενοφῶν',
#   'ἱστορέω',
#   'Ἀπομνημόνευμα'],
#  ['λόγος',
#   'δέω',
#   'πολίτης',
#   'συγγράφω',
#   'δικαστήριον',
#   'ἀγών',
#   'πρῶτος',
#   'τρέπω',
#   'φημί'],
#  ['γίγνομαι',
#   'φέρω',
#   'δικανικός',
#   'λόγος',
#   'ἔθος',
#   'συγγράφω',
#   'εἰμί',
#   'Θεμιστοκλῆς',
#   'Ἀριστείδης',
#   'Περικλῆς',
#   'πολύς',
#   'ἀφορμή',
#   'ἀνάγκη',
#   'παρέχω',
#   'καιρός'],
#  ['ἀσθένεια',
#   'ἀπολείπω',
#   'συγγράφω',
#   'δῆλος',
#   'λέγω',
#   'συγγραφεύς',
#   'προλέγω',
#   'ἀνήρ'],
#  ['ἔχω',
#   'παλαιός',
#   'ἀναφέρω',
#   'ἀπομνημονεύω',
#   'ἰδέα',
#   'λόγος',
#   'μεταχειρίζω',
#   'εὑρίσκω',
#   'ἐπιβάλλω',
#   'Ἀντιφών',
#   'πρεσβύτης',
#   'εἰμί',
#   'Ἀλκιβιάδης',
#   'Κριτίας',
#   'Λυσίας',
#   'Ἀρχῖνος'],
#  ['πρῶτος', 'ῥητορικός', 'τέχνη', 'ἐκφέρω', 'γίγνομαι', 'ἀγχίνοος'],
#  ['Νέστωρ', 'ἐπικαλέω'],
#  ['Καικίλιος',
#   'σύνταγμα',
#   'Θουκυδίδης',
#   'συγγραφεύς',
#   'καθηγητής',
#   'τεκμαίρομαι',
#   'γίγνομαι',
#   'ἐπαινέω',
#   'Ἀντιφῶν'],
#  ['εἰμί',
#   'λόγος',
#   'ἀκριβής',
#   'πιθανός',
#   'δεινός',
#   'εὕρεσις',
#   'ἄπορος',
#   'τεχνικός',
#   'ἐπιχειρέω',
#   'ἄδηλος',
#   'νόμος',
#   'πάθος',
#   'τρέπω',
#   'λόγος',
#   'εὐπρεπής',
#   'στοχάζομαι'],
#  ['γίγνομαι', 'Περσικός', 'Γοργίας', 'σοφιστής', 'ὀλίγος', 'εἰμί', 'νέος'],
#  ['παρατείνω',
#   'κατάλυσις',
#   'δημοκρατία',
#   'γίγνομαι',
#   'δοκέω',
#   'συγκατασκευάζω',
#   'τριηραρχέω',
#   'ναῦς',
#   'στρατηγέω',
#   'πολύς',
#   'μάχη',
#   'νικάω',
#   'συμμαχία',
#   'μέγας',
#   'προσάγω',
#   'ἀκμάζω',
#   'ὁπλίζω',
#   'τριήρης',
#   'πληρόω',
#   'πρεσβεύω',
#   'Λακεδαίμων',
#   'τειχίζω',
#   'Ἠετιώνεια'],
#  ['κατάλυσις',
#   'εἰσαγγέλλω',
#   'Ἀρχεπτόλεμος',
#   'ἁλίσκομαι',
#   'προδότης',
#   'ἐπιτίμιον',
#   'ὑπάγω',
#   'ἄταφος',
#   'ῥίπτω',
#   'ἔκγονος',
#   'ἄτιμος',
#   'ἐγγράφω'],
#  ['ἀναιρέω', 'ἱστορέω', 'Λυσίας', 'Ἀντιφῶν', 'θυγάτηρ', 'λόγος'],
#  ['γίγνομαι', 'θυγάτριον', 'Κάλλαισχρος', 'ἐπιδικάζω'],
#  ['ἀποθνῄσκω', 'ἱστορέω', 'Θεόπομπος', 'πεντεκαιδέκατος', 'Φιλιππικός'],
#  ['εἰμί',
#   'Λυσιδωνίδης',
#   'πατήρ',
#   'Κρατῖνος',
#   'Πυτίνη',
#   'πονηρός',
#   'μνημονεύω'],
#  ['προθνῄσκω', 'ἀναιρέω', 'εἰμί'],
#  ['εἰμί', 'λόγος', 'τελευτή'],
#  ['πρεσβευτής',
#   'εἰμί',
#   'Συράκουσαι',
#   'πλέω',
#   'ἀκμάζω',
#   'πρότερος',
#   'Διονύσιος',
#   'τυραννίς'],
#  ['γίγνομαι',
#   'πότος',
#   'ζήτησις',
#   'ἀγαθός',
#   'εἰμί',
#   'χαλκός',
#   'πολύς',
#   'διαφέρω',
#   'λέγω',
#   'ἀγαθός',
#   'εἰμί',
#   'Ἁρμόδιος',
#   'Ἀριστογείτων',
#   'ποιέω'],
#  ['ἀκούω',
#   'Διονύσιος',
#   'ὑπονοέω',
#   'προτροπή',
#   'ἐπίθεσις',
#   'εἰμί',
#   'λέγω',
#   'προστάσσω',
#   'ἀναιρέω'],
#  ['τραγῳδία', 'διασύρω', 'χαλεπαίνω'],
#  ['φέρω', 'ῥήτωρ', 'λόγος', 'καταψεύδομαι', 'φημί', 'Καικίλιος', 'εἰμί'],
#  ['κωμῳδέω', 'φιλαργυρία', 'Πλάτων', 'Πείσανδρος'],
#  ['λέγω', 'τραγῳδία', 'συντίθημι', 'ἴδιος', 'Διονύσιος', 'τύραννος'],
#  ['εἰμί',
#   'ποίησις',
#   'τέχνη',
#   'ἀλυπία',
#   'συνίστημι',
#   'νοσέω',
#   'ἰατρός',
#   'θεραπεία',
#   'ὑπάρχω'],
#  ['Κόρινθος',
#   'κατασκευάζω',
#   'οἴκημα',
#   'ἀγορά',
#   'προγράφω',
#   'δύναμαι',
#   'λυπέω',
#   'λόγος',
#   'θεραπεύω'],
#  ['πυνθάνομαι', 'αἰτία', 'παραμυθέομαι', 'κάμνω'],
#  ['νομίζω', 'τέχνη', 'ἐλαχύς', 'εἰμί', 'ῥητορική', 'ἀποτρέπω'],
#  ['εἰμί', 'Γλαῦκος', 'Ῥήγιον', 'ποιητής', 'βιβλίον', 'Ἀντιφῶν', 'ἀναφέρω'],
#  ['ἐπαινέω',
#   'Ἡρώδης',
#   'Ἐρασίστρατος',
#   'ταώς',
#   'εἰσαγγελία',
#   'γράφω',
#   'Δημοσθένης',
#   'στρατηγός',
#   'παράνομος'],
#  ['γράφω', 'Ἱπποκράτης', 'ἰατρός', 'στρατηγός', 'λόγος', 'αἱρέω', 'ἐρῆμος'],
#  ['ψήφισμα',
#   'Θεόπομπος',
#   'ἄρχων',
#   'καταλύω',
#   'Ψήφισμα',
#   'δοκέω',
#   'Ἀντιφῶν',
#   'κρίνω',
#   'Καικίλιος',
#   'παρατίθημι'],
#  ['δοκέω', 'βουλή', 'εἰκοστός', 'πρυτανεία'],
#  ['Δημόνικος', 'γραμματεύω'],
#  ['Φιλόστρατος', 'Παλληνεύς', 'ἐπιστατέω'],
#  ['ἀναδράω', 'λέγω'],
#  ['ἀνήρ',
#   'ἀποφαίνω',
#   'στρατηγός',
#   'πρεσβεύω',
#   'Λακεδαίμων',
#   'κακός',
#   'πόλις',
#   'Ἀθηναῖος',
#   'στρατόπεδον',
#   'πλέω',
#   'πολέμιος',
#   'ναῦς',
#   'πεζεύω',
#   'Δεκέλεια',
#   'Ἀρχεπτόλεμος',
#   'Ὀνομακλῆς',
#   'Ἀντιφῶν',
#   'συλλαμβάνω',
#   'ἀποδίδωμι',
#   'δικαστήριον',
#   'δίδωμι',
#   'δίκη'],
#  ['παρέχω',
#   'στρατηγός',
#   'βουλή',
#   'δοκέω',
#   'στρατηγός',
#   'προσαιρέομαι',
#   'πάρειμι',
#   'γίγνομαι',
#   'κρίσις'],
#  ['προσκαλέω',
#   'θεσμοθέτης',
#   'ἡμέρα',
#   'εἰσάγω',
#   'κλῆσις',
#   'ἐξήκω',
#   'δικαστήριον',
#   'προδοσία',
#   'κατηγορέω',
#   'αἱρέω',
#   'συνήγορος',
#   'στρατηγός',
#   'βούλομαι'],
#  ['καταψηφίζομαι', 'δικαστήριον', 'ποιέω', 'νόμος', 'κεῖμαι', 'προδίδωμι'],
#  ['ὑπογράφω', 'δόγμα', 'καταδίκη'],
#  ['προδοσία',
#   'ὀφλισκάνω',
#   'Ἀρχεπτόλεμος',
#   'Ἱππόδαμος',
#   'πάρειμι',
#   'Ἀντιφῶν',
#   'Σόφιλος',
#   'Ῥαμνούσιος',
#   'πάρειμι'],
#  ['τιμάω',
#   'παραδίδωμι',
#   'χρῆμα',
#   'δημόσιος',
#   'εἰμί',
#   'θεός',
#   'ἐπιδέκατος',
#   'οἰκίον',
#   'κατασκάπτω',
#   'ὅρος',
#   'τίθημι',
#   'οἰκόπεδον',
#   'ἐπιγράφω',
#   'Ἀρχεπτόλεμος',
#   'Ἀντιφῶν',
#   'προδότης'],
#  ['δήμαρχος',
#   'ἀποφαίνω',
#   'οὐσία',
#   'ἔξεστι',
#   'θάπτω',
#   'Ἀρχεπτόλεμος',
#   'Ἀντιφῶν',
#   'Ἀθηναῖος',
#   'κρατέω'],
#  ['ἄτιμος', 'εἰμί', 'Ἀρχεπτόλεμος', 'Ἀντιφῶν', 'γένος', 'νόθος', 'γνήσιος'],
#  ['ποιέω', 'Ἀρχεπτόλεμος', 'Ἀντιφῶν', 'ἄτιμος', 'εἰμί', 'ποιέω'],
#  ['γράφω', 'στήλη', 'χάλκεος'],
#  ['ἀνάκειμαι', 'ψήφισμα', 'Φρύνιχος', 'τίθημι'],
#  ['Ἀνδοκίδης',
#   'Λεώγορος',
#   'εἰμί',
#   'πατήρ',
#   'Ἀνδοκίδης',
#   'τίθημι',
#   'Λακεδαιμόνιος',
#   'εἰρήνη',
#   'Ἀθηναῖος',
#   'δῆμος',
#   'Κυδαθήναιος',
#   'Θορεύς',
#   'γένος',
#   'εὐπατριδοῦς',
#   'Ἑλλάνικος',
#   'Ἑρμῆς'],
#  ['καθήκω', 'κῆρυξ', 'γένος'],
#  ['προχειρίζω',
#   'Γλαύκων',
#   'ναῦς',
#   'Κερκυραῖος',
#   'βοηθέω',
#   'διαφέρω',
#   'Κορίνθιος'],
#  ['αἰτιάομαι',
#   'ἀσεβέω',
#   'Ἑρμῆς',
#   'περικόπτω',
#   'Δημήτηρ',
#   'ἁμαρτάνω',
#   'μυστήριον',
#   'ἀκόλαστος',
#   'εἰμί',
#   'κωμάζω',
#   'θραύω',
#   'ἄγαλμα',
#   'θεός',
#   'εἰσαγγέλλω',
#   'βούλομαι',
#   'ζητέω',
#   'κατήγορος',
#   'δοῦλος',
#   'ἐκδίδωμι',
#   'διαβάλλω',
#   'αἰτία',
#   'δεύτερος',
#   'γραφή',
#   'ὕποπτος',
#   'γίγνομαι',
#   'πολύς',
#   'χρόνος',
#   'Σικελία',
#   'στόλος',
#   'συμβαίνω',
#   'γίγνομαι',
#   'Κορίνθιος',
#   'εἰσπέμπω',
#   'Λεοντῖνος',
#   'Αἰγεσταῖος',
#   'ἀνήρ',
#   'ἴδιος',
#   'μέλλω',
#   'βοηθέω',
#   'Ἀθηναῖος',
#   'ἀγορά',
#   'Ἑρμῆς',
#   'περικόπτω'],
#  ['Κράτιππος',
#   'φημί',
#   'προσαμαρτάνω',
#   'μυστήριον',
#   'κρίνω',
#   'ἀποφεύγω',
#   'μηνύω',
#   'ἀδικέω'],
#  ['σπουδή', 'εἰσφέρω', 'ἐξευρίσκω', 'ἱερόν', 'ἁμαρτάνω', 'πατήρ', 'μηνύω'],
#  ['ἐλέγχω',
#   'ποιέω',
#   'ἀπόλλυμι',
#   'πατήρ',
#   'ἐρύω',
#   'δέω',
#   'ὑπισχνέομαι',
#   'πολύς',
#   'λυσιτελέω',
#   'πόλις'],
#  ['ψεύδω'],
#  ['ἐλέγχω', 'Λεωγόρας', 'πολύς', 'δημόσιος', 'χρῆμα', 'σφετερίζω', 'ἀδικέω'],
#  ['ἀφίημι', 'αἰτία'],
#  ['εὐδοκιμέω',
#   'Ἀνδοκίδης',
#   'πολιτεύω',
#   'ἐπιτίθημι',
#   'ναυκληρία',
#   'Κύπριος',
#   'βασιλεύς',
#   'πολύς',
#   'δόκιμος',
#   'ἐπιξενόομαι'],
#  ['πολῖτις',
#   'Ἀριστείδης',
#   'θυγάτηρ',
#   'ἀνεψιός',
#   'εἰμί',
#   'οἰκεῖος',
#   'ἐξάγω',
#   'πέμπω',
#   'δῶρον',
#   'Κύπριος',
#   'βασιλεύς'],
#  ['μέλλω',
#   'δικαστήριον',
#   'εἰσάγω',
#   'ἐκκλέπτω',
#   'Κύπρος',
#   'λαμβάνω',
#   'βασιλεύς',
#   'δέω'],
#  ['διαδιδράσκω', 'ἥκω', 'πόλις', 'χρόνος', 'διαλέγω', 'πρᾶγμα'],
#  ['δέω',
#   'διαφεύγω',
#   'καταλύω',
#   'ὀλιγαρχία',
#   'ἐκπίπτω',
#   'πόλις',
#   'ἀρχή',
#   'παραλαμβάνω'],
#  ['οἰκέω',
#   'φυγή',
#   'χρόνος',
#   'Ἦλις',
#   'κατέρχομαι',
#   'Θρασύβουλος',
#   'ἥκω',
#   'πόλις'],
#  ['πέμπω', 'εἰρήνη', 'Λακεδαίμων', 'δοκέω', 'ἀδικέω', 'φεύγω'],
#  ['δηλόω', 'λόγος', 'συγγράφω'],
#  ['ἀπολογέομαι', 'μυστήριον', 'εἰμί', 'κάθοδος', 'δέω'],
#  ['σῴζω', 'ἔνδειξις', 'λόγος', 'ἀπολογία', 'Φαίαξ', 'εἰρήνη'],
#  ['ἀκμάζω', 'χρόνος', 'Σωκράτης', 'φιλόσοφος'],
#  ['ἀρχή',
#   'γένεσις',
#   'ὀλυμπιάς',
#   'ἑβδομηκοστός',
#   'ὄγδοος',
#   'ἄρχων',
#   'Θεογενίδης'],
#  ['εἰμί', 'πρέσβυς', 'Λύσιος', 'ἔτος'],
#  ['ἐπώνυμος',
#   'εἰμί',
#   'Ἑρμῆς',
#   'Ἀνδοκίδης',
#   'καλέω',
#   'ἀνάθημα',
#   'εἰμί',
#   'φυλή',
#   'Αἰγηΐς',
#   'ἐπικαλέω',
#   'Ἀνδοκίδης',
#   'παροικέω',
#   'Ἀνδοκίδης'],
#  ['χορηγέω',
#   'κύκλιος',
#   'χορός',
#   'φυλή',
#   'ἀγωνίζομαι',
#   'διθύραμβος',
#   'νικάω',
#   'ἀνατίθημι',
#   'τρίπους',
#   'ὑψηλός',
#   'πώρινος',
#   'Σειληνός'],
#  ['εἰμί', 'ἁπλόος', 'ἀκατάσκευος', 'λόγος', 'ἀφελής', 'ἀσχημάτιστος'],
#  ['Λυσίας',
#   'υἱός',
#   'εἰμί',
#   'Κέφαλος',
#   'Λυσανίας',
#   'Κέφαλος',
#   'Συρακούσιος',
#   'γένος',
#   'μετανίστημι',
#   'Ἀθῆναι',
#   'ἐπιθυμία',
#   'πόλις',
#   'Περικλῆς',
#   'Ξάνθιππος',
#   'πείθω',
#   'φίλος',
#   'εἰμί',
#   'ξένος',
#   'πλοῦτος',
#   'διαφέρω'],
#  ['ἐκπίπτω', 'Συράκουσαι', 'Γέλων', 'τυραννεύω'],
#  ['γίγνομαι',
#   'Φιλοκλῆς',
#   'ἄρχω',
#   'Φρασικλῆς',
#   'δεύτερος',
#   'ἔτος',
#   'ὀγδοηκοστός',
#   'δεύτερος',
#   'ὀλυμπιάς',
#   'πρῶτος',
#   'συμπαιδεύω',
#   'ἐπιφανής',
#   'Ἀθηναῖος'],
#  ['Σύβαρις',
#   'ἀποικία',
#   'Θούριος',
#   'μετονομάζω',
#   'στέλλω',
#   'πόλις',
#   'οἴχομαι',
#   'πρέσβυς',
#   'ἀδελφός',
#   'Πολέμαρχος',
#   'εἰμί',
#   'Εὐθύδημος',
#   'Βράχυλλος',
#   'πατήρ',
#   'τελευτάω',
#   'κοινωνέω',
#   'κλῆρος',
#   'ἔτος',
#   'γίγνομαι',
#   'Πραξιτέλης',
#   'ἄρχων',
#   'διαμένω',
#   'παιδεύω',
#   'Τισίας',
#   'Νικίας',
#   'Συρακούσιος',
#   'κτάομαι',
#   'οἰκία',
#   'κλῆρος',
#   'τυγχάνω',
#   'πολιτεύω',
#   'Κλεόκριτος',
#   'ἄρχω',
#   'ἔτος',
#   'Καλλίας',
#   'ὀλυμπιάς',
#   'ἐνενηκοστός',
#   'δεύτερος',
#   'Σικελία',
#   'συμβαίνω',
#   'Ἀθηναῖος',
#   'κίνησις',
#   'γίγνομαι',
#   'σύμμαχος',
#   'Ἰταλία',
#   'οἰκέω',
#   'αἰτιάομαι',
#   'Ἀττικίζω',
#   'ἐκπίπτω'],
#  ['παραγίγνομαι',
#   'Καλλίας',
#   'Κλεόκριτος',
#   'ἄρχων',
#   'κατέχω',
#   'πόλις',
#   'διατρίβω'],
#  ['Αἴξ',
#   'ποταμός',
#   'ναυμαχία',
#   'γίγνομαι',
#   'παραλαμβάνω',
#   'πόλις',
#   'ἐκπίπτω',
#   'ἔτος',
#   'μένω',
#   'ἀφαιρέω',
#   'οὐσία',
#   'ἀδελφός',
#   'Πολέμαρχος',
#   '·αὐτός',
#   'διαδιδράσκω',
#   'οἰκία',
#   'ἀμφίθυρος',
#   'εἰμί',
#   'φυλάσσω',
#   'ἀπόλλυμι',
#   'διάγω',
#   'Μέγαρα'],
#  ['ἐπιτίθημι',
#   'Φυλή',
#   'κάθοδος',
#   'χρήσιμος',
#   'ὁράω',
#   'χρῆμα',
#   'παρέχω',
#   'δραχμή',
#   'ἀσπίς',
#   'πέμπω',
#   'Ἑρμάν',
#   'ἐπίκουρος',
#   'μισθόω',
#   'πείθω',
#   'τάλαντον',
#   'δίδωμι',
#   'Θρασυδαῖος',
#   'Ἠλεῖος',
#   'ξένος',
#   'γίγνομαι'],
#  ['γράφω',
#   'Θρασύβουλος',
#   'πολιτεία',
#   'κάθοδος',
#   'ἀναρχία',
#   'Εὐκλείδης',
#   'δῆμος',
#   'κυρόω',
#   'δωρεά',
#   'ἀποφέρω',
#   'Ἀρχῖνος',
#   'γραφή',
#   'παράνομος',
#   'ἀπροβούλευτος',
#   'εἰσάγω',
#   'ἁλίσκομαι',
#   'ψήφισμα'],
#  ['ἀπελαύνω',
#   'πολιτεία',
#   'λοιπός',
#   'οἰκέω',
#   'χρόνος',
#   'ἰσοτελής',
#   'εἰμί',
#   'τελευτάω',
#   'ἔτος',
#   'βιόω',
#   'ὁράω',
#   'Δημοσθένης',
#   'μειράκιον',
#   'εἰμί'],
#  ['γεννάω', 'φημί', 'Φιλοκλῆς', 'ἄρχων'],
#  ['φέρω', 'λόγος'],
#  ['γνήσιος', 'φημί', 'Διονύσιος', 'Καικίλιος', 'εἰμί', 'ἡσσάομαι', 'λέγω'],
#  ['εἰμί', 'ψήφισμα', 'γράφω', 'Ἀρχῖνος', 'πολιτεία', 'περιαιρέω'],
#  ['γίγνομαι', 'πιθανός', 'βραχύς', 'ἰδιώτης', 'πολύς', 'λόγος', 'ἐκδίδωμι'],
#  ['εἰμί',
#   'τέχνη',
#   'ῥητορικός',
#   'ποιέω',
#   'δημηγορία',
#   'ἐπιστολή',
#   'ἐγκώμιον',
#   'ἐπιτάφιος',
#   'ἐρωτικός',
#   'Σωκράτης',
#   'ἀπολογία',
#   'στοχάζομαι',
#   'δικαστής'],
#  ['δοκέω', 'λέξις', 'εὔκολος', 'εἰμί', 'δυσμίμητος', 'εἰμί'],
#  ['Δημοσθένης',
#   'Νέαιρα',
#   'λόγος',
#   'ἐραστής',
#   'φημί',
#   'γίγνομαι',
#   'Μετανείρα',
#   'ὁμόδουλος',
#   'Νέαιρα'],
#  ['γαμέω', 'Βραχύλλος', 'ἀδελφός', 'θυγάτηρ'],
#  ['μνημονεύω', 'Πλάτων', 'Φαῖδρος', 'δεινός', 'λέγω', 'Ἰσοκράτης', 'πρέσβυς'],
#  ['ποιέω',
#   'ἐπίγραμμα',
#   'Φιλίσκος',
#   'Ἰσοκράτης',
#   'γνώριμος',
#   'ἑταῖρος',
#   'Λύσιος',
#   'φανερός',
#   'προλαμβάνω',
#   'ἔτος',
#   'Πλάτων',
#   'λέγω',
#   'ἀποδείκνυμι'],
#  ['ἔχω'],
#  ['Καλλιόπη',
#   'θυγάτηρ',
#   'πολυήγορος',
#   'Φρόντις',
#   'δείκνυμι',
#   'φρονέω',
#   'περισσός',
#   'ἔχω'],
#  ['σχῆμα',
#   'μεθαρμόζω',
#   'κόσμος',
#   'βίος',
#   'σῶμα',
#   'λαμβάνω',
#   'δέω',
#   'ἀρετή',
#   'κῆρυξ',
#   'τίκτω',
#   'Λυσίας',
#   'ὕμνος',
#   'δίδωμι',
#   'καταφθίνω',
#   'σοφός',
#   'ἀθάνατος',
#   'ἐμός',
#   'ψυχή',
#   'δείκνυμι',
#   'φιλέταιρος',
#   'φθίω',
#   'βροτός',
#   'ἀρετή'],
#  ['συγγράφω',
#   'λόγος',
#   'Ἰφικράτης',
#   'Ἁρμόδιος',
#   'προδοσία',
#   'κρίνω',
#   'Τιμόθεος',
#   'ἀμφότερος',
#   'νικάω'],
#  ['ἀναδέχομαι',
#   'Ἰφικράτης',
#   'Τιμόθεος',
#   'πρᾶξις',
#   'εὔθυνα',
#   'ἀναλαμβάνω',
#   'προδοσία',
#   'αἰτία',
#   'ἀπολογέομαι',
#   'Λύσιος',
#   'λόγος'],
#  ['ἀπολύω', 'Τιμόθεος', 'ζημιόω', 'πολύς', 'χρῆμα'],
#  ['ἀναγιγνώσκω',
#   'Ὀλυμπιακός',
#   'πανήγυρις',
#   'λόγος',
#   'μέγας',
#   'διαλλάσσω',
#   'Ἕλλην',
#   'καταλύω',
#   'Διονύσιος'],
#  ['Ἰσοκράτης',
#   'Θεόδωρος',
#   'εἰμί',
#   'παῖς',
#   'Ἐρχιεύς',
#   'μέτριος',
#   'πολίτης',
#   'θεράπων',
#   'αὐλοποιός',
#   'κτάομαι',
#   'εὐπορέω',
#   'χορηγέω',
#   'παιδεύω',
#   'υἱός'],
#  ['εἰμί', 'Τελέσιππος', 'Διόμνηστος'],
#  ['εἰμί', 'θυγάτριον'],
#  ['αὐλός', 'κωμῳδέω', 'Ἀριστοφάνης', 'Στράττις'],
#  ['γίγνομαι',
#   'ὀγδοηκοστός',
#   'ἕκτος',
#   'ὀλυμπιάς',
#   'Λυσίμαχος',
#   'Μυρρινούσιος',
#   'ἄρχω',
#   'νέος',
#   'Λύσιος',
#   'ἔτος',
#   'πρέσβυς',
#   'Πλάτων',
#   'Παῖς',
#   'εἰμί',
#   'παιδεύω',
#   'ἥσσων',
#   'Ἀθηναῖος',
#   'ἀκροάομαι',
#   'Πρόδικος',
#   'Κέως',
#   'Γοργίας',
#   'Λεοντῖνος',
#   'Τισίας',
#   'Συρακούσιος',
#   'Θηραμένης',
#   'ῥήτωρ'],
#  ['συλλαμβάνω',
#   'φεύγω',
#   'Βουλαῖος',
#   'Ἑστία',
#   'καταπλήσσω',
#   'μόνος',
#   'ἀνίστημι',
#   'βοηθέω',
#   'πολύς',
#   'χρόνος',
#   'σιγάω',
#   'ἀρχή',
#   'παραιτέομαι',
#   'λέγω',
#   'ὀδυνηρός',
#   'συμβαίνω',
#   'φίλος',
#   'ἀπολαύω',
#   'συμφορά'],
#  ['εἰμί',
#   'τέχνη',
#   'φημί',
#   'συμπραγματεύομαι',
#   'δικαστήριον',
#   'συκοφαντέω',
#   'εἰμί',
#   'ἐπιγράφω',
#   'Βότων'],
#  ['ἀνδρόω',
#   'πολιτικός',
#   'πρᾶγμα',
#   'ἀπέχω',
#   'ἰσχνόφωνος',
#   'εἰμί',
#   'εὐλαβής',
#   'τρόπος',
#   'πατρῷος',
#   'ἀποβάλλω',
#   'Λακεδαιμόνιος',
#   'πόλεμος'],
#  ['συναγωνίζομαι', 'μαρτυρέω', 'φαίνω', 'μόνος', 'λέγω', 'λόγος', 'ἀντίδοσις'],
#  ['διατριβή',
#   'συνίστημι',
#   'φιλοσοφέω',
#   'γράφω',
#   'διανοέω',
#   'τρέπω',
#   'Πανηγυρικός',
#   'λόγος',
#   'συμβουλευτικός',
#   'γράφω',
#   'ἀναγιγνώσκω',
#   'παρασκευάζω',
#   'ἡγέομαι',
#   'δέω',
#   'φρονέω',
#   'Ἕλλην',
#   'προσρέπω'],
#  ['διαμαρτάνω',
#   'προαίρεσις',
#   'ἀφίστημι',
#   'σχολή',
#   'ἡγέομαι',
#   'φημί',
#   'πρῶτος',
#   'Χίος',
#   'μαθητής',
#   'ἔχω'],
#  ['ὁράω', 'μισθός', 'ἀριθμέω', 'λέγω', 'δακρύω', 'ἐπιγιγνώσκω', 'πιπράσκω'],
#  ['ὁμιλέω',
#   'βούλομαι',
#   'χωρίζω',
#   'πρῶτος',
#   'ἐριστικός',
#   'λόγος',
#   'πολιτικός',
#   'σπουδάζω'],
#  ['ἀρχή', 'Χίος', 'καθίστημι', 'πατρίς', 'πολιτεία'],
#  ['ἀργύριον', 'σοφιστής', 'εὐπορέω', 'τριηραρχέω'],
#  ['ἀκροατής',
#   'γίγνομαι',
#   'πολύς',
#   'Τιμόθεος',
#   'Κόνων',
#   'πολύς',
#   'πόλις',
#   'ἐπέρχομαι',
#   'συντίθημι',
#   'Ἀθηναῖος',
#   'Τιμόθεος',
#   'πέμπω',
#   'ἐπιστολή'],
#  ['δωρέω', 'τάλαντον', 'Σάμος', 'περιγίγνομαι'],
#  ['μαθητεύω',
#   'Θεόπομπος',
#   'Χῖος',
#   'Ἔφορος',
#   'Κυμαῖος',
#   'Ἀσκληπιάδης',
#   'τραγῳδέω',
#   'συγγράφω',
#   'Θεοδέκτης',
#   'Φασηλίτης',
#   'τραγῳδία',
#   'γράφω',
#   'εἰμί',
#   'μνῆμα',
#   'Κυαμῖτις',
#   'πορεύω',
#   'ἱερός',
#   'ὁδός',
#   'Ἐλευσίς',
#   'κατερηρείιμω'],
#  ['ἔνδοξος', 'ποιητής', 'ἀνίστημι', 'Ὅμηρος', 'ποιητής', 'σῴζω', 'μόνος'],
#  ['Λεώδαμος', 'Ἀθηναῖος', 'Λάκριτος', 'νομοθέτης', 'Ἀθηναῖος'],
#  ['φημί', 'Ὑπερείδης', 'Ἰσαῖος'],
#  ['Δημοσθένης',
#   'ῥητορεύω',
#   'φημί',
#   'σπουδή',
#   'προσέρχομαι',
#   'μόνος',
#   'εἰσπράσσω',
#   'ἔχω',
#   'φημί',
#   'παρέχω',
#   'μόνος',
#   'δίδωμι',
#   'πέμπτος',
#   'μέρος',
#   'ἐκμανθάνω'],
#  ['ἀποκρίνω', 'τεμαχίζω', 'Δημοσθένης', 'πραγματεία'],
#  ['καλός',
#   'ἰχθῦς',
#   'ὅλος',
#   'πωλέω',
#   'βούλομαι',
#   'μαθητεύω',
#   'ὁλόκληρος',
#   'ἀποδίδωμι',
#   'τέχνη'],
#  ['τελευτάω',
#   'Χαιρώνδας',
#   'ἄρχων',
#   'ἀπαγγέλλω',
#   'Χαιρώνεια',
#   'Ἱπποκράτης',
#   'παλαίστρα',
#   'πυνθάνομαι',
#   'ἐξάγω',
#   'βίος',
#   'ἡμέρα',
#   'σιτίον',
#   'ἀπέχω',
#   'προλέγω',
#   'ἀρχή',
#   'δρᾶμα',
#   'Εὐριπίδης',
#   'Δαναός',
#   'θυγάτηρ',
#   'πατήρ',
#   'Πέλοψ',
#   'Ταντάλειος',
#   'Πῖσα',
#   'βλώσκω',
#   'Σιδώνιος',
#   'ἄστυ',
#   'Κάδμος',
#   'ἐκλείπω',
#   'ἔτος',
#   'βιόω',
#   'ὑπομένω',
#   'ὁράω',
#   'Ἑλλάς',
#   'καταδουλόω'],
#  ['ἐνιαυτός', 'τελευτή', 'συγγράφω', 'Παναθηναικός'],
#  ['Πανηγυρικός',
#   'ἔτος',
#   'συντίθημι',
#   'λέγω',
#   'μεταφέρω',
#   'Γοργίας',
#   'Λεοντῖνος',
#   'Λύσιος'],
#  ['ἀντίδοσις', 'ἔτος', 'γίγνομαι'],
#  ['Φίλιππος', 'ὀλίγος', 'θάνατος'],
#  ['γίγνομαι',
#   'παῖς',
#   'Ἀφαρεύς',
#   'πρεσβύτης',
#   'εἰμί',
#   'Πλαθάνη',
#   'Ἵππιος',
#   'ῥήτωρ',
#   'ποιητός',
#   'γυνή',
#   'παῖς',
#   'νέος'],
#  ['εὐπορέω',
#   'ἀργύριον',
#   'εἰσπράσσω',
#   'γνώριμος',
#   'Νικοκλῆς',
#   'Κύπριος',
#   'βασιλεύς',
#   'εἰμί',
#   'υἱός',
#   'Εὐαγόρας',
#   'τάλαντον',
#   'λαμβάνω',
#   'γράφω',
#   'λόγος'],
#  ['φθονέω',
#   'προβάλλω',
#   'τριηραρχέω',
#   'ἀσθένεια',
#   'σκήπτω',
#   'παῖς',
#   'παραιτέομαι',
#   'τρίτος',
#   'ὑφίστημι',
#   'ἀναλίσκω',
#   'ὀλίγος'],
#  ['λέγω',
#   'πατήρ',
#   'ἀνδράποδον',
#   'συμπέμπω',
#   'αἰτέω',
#   'παιδίον',
#   'φημί',
#   'ἀπέρχομαι'],
#  ['ἔχω', 'ἀνδράποδον'],
#  ['ἀγωνίζομαι', 'Μαύσωλος', 'τίθημι', 'Ἀρτεμισία', 'ἀγών'],
#  ['ἐγκώμιον', 'σῴζω'],
#  ['ποιέω',
#   'Ἑλένη',
#   'ἐγκώμιον',
#   'Ἀρεοπαγιτικός',
#   'ἐξέρχομαι',
#   'βίος',
#   'ἐναταῖος',
#   'φημί',
#   'σῖτος',
#   'ἀπέχω',
#   'τεταρταῖος',
#   'ταφή',
#   'Χαιρωνεία',
#   'πίπτω'],
#  ['συγγράφω', 'παῖς', 'Ἀφαρεύς', 'λόγος'],
#  ['θάπτω',
#   'συγγένεια',
#   'Κυνόσαργες',
#   'λόφος',
#   'ἀριστερός',
#   'πατήρ',
#   'Θεόδωρος',
#   'μήτηρ'],
#  ['ἀδελφή',
#   'τηθίς',
#   'ῥήτωρ',
#   'Ἀνακώ',
#   'ποιητός',
#   'υἱός',
#   'Ἀφαρεύς',
#   'ἀνεψιός',
#   'Σωκράτης',
#   'μήτηρ',
#   'Ἰσοκράτης',
#   'ἀδελφή',
#   'Ἀνακοῦς',
#   'υἱός',
#   'εἰμί',
#   'ἀδελφός',
#   'ὁμώνυμος',
#   'πατήρ',
#   'Θεόδωρος',
#   'υἱωνός',
#   'ποιέω',
#   'παῖς',
#   'Ἀφαρεύς',
#   'Ἀφαρεύς',
#   'πατήρ',
#   'Θεόδωρος',
#   'γυνή',
#   'Πλαθάνη',
#   'μήτηρ',
#   'ποιητής',
#   'Ἀφαρεύς'],
#  ['τράπεζα', 'ἔπειμι', 'σῴζω'],
#  ['Ἰσοκράτης', 'μνῆμα', 'ἔπειμι', 'κίων', 'πῆχυς', 'σειρά', 'πῆχυς', 'σῴζω'],
#  ['εἰμί',
#   'τράπεζα',
#   'ἔχω',
#   'ποιητής',
#   'διδάσκαλος',
#   'Γοργίας',
#   'σφαῖρα',
#   'ἀστρολογικός',
#   'βλέπω',
#   'Ἰσοκράτης',
#   'παρίστημι'],
#  ['ἀνάκειμαι',
#   'Ἐλευσίς',
#   'εἰκών',
#   'χάλκεος',
#   'προστῷον',
#   'Τιμόθεος',
#   'Κόνων',
#   'ἐπιγράφω',
#   'Τιμόθεος',
#   'φιλία',
#   'χάρις',
#   'σύνεσις',
#   'προτιμάω',
#   'Ἰσοκράτης',
#   'εἰκών',
#   'ἀνατίθημι',
#   'θεά'],
#  ['Λεωχάρης', 'ἔργον'],
#  ['φέρω',
#   'λόγος',
#   'εἰμί',
#   'γνήσιος',
#   'Διονύσιος',
#   'Καικίλιος',
#   'καταψεύδομαι'],
#  ['ἔχω',
#   'ἐπίδειξις',
#   'ἀφικνέομαι',
#   'ἀκρόασις',
#   'κατέχω',
#   'τρίτος',
#   'ἀπολύω',
#   'φημί',
#   'ἐπέρχομαι',
#   'ἥκω'],
#  ['θέατρον', 'εἰμί', 'ἀκρωτήριον'],
#  ['εἴωθα',
#   'γνώριμος',
#   'λέγω',
#   'μνᾶ',
#   'διδάσκω',
#   'διδάσκω',
#   'τόλμα',
#   'εὐφωνία',
#   'δίδωμι',
#   'δεκακισχιλία'],
#  ['ἔρομαι',
#   'εἰμί',
#   'ἱκανός',
#   'ποιέω',
#   'λέγω',
#   'ἀκόνη',
#   'τέμνω',
#   'δύναμαι',
#   'σίδηρος',
#   'τμητικός',
#   'ποιέω'],
#  ['εἰμί', 'τέχνη', 'λέγω', 'συγγράφω', 'μέθοδος', 'ἄσκησις', 'χράω'],
#  ['πολίτης', 'εἰσπράσσω', 'μισθός'],
#  ['προστάσσω', 'γνώριμος', 'ἐκκλησία', 'ἀπαντάω', 'ἀναφέρω', 'λέγω'],
#  ['λυπέω', 'Σωκράτης', 'θάνατος', 'μελανειμονέω', 'ὑστεραῖος', 'προέρχομαι'],
#  ['ἔρομαι',
#   'ῥητορικός',
#   'λέγω',
#   'μικρός',
#   'μέγας',
#   'μέγας',
#   'μικρός',
#   'ποιέω'],
#  ['ἑστιόομαι',
#   'Νικοκρέων',
#   'Κύπρος',
#   'τύραννος',
#   'προσρέπω',
#   'πάρειμι',
#   'διαλέγω',
#   'φημί',
#   'δεινός',
#   'καιρός',
#   'καιρός',
#   'δεινός'],
#  ['Σοφοκλῆς',
#   'τραγικός',
#   'θεάομαι',
#   'ἕπομαι',
#   'παῖς',
#   'λέγω',
#   'δέω',
#   'Σοφοκλῆς',
#   'χείρ',
#   'ἔχω',
#   'ὀφθαλμός'],
#  ['Κυμαῖος',
#   'Ἔφορος',
#   'ἄπρακτος',
#   'σχολή',
#   'ἐξέρχομαι',
#   'πατήρ',
#   'Δημόφιλος',
#   'πέμπω',
#   'δεύτερος',
#   'μισθός',
#   'παίζω',
#   'Δίφορος',
#   'καλέω'],
#  ['σπουδάζω', 'ἀνήρ', 'ὑπόθεσις', 'χρεία', 'ὑποτίθημι'],
#  ['γίγνομαι',
#   'ἀφροδίσιος',
#   'καταφερής',
#   'ὑπόπαστον',
#   'παρέλκω',
#   'κοίτη',
#   'χράω',
#   'κρόκος',
#   'διάβροχος',
#   'ἔχω',
#   'προσκεφάλαιον'],
#  ['νέος',
#   'εἰμί',
#   'γαμέω',
#   'γηράσκω',
#   'ἑταίρα',
#   'σύνειμι',
#   'ὄνομα',
#   'εἰμί',
#   'Λαγίσκη',
#   'ἔχω',
#   'θυγάτριον',
#   'γίγνομαι',
#   'ἔτος',
#   'γάμος',
#   'τελευτάω'],
#  ['Πλαθάνη',
#   'Ἵππιος',
#   'ῥήτωρ',
#   'γυνή',
#   'ἄγω',
#   'παῖς',
#   'ἔχω',
#   'Ἀφαρεύς',
#   'προλέγω',
#   'ποιέω',
#   'εἰκών',
#   'χάλκεος',
#   'ἀνατίθημι',
#   'Ὀλυμπιεῖον',
#   'κίων',
#   'ἐπιγράφω',
#   'Ἰσοκράτης',
#   'Ἀφαρεύς',
#   'πατήρ',
#   'εἰκών',
#   'ἀνατίθημι',
#   'Ζεύς',
#   'θεός',
#   'σέβω',
#   'γονεύς',
#   'ἀρετή'],
#  ['λέγω', 'κελητίζω', 'παῖς', 'εἰμί'],
#  ['ἀνάκειμαι',
#   'ἀκρόπολις',
#   'χάλκεος',
#   'σφαιρίστρα',
#   'Ἀρρηφόροι',
#   'κελητίζω',
#   'παῖς',
#   'εἰμί',
#   'λέγω'],
#  ['βίος', 'συνίστημι', 'ἀγών'],
#  ['πρότερος',
#   'ἀντίδοσις',
#   'προκαλέω',
#   'Μεγακλείδης',
#   'ἀπαντάω',
#   'νόσος',
#   'υἱός',
#   'πέμπω',
#   'Ἀφαρεύς',
#   'νικάω'],
#  ['δεύτερος', 'Λυσίμαχος', 'προκαλέω', 'τριηραρχία', 'ἀντίδοσις'],
#  ['ἡσσάομαι', 'τριηραρχία', 'ὑφίστημι'],
#  ['εἰμί', 'γραπτός', 'εἰκών', 'Πομπεῖον'],
#  ['Ἀφαρεύς', 'συγγράφω', 'λόγος', 'πολύς', 'δικανικός', 'συμβουλευτικός'],
#  ['ποιέω', 'τραγῳδία', 'ἀντιλέγω'],
#  ['ἄρχω',
#   'Λυσίστρατος',
#   'διδάσκω',
#   'Σωσιγένης',
#   'ἔτος',
#   'διδασκαλία',
#   'ἀστικός',
#   'καθίημι',
#   'νικάω',
#   'Διονύσιος',
#   'καθίημι',
#   'Ληναικός'],
#  ['μήτηρ',
#   'Ἰσοκράτης',
#   'Θεόδωρος',
#   'ἀδελφή',
#   'Νακώ',
#   'εἰκών',
#   'ἀνάκειμαι',
#   'ἀκρόπολις'],
#  ['μήτηρ', 'Ὑγίεια', 'κεῖμαι', 'μετεπιγράφω', 'Νακώ', 'σῴζω'],
#  ['ἔχω', 'υἱός', 'Ἀλέξανδρος', 'Κόννος', 'Σωσικλῆς', 'Λύσιος'],
#  ['Ἰσαῖος',
#   'Χαλκιδεύς',
#   'εἰμί',
#   'γένος',
#   'παραγίγνομαι',
#   'Ἀθῆναι',
#   'σχολάζω',
#   'Ἰσοκράτης',
#   'φημί',
#   'Ἕρμιππος',
#   'ἀκολουθέω',
#   'Λυσίας',
#   'ὄνομα',
#   'ἁρμονία',
#   'πρᾶγμα',
#   'δεινότης',
#   'ἔμπειρος',
#   'χαρακτήρ',
#   'ἀνήρ',
#   'εἰμί',
#   'διαγιγνώσκω',
#   'πολύς',
#   'λόγος',
#   'ῥήτωρ',
#   'εἰμί'],
#  ['ἀκμάζω',
#   'Πελοποννησιακός',
#   'πόλεμος',
#   'εἰμί',
#   'τεκμαίρομαι',
#   'λόγος',
#   'Φίλιππος',
#   'ἀρχή',
#   'παρατείνω'],
#  ['καθηγέομαι', 'Δημοσθένης', 'ἀφίστημι', 'σχολή', 'δραχμή', 'μυρίος'],
#  ['ἐπιφανής', 'γίγνομαι'],
#  ['ἐπιτροπικός', 'λόγος', 'συντάσσω', 'Δημοσθένης', 'λέγω'],
#  ['καταλείπω', 'λόγος', 'εἰμί', 'γνήσιος', 'ἴδιος', 'τέχνη'],
#  ['πρῶτος', 'σχηματίζω', 'ἄρχω', 'τρέπω', 'πολιτικός', 'διάνοια'],
#  ['μιμέομαι', 'Δημοσθένης'],
#  ['μνημονεύω', 'Θεόπομπος', 'κωμικός', 'Θησεύς'],
#  ['Αἰσχίνης',
#   'Ἀτρόμητος',
#   'φεύγω',
#   'συγκατάγω',
#   'δῆμος',
#   'Γλαυκοθέας',
#   'δῆμος',
#   'Κοθωκίδης',
#   'γένος',
#   'ἐπιφανής',
#   'περιουσία',
#   'χρῆμα'],
#  ['νέος', 'εἰμί', 'ῥώννυμι', 'σῶμα', 'γυμνάσιον', 'πονέω'],
#  ['λαμπρόφωνος', 'εἰμί', 'τραγῳδία', 'ἀσκέω'],
#  ['Δημοσθένης',
#   'φημί',
#   'ὑπογραμματεύω',
#   'τριταγωνιστέω',
#   'Ἀριστόδημος',
#   'Διονύσιον',
#   'διατελέω',
#   'ἀναλαμβάνω',
#   'σχολή',
#   'παλαιός',
#   'τραγῳδία',
#   'παῖς',
#   'εἰμί',
#   'διδάσκω',
#   'γράμμα',
#   'πατήρ',
#   'μειράκιον',
#   'εἰμί',
#   'στρατεύω',
#   'περίπολος'],
#  ['ἀκροατής',
#   'γίγνομαι',
#   'λέγω',
#   'Ἰσοκράτης',
#   'Πλάτων',
#   'Καικίλιος',
#   'Λεωδάμας',
#   'πολιτεύω',
#   'ἐναντίος',
#   'μερίς',
#   'Δημοσθένης',
#   'πρεσβεύω',
#   'πρεσβεία',
#   'πολύς',
#   'Φίλιππος',
#   'εἰρήνη'],
#  ['κατηγορέω',
#   'Δημοσθένης',
#   'ἀναιρέω',
#   'Φωκεύς',
#   'ἔθνος',
#   'πόλεμος',
#   'ἐξάπτω',
#   'πυλαγόρας',
#   'αἱρέω',
#   'Ἀμφικτύονες',
#   'Ἀμφισσεύς',
#   'ἱερός',
#   'γῆ',
#   'λιμήν',
#   'ἐργάζομαι'],
#  ['συμβαίνω',
#   'Ἀμφικτύονες',
#   'Φίλιππος',
#   'προσφεύγω',
#   'Αἰσχίνης',
#   'συνεργέω',
#   'ἐπιτίθημι',
#   'πρᾶγμα',
#   'Φωκίς',
#   'λαμβάνω'],
#  ['συλλέγω',
#   'Εὔβουλος',
#   'Σπίνθαρος',
#   'Προβαλλούσιος',
#   'δημαγωγέω',
#   'ψῆφος',
#   'ἀποφεύγω'],
#  ['εἰμί',
#   'φημί',
#   'συγγράφω',
#   'ῥήτωρ',
#   'λόγος',
#   'γίγνομαι',
#   'Χαιρώνεια',
#   'δίκη',
#   'εἰσέρχομαι'],
#  ['χρόνος',
#   'Φίλιππος',
#   'τελευτάω',
#   'Ἀλέξανδρος',
#   'διαβαίνω',
#   'Ἀσία',
#   'γράφω',
#   'Κτησιφῶν',
#   'παράνομος',
#   'Δημοσθένης',
#   'τιμή'],
#  ['μεταλαμβάνω',
#   'πέμπτος',
#   'μέρος',
#   'ψῆφος',
#   'φεύγω',
#   'Ῥόδος',
#   'δραχμή',
#   'ἧσσα',
#   'βούλομαι',
#   'κατατίθημι'],
#  ['ἀτιμία',
#   'προστιμάω',
#   'λέγω',
#   'ἐθέλω',
#   'ἐξέρχομαι',
#   'πόλις',
#   'ἔρχομαι',
#   'Ἔφεσος',
#   'Ἀλέξανδρος'],
#  ['τελευτάω',
#   'ταραχή',
#   'εἰμί',
#   'ἀπαίρω',
#   'Ῥόδος',
#   'σχολή',
#   'καθίστημι',
#   'διδάσκω'],
#  ['ἀναγιγνώσκω', 'Ῥόδιος', 'Κτησιφῶν', 'λόγος', 'ἐπιδείκνυμι'],
#  ['θαυμάζω',
#   'λέγω',
#   'ἡσσάομαι',
#   'φημί',
#   'θαυμάζω',
#   'Ῥόδιος',
#   'Δημοσθένης',
#   'λέγω',
#   'ἀκούω'],
#  ['σχολή', 'προσκαταλείπω', 'Ῥοδιακός', 'διδασκαλεῖον', 'καλέω'],
#  ['πλέω', 'Σάμος', 'διατρίβω', 'νῆσος', 'ὀλίγος', 'τελευτάω'],
#  ['γίγνομαι', 'εὔφωνος', 'δῆλος', 'φημί', 'Δημοσθένης', 'Δημοχάρης', 'λόγος'],
#  ['φέρω',
#   'λόγος',
#   'Τίμαρχος',
#   'παραπρεσβεία',
#   'Κτησιφῶν',
#   'μόνος',
#   'εἰμί',
#   'γνήσιος'],
#  ['ἐπιγράφω', 'Δηλιακός', 'εἰμί', 'Αἰσχίνης'],
#  ['ἀποδείκνυμι', 'κρίσις', 'ἀγών', 'ἱερός', 'Δῆλος', 'συνίστημι', 'συνήγορος'],
#  ['λέγω', 'λόγος'],
#  ['χειροτονέω',
#   'Ὑπερείδης',
#   'φημί',
#   'Δημοσθένης',
#   'ἔχω',
#   'ἀδελφός',
#   'φημί',
#   'Ἀφόβητος',
#   'Φιλοχάρας'],
#  ['ἀπαγγέλλω',
#   'Ταμύναι',
#   'νίκη',
#   'πρῶτος',
#   'Ἀθηναῖος',
#   'στεφανόω',
#   'δεύτερος'],
#  ['λέγω',
#   'μαθητεύω',
#   'Αἰσχίνης',
#   'ὑπογραμματεία',
#   'ἀείρω',
#   'δικαστήριον',
#   'διάγω'],
#  ['πρῶτος',
#   'λέγω',
#   'δῆμος',
#   'Φίλιππος',
#   'εὐδοκιμέω',
#   'πρεσβευτής',
#   'χειροτονέω',
#   'Ἀρκάς'],
#  ['ἀφικνέομαι', 'συνίστημι', 'μυρίος', 'Φίλιππος'],
#  ['γράφω', 'Τίμαρχος', 'ἑταίρησις'],
#  ['ἐκλείπω', 'ἀγών', 'ἀναρτάω', 'φημί', 'Δημοσθένης'],
#  ['χειροτονέω',
#   'πρεσβευτής',
#   'Φίλιππος',
#   'Κτησιφῶν',
#   'Δημοσθένης',
#   'εἰρήνη',
#   'ἀγαθός',
#   'Δημοσθένης',
#   'φέρω'],
#  ['δεύτερος',
#   'δέκατος',
#   'εἰμί',
#   'κυρόω',
#   'ὅρκος',
#   'εἰρήνη',
#   'κρίνω',
#   'ἀποφεύγω',
#   'προλέγω'],
#  ['Λυκοῦργος',
#   'πατήρ',
#   'εἰμί',
#   'Λυκόφρων',
#   'Λυκοῦργος',
#   'τύραννος',
#   'ἀποκτείνω',
#   'αἴτιος',
#   'ἀναίρεσις',
#   'γίγνομαι',
#   'Ἀριστόδημος',
#   'ἑλληνοταμίας',
#   'γίγνομαι',
#   'φεύγω',
#   'δημοκρατία'],
#  ['δῆμος', 'Βουτάδης', 'γένος', 'Ἐτεοβουτάδης'],
#  ['ἀκροατής', 'γίγνομαι', 'Πλάτων', 'φιλόσοφος', 'πρῶτος', 'φιλοσοφέω'],
#  ['Ἰσοκράτης',
#   'ῥήτωρ',
#   'γνώριμος',
#   'γίγνομαι',
#   'πολιτεύω',
#   'λέγω',
#   'πράσσω',
#   'πιστεύω',
#   'διοίκησις',
#   'χρῆμα'],
#  ['ταμίας',
#   'γίγνομαι',
#   'πενταετηρίς',
#   'τάλαντον',
#   'μυρίος',
#   'μυρίος',
#   'τιμή',
#   'ψηφίζω',
#   'Στρατοκλῆς',
#   'ῥήτωρ',
#   'πρῶτος',
#   'αἱρέω',
#   'φίλος',
#   'ἐπιγράφω',
#   'ποιέω',
#   'διοίκησις',
#   'φθάνω',
#   'νόμος',
#   'εἰσφέρω',
#   'πολύς',
#   'ἔτος',
#   'διέπω',
#   'χειροτονέω',
#   'δημόσιος',
#   'χρῆμα'],
#  ['ἐφίστημι', 'ἔργον', 'διατελέω', 'θέρος', 'χειμών'],
#  ['πόλεμος',
#   'παρασκευή',
#   'χειροτονέω',
#   'πολύς',
#   'πόλις',
#   'ἐπανορθόω',
#   'τριήρης',
#   'παρασκευάζω',
#   'δῆμος',
#   'Λύκειον',
#   'γυμνάσιον',
#   'ποιέω',
#   'φυτεύω',
#   'παλαίστρα',
#   'οἰκοδομέω',
#   'Διόνυσος',
#   'θέατρον',
#   'ἐπιστατέω',
#   'ἐπιτελέω'],
#  ['πιστεύω',
#   'παρακαταθήκη',
#   'ἰδιώτης',
#   'τάλαντον',
#   'φυλάσσω',
#   'πομπεῖον',
#   'χρύσεος',
#   'ἀργύρεος',
#   'πόλις',
#   'κατασκευάζω',
#   'Νίκη',
#   'χρύσεος'],
#  ['πολύς', 'ἡμίεργος', 'παραλαμβάνω', 'ἐκτελέω', 'νεώσοικος', 'σκευοθήκη'],
#  ['στάδιον',
#   'Παναθηναικός',
#   'κρηπίς',
#   'περιτίθημι',
#   'ἐξεργάζομαι',
#   'χαράδρα',
#   'ὁμαλός',
#   'ποιέω',
#   'Δεινίας',
#   'κτάομαι',
#   'χωρίον',
#   'ἀνίημι',
#   'πόλις',
#   'προλέγω',
#   'χαρίζω',
#   'Λυκοῦργος'],
#  ['ἔχω',
#   'ἄστυ',
#   'φυλακή',
#   'κάκουργος',
#   'σύλληψις',
#   'ἐξελαύνω',
#   'σοφιστής',
#   'ἔνιοι',
#   'λέγω',
#   'Λυκοῦργος',
#   'μέλας',
#   'θάνατος',
#   'χράω',
#   'κάλαμος',
#   'πονηρός',
#   'συγγράφω'],
#  ['ἐξαιτέω', 'Ἀλέξανδρος', 'βασιλεύς', 'δῆμος', 'προίημι'],
#  ['χρόνος',
#   'πολεμέω',
#   'Φίλιππος',
#   'Ἀθηναῖος',
#   'δεύτερος',
#   'πόλεμος',
#   'πρεσβεύω',
#   'Πολυεύκτος',
#   'Δημοσθένης',
#   'Πελοπόννησος',
#   'πόλις'],
#  ['διατελέω',
#   'χρόνος',
#   'εὐδοκιμέω',
#   'Ἀθηναῖος',
#   'δίκαιος',
#   'εἰμί',
#   'νομίζω',
#   'δικαστήριον',
#   'φημί',
#   'Λυκοῦργος',
#   'δοκέω',
#   'βοήθημα',
#   'εἰμί',
#   'συναγορεύω'],
#  ['εἰσφέρω',
#   'νόμος',
#   'κωμῳδός',
#   'ἀγών',
#   'Χύτρος',
#   'ἐπιτελέω',
#   'ἐφάμιλλος',
#   'θέατρον',
#   'νικάω',
#   'ἄστυ',
#   'καταλέγω',
#   'ἔξεστι',
#   'ἀναλαμβάνω',
#   'ἀγών',
#   'ἐκλείπω'],
#  ['χάλκεος',
#   'εἰκών',
#   'ἀνατίθημι',
#   'ποιητής',
#   'Αἰσχύλος',
#   'Σοφοκλῆς',
#   'Εὐριπίδης',
#   'τραγῳδία',
#   'κοινός',
#   'γράφω',
#   'φυλάσσω',
#   'πόλις',
#   'γραμματεύς',
#   'παραναγιγνώσκω',
#   'ὑποκρίνομαι'],
#  ['ἔξεστι', 'ὑποκρίνομαι'],
#  ['τρίτος',
#   'ἔξεστι',
#   'Ἀθηναῖος',
#   'οἰκέω',
#   'ἐλεύθερος',
#   'σῶμα',
#   'πρίαμαι',
#   'δουλεία',
#   'ἁλίσκομαι',
#   'δοῦλος',
#   'πρότερος',
#   'δεσπότης',
#   'γνώμη'],
#  ['Ποσειδῶν',
#   'ἀγών',
#   'ποιέω',
#   'Πειραιεύς',
#   'κύκλιος',
#   'χορός',
#   'ἐλαχύς',
#   'δίδωμι',
#   'νικάω',
#   'ἐλαχύς',
#   'μνᾶ',
#   'δεύτερος',
#   'τρίτος',
#   'κρίνω'],
#  ['ζεῦγος', 'ἀπέρχομαι', 'γυνή', 'ἐλασσόω', 'δημοτικός', 'πλουσιάω'],
#  ['φωράω', 'ἀποτίνω', 'δραχμή'],
#  ['γυνή', 'πείθω', 'συκοφάντης', 'φωράω', 'τάλαντον', 'δίδωμι'],
#  ['κατηγορέω', 'ὕστερος', 'δῆμος', 'φημί', 'δίδωμι', 'λαμβάνω', 'ὁράω'],
#  ['τελώνης',
#   'ἐπιβάλλω',
#   'Ξενοκράτης',
#   'φιλόσοφος',
#   'χείρ',
#   'μετοίκιον',
#   'ἀπάγω',
#   'ἀπαντάω',
#   'ῥάβδος',
#   'κεφαλή',
#   'τελώνης',
#   'καταφέρω',
#   'Ξενοκράτης',
#   'ἀπολύω',
#   'πρέπω',
#   'δράω',
#   'δεσμωτήριον',
#   'κατακλείω'],
#  ['ἐπαινέω',
#   'πρᾶξις',
#   'ἡμέρα',
#   'συντυγχάνω',
#   'Ξενοκράτης',
#   'παῖς',
#   'Λυκοῦργος',
#   'φημί',
#   'πατήρ',
#   'ἀποδίδωμι',
#   'παῖς',
#   'χάρις'],
#  ['ἐπαινέω', 'πολύς', 'βοηθέω'],
#  ['εἰσφέρω', 'ψήφισμα', 'Εὐκλείδης', 'Ὀλύνθιος', 'χράω', 'ἱκανός', 'ψήφισμα'],
#  ['εὔπορος',
#   'εἰμί',
#   'ἱμάτιον',
#   'φορέω',
#   'χειμών',
#   'θέρος',
#   'ὑποδέω',
#   'ἀναγκαῖος',
#   'ἡμέρα'],
#  ['μελετάω',
#   'νύξ',
#   'ἡμέρα',
#   'αὐτοσχέδιος',
#   'φύω',
#   'κλινίδιον',
#   'ὑπόκειμαι',
#   'εἰμί',
#   'κώδιον',
#   'προσκεφάλαιον',
#   'ἐγείρω',
#   'μελετάω'],
#  ['ἐγκαλέω',
#   'μισθός',
#   'σοφιστής',
#   'δίδωμι',
#   'λόγος',
#   'διατρίβω',
#   'ἐπαγγέλλω',
#   'φημί',
#   'υἱός',
#   'ἀγαθός',
#   'ποιέω',
#   'ἥμισυς',
#   'οὐσία',
#   'προίημι'],
#  ['εἰμί', 'παρρησιαστής', 'εὐγένεια'],
#  ['Ἀθηναῖος',
#   'ἀνέχω',
#   'δημηγορέω',
#   'ἀνακράζω',
#   'ἐκβάλλω',
#   'Κερυκυραῖος',
#   'μάστιξ',
#   'πολύς',
#   'τάλαντον',
#   'εἰμί',
#   'ἄξιος'],
#  ['θεός',
#   'ἀναγορεύω',
#   'Ἀλέξανδρος',
#   'ποδαπός',
#   'εἰμί',
#   'λέγω',
#   'θεός',
#   'ἱερός',
#   'ἐξέρχομαι',
#   'δέω',
#   'περιρραίνω'],
#  ['ἀποθνῄσκω',
#   'παραδίδωμι',
#   'παῖς',
#   'Μενέσαιχμος',
#   'κατηγορέω',
#   'γράφω',
#   'Θρασυκλέης'],
#  ['Δημοσθένης',
#   'φεύγω',
#   'χρόνος',
#   'ἐπιστέλλω',
#   'Ἀθηναῖος',
#   'ἀκούω',
#   'Λυκοῦργος',
#   'παιδίον',
#   'μετανοέω',
#   'ἀφίημι',
#   'Δημοκλῆς',
#   'Θεόφραστος',
#   'μαθητής',
#   'ἀπολογέομαι'],
#  ['θάπτω', 'ἔκγονος'],
#  ['εἰμί',
#   'μνῆμα',
#   'Παιώνιος',
#   'Ἀθήνη',
#   'Μελάνθιος',
#   'φιλόσοφος',
#   'κῆπος',
#   'τράπεζα',
#   'ποιέω',
#   'Λυκοῦργος',
#   'παῖς',
#   'ἐπιγράφω',
#   'σῴζω'],
#  ['μέγας', 'τάλαντον', 'πρόσοδος', 'πόλις', 'καθίστημι', 'προσέρχομαι'],
#  ['μέλλω',
#   'τελευτάω',
#   'μητρῷος',
#   'βουλευτήριον',
#   'κελεύω',
#   'κομίζω',
#   'βούλομαι',
#   'εὔθυνα',
#   'δίδωμι',
#   'πολιτεύω'],
#  ['κατηγορέω',
#   'τολμάω',
#   'Μενέσαιχμος',
#   'διαβολή',
#   'ἀπολύω',
#   'οἰκία',
#   'ἀποκομίζω',
#   'τελευτάω',
#   'ἐπιεικής',
#   'νομίζω',
#   'βίος',
#   'χρόνος',
#   'λόγος',
#   'ἐπαινέω',
#   'ἀγών',
#   'ἁλίσκομαι',
#   'πολύς',
#   'κατηγορέω'],
#  ['ἔχω',
#   'παῖς',
#   'Καλλιστώ',
#   'Ἅβρων',
#   'θυγάτηρ',
#   'Καλλίας',
#   'Ἅβρων',
#   'ἀδελφή',
#   'ταμιεύω',
#   'στρατιωτικός',
#   'Χαιρώνδας',
#   'ἄρχων'],
#  ['κηδεία', 'λέγω', 'Δείναρχος', 'Πίστιος'],
#  ['καταλείπω', 'παῖς', 'Ἅβρων', 'Λυκοῦργος', 'Λυκόφρων'],
#  ['Ἅβρων', 'Λυκοῦργος', 'ἄπαις', 'μεταλλάσσω'],
#  ['Ἅβρων',
#   'πολιτεύω',
#   'μεταλλάσσω',
#   'Λυκόφρων',
#   'γαμέω',
#   'Καλλιστομάχη',
#   'Φίλιππος',
#   'Αἰξωνεύς',
#   'γεννάω',
#   'Καλλιστώ'],
#  ['γαμέω', 'Κλεόμβροτος', 'Δεινοκράτης', 'Ἀχαρνεύς', 'γεννάω', 'Λυκόφρων'],
#  ['πάππος', 'εἰσποιέω', 'Λυκόφρων'],
#  ['τελευτάω', 'ἄπαις'],
#  ['Λυκόφρων',
#   'τελευτή',
#   'γαμέω',
#   'Καλλιστώ',
#   'Σωκράτης',
#   'ἔχω',
#   'υἱός',
#   'Σύμμαχος'],
#  ['γίγνομαι', 'Ἀριστώνυμος', 'Χαρμίδης', 'Φιλίππη'],
#  ['Λύσανδρος', 'Μήδειος', 'ἐξηγητής', 'Εὐμολπίδαι', 'γίγνομαι'],
#  ['Τιμοθέα',
#   'Γλαῦκος',
#   'παῖς',
#   'Λαοδάμεια',
#   'Μήδειος',
#   'ἱερωσύνη',
#   'Ποσειδῶν',
#   'Ἐρεχθεύς',
#   'ἔχω',
#   'Φιλίππη',
#   'ἱεράομαι',
#   'Ἀθήνη'],
#  ['γαμέω', 'Διοκλῆς', 'Μελιτεύς', 'γεννάω', 'Διοκλῆς', 'ὁπλίτης', 'στρατηγέω'],
#  ['γαμέω', 'Ἡδίστης', 'Ἅβρων', 'Φιλιππίδης', 'Νικόστρατη', 'γεννάω'],
#  ['γαμέω',
#   'Νικόστρατη',
#   'Θεμιστοκλῆς',
#   'Θεόφραστος',
#   'δᾳδοῦχος',
#   'γεννάω',
#   'Θεόφραστος',
#   'Διοκλῆς'],
#  ['διατάσσω', 'ἱερωσύνη', 'Ποσειδῶν', 'Ἐρεχθεύς'],
#  ['φέρω', 'ῥήτωρ', 'λόγος'],
#  ['στεφανόω', 'δῆμος', 'εἰκών', 'τυγχάνω'],
#  ['ἀνάκειμαι',
#   'χάλκεος',
#   'εἰκών',
#   'Κεραμεικός',
#   'ψήφισμα',
#   'Ἀναξικράτης',
#   'ἄρχων'],
#  ['λαμβάνω',
#   'σίτησις',
#   'πρυτανεῖον',
#   'Λυκοῦργος',
#   'πρέσβυς',
#   'ἔκγονος',
#   'ψήφισμα'],
#  ['ἀποθνῄσκω',
#   'Λυκοῦργος',
#   'πρέσβυς',
#   'παῖς',
#   'Λυκόφρων',
#   'ἀμφισβητέω',
#   'δωρεά'],
#  ['λέγω', 'ἱερός'],
#  ['γράφω',
#   'Αὐτόλυκος',
#   'Ἀρεοπαγίτης',
#   'Λυσικλῆς',
#   'στρατηγός',
#   'Δημάδης',
#   'Δημέας',
#   'Μενέσαιχμος',
#   'πολύς',
#   'αἱρέω'],
#  ['κρίνω',
#   'Δίφιλος',
#   'ἀργύρειος',
#   'μέταλλον',
#   'μεσοκρινής',
#   'βαστάζω',
#   'ὑπέρκειμαι',
#   'βάρος',
#   'ὑφαιρέω',
#   'πλουτέω',
#   'νόμος'],
#  ['θάνατος',
#   'εἰμί',
#   'ἐπιτίμιον',
#   'ἁλίσκομαι',
#   'ποιέω',
#   'δραχμή',
#   'οὐσία',
#   'πολίτης',
#   'διανέμω',
#   'συνάγω',
#   'τάλαντον'],
#  ['μνᾶ'],
#  ['γράφω', 'εὔθυνα', 'Ἀριστογείτων', 'Λεωκράτης', 'Αὐτόλυκος', 'δειλία'],
#  ['ἐπικαλέω', 'Λυκοῦργος', 'ἶβις', 'φημί', 'Ἀριστοφάνης'],
#  ['ἶβις',
#   'Λυκοῦργος',
#   'Χαιρεφῶν',
#   'νυκτερίς',
#   'κατάγω',
#   'γένος',
#   'Βούτης',
#   'Ἐρεχθεύς',
#   'Γῆ',
#   'Ἥφαιστος',
#   'Λυκομήδης',
#   'Λυκοῦργος',
#   'δῆμος',
#   'ταφή',
#   'τιμάω'],
#  ['εἰμί',
#   'καταγωγή',
#   'γένος',
#   'ἱεράομαι',
#   'Ποσειδῶν',
#   'πίναξ',
#   'τέλειος',
#   'ἀνάκειμαι',
#   'Ἐρέχθειον',
#   'γράφω',
#   'Ἰσμηνίας',
#   'Χαλκιδεύς'],
#  ['εἰκών',
#   'ξύλινος',
#   'Λυκοῦργος',
#   'υἱός',
#   'Ἅβρων',
#   'Λυκοῦργος',
#   'Λυκόφρων',
#   'ἐργάζομαι',
#   'Τίμαρχος',
#   'Κηφισόδοτος',
#   'Πραξιτέλης',
#   'υἱός'],
#  ['πίναξ',
#   'ἀνατίθημι',
#   'Ἅβρων',
#   'παῖς',
#   'λαγχάνω',
#   'γένος',
#   'ἱερωσύνη',
#   'παραχωρέω',
#   'ἀδελφός',
#   'Λυκόφρων'],
#  ['ποιέω', 'Ἅβρων', 'προσδίδωμι', 'τρίαινα'],
#  ['διοικέω',
#   'ἀναγραφή',
#   'ποιέω',
#   'ἀνατίθημι',
#   'στήλη',
#   'κατασκευάζω',
#   'παλαίστρα',
#   'σκοπέω',
#   'βούλομαι'],
#  ['δύναμαι', 'ἐλέγχω', 'ἀνήρ', 'νοσφισμός'],
#  ['γράφω',
#   'Νεοπτόλεμος',
#   'Ἀντικλῆς',
#   'στεφανόω',
#   'εἰκών',
#   'ἀνατίθημι',
#   'ἐπαγγέλλω',
#   'χρυσόω',
#   'βωμός',
#   'Ἀπόλλων',
#   'ἀγορά',
#   'μαντεία',
#   'θεός'],
#  ['ψηφίζω',
#   'Διότιμος',
#   'Διοπείθης',
#   'Εὐωνυμεύς',
#   'τιμή',
#   'Κτησικλῆς',
#   'ἄρχων'],
#  ['Δημοσθένης',
#   'Δημοσθένης',
#   'Κλεοβούλη',
#   'Γύλων',
#   'θυγάτηρ',
#   'δῆμος',
#   'Παιανιεύς',
#   'καταλείπω',
#   'πατήρ',
#   'ἔτος',
#   'ἀδελφή',
#   'πενταέτης',
#   'ὀρφανία',
#   'χρόνος',
#   'μήτηρ',
#   'διάγω',
#   'σχολάζω',
#   'Ἰσοκράτης',
#   'φημί',
#   'πολύς',
#   'Ἰσαῖος',
#   'Χαλκιδεύς',
#   'εἰμί',
#   'Ἰσοκράτης',
#   'μαθητής',
#   'διάγω',
#   'Ἀθῆναι',
#   'ζηλέω',
#   'Θουκυδίδης',
#   'Πλάτων',
#   'φιλόσοφος',
#   'λέγω',
#   'σχολάζω'],
#  ['Ἡγησίας',
#   'Μάγνης',
#   'φημί',
#   'δέω',
#   'παιδαγωγός',
#   'Καλλίστρατος',
#   'Ἔμπεδος',
#   'Ἀφιδναῖος',
#   'ῥήτωρ',
#   'δόκιμος',
#   'ἱππαρχέω',
#   'ἀνατίθημι',
#   'βωμός',
#   'Ἑρμῆς',
#   'ἀγοραῖος',
#   'μέλλω',
#   'δῆμος',
#   'λέγω',
#   'ἀκούω'],
#  ['ἀκούω', 'ἐραστής', 'γίγνομαι', 'λόγος'],
#  ['ὀλίγος', 'ἀκούω', 'ἐπιδημέω'],
#  ['φεύγω', 'Θρᾴκη', 'γίγνομαι', 'ἔφηβος', 'παραβάλλω', 'Ἰσοκράτης', 'Πλάτων'],
#  ['Ἰσαῖος',
#   'ἀναλαμβάνω',
#   'οἰκία',
#   'τετραετής',
#   'χρόνος',
#   'διαπονέω',
#   'μιμέομαι',
#   'λόγος'],
#  ['Κτησίβιος',
#   'φημί',
#   'φιλοσοφία',
#   'Καλλίας',
#   'Συρακούσιος',
#   'πορίζω',
#   'Ζῆθος',
#   'Ἀμφιπολίτης',
#   'λόγος',
#   'Χαρικλής',
#   'Καρύστιος',
#   'Ἀλκιδάμας',
#   'ἀναλαμβάνω'],
#  ['τελειόω',
#   'ἐλαχύς',
#   'ἐπίτροπος',
#   'παραλαμβάνω',
#   'κρίνω',
#   'ἐπιτροπή',
#   'Τιμοκράτης',
#   'ἄρχω',
#   'εἰμί',
#   'Ἄφοβος',
#   'Θηριππίδης',
#   'Δημοφῶν',
#   'Δημέας'],
#  ['πρῶτος',
#   'κατηγορέω',
#   'ἀδελφός',
#   'μήτηρ',
#   'εἰμί',
#   'τάλαντον',
#   'τίμημα',
#   'δίκη',
#   'ἐπιγράφω'],
#  ['αἱρέω'],
#  ['καταδίκη', 'πράσσω', 'ἀφίημι', 'ἀργύριον', 'χάρις'],
#  ['Ἀριστοφῶν', 'προστασία', 'γῆρας', 'καταλείπω', 'χορηγός', 'γίγνομαι'],
#  ['μειδιάω',
#   'Ἀναγυράσιος',
#   'πλήσσω',
#   'θέατρον',
#   'χορηγέω',
#   'κρίσις',
#   'καθίστημι',
#   'λαμβάνω',
#   'ἀφίημι',
#   'δίκη'],
#  ['λέγω',
#   'νέος',
#   'εἰμί',
#   'σπήλαιον',
#   'ἀπέρχομαι',
#   'φιλολογέω',
#   'ἥμισυς',
#   'κεφαλή',
#   'ξυράω',
#   'προέρχομαι'],
#  ['στενός', 'κλίνη', 'κοιμάω', 'ταχύς', 'ἀνίστημι'],
#  ['ῥῶ',
#   'δύναμαι',
#   'λέγω',
#   'ἐκπονέω',
#   'ὦμος',
#   'μελετάω',
#   'κινέω',
#   'καταπαύω',
#   'παραρτάω',
#   'ὀβελίσκος',
#   'ξιφίδιον',
#   'ὀροφή',
#   'φοβέω',
#   'ἠρεμέω'],
#  ['προβαίνω',
#   'λόγος',
#   'ἰσχύς',
#   'ἔσοπτρον',
#   'ἰσομεγέθης',
#   'κατασκευάζω',
#   'ἀφοράω',
#   'μελετάω',
#   'ἐπανορθόω',
#   'ἐλλείπω'],
#  ['κατέρχομαι',
#   'Φαληρικός',
#   'κῦμα',
#   'ἐμβολή',
#   'σκέψις',
#   'ποιέω',
#   'θορυβέω',
#   'δῆμος',
#   'ἐξίστημι'],
#  ['πνεῦμα',
#   'ἐνδέω',
#   'Νεοπτόλεμος',
#   'ὑποκριτής',
#   'μυρίος',
#   'δίδωμι',
#   'ὅλος',
#   'περίοδος',
#   'λέγω'],
#  ['πολιτεύω',
#   'προσέρχομαι',
#   'διαιρέω',
#   'πόλις',
#   'φιλιππίζω',
#   'ἐλευθερία',
#   'δημηγορέω',
#   'ἀντιπολιτεύομαι',
#   'Φίλιππος',
#   'τάξις',
#   'αἱρέω'],
#  ['χρόνος',
#   'διατελέω',
#   'συμβουλεύω',
#   'κινδυνεύω',
#   'Φίλιππος',
#   'γίγνομαι',
#   'βοηθέω',
#   'συμπολιτεύω',
#   'Ὑπερείδης',
#   'Ναυσικλῆς',
#   'Πολυεύκτος',
#   'Διότιμος'],
#  ['σύμμαχος',
#   'Ἀθηναῖος',
#   'ποιέω',
#   'Θηβαῖος',
#   'Εὐβοεύς',
#   'Κερκυραῖος',
#   'Κορίνθιος',
#   'Βοιωτός',
#   'πολύς'],
#  ['ἐκπίπτω', 'ἐκκλησία', 'ἀθυμόω', 'βαδίζω'],
#  ['συντυγχάνω',
#   'Εὔνομος',
#   'Θριάσιος',
#   'πρεσβύτης',
#   'εἰμί',
#   'προτρέπω',
#   'Δημοσθένης',
#   'ὑποκριτής',
#   'Ἀνδρόνικος',
#   'λέγω',
#   'λόγος',
#   'ἔχω',
#   'λείπω',
#   'ὑπόκρισις',
#   'ἀπομνημονεύω',
#   'ἐκκλησία',
#   'λέγω'],
#  ['πιστεύω', 'Δημοσθένης', 'παραδίδωμι', 'Ἀνδρόνικος'],
#  ['ἔρομαι', 'πρῶτος', 'ῥητορικός', 'λέγω', 'ὑπόκρισις'],
#  ['δεύτερος', 'ὑπόκρισις'],
#  ['τρίτος', 'ὑπόκρισις'],
#  ['προέρχομαι',
#   'ἐκκλησία',
#   'λέγω',
#   'διασύρω',
#   'κωμῳδέω',
#   'Ἀντιφάνης',
#   'Τιμοκλῆς',
#   'γῆ',
#   'κρήνη',
#   'ποταμός',
#   'νᾶμα'],
#  ['ὄμνυμι', 'τρόπος', 'δῆμος', 'θόρυβος', 'κινέω'],
#  ['ὄμνυμι', 'Ἀσκληπιός', 'προπαροξύνω', 'Ἀσκλήπιος'],
#  ['παραδείκνυμι', 'λέγω'],
#  ['εἰμί', 'θεός', 'ἤπιος'],
#  ['θορυβέω'],
#  ['σχολάζω', 'Εὐβουλίδης', 'διαλεκτικός', 'Μιλήσιος', 'ἐπανορθόω'],
#  ['γίγνομαι',
#   'Ὀλυμπιακός',
#   'πανήγυρις',
#   'ἀκούω',
#   'Λάμαχος',
#   'Τερειναῖος',
#   'Φίλιππος',
#   'Ἀλέξανδρος',
#   'ἐγκώμιον',
#   'ἀναγιγνώσκω',
#   'Θηβαῖος',
#   'Ὀλύνθιος',
#   'κατατρέχω',
#   'παρανίστημι',
#   'ἀρχαῖος',
#   'ποιητής',
#   'μαρτυρία',
#   'προφέρω',
#   'Θηβαῖος',
#   'Ὀλύνθιος',
#   'πράσσω',
#   'παύω',
#   'λοιπός',
#   'Λάμαχος',
#   'φεύγω',
#   'πανήγυρις'],
#  ['Φίλιππος',
#   'ἀναφέρω',
#   'δημηγορία',
#   'λέγω',
#   'ἀκούω',
#   'λέγω',
#   'Δημοσθένης',
#   'χειροτονέω',
#   'ἀνήρ',
#   'πόλεμος'],
#  ['καλέω',
#   'λόγος',
#   'ὅμοιος',
#   'στρατιώτης',
#   'πολεμικός',
#   'δύναμις',
#   'Ἰσοκράτης',
#   'ἀθλητής'],
#  ['τέρψις', 'παρέχω', 'θεατρικός'],
#  ['ἔτος',
#   'γίγνομαι',
#   'λογίζομαι',
#   'Δεξίθεος',
#   'Καλλίμαχος',
#   'Ὀλύνθιος',
#   'ἵημι',
#   'πρεσβεία',
#   'βοήθεια',
#   'πιέζω',
#   'Φίλιππος',
#   'πόλεμος',
#   'πείθω',
#   'ἐκπέμπω',
#   'βοήθεια'],
#  ['Πλάτων', 'τελευτάω', 'Φίλιππος', 'Ὀλύνθιος', 'καταστρέφω'],
#  ['γιγνώσκω', 'Ξενοφῶν', 'Σωκρατικός', 'ἄρχω', 'ἀκμάζω'],
#  ['Ἑλληνικός', 'τελέω', 'Μαντίνεια', 'μάχη', 'ἄρχω', 'Χαρικλείδης'],
#  ['Τιμοκράτης', 'αἱρέω', 'ἐπίτροπος'],
#  ['φεύγω', 'Αἰσχίνης', 'δίκη', 'ἵππος', 'καταδιώκω'],
#  ['οἴομαι',
#   'συλλαμβάνω',
#   'προσπίπτω',
#   'συγκαλύπτω',
#   'ἀνίστημι',
#   'παραμυθέομαι',
#   'τάλαντον',
#   'δίδωμι',
#   'ἀργύριον'],
#  ['συμβουλεύω', 'δῆμος', 'ξενικός', 'Θάσος', 'τρέφω', 'τριηραρχέω', 'ἐκπλέω'],
#  ['σιτώνης', 'γίγνομαι', 'κατηγορέω', 'κλοπή', 'ἀφίημι'],
#  ['Φίλιππος',
#   'Ἐλατεία',
#   'καταλαμβάνω',
#   'Χαιρωνεία',
#   'μάχομαι',
#   'συνεξέρχομαι'],
#  ['δοκέω',
#   'τάξις',
#   'λείπω',
#   'φεύγω',
#   'βάτος',
#   'ἐπιλαμβάνω',
#   'χλαμύς',
#   'ἐπιστρέφω',
#   'λέγω',
#   'ζωγρέω'],
#  ['ἔχω', 'ἐπίσημον', 'ἀσπίς', 'ἀγαθός', 'τύχη'],
#  ['λέγω', 'ἐπιτάφιος', 'πίπτω'],
#  ['ἐπισκευή',
#   'πόλις',
#   'ἐπιμέλεια',
#   'προσέρχομαι',
#   'τεῖχος',
#   'ἐπιμελητής',
#   'χειροτονέω',
#   'ἴδιος',
#   'οὐσία',
#   'εἰσφέρω',
#   'ἀναλίσκω',
#   'ἀργύριον',
#   'μνᾶ'],
#  ['ἐπιδίδωμι', 'θεωρός', 'μυρίος'],
#  ['τριήρης', 'ἐπιβαίνω', 'περιπλέω', 'σύμμαχος', 'ἀργυρολογέω'],
#  ['στεφανόω',
#   'Δημομελώ',
#   'Ἀριστόνικος',
#   'Ὑπερείδης',
#   'χρύσεος',
#   'στέφανος',
#   'τελευταῖος',
#   'Κτησιφῶν'],
#  ['γράφω',
#   'ψήφισμα',
#   'παράνομος',
#   'Διόδοτος',
#   'Αἰσχίνης',
#   'ἀπολογέομαι',
#   'νικάω',
#   'πέμπτος',
#   'μέρος',
#   'ψῆφος',
#   'διώκω',
#   'μεταλαμβάνω'],
#  ['Ἀλέξανδρος',
#   'Ἀσία',
#   'στρατεύω',
#   'φεύγω',
#   'Ἅρπαλος',
#   'χρῆμα',
#   'Ἀθῆναι',
#   'πρῶτος',
#   'κωλύω',
#   'εἰσδέχομαι'],
#  ['εἰσπλέω', 'λαμβάνω', 'Δαρεικός', 'μετατάσσω'],
#  ['βούλομαι',
#   'Ἀθηναῖος',
#   'Ἀντίπατρος',
#   'παραδίδωμι',
#   'ἄνθρωπος',
#   'ἀντιλέγω',
#   'γράφω',
#   'ἀποτίθημι',
#   'χρῆμα',
#   'ἀκρόπολις',
#   'δῆμος',
#   'ἀριθμός',
#   'λέγω'],
#  ['φημί',
#   'Ἅρπαλος',
#   'συγκατακομίζω',
#   'τάλαντον',
#   'ἀναφέρω',
#   'ἀκρόπολις',
#   'εὑρίσκω',
#   'ὀλίγος',
#   'πολύς',
#   'φημί',
#   'Φιλόχορος'],
#  ['φεύγω',
#   'Ἅρπαλος',
#   'δεσμωτήριον',
#   'φυλάσσω',
#   'ἀφικνέομαι',
#   'Ἀλέξανδρος',
#   'πορεύω',
#   'Κρήτη',
#   'ἔνιοι',
#   'Ταίναρος',
#   'Λακωνικός',
#   'αἰτία',
#   'ἔχω',
#   'Δημοσθένης',
#   'δωροδοκία',
#   'ἀριθμός',
#   'ἀνακομίζω',
#   'μηνύω',
#   'φυλάσσω',
#   'ἀμέλεια'],
#  ['εἰσάγω',
#   'δικαστήριον',
#   'Ὑπερείδης',
#   'Πυθέας',
#   'Μενέσαιχμος',
#   'Ἱμεραῖος',
#   'Πάτροκλος',
#   'ποιέω',
#   'καταγιγνώσκω',
#   'Ἄρειος',
#   'πάγος',
#   'βουλή',
#   'ἁλίσκομαι',
#   'φεύγω',
#   'πενταπλασίων',
#   'ἀποτίνω',
#   'δύναμαι',
#   'ἔχω',
#   'αἰτία',
#   'τάλαντον',
#   'λαμβάνω',
#   'ἔνιοι',
#   'ὑπομένω',
#   'κρίσις'],
#  ['χρόνος',
#   'Ἀθηναῖος',
#   'Πολυεύκτος',
#   'πέμπω',
#   'πρεσβευτής',
#   'κοινός',
#   'Ἀρκάς',
#   'ἀφίστημι',
#   'Μακεδών',
#   'συμμαχία',
#   'Πολυεύκτος',
#   'πείθω',
#   'δύναμαι',
#   'ἐπιφαίνω',
#   'Δημοσθένης',
#   'συλλέγω',
#   'πείθω'],
#  ['θαυμάζω',
#   'χρόνος',
#   'κάθοδος',
#   'εὑρίσκω',
#   'ψήφισμα',
#   'γράφω',
#   'τριήρης',
#   'ἀποστέλλω'],
#  ['Ἀθηναῖος',
#   'ψηφίζω',
#   'ὀφέλλω',
#   'τάλαντον',
#   'κοσμέω',
#   'βωμός',
#   'σωτήρ',
#   'Ζεύς',
#   'Πειραιεύς',
#   'ἀφίημι',
#   'γράφω',
#   'ψήφισμα',
#   'Δήμων',
#   'Παιανιεύς',
#   'εἰμί',
#   'ἀνεψιός',
#   'εἰμί',
#   'πολιτεύω'],
#  ['Ἀντίπατρος',
#   'Λάμεια',
#   'Ἕλλην',
#   'συγκλείω',
#   'Ἀθηναῖος',
#   'εὐαγγέλιον',
#   'θύω',
#   'ἑταῖρος',
#   'Ἀγησίστρατος',
#   'φημί',
#   'γνώμη',
#   'ἔχω',
#   'πρᾶγμα'],
#  ['ἐπίσταμαι',
#   'λέγω',
#   'Ἕλλην',
#   'στάδιον',
#   'πολεμέω',
#   'οἶδα',
#   'δύναμαι',
#   'δόλιχος'],
#  ['Φάρσαλος',
#   'αἱρέω',
#   'Ἀντίπατρος',
#   'πολιορκέω',
#   'ἀπειλέω',
#   'Ἀθηναῖος',
#   'ῥήτωρ',
#   'ἐκδίδωμι',
#   'καταλείπω',
#   'Δημοσθένης',
#   'πόλις',
#   'φεύγω',
#   'πρῶτος',
#   'Αἴγινα',
#   'Αἰάκειος',
#   'καθέζομαι',
#   'φοβέω',
#   'Καλαυρία',
#   'μεθίστημι'],
#  ['ἐκδίδωμι',
#   'ῥήτωρ',
#   'Ἀθηναῖος',
#   'ψηφίζω',
#   'καθέζομαι',
#   'ἱκέτης',
#   'Ποσειδῶν',
#   'ἱερόν'],
#  ['ἔρχομαι',
#   'Ἀρχίας',
#   'Φυγαδόθηρος',
#   'ἐπικαλέω',
#   'παραβάλλω',
#   'Ἀναξιμένης',
#   'ῥήτωρ',
#   'πείθω',
#   'ἀνίστημι',
#   'φίλος',
#   'Ἀντίπατρος',
#   'γίγνομαι',
#   'λέγω',
#   'τραγῳδέω',
#   'πείθω',
#   'πείθω',
#   'συμβουλεύω'],
#  ['ἐπιχειρέω', 'βιάζω', 'κωλύω', 'πόλις'],
#  ['Δημοσθένης',
#   'φημί',
#   'σωτηρία',
#   'δέω',
#   'καταφεύγω',
#   'Καλαυρία',
#   'ἐλέγχω',
#   'Μακεδών',
#   'θεός',
#   'βιάζω'],
#  ['αἰτέω',
#   'γραμματεῖον',
#   'γράφω',
#   'Δημήτριος',
#   'Μάγνης',
#   'φημί',
#   'εἰκών',
#   'ἐλεγεῖον',
#   'ἐπιγράφω',
#   'Ἀθηναῖος',
#   'ἴσος',
#   'ῥώμη',
#   'γνώμη',
#   'Δημοσθένης',
#   'ἔχω',
#   'Ἕλλην',
#   'ἄρχω',
#   'Ἄρης',
#   'Μακεδών'],
#  ['κεῖμαι', 'εἰκών', 'περισχοίνισμα', 'βωμός', 'θεός', 'Πολυεύκτος', 'ποιέω'],
#  ['ἔνιοι', 'φημί', 'εὑρίσκω', 'γράφω', 'Δημοσθένης', 'Ἀντίπατρος', 'χαίρω'],
#  ['ἀποθνῄσκω', 'Φιλόχορος', 'φημί', 'φάρμακον', 'πίνω'],
#  ['Σάτυρος',
#   'συγγραφεύς',
#   'κάλαμος',
#   'φαρμάσσω',
#   'γράφω',
#   'ἄρχω',
#   'ἐπιστολή',
#   'γεύω',
#   'ἀποθνῄσκω'],
#  ['Ἐρατοσθένης',
#   'πολύς',
#   'δείδω',
#   'Μακεδών',
#   'βραχίων',
#   'κρίκος',
#   'περίκειμαι',
#   'φαρμάσσω'],
#  ['εἰμί', 'φημί', 'συνέχω', 'πνεῦμα', 'ἀποθνῄσκω'],
#  ['λέγω', 'σφραγίς', 'φάρμακον', 'γεύω'],
#  ['βιόω', 'πολύς', 'λέγω', 'ἔτος', 'ἐλαχύς'],
#  ['πολιτεύω'],
#  ['Φίλιππος',
#   'θνῄσκω',
#   'λαμπρός',
#   'ἐσθής',
#   'προέρχομαι',
#   'ἔχω',
#   'θυγάτηρ',
#   'τελευτάω',
#   'ἐφήδομαι',
#   'Μακεδών',
#   'θάνατος'],
#  ['συνεργέω', 'Θηβαῖος', 'Ἀλέξανδρος', 'πολεμέω', 'Ἕλλην', 'ἐπιρρώννυμι'],
#  ['Θῆβαι',
#   'κατασκάπτω',
#   'ἐξαιτέω',
#   'Ἀθηναῖος',
#   'Ἀλέξανδρος',
#   'ἀπειλέω',
#   'δίδωμι'],
#  ['στρατεύω',
#   'Πέρσης',
#   'αἰτέω',
#   'ναυτικός',
#   'Ἀθηναῖος',
#   'ἀντιλέγω',
#   'ἄδηλος',
#   'λέγω',
#   'παρέχω',
#   'χράω'],
#  ['καταλείπω', 'παῖς', 'Σάμιος', 'γυνή', 'εὐδόκιμος', 'Ἡλιόδωρος', 'θυγάτηρ'],
#  ['θυγάτηρ', 'ἔχω', 'παῖς', 'εἰμί', 'γάμος', 'τελευτάω'],
#  ['ἔχω',
#   'ἀδελφή',
#   'Λάχος',
#   'Λευκονοεύς',
#   'ἀδελφιδέος',
#   'Δημοχάρης',
#   'γίγνομαι',
#   'ἀνήρ',
#   'πόλεμος',
#   'ἀγαθός',
#   'πολιτικός',
#   'λόγος',
#   'κακός'],
#  ['εἰμί',
#   'εἰκών',
#   'πρυτανεῖον',
#   'εἰσέρχομαι',
#   'ἑστία',
#   'δεξιός',
#   'πρῶτος',
#   'περιζώννυμαι',
#   'ἱμάτιον',
#   'ξίφος'],
#  ['δημηγορέω', 'λέγω', 'Ἀντίπατρος', 'ἐξαιτέω', 'ῥήτωρ'],
#  ['χρόνος',
#   'Ἀθηναῖος',
#   'σίτησις',
#   'πρυτανεῖον',
#   'συγγενής',
#   'Δημοσθένης',
#   'δίδωμι',
#   'τελευτάω',
#   'εἰκών',
#   'ἀνατίθημι',
#   'ἀγορά',
#   'Γοργίας',
#   'ἄρχων',
#   'αἰτέω',
#   'δωρεά',
#   'ἀδελφιδέος',
#   'Δημοχάρης'],
#  ['υἱός',
#   'Λάχης',
#   'Δημοχάρης',
#   'Λευκονοεύς',
#   'αἰτέω',
#   'δωρεά',
#   'Πυθάρατος',
#   'ἄρχων',
#   'δέκατος',
#   'ἔτος',
#   'εἰκών',
#   'στάσις',
#   'ἀγορά',
#   'σίτησις',
#   'πρυτανεῖον',
#   'ἔκγονος',
#   'πρέσβυς',
#   'προεδρία',
#   'ἀγών'],
#  ['εἰμί',
#   'ψήφισμα',
#   'ἀμφότερος',
#   'ἀναγράφω',
#   'εἰκών',
#   'Δημοχάρης',
#   'πρυτανεῖον',
#   'μετακομίζω',
#   'προλέγω'],
#  ['φέρω', 'λόγος', 'γνήσιος'],
#  ['φημί',
#   'βιόω',
#   'γυναικεῖος',
#   'ἔσθος',
#   'χράω',
#   'κωμάζω',
#   'Βάταλος',
#   'ἐπικαλέω'],
#  ['ὄνομα', 'τροφός', 'λέγω', 'λοιδορέω'],
#  ['Διογένης',
#   'κύων',
#   'θεάομαι',
#   'καπηλεῖον',
#   'αἰσχύνω',
#   'ὑποχωρέω',
#   'λέγω',
#   'ὑποχωρέω',
#   'καπηλεῖον',
#   'εἰμί'],
#  ['λέγω', 'παρασκώπτω', 'λόγος', 'Σκύθης', 'εἰμί', 'μάχη', 'ἀστικός'],
#  ['λαμβάνω',
#   'Ἐφιάλτης',
#   'χρυσίον',
#   'δημαγωγός',
#   'πρεσβεύω',
#   'βασιλεύς',
#   'χρῆμα',
#   'φέρω',
#   'ἵημι',
#   'διανέμω',
#   'δημαγωγός',
#   'Φίλιππος',
#   'ἐξάπτω',
#   'πόλεμος'],
#  ['ἴδιος', 'δωροδοκέω', 'βασιλεύς', 'φημί', 'δαρεικός'],
#  ['Ἀναξίλης',
#   'Ὠρείτης',
#   'ξένος',
#   'γίγνομαι',
#   'συλλαμβάνω',
#   'βασανίζω',
#   'κατάσκοπος',
#   'ἐκλέγω',
#   'ψηφίζω',
#   'παραδίδωμι'],
#  ['λέγω',
#   'κωλύω',
#   'Ἀθηναῖος',
#   'ἐκκλησία',
#   'βραχύς',
#   'φημί',
#   'βούλομαι',
#   'λέγω',
#   'σιωπάω',
#   'νεανίας',
#   'λέγω',
#   'θέρος',
#   'ὥρα',
#   'μισθόω',
#   'ἄστυ',
#   'ὄνος'],
#  ['μεσόω', 'ἡμέρα', 'φλέγω', 'ἥλιος', 'βούλομαι', 'ὑποδύω', 'σκιά'],
#  ['ἔργω', 'μισθόω', 'ὄνος', 'σκιά', 'λέγω', 'μισθόω', 'ἔχω', 'ἐξουσία'],
#  ['λέγω', 'ἀπέρχομαι'],
#  ['Ἀθηναῖος',
#   'ἐπέχω',
#   'δέω',
#   'πέρας',
#   'ἐπιτίθημι',
#   'λόγος',
#   'ὄνος',
#   'σκιά',
#   'φημί',
#   'βούλομαι',
#   'ἀκούω',
#   'λέγω',
#   'σπουδαῖος',
#   'πρᾶγμα',
#   'βούλομαι'],
#  ['Πῶλος',
#   'ὑποκριτής',
#   'λέγω',
#   'ἡμέρα',
#   'ἀγωνίζομαι',
#   'τάλαντον',
#   'λαμβάνω',
#   'μισθός',
#   'λέγω',
#   'τάλαντον',
#   'ἡμέρα',
#   'σιωπάω'],
#  ['παραφθείρω',
#   'φωνή',
#   'ἐκκλησία',
#   'θορυβέω',
#   'ὑποκριτής',
#   'φημί',
#   'δέω',
#   'κρίνω',
#   'φωνή',
#   'ῥήτωρ',
#   'γνώμη'],
#  ['ὀνειδίζω',
#   'Ἐπικλέης',
#   'σκοπέω',
#   'αἰσχύνω',
#   'λέγω',
#   'δῆμος',
#   'συμβουλεύω',
#   'αὐτοσχεδιάζω'],
#  ['ἱστορέω', 'λύχνος', 'σβέννυμι', 'ἔτος', 'γίγνομαι', 'διακριβόω', 'λόγος'],
#  ['φημί', 'ὑδροποσία', 'χράω'],
#  ['γιγνώσκω',
#   'Λυσίας',
#   'ῥήτωρ',
#   'Ἰσοκράτης',
#   'ὁράω',
#   'πολιτεύω',
#   'Χαιρωνεία',
#   'μάχη',
#   'Σωκρατικός',
#   'φιλόσοφος'],
#  ['πολύς', 'λόγος', 'λέγω', 'αὐτοσχεδιάζω', 'φύω'],
#  ['πρῶτος',
#   'γράφω',
#   'στεφανόω',
#   'χρύσεος',
#   'στέφανος',
#   'Ἀριστόνικος',
#   'Νικοφάνης',
#   'Ἀναγυράσιος',
#   'ὑπόμνυμαι',
#   'Διώνδας'],
#  ['Ὑπερείδης',
#   'Γλαύκιππος',
#   'εἰμί',
#   'πατήρ',
#   'Διονύσιος',
#   'δῆμος',
#   'Κολλυτεύς'],
#  ['ἔχω',
#   'υἱός',
#   'ὁμώνυμος',
#   'πατήρ',
#   'Γλαύκιππος',
#   'ῥήτωρ',
#   'λόγος',
#   'συγγράφω'],
#  ['Ἀλφίνους', 'γίγνομαι'],
#  ['ἀκροατής',
#   'Πλάτων',
#   'γίγνομαι',
#   'φιλόσοφος',
#   'Λυκοῦργος',
#   'Ἰσοκράτης',
#   'ῥήτωρ',
#   'πολιτεύω',
#   'χρόνος',
#   'Ἀλέξανδρος',
#   'Ἑλληνικός',
#   'ἅπτω',
#   'πρᾶγμα'],
#  ['στρατηγός', 'αἰτέω', 'Ἀθηναῖος', 'ἀντιλέγω', 'τριήρης'],
#  ['συμβουλεύω',
#   'Ταίναρος',
#   'ξενικός',
#   'διαλύω',
#   'Χάρης',
#   'ἡγέομαι',
#   'στρατηγός',
#   'διάκειμαι'],
#  ['πρῶτος', 'μισθός', 'δίκη', 'λέγω'],
#  ['δοκέω',
#   'κοινωνέω',
#   'Περσικός',
#   'χρῆμα',
#   'Ἐφιάλτης',
#   'τριήραρχος',
#   'αἱρέω',
#   'Βυζάντιον',
#   'πολιορκέω',
#   'Φίλιππος',
#   'βοηθός',
#   'Βυζάντιος',
#   'ἐκπέμπω',
#   'ἐνιαυτός',
#   'ὑφίστημι',
#   'χορηγέω',
#   'λειτουργία',
#   'ἀφίημι'],
#  ['γράφω',
#   'Δημοσθένης',
#   'τιμή',
#   'ψήφισμα',
#   'Διώνδας',
#   'παράνομος',
#   'γράφω',
#   'ἀποφεύγω'],
#  ['φίλος', 'εἰμί', 'Δημοσθένης', 'Λυσικλῆς', 'Λυκοῦργος', 'ἐμμένω', 'τέλος'],
#  ['Λυσικλῆς',
#   'Λυκοῦργος',
#   'θνῄσκω',
#   'Δημοσθένης',
#   'Ἅρπαλος',
#   'δωροδοκέω',
#   'κρίνω',
#   'προχειρίζω',
#   'μόνος',
#   'μένω',
#   'ἀδωροδόκητος',
#   'κατηγορέω'],
#  ['κρίνω',
#   'Ἀριστογείτων',
#   'παράνομος',
#   'γράφω',
#   'Χαιρώνεια',
#   'μέτοικος',
#   'πολίτης',
#   'ποιέω',
#   'δοῦλος',
#   'ἐλεύθερος',
#   'ἱερόν',
#   'παῖς',
#   'γυνή',
#   'Πειραιεύς',
#   'ἀποτίθημι',
#   'ἀποφεύγω'],
#  ['αἰτιάομαι',
#   'παροράω',
#   'πολύς',
#   'νόμος',
#   'ψήφισμα',
#   'ἐπισκοτέω',
#   'φημί',
#   'Μακεδών',
#   'ὅπλον'],
#  ['ψήφισμα', 'γράφω', 'Χαιρωνεία', 'μάχη'],
#  ['νεκρός',
#   'δίδωμι',
#   'ἀναίρεσις',
#   'Φίλιππος',
#   'φοβέω',
#   'δίδωμι',
#   'ἔρχομαι',
#   'Λεβαδεία',
#   'κῆρυξ'],
#  ['Κραννών',
#   'συμβαίνω',
#   'ἐξαιτέω',
#   'Ἀντίπατρος',
#   'μέλλω',
#   'ἐκδίδωμι',
#   'δῆμος',
#   'φεύγω',
#   'πόλις',
#   'Αἴγινα',
#   'καταψηφίζομαι'],
#  ['συμβάλλω',
#   'Δημοσθένης',
#   'διαφορά',
#   'ἀπολογέομαι',
#   'ἀπαλλάσσω',
#   'Ἀρχίας',
#   'Φυγαδόθηρος',
#   'ἐπικαλέω',
#   'Θούριος',
#   'γένος',
#   'ὑποκριτής',
#   'πρῶτος',
#   'Ἀντίπατρος',
#   'βοηθέω',
#   'λαμβάνω',
#   'βία',
#   'ἱερόν',
#   'Ποσειδῶν',
#   'ἔχω',
#   'ἄγαλμα'],
#  ['ἄγω',
#   'Ἀντίπατρος',
#   'Κόρινθος',
#   'βασανίζω',
#   'διεσθίω',
#   'γλῶσσα',
#   'ἐκλέγω',
#   'πόλις',
#   'ἀπόρρητος',
#   'δύναμαι'],
#  ['τελευτάω', 'Πυανεψιών', 'ἔνατος', 'ἵστημι'],
#  ['Ἕρμιππος',
#   'φημί',
#   'γλωσσοτομέω',
#   'Μακεδονία',
#   'ἔρχομαι',
#   'ῥίπτω',
#   'ἄταφος',
#   'Ἀλφίνους',
#   'ἀνεψιός',
#   'εἰμί',
#   'Γλαύκιππος',
#   'υἱός',
#   'υἱός',
#   'Φιλοπείθης',
#   'ἰατρός',
#   'λαμβάνω',
#   'ἐξουσία',
#   'σῶμα',
#   'καίω',
#   'ὀστέον',
#   'κομίζω',
#   'Ἀθῆναι',
#   'προσήκω',
#   'Ἀθηναῖος',
#   'Μακεδών',
#   'δόγμα'],
#  ['κελεύω', 'φεύγω', 'οἰκεῖος', 'θάπτω'],
#  ['Κλεωναί',
#   'ἀποθνῄσκω',
#   'λέγω',
#   'ἀπάγω',
#   'γλωσσοτομέω',
#   'διαφθείρω',
#   'προλέγω',
#   'τρόπος'],
#  ['οἰκεῖος',
#   'ὀστέον',
#   'λαμβάνω',
#   'θάπτω',
#   'γονεύς',
#   'Ἱππάς',
#   'πύλη',
#   'φημί',
#   'Ἡλιόδωρος',
#   'τρίτος',
#   'μνῆμα'],
#  ['κατεραρείλπω', 'μνῆμα', 'εἰμί', 'ἄδηλος'],
#  ['δημηγορία', 'διαφέρω', 'λέγω'],
#  ['τάσσω', 'ἔνιοι', 'Δημοσθένης'],
#  ['φέρω', 'λόγος', 'γνήσιος', 'εἰμί'],
#  ['γίγνομαι',
#   'ἀφροδίσιος',
#   'καταφερής',
#   'ἐκβάλλω',
#   'υἱός',
#   'εἰσάγω',
#   'Μυρρίνη',
#   'πολυτελής',
#   'ἑταίρα',
#   'Πειραιεύς',
#   'ἔχω',
#   'Ἀρισταγόρας',
#   'Ἐλευσίς',
#   'ἴδιος',
#   'κτῆμα',
#   'Φίλα',
#   'Θηβαῖος',
#   'μνᾶ',
#   'λυτρόω'],
#  ['ποιέω', 'περίπατος', 'ἰχθυόπωλις', 'ἔοικα'],
#  ['δίκη', 'Φρύνη', 'ἑταίρα', 'ἀσεβέω', 'κρίνω', 'συνεξετάζω'],
#  ['ἀρχή', 'λόγος', 'δηλόω'],
#  ['μέλλω',
#   'ἁλίσκομαι',
#   'παράγω',
#   'μέσος',
#   'περιρρήσσω',
#   'ἐσθής',
#   'ἐπιδείκνυμι',
#   'στέρνον',
#   'γυνή',
#   'δικαστής',
#   'κάλλος',
#   'ἀφοράω',
#   'ἀφίημι'],
#  ['συντίθημι', 'Δημοσθένης', 'ἔγκλημα', 'φωράω'],
#  ['νοσέω',
#   'Ὑπερείδης',
#   'ἥκω',
#   'οἰκία',
#   'Δημοσθένης',
#   'ἐπισκοπέω',
#   'καταλαμβάνω',
#   'κατέχω',
#   'βιβλίον'],
#  ['ἀγανακτέω',
#   'λέγω',
#   'φίλος',
#   'εἰμί',
#   'λυπέω',
#   'ἐχθρός',
#   'γίγνομαι',
#   'κωλύω',
#   'πράσσω'],
#  ['ψηφίζω', 'τιμή', 'Ἰόλη', 'δοκέω', 'Ἀλέξανδρος', 'φάρμακον', 'δίδωμι'],
#  ['κοινωνέω',
#   'Λεωσθένης',
#   'Λαμιακός',
#   'πόλεμος',
#   'πίπτω',
#   'λέγω',
#   'ἐπιτάφιος'],
#  ['Φίλιππος',
#   'πλέω',
#   'Εὔβοια',
#   'παρασκευάζω',
#   'Ἀθηναῖος',
#   'ἔχω',
#   'τριήρης',
#   'ἀθροίζω',
#   'ἐπίδοσις',
#   'πρῶτος',
#   'παῖς',
#   'ἐπιδίδωμι',
#   'τριήρης'],
#  ['συνίστημι',
#   'Δήλιος',
#   'ἀμφισβήτημα',
#   'δέω',
#   'προΐστημι',
#   'ἱερός',
#   'αἱρέω',
#   'Αἰσχίνης',
#   'συλλέγω',
#   'Ἄρειος',
#   'πάγος',
#   'βουλή',
#   'Ὑπερείδης',
#   'χειροτονέω'],
#  ['εἰμί', 'λόγος', 'Δηλιακός', 'ἐπιγράφω', 'πρεσβεύω', 'Ῥόδιος'],
#  ['ἥκω',
#   'Ἀντίπατρος',
#   'πρέσβυς',
#   'ἐπαινέω',
#   'Ἀντίπατρος',
#   'χρηστός',
#   'ἀπαντάω',
#   'λέγω',
#   'οἶδα',
#   'χρηστός',
#   'ὑπάρχω',
#   'δέω',
#   'χρηστός',
#   'δεσπότης'],
#  ['λέγω',
#   'ὑπόκρισις',
#   'δημηγορέω',
#   'διηγέομαι',
#   'πράσσω',
#   'ἐνοχλέω',
#   'δικαστής'],
#  ['πέμπω',
#   'Ἠλεῖος',
#   'ἀπολογέομαι',
#   'Κάλλιππος',
#   'ἀθλητής',
#   'ἔχω',
#   'αἰτία',
#   'φθείρω',
#   'ἀγών',
#   'νικάω'],
#  ['γράφω',
#   'Φωκίων',
#   'δωρεά',
#   'λέγω',
#   'Μειδίας',
#   'Μειδίας',
#   'Ἀναγυράσιος',
#   'Ξένιος',
#   'ἄρχων',
#   'Γαμηλιών',
#   'ἕβδομος',
#   'φθίω',
#   'ἡσσάομαι'],
#  ['Δείναρχος',
#   'Σωκράτης',
#   'Σώστρατος',
#   'ἐγχώριος',
#   'δοκέω',
#   'Κορίνθιος',
#   'ἀφικνέομαι',
#   'Ἀθῆναι',
#   'νέος',
#   'χρόνος',
#   'Ἀλέξανδρος',
#   'Ἀσία',
#   'στρατεύω',
#   'κατοικέω',
#   'ἀκροατής',
#   'γίγνομαι',
#   'Θεόφραστος',
#   'διαδέχομαι',
#   'Ἀριστοτέλης',
#   'διατριβή',
#   'ὁμιλέω',
#   'Δημήτριος',
#   'Φαληρεύς'],
#  ['πολιτεύω', 'Ἀντίπατρος', 'τελευτή', 'ἀναιρέω', 'ῥήτωρ', 'φεύγω'],
#  ['φίλος',
#   'Κάσσανδρος',
#   'γίγνομαι',
#   'πολύς',
#   'προκόπτω',
#   'χρῆμα',
#   'λόγος',
#   'εἰσπράσσω',
#   'δέω',
#   'συγγράφω'],
#  ['ἀντιτάσσω', 'ἐπιφανής', 'ῥήτωρ', 'δῆμος', 'παρέρχομαι'],
#  ['εἰμί'],
#  ['ἐναντιόομαι', 'λόγος', 'συγγράφω'],
#  ['Ἅρπαλος',
#   'διαδιδράσκω',
#   'πολύς',
#   'λόγος',
#   'συγγράφω',
#   'αἰτία',
#   'λαμβάνω',
#   'δωροδοκέω',
#   'κατήγορος',
#   'ἐκδίδωμι'],
#  ['χρόνος',
#   'αἰτιάομαι',
#   'λόγος',
#   'παραγίγνομαι',
#   'Ἀντίπατρος',
#   'Κάσσανδρος',
#   'κατάληψις',
#   'Μουνυχία',
#   'Ἀντίγονος',
#   'Δημήτριος',
#   'φρουρέω',
#   'Ἀναξικράτης',
#   'ἄρχων',
#   'ἐξαργυρίζω',
#   'πολύς',
#   'οὐσία',
#   'φεύγω',
#   'Χαλκίς'],
#  ['διατρίβω',
#   'φυγή',
#   'ἔτος',
#   'πολύς',
#   'οὐσία',
#   'κτάομαι',
#   'κατέρχομαι',
#   'πράσσω',
#   'κάθοδος',
#   'Θεόφραστος',
#   'φυγάς'],
#  ['καταλύω',
#   'Πρόξενος',
#   'ἑταῖρος',
#   'χρυσίον',
#   'ἀπόλλυμι',
#   'γηραιός',
#   'εἰμί',
#   'ὅρασις',
#   'ἀσθενής',
#   'βούλομαι',
#   'Πρόξενος',
#   'ἀναζητέω',
#   'λαγχάνω',
#   'δίκη',
#   'πρῶτος',
#   'λέγω',
#   'δικαστήριον'],
#  ['σῴζω', 'λόγος'],
#  ['φέρω', 'λόγος', 'γνήσιος'],
#  ['ἔνιοι', 'παραλαμβάνω', 'Ἀριστογείτων'],
#  ['ζηλωτής', 'γίγνομαι', 'Ὑπερείδης', 'παθητικός', 'Δημοσθένης', 'σφοδρός'],
#  ['σχῆμα', 'μιμητής', 'ὑπάρχω'],
#  ['Δημοχάρης',
#   'Λάχης',
#   'Λευκονοεύς',
#   'αἰτέω',
#   'Δημοσθένης',
#   'Δημοσθένης',
#   'Παιανιεύς',
#   'δωρεά',
#   'εἰκών',
#   'χάλκεος',
#   'ἀγορά',
#   'σίτησις',
#   'πρυτανεῖον',
#   'προεδρία',
#   'ἔκγονος',
#   'πρέσβυς'],
#  ['εὐεργέτης',
#   'σύμβουλος',
#   'γίγνομαι',
#   'πολύς',
#   'καλός',
#   'δῆμος',
#   'Ἀθηναῖος',
#   'οὐσία',
#   'κοινός',
#   'καθίημι',
#   'ἐφοράω',
#   'τάλαντον',
#   'τριήρης',
#   'δῆμος',
#   'ἐλευθερόω',
#   'Εὔβοια'],
#  ['Ἑλλήσποντος', 'Κηφισόδωρος', 'ἐκπλέω'],
#  ['Χάρης', 'Φωκίων', 'στρατηγός', 'ἐκπέμπω', 'Βυζάντιον', 'δῆμος'],
#  ['λυτρόω', 'πολύς', 'ἁλίσκομαι', 'Πύδνα', 'Μεθώνη', 'Ὄλυνθος', 'Φίλιππος'],
#  ['χορηγία',
#   'ἀνήρ',
#   'ἐφοράω',
#   'ἐκλείπω',
#   'Πανδιονίδης',
#   'χορηγέω',
#   'ἐπιδίδωμι',
#   'καθοπλίζω',
#   'πολίτης',
#   'ἐλλείπω'],
#  ['τειχοποιΐα',
#   'ἀναλίσκω',
#   'χειροτονέω',
#   'δῆμος',
#   'ἐπιδίδωμι',
#   'τάλαντον',
#   'ἐπιδίδωμι',
#   'τάφρος',
#   'Πειραιεύς',
#   'ταφρεύω'],
#  ['Χαιρωνεία',
#   'μάχη',
#   'ἐπιδίδωμι',
#   'τάλαντον',
#   'σιτωνία',
#   'ἐπιδίδωμι',
#   'σιτοδεία',
#   'τάλαντον'],
#  ['συμμαχία',
#   'δῆμος',
#   'προσάγω',
#   'πείθω',
#   'εὐεργέτης',
#   'γίγνομαι',
#   'σύμβουλος',
#   'Θηβαῖος',
#   'πείθω',
#   'Θηβαῖος',
#   'Εὐβοεύς',
#   'Κορίνθιος',
#   'Μεγαρεύς',
#   'Ἀχαιός',
#   'Λοκροί',
#   'Βυζάντιος',
#   'Μεσσήνιος',
#   'δύναμις',
#   'συνίστημι',
#   'δῆμος',
#   'σύμμαχος',
#   'πεζός',
#   'μυρίος',
#   'ἱππεύς',
#   'σύνταξις',
#   'χρῆμα',
#   'πείθω',
#   'πρεσβεύω',
#   'δίδωμι',
#   'σύμμαχος',
#   'πόλεμος',
#   'πολύς',
#   'τάλαντον'],
#  ['κωλύω',
#   'Πελοποννήσιος',
#   'Θῆβαι',
#   'Ἀλέξανδρος',
#   'βοηθέω',
#   'χρῆμα',
#   'δίδωμι',
#   'πρεσβεύω'],
#  ['πολύς',
#   'καλός',
#   'δῆμος',
#   'σύμβουλος',
#   'γίγνομαι',
#   'πολιτεύω',
#   'ἐλευθερία',
#   'δημοκρατία',
#   'ἀγαθός'],
#  ['φεύγω',
#   'ὀλιγαρχία',
#   'καταλύω',
#   'δῆμος',
#   'τελευτάω',
#   'Καλαυρία',
#   'δῆμος',
#   'εὔνοια',
#   'πέμπω',
#   'στρατιώτης',
#   'Ἀντίπατρος',
#   'διαμένω',
#   'πλῆθος',
#   'εὔνοια',
#   'οἰκειότης',
#   'ὑποχείριος',
#   'γίγνομαι',
#   'ἐχθρός',
#   'ἀνάξιος',
#   'κίνδυνος',
#   'πράσσω',
#   'δῆμος'],
#  ['ἄρχων', 'Πυθάρατος'],
#  ['Λάχης',
#   'Δημοχάρης',
#   'Λευκονοεύς',
#   'αἰτέω',
#   'δωρεά',
#   'βουλή',
#   'δῆμος',
#   'Ἀθηναῖος',
#   'Δημοχάρης',
#   'Λάχης',
#   'Λευκονοεύς',
#   'εἰκών',
#   'χάλκεος',
#   'ἀγορά',
#   'σίτησις',
#   'πρυτανεῖον',
#   'ἔκγονος',
#   'πρέσβυς',
#   'προεδρία',
#   'ἀγών',
#   'εὐεργέτης',
#   'σύμβουλος',
#   'γίγνομαι',
#   'ἀγαθός',
#   'δῆμος',
#   'Ἀθηναῖος',
#   'εὐεργετέω',
#   'δῆμος',
#   'πρεσβεύω',
#   'γράφω',
#   'πολιτεύω'],
#  ['οἰκοδομή',
#   'τεῖχος',
#   'παρασκευή',
#   'ὅπλον',
#   'βέλος',
#   'μηχάνημα',
#   'ὀχυρόω',
#   'πόλις',
#   'τετραετής',
#   'πόλεμος',
#   'εἰρήνη',
#   'ἀνοχή',
#   'συμμαχία',
#   'ποιέω',
#   'Βοιωτός'],
#  ['ἐκπίπτω', 'καταλύω', 'δῆμος'],
#  ['κατέρχομαι',
#   'Διοκλῆς',
#   'ἄρχων',
#   'δῆμος',
#   'συστέλλω',
#   'διοίκησις',
#   'πρῶτος',
#   'φείδομαι',
#   'ὑπάρχω',
#   'πρεσβεύω',
#   'Λυσίμαχος',
#   'λαμβάνω',
#   'δῆμος',
#   'τάλαντον',
#   'ἀργύριον'],
#  ['γράφω',
#   'πρεσβεία',
#   'Πτολεμαῖος',
#   'Αἴγυπτος',
#   'ἐκπλέω',
#   'κομίζω',
#   'τάλαντον',
#   'ἀργύριον',
#   'δῆμος'],
#  ['Ἀντίπατρος',
#   'πρεσβεύω',
#   'λαμβάνω',
#   'τάλαντον',
#   'ἀργύριον',
#   'Ἐλευσίς',
#   'κομίζω',
#   'δῆμος',
#   'πείθω',
#   'αἱρέω',
#   'δῆμος',
#   'πράσσω',
#   'φεύγω',
#   'δημοκρατία',
#   'μετέχω',
#   'ὀλιγαρχία',
#   'ἀρχή',
#   'ἄρχω',
#   'καταλύω',
#   'δῆμος'],
#  ['μόνος',
#   'Ἀθηναῖος',
#   'ἡλικία',
#   'πολιτεύω',
#   'μελετάω',
#   'πατρίς',
#   'κινέω',
#   'πολίτευμα',
#   'δημοκρατία'],
#  ['κρίσις',
#   'νόμος',
#   'δικαστήριον',
#   'οὐσία',
#   'Ἀθηναῖος',
#   'ἀσφαλής',
#   'ποιέω',
#   'πολιτεία',
#   'ὑπεναντίος',
#   'δημοκρατία',
#   'πράσσω',
#   'λόγος',
#   'ἔργον'],
#  ['Λυκόφρων',
#   'Λυκοῦργος',
#   'Βουτάδης',
#   'ἀπογράφω',
#   'εἰμί',
#   'σίτησις',
#   'πρυτανεῖον',
#   'δίδωμι',
#   'δωρεά',
#   'δῆμος',
#   'Λυκοῦργος',
#   'Βουτάδης'],
#  ['Ἀναξικράτης',
#   'ἄρχων',
#   'Ἀντιοχίς',
#   'ἕκτος',
#   'πρυτανεία',
#   'Στρατοκλῆς',
#   'Εὐθύδημος',
#   'Διομειεύς',
#   'λέγω'],
#  ['Λυκοῦργος',
#   'Λυκόφρων',
#   'Βουτάδης',
#   'παραλαμβάνω',
#   'πρόγονος',
#   'οἰκεῖος',
#   'παλαιός',
#   'δῆμος',
#   'εὔνοια',
#   'πρόγονος',
#   'Λυκοῦργος',
#   'Λυκομήδης',
#   'Λυκοῦργος',
#   'ζάω',
#   'τιμάω',
#   'δῆμος',
#   'τελευτάω',
#   'ἀνδραγαθία',
#   'δίδωμι',
#   'δῆμος',
#   'δημόσιος',
#   'ταφή',
#   'Κεραμεικός',
#   'Λυκοῦργος',
#   'πολιτεύω',
#   'νόμος',
#   'πολύς',
#   'καλός',
#   'τίθημι',
#   'πατρίς',
#   'γίγνομαι',
#   'κοινός',
#   'πρόσοδος',
#   'ταμίας',
#   'πόλις',
#   'πενταετηρίς',
#   'διανέμω',
#   'κοινός',
#   'πρόσοδος',
#   'μυρίος',
#   'τάλαντον',
#   'πολύς',
#   'ἰδιώτης',
#   'πίστις',
#   'λαμβάνω',
#   'προδανείζω',
#   'πόλις',
#   'καιρός',
#   'δῆμος',
#   'τάλαντον',
#   'δοκέω',
#   'διοικέω',
#   'στεφανόω',
#   'πόλις',
#   'αἱρέω',
#   'δῆμος',
#   'χρῆμα',
#   'πολύς',
#   'συνάγω',
#   'ἀκρόπολις',
#   'παρασκευάζω',
#   'θεός',
#   'κόσμος',
#   'Νίκη',
#   'ὁλόχρυσος',
#   'πομπεῖον',
#   'χρύσεος',
#   'ἀργύρεος',
#   'κόσμος',
#   'χρύσεος',
#   'κανήφορος',
#   'χειροτονέω',
#   'πόλεμος',
#   'παρασκευή',
#   'ὅπλον',
#   'πολύς',
#   'βέλος',
#   'μυριάς',
#   'ἀναφέρω',
#   'ἀκρόπολις',
#   'τριήρης',
#   'πλώϊμος',
#   'κατασκευάζω',
#   'ἐπισκευάζω',
#   'ἀρχή',
#   'ναυπηγέω',
#   'ἡμίεργος',
#   'παραλαμβάνω',
#   'νεώσοικος',
#   'σκευοθήκη',
#   'θέατρον',
#   'Διονυσιακός',
#   'ἐξεργάζομαι',
#   'ἐπιτελέω',
#   'στάδιον',
#   'Παναθηναικός',
#   'γυμνάσιον',
#   'Λύκειος',
#   'κατασκευάζω',
#   'πολύς',
#   'κατασκευή',
#   'κοσμέω',
#   'πόλις',
#   'Ἀλέξανδρος',
#   'βασιλεύς',
#   'Ἀσία',
#   'καταστρέφω',
#   'Ἕλλην',
#   'ἐπιτάσσω',
#   'ἀξιόω',
#   'ἐξαιτέω',
#   'Λυκοῦργος',
#   'ἐναντίος',
#   'πράσσω',
#   'ἐκδίδωμι',
#   'δῆμος',
#   'Ἀλέξανδρος',
#   'φόβος',
#   'δίδωμι',
#   'εὔθυνα',
#   'πολιτεύω',
#   'ἐλεύθερος',
#   'δημοκρατέομαι',
#   'πόλις',
#   'διατελέω',
#   'ἀνεξέλεγκτος',
#   'ἀδωροδόκητος',
#   'χρόνος'],
#  ['οἶδα',
#   'προαιρέω',
#   'δημοκρατία',
#   'ἐλευθερία',
#   'πολιτεύω',
#   'ζάω',
#   'πολύς',
#   'ποιέω',
#   'τελευτάω',
#   'ἀποδίδωμι',
#   'χάρις',
#   'ἀείμνηστος',
#   'ἀγαθός',
#   'τύχη',
#   'δοκέω',
#   'δῆμος',
#   'ἐπαινέω',
#   'Λυκοῦργος',
#   'Λυκόφρων',
#   'Βουτάδης',
#   'ἀρετή',
#   'δικαιοσύνη',
#   'ἵστημι',
#   'δῆμος',
#   'χάλκεος',
#   'εἰκών',
#   'ἀγορά',
#   'νόμος',
#   'ἀπαγορεύω',
#   'ἵστημι',
#   'δίδωμι',
#   'σίτησις',
#   'πρυτανεῖον',
#   'ἔκγονος',
#   'Λυκοῦργος',
#   'πρέσβυς',
#   'χρόνος',
#   'ἀνατίθημι',
#   'εἰμί',
#   'κύριος',
#   'ψήφισμα',
#   'γραμματεύς',
#   'δῆμος',
#   'στήλη',
#   'λίθινος',
#   'ἵστημι',
#   'ἀκρόπολις',
#   'ἀνάθημα'],
#  ['ἀναγραφή',
#   'στήλη',
#   'δίδωμι',
#   'ταμίας',
#   'δῆμος',
#   'δραχμή',
#   'ψήφισμα',
#   'ἀναλίσκω',
#   'δῆμος']]

# %%
def get_row_data(row):
    doc_id = row["doc_id"]
    source = row["source"]
    lemmata_source = row["lemmata_source"]
    try:
        file_path = target_path + doc_id + ".pickle"
        with open(file_path, "rb") as f:
            sentences_data = pickle.load(f)
        sentences = [sent[2] for sent in sentences_data]
        lemmatized_sentences = [[t[1] for t in sent[3] if t[2] in ["n", "a", "v", "NOUN", "PROPN", "ADJ", "VERB"]] for sent in sentences_data]
        source = "glaux1"
        lemmata_source = "glaux1"
    except:
        sentences = None
        lemmatized_sentences = None
    return sentences, lemmatized_sentences, source, lemmata_source

# %%
# %%time
result = LAGT.apply(lambda row: pd.Series(get_row_data(row)), axis=1)
# Out:
# CPU times: user 16.7 s, sys: 367 ms, total: 17 s
# Wall time: 17 s

# %%
len(result)
# Out:
# 1710

# %%
LAGT["glaux1_lemmatized_sentences"] = result[1]

# %%
LAGT["sentences_n_lagt3"] = LAGT["lemmatized_sentences"].apply(len)
LAGT["sentences_n_glaux1"] = LAGT["glaux1_lemmatized_sentences"].apply(lambda x: len(x) if isinstance(x, list) else 0)

# %%
LAGT.sample(10)
# Out:
#      author_id          doc_id                         filename  \
# 876    tlg2137  tlg2137.tlg001    tlg2137.tlg001.1st1K-grc1.xml
# 771    tlg2018  tlg2018.tlg011    tlg2018.tlg011.1st1K-grc1.xml
# 177    tlg0057  tlg0057.tlg092    tlg0057.tlg092.1st1K-grc1.xml
# 1545  tlg0031e  tlg0031.tlg021  tlg0031.tlg021.perseus-grc2.xml
# 1816   tlg0533  tlg0533.tlg015  tlg0533.tlg015.perseus-grc4.xml
# 810    tlg2035  tlg2035.tlg131    tlg2035.tlg131.1st1K-grc1.xml
# 162    tlg0057  tlg0057.tlg073    tlg0057.tlg073.1st1K-grc2.xml
# 1043   tlg4016  tlg4016.tlg001    tlg4016.tlg001.1st1K-grc1.xml
# 1799   tlg0284  tlg0284.tlg052  tlg0284.tlg052.perseus-grc2.xml
# 1360   tlg0010  tlg0010.tlg024  tlg0010.tlg024.perseus-grc2.xml
#
#                 author                                              title  \
# 876         Gaudentius                              Harmonica introductio
# 771           Eusebius                                        Onomasticon
# 177              Galen                          In Hippocratis Aphorismos
# 1545              None                            New Testament - 1 Peter
# 1816       Callimachus                                            εἰς Δία
# 810         Athanasius                           Oratio II contra Arianos
# 162              Galen  Quos quibus catharticis medicamentis et quando...
# 1043          Ammonius           In Porphyrii Isagogen Sive Quinque Voces
# 1799  Aelius Aristides                          Πρεσβευτικὸς πρὸς Ἀχιλλέα
# 1360         Isocrates                                      To Archidamus
#
#                                                  string  wordcount   source  \
# 876   „Ἀείδω ξυνετοῖσι, θύρας δʼ ἐπίθεσθε βέβηλοι“\n...       6511     1Kgr
# 771   Εὐσεβίου τοῦ Παμφίλου ἐπισκόπου Καισαρείας τῆς...      19324     1Kgr
# 177   Ὅτι μὲν οὖν οὗτος ὁ λόγος, εἴθ’ εἷς ἀφορισμός ...      89005     1Kgr
# 1545  \n\n                    ΠΕΤΡΟΣ ἀπόστολος Ἰησοῦ...       1668  perseus
# 1816  Ζηνὸς ἔοι τί κεν ἄλλο παρὰ σπονδῆισιν ἀείδειν ...        703  perseus
# 810   1. ἘΓΩ μὲν ᾤμην τοὺς τῆς Ἀρείου μανίας ὑποκριτ...      31636     1Kgr
# 162   Τοὺϲ ὑγιεινὰ τὰ ϲώματα ἔχονταϲ ἐργῶδεϲ καθαίρε...       2930     1Kgr
# 1043  D=Laurentianus 10,26 E=Marcianus 225 F=Parisin...      59111     1Kgr
# 1799   ἄριστε Ἀχιλλεῦ, τὸ μὲν θυμοῦσθαί σε καὶ χαλεπ...       3439  perseus
# 1360  εἰδώς, ὦ Ἀρχίδαμε, πολλοὺς ὡρμημένους ἐγκωμιάζ...       1143  perseus
#
#                                    lemmatized_sentences lemmata_source  \
# 876   [[ἀειδλώ, ξυνετός], [θύρα, ἐπιτίθημι, βέβηλος,...          grecy
# 771   [[Εὐσεβίας, Παμφίλος, ἐπίσκοπος, Καισάρεια, Πα...          grecy
# 177   [[οὗτος, λόγος, εἷς, ἀφορισμός, εἰμί, δύο, προ...          glaux
# 1545  [[Πέτρος, ἀπόστολος, Ἰησοῦς, Χριστός, ἐκλεκτός...       morphgnt
# 1816  [[Ζεύς, εἰμί, τίς, ἄλλος, σπονδῆισις, ἀείδω, λ...          glaux
# 810   [[οἴομαι, Ἄρειας, μανία, ὑποκριτής, προερέω, ο...          grecy
# 162   [[ὑγιεινός, σῶμα, ἔχω, ἐργώδης, καθαίρω], [ἰλι...          glaux
# 1043  [[Μέλλω, ἄρχω, φιλόσοφος, λόγος, ἀναγκαῖος, μα...          grecy
# 1799  [[ἀγαθός, Ἀχιλλεύς, θυμόω, χαλεπαίνω, ὑβρίσθνω...          glaux
# 1360  [[οἶδα, Ἀρχίδαμος, πολύς, ὁρμάω, ἐγκωμιάζω, πα...          glaux
#
#       tlg_date  not_before  not_after date_uncertain  \
# 876       None       101.0      500.0           None
# 771     A.D. 4       301.0      400.0          False
# 177     A.D. 2       101.0      200.0          False
# 1545    A.D. 1         1.0      100.0          False
# 1816  4-3 B.C.      -400.0     -201.0          False
# 810     A.D. 4       301.0      400.0          False
# 162     A.D. 2       101.0      200.0          False
# 1043    A.D. 5       401.0      500.0          False
# 1799    A.D. 2       101.0      200.0          False
# 1360  5-4 B.C.      -500.0     -301.0          False
#
#                                  tlg_epithet provenience  lemmatacount  \
# 876                                       []       pagan          2583
# 771   [Scriptores Ecclesiastici, Theologici]   christian          8602
# 177                                 [Medici]       pagan         44724
# 1545                                      []   christian           872
# 1816                             [Philologi]       pagan           425
# 810                             [Theologici]   christian         12621
# 162                                 [Medici]       pagan          1009
# 1043                      [Philosophici/-ae]       pagan         20199
# 1799                             [Rhetorici]       pagan          1701
# 1360                              [Oratores]       pagan           567
#
#                             glaux1_lemmatized_sentences  sentences_n_lagt3  \
# 876   [[ἀείδω, συνετός, θύρα, ἐπιτίθημι, βέβηλος, ἁρ...                442
# 771                                                None               1178
# 177   [[βίος, βραχύς, τέχνη, μακρός, καιρός, ὀξύς, π...               4122
# 1545  [[Πέτρος, ἀπόστολος, Ἰησοῦς, Χριστός, ἐκλεκτός...                 95
# 1816  [[Ζεύς, εἰμί, σπονδή, ἀείδω, λωΐων, θεός, μέγα...                 62
# 810                                                None               2768
# 162   [[ὑγιεινός, σῶμα, ἔχω, ἐργώδης, καθαίρω], [ἰλι...                 96
# 1043                                               None               4761
# 1799  [[ἀγαθός, Ἀχιλλεύς, θυμόω, χαλεπαίνω, ὑβρίζω, ...                195
# 1360  [[οἶδα, Ἀρχίδαμος, πολύς, ὁρμάω, ἐγκωμιάζω, πα...                 35
#
#       sentences_n_glaux1
# 876                  282
# 771                    0
# 177                 4645
# 1545                  88
# 1816                  62
# 810                    0
# 162                   96
# 1043                   0
# 1799                 195
# 1360                  35

# %%
LAGT[LAGT["sentences_n_glaux1"]==0]
# Out:
#      author_id          doc_id                         filename  \
# 2      ogl0001  ogl0001.ogl001    ogl0001.ogl001.1st1K-grc1.xml
# 8      tlg0005  tlg0005.tlg003    tlg0005.tlg003.1st1K-grc1.xml
# 9      tlg0006  tlg0006.tlg020    tlg0006.tlg020.1st1K-grc1.xml
# 10     tlg0007  tlg0007.tlg146    tlg0007.tlg146.1st1K-grc1.xml
# 11     tlg0007  tlg0007.tlg147    tlg0007.tlg147.1st1K-grc1.xml
# ...        ...             ...                              ...
# 1951   tlg2003  tlg2003.tlg017  tlg2003.tlg017.perseus-grc1.xml
# 1952   tlg2018  tlg2018.tlg002  tlg2018.tlg002.perseus-grc1.xml
# 1953   tlg2040  tlg2040.tlg002  tlg2040.tlg002.perseus-grc1.xml
# 1954   tlg2040  tlg2040.tlg004  tlg2040.tlg004.perseus-grc1.xml
# 1955   tlg2045  tlg2045.tlg001  tlg2045.tlg001.perseus-grc2.xml
#
#                                 author  \
# 2                              Pinytus
# 8                           Theocritus
# 9                            Euripides
# 10                            Plutarch
# 11                            Plutarch
# ...                                ...
# 1951                Julian the Emperor
# 1952              Eusebius of Caesarea
# 1953  Basil, Saint, Bishop of Caesarea
# 1954  Basil, Saint, Bishop of Caesarea
# 1955               Nonnus of Panopolis
#
#                                                   title  \
# 2                       De Epistola Pinyti ad Dionysium
# 8                                                Syrinx
# 9                                             Fragmenta
# 10                    Παροιμίαι αἷς Ἀλεξανδρεῖς ἐχρῶντο
# 11                             Ἐκλογὴ περὶ τῶν ἀδυνάτων
# ...                                                 ...
# 1951                                   Contra Galilaeos
# 1952                             Historia ecclesiastica
# 1953  To Young Men, On How They Might Dervice Profit...
# 1954                                          Epistulae
# 1955                                         Διονυσιακά
#
#                                                  string  wordcount   source  \
# 2     FRAGMENTUM BEATI PINYTI, CNOSSI IN CRETA EPISC...        180     1Kgr
# 8     Οὐδενὸς εὐνάτειρα Μακροπτολέμοιο δὲ μάτηρ  μαί...         77     1Kgr
# 9     ποίαν σε φῶμεν γαῖαν ἐκλελοιπότα πόλει ξενοῦσθ...      17708     1Kgr
# 10    Οἴκοι τὰ Μιλήσια: ἐπὶ τῶν ὅποι μὴ προςήκει τὴν...       2685     1Kgr
# 11    Κατὰ πετρῶν σπείρεις. Πλίνθον πλύνεις. Δικτύῳ ...        143     1Kgr
# ...                                                 ...        ...      ...
# 1951  \n Καλῶς ἔχειν ἔμοιγε φαίνεται τὰς αἰτίας ἐκθέ...      10662  perseus
# 1952  \nΑ\nΤάδε ἡ πρώτη περιέχει βίβλος τῆς\nἘκκλησι...     103161  perseus
# 1953  *polla/ me ta\ parakalou=nta/ e)sti cumbouleu=...       4969  perseus
# 1954  Ἀπειρηκότα με ἤδη πρὸς τὰς παρὰ τῆς λεγομένηςλ...     140861  perseus
# 1955  πρῶτον ἔχει Κρονίωνα, φαεσφόρον ἅρπαγα νύμφης,...     128177  perseus
#
#                                    lemmatized_sentences lemmata_source  \
# 2     [[Πινυτός, ἀντιγράφω, θαυμάζω, ἀποδέχω, Διονύσ...          grecy
# 8     [[οὐδενός, εὐνητήρ], [μακροπτολέμοιο, μήτηρ, μ...          grecy
# 9     [[φημί, γῆ, ἐκλείπω, πόλις, ξενοῦσθαι], [πάτρα...          grecy
# 10    [[Μιλήσιος], [προςήκω, τρυφή, ἐπιδείκνυμι], [Ἀ...          grecy
# 11    [[πέτρα, σπείρω], [Πλίνθος, πλύνω, Δίκτυον, ἄν...          grecy
# ...                                                 ...            ...
# 1951  [[ἔχω, φαίνω, αἰτία, ἐκθέσθαι, ἄνθρωπος, ἐπιέν...          grecy
# 1952  [[ὅδε, πρῶτος, περιέχω, βίβλος, Ἐκκλησιαστικός...          grecy
# 1953                                                 []          grecy
# 1954  [[Ἀπειρηκότα, λεγομένηςλεγομένη, τύχη, ἐπηρεία...          grecy
# 1955  [[πρῶτος, ἔχω, Κρονίων, φαεσφόρος, ἁρπάγη, νύμ...          grecy
#
#       tlg_date  not_before  not_after date_uncertain  \
# 2         None       101.0      200.0           None
# 8     4-3 B.C.      -400.0     -201.0          False
# 9       5 B.C.      -500.0     -401.0          False
# 10    A.D. 1-2         1.0      200.0          False
# 11    A.D. 1-2         1.0      200.0          False
# ...        ...         ...        ...            ...
# 1951    A.D. 4       301.0      400.0          False
# 1952    A.D. 4       301.0      400.0          False
# 1953    A.D. 4       301.0      400.0          False
# 1954    A.D. 4       301.0      400.0          False
# 1955    A.D. 5       401.0      500.0          False
#
#                                  tlg_epithet provenience  lemmatacount  \
# 2                                         []   christian            34
# 8                                 [Bucolici]       pagan            61
# 9                                  [Tragici]       pagan         10277
# 10             [Biographi, Philosophici/-ae]       pagan          1488
# 11             [Biographi, Philosophici/-ae]       pagan           125
# ...                                      ...         ...           ...
# 1951                      [Philosophici/-ae]       pagan          4889
# 1952  [Scriptores Ecclesiastici, Theologici]   christian         49216
# 1953                            [Theologici]   christian             0
# 1954                            [Theologici]   christian         62724
# 1955                             [Epici/-ae]       pagan         98005
#
#      glaux1_lemmatized_sentences  sentences_n_lagt3  sentences_n_glaux1
# 2                           None                  3                   0
# 8                           None                  8                   0
# 9                           None               2036                   0
# 10                          None                297                   0
# 11                          None                 33                   0
# ...                          ...                ...                 ...
# 1951                        None                857                   0
# 1952                        None               6089                   0
# 1953                        None                  0                   0
# 1954                        None               9581                   0
# 1955                        None              13006                   0
#
# [531 rows x 20 columns]

# %%
LAGT["sentences_n_glaux1"].apply(lambda x: x  0).sum()
# Out:
# np.int64(1709)

# %%
# %%time
result = LAGT.apply(lambda row: pd.Series(get_row_data(row)), axis=1)
LAGT["sentences"] = result[0]  # Extract sentences
LAGT["lemmatized_sentences"] = result[1]
LAGT["source"] = result[2]
LAGT["lemmata_source"] = result[3]
# Out:
# CPU times: user 15.3 s, sys: 979 ms, total: 16.3 s
# Wall time: 18.1 s

# %%
LAGT["lemmatized_sentences"].notnull().sum()
# Out:
# 1696

# %% [markdown]
# ### Adding additional files from glaux

# %%
not_lagt = [glaux_fn for glaux_fn in os.listdir(target_path) if glaux_fn.rpartition(".")[0] not in list(LAGT["doc_id"])]
not_lagt[:10]
# Out:
# []

# %%
doc_id = "tlg0497.tlg005"
url = "http://data.perseus.org/catalog/urn:cts:greekLit:{}".format(doc_id)
soup = BeautifulSoup(requests.get(url).text)#

# %%
def get_dd_content(dt_text):
    dt_tag = soup.find('dt', string=dt_text)
    if dt_tag is not None:
        dd_tag = dt_tag.find_next_sibling('dd')
        if dd_tag is not None:
            return dd_tag.get_text(strip=True)  # Extract text and strip whitespace
    return None


work_title = get_dd_content("Work title:")
author = get_dd_content("Author:")

# %%
work_title
# Out:
# 'Epigramma'

# %%
not_lagt_data = []
for fn in not_lagt:
    doc_id = fn.rpartition(".")[0]
    author_id = doc_id.partition(".")[0]
    author = ""
    title = ""
    try:
        url = "http://data.perseus.org/catalog/urn:cts:greekLit:{}".format(doc_id)
        soup = BeautifulSoup(requests.get(url).text)#
        try:
            author = get_dd_content("Author:")
            title = get_dd_content("Work title:")
        except:
            url = "http://data.perseus.org/catalog/urn:cts:greekLit:{}".format(author_id)
            soup = BeautifulSoup(requests.get(url).text)
            try:
                author = get_dd_content("Author:")
            except:
                pass
    except:
        pass
    file_path = target_path + doc_id + ".pickle"
    with open(file_path, "rb") as f:
        sentences_data = pickle.load(f)
    sentences = [sent[2] for sent in sentences_data]
    lemmatized_sentences = [[t[1] for t in sent[3] if t[2] in ["n", "a", "v"]] for sent in sentences_data]
    not_lagt_data.append({
        "author_id" : author_id,
        "doc_id" : doc_id,
        "author" : author,
        "title" : title,
        "sentences" : sentences,
        "lemmatized_sentences" : lemmatized_sentences,
        "source" : "glaux1",
        "lemmata_source" : "glaux1"}
    )

# %%
LAGT_glaux1 = pd.DataFrame(not_lagt_data)
len(LAGT_glaux1)
# Out:
# 229

# %%
len(LAGT)
# Out:
# 1710

# %%
LAGT = pd.concat([LAGT, LAGT_glaux1], ignore_index=True)

# %%
LAGT.sample(10)
# Out:
#      author_id          doc_id                         filename  \
# 25     tlg0018  tlg0018.tlg020    tlg0018.tlg020.1st1K-grc1.xml
# 1396   tlg0059  tlg0059.tlg036  tlg0059.tlg036.perseus-grc2.xml
# 1560   tlg0284  tlg0284.tlg052  tlg0284.tlg052.perseus-grc2.xml
# 214    tlg0087  tlg0087.tlg005    tlg0087.tlg005.1st1K-grc1.xml
# 205    tlg0086  tlg0086.tlg044    tlg0086.tlg044.1st1K-grc1.xml
# 1453   tlg0062  tlg0062.tlg056  tlg0062.tlg056.perseus-grc3.xml
# 470    tlg0656  tlg0656.tlg001    tlg0656.tlg001.1st1K-grc1.xml
# 659    tlg2022  tlg2022.tlg010    tlg2022.tlg010.1st1K-grc1.xml
# 1842   tlg0242  tlg0242.tlg003                              NaN
# 647    tlg2018  tlg2018.tlg011    tlg2018.tlg011.1st1K-grc1.xml
#
#                           author                      title  \
# 25                 Philo Judaeus                De Abrahamo
# 1396                       Plato                   Epistles
# 1560            Aelius Aristides  Πρεσβευτικὸς πρὸς Ἀχιλλέα
# 214                   Herodianus             Περὶ πνευμάτων
# 205                    Aristotle                     Topica
# 1453          Lucian of Samosata          Ἡρόδοτος ἢ Ἀετίων
# 470         Dioscurides Pedianus          De materia medica
# 659        Gregorius Nazianzenus        De Filio (Orat. 30)
# 1842  Asius Samius 6. Jh. v. Chr            Fragmenta Epica
# 647                     Eusebius                Onomasticon
#
#                                                  string  wordcount  source  \
# 25     Τῶν ἱερῶν νόμων ἐν πέντε βίβλοις ἀναγραφέντων...    25197.0  glaux1
# 1396  \n\n\nΠλάτων Διονυσίῳ εὖ πράττειν.διατρίψας ἐγ...    16876.0  glaux1
# 1560   ἄριστε Ἀχιλλεῦ, τὸ μὲν θυμοῦσθαί σε καὶ χαλεπ...     3439.0  glaux1
# 214   1. Theognost. Cr. II 19, 30, Bekk. An. 1428: Π...       72.0  glaux1
# 205   Ἡ ΜΕΝ πρόθεσις τῆς πραγματείας μέθοδον εὑρεῖν,...    44116.0  glaux1
# 1453   Ἡροδότου εἴθε μὲν καὶ τὰ ἄλλα μιμήσασθαι δυνα...      961.0  glaux1
# 470   Πολλῶν οὐ μόνον ἀρχαίων ἀλλὰ καὶ νέων συνταξαμ...   269358.0  glaux1
# 659   Ἐπειδή σοι τὰς μὲν ἐκ τῶν λογισμῶν στροφὰς καὶ...    15916.0  glaux1
# 1842                                                NaN        NaN  glaux1
# 647   Εὐσεβίου τοῦ Παμφίλου ἐπισκόπου Καισαρείας τῆς...    19324.0  glaux1
#
#                                    lemmatized_sentences lemmata_source  \
# 25    [[ἱερός, νόμος, βίβλος, ἀναγράφω, πρῶτος, καλέ...         glaux1
# 1396  [[Πλάτων, Διονύσιος, πράσσω], [διατρίβω, χρόνο...         glaux1
# 1560  [[ἀγαθός, Ἀχιλλεύς, θυμόω, χαλεπαίνω, ὑβρίζω, ...         glaux1
# 214   [[], [], [], [ζ, ξ, ψ, υ, ἀρχή, λέξις, εὑρίσκω...         glaux1
# 205   [[πρόθεσις, πραγματεία, μέθοδος, εὑρίσκω, δύνα...         glaux1
# 1453  [[Ἡρόδοτος, μιμέομαι, δυνατός, εἰμί], [φημί, π...         glaux1
# 470   [[πολύς, ἀρχαῖος, νέος, συντάσσω, φάρμακον, σκ...         glaux1
# 659   [[λογισμός, στροφή, πλοξ, διεσείω, δύναμις, πν...         glaux1
# 1842  [[Ἀντιόπη, τίκτω, Ζῆθος, Ἀμφίων, δῖος, Ἀσωπός,...         glaux1
# 647   [[εὐσεβῖος, παμφίλου, ἐπισκόπης, καισαρεία, πα...         glaux1
#
#            tlg_date  not_before  not_after date_uncertain  \
# 25    1 B.C.-A.D. 1      -100.0      100.0          False
# 1396       5-4 B.C.      -500.0     -301.0          False
# 1560         A.D. 2       101.0      200.0          False
# 214          A.D. 2       101.0      200.0          False
# 205          4 B.C.      -400.0     -301.0          False
# 1453         A.D. 2       101.0      200.0          False
# 470          A.D. 1         1.0      100.0          False
# 659          A.D. 4       301.0      400.0          False
# 1842            NaN         NaN        NaN            NaN
# 647          A.D. 4       301.0      400.0          False
#
#                                  tlg_epithet provenience  lemmatacount  \
# 25                        [Philosophici/-ae]      jewish        9790.0
# 1396                      [Philosophici/-ae]       pagan        8597.0
# 1560                             [Rhetorici]       pagan        1701.0
# 214                  [Grammatici, Rhetorici]       pagan          23.0
# 205                       [Philosophici/-ae]       pagan       20961.0
# 1453                             [Sophistae]       pagan         500.0
# 470                                 [Medici]       pagan       87941.0
# 659                             [Theologici]   christian        2866.0
# 1842                                     NaN         NaN           NaN
# 647   [Scriptores Ecclesiastici, Theologici]   christian        8602.0
#
#                                               sentences
# 25    [τῶν ἱερῶν νόμων ἐν πέντε βίβλοις ἀναγραφέντων...
# 1396  [Πλάτων Διονυσίῳ εὖ πράττειν. E, διατρίψας ἐγὼ...
# 1560  [ἄριστε Ἀχιλλεῦ, τὸ μὲν θυμοῦσθαί σε καὶ χαλεπ...
# 214   [., . ., , , . ., : Πρό τόῦ ζ ἤ ξ ἤ ψ τό υ κατ...
# 205   [ἡ μὲν πρόθεσις τῆς πραγματείας μέθοδον εὑρεῖν...
# 1453  [Ἡροδότου εἴθε μὲν καὶ τὰ ἄλλα μιμήσασθαι δυνα...
# 470   [πολλῶν οὐ μόνον ἀρχαίων ἀλλὰ καὶ νέων συνταξα...
# 659   [Ἐπειδή σοι τάς μέν ἐκ τῶν λογισμῶν στροφάς κα...
# 1842  [Ἀντιόπη δ’ ἔτεκε Ζῆθον κα- κἀμφίονα δῖον Ἀσωπ...
# 647   [Εὐσεβίου τοῦ Παμφίλου ἐπισκόπου Καισαρείας τῆ...

# %%
len(LAGT)
# Out:
# 2168

# %%
LAGT = LAGT.drop_duplicates(subset=['doc_id'], keep='first')

# %%
LAGT.to_parquet("../data/large_files/LAGT_glauxed.parquet", engine="pyarrow")
