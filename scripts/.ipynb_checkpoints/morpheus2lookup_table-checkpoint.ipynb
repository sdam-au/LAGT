# %% [markdown]
# The aim of this notebook is to transform an ancient Greek Dictionary Morpheus (https://github.com/gcelano/LemmatizedAncientGreekXML/tree/master/Morpheus) into a form of lookup table suitable for `spacy train`, e.g. the one present in Spacy (modern) Greek language model.

# %% [markdown]
# # Requirements

# %%
import os
import json
import pandas as pd
import numpy as np
import json
import unicodedata
import requests
import re
from importlib import reload
import pyconll # universal dependencies parser

import sddk

#from anda import gr
# OR uncomment the following:
#script_url = "https://raw.githubusercontent.com/sdam-au/anda_py/master/anda/gr.py"
#exec(requests.get(script_url).content)

# %%
# path to our own local morpheus file (if working locally)
# if not available, load it from sciencedata
path = "/Users/au648597/Documents/projects/anda/anda_repo/anda/data/morpheus_dict.json"
try:
    morpheus_dict = json.load(open(path))
except:
    publicfolder = "8fe7d59de1eafe5f8eaebc0044534606"
    morpheus_dict = json.loads(requests.get("https://sciencedata.dk/public/" + publicfolder + "/morpheus_dict.json").content)

# %%
len(morpheus_dict)
# Out:
# 706506

# %%
# morpheus has the following structure
[it for it in morpheus_dict.items()][10:12]
# Out:
# [('ἀᾱ́ατος',
#   [{'i': '6',
#     'f': 'ἀᾱ́ατος',
#     'b': 'αᾱατος',
#     'l': 'ἀάατος',
#     'e': 'ααατος',
#     'p': 'a-s---fn-',
#     'd': '1',
#     's': 'not to be injured, inviolable',
#     'a': None},
#    {'i': '13',
#     'f': 'ἀᾱ́ατος',
#     'b': 'αᾱατος',
#     'l': 'ἀάατος',
#     'e': 'ααατος',
#     'p': 'a-s---mn-',
#     'd': '1',
#     's': 'not to be injured, inviolable',
#     'a': None}]),
#  ('αᾱατος',
#   [{'i': '6',
#     'f': 'ἀᾱ́ατος',
#     'b': 'αᾱατος',
#     'l': 'ἀάατος',
#     'e': 'ααατος',
#     'p': 'a-s---fn-',
#     'd': '1',
#     's': 'not to be injured, inviolable',
#     'a': None},
#    {'i': '13',
#     'f': 'ἀᾱ́ατος',
#     'b': 'αᾱατος',
#     'l': 'ἀάατος',
#     'e': 'ααατος',
#     'p': 'a-s---mn-',
#     'd': '1',
#     's': 'not to be injured, inviolable',
#     'a': None}])]

# %% [markdown]
# POS tag used in morpheus (extracted from https://github.com/gcelano/LemmatizedAncientGreekXML/blob/master/README.md)
#   * ```n```: noun
#   * ```v```: verb
#   * ```a```: adjective
#   * ```d```: adverb
#   * ```l```: article
#   * ```g```: particle
#   * ```c```: conjunction
#   * ```r```: preposition
#   * ```p```: pronoun
#   * ```m```: numeral
#   * ```i```: interjection
#   * ```u```: punctuation

# %% [markdown]
# We have to transform this data into the following format: https://github.com/explosion/spacy-lookups-data/blob/master/spacy_lookups_data/data/el_lemma_exc.json

# %% [markdown]
# # "p" (="xpos") into universal dependency "upos"
# As a first step: to translate the "p" tag here into the standardized tags used by universal dependency treebanks and spacy:

# %%
corpus_perseus = pyconll.load.iter_from_url("https://raw.githubusercontent.com/UniversalDependencies/UD_Ancient_Greek-Perseus/master/grc_perseus-ud-train.conllu")
corpus_proiel = pyconll.load.iter_from_url("https://raw.githubusercontent.com/UniversalDependencies/UD_Ancient_Greek-PROIEL/master/grc_proiel-ud-train.conllu")

# %%
upos_xpos = []
for sentence in corpus_perseus:
    for token in sentence:
        upos_xpos.append((token.upos, token.xpos))
for sentence in corpus_proiel:
    for token in sentence:
        upos_xpos.append((token.upos, token.xpos))

# %%
upos_xpos[:10]
# Out:
# [('VERB', 'v3spia---'),
#  ('ADV', 'd--------'),
#  ('ADJ', 'a-s---mn-'),
#  ('NOUN', 'n-s---mn-'),
#  ('VERB', 'v--ana---'),
#  ('NOUN', 'n-s---fa-'),
#  ('PUNCT', 'u--------'),
#  ('NOUN', 'n-s---mn-'),
#  ('CCONJ', 'c--------'),
#  ('NOUN', 'n-s---fa-')]

# %%
upos_unique = list(set([tup[0] for tup in upos_xpos]))
upos_unique
# Out:
# ['NOUN',
#  'ADV',
#  'ADJ',
#  'VERB',
#  'PRON',
#  'SCONJ',
#  'X',
#  'PUNCT',
#  'CCONJ',
#  'NUM',
#  'ADP',
#  'PROPN',
#  'AUX',
#  'DET',
#  'INTJ',
#  'PART']

# %%
upos_dict = {}
for upos in upos_unique:
    upos_dict[upos] = list(set([tup[1][:2] for tup in upos_xpos if tup[0] == upos]))
upos_dict
# Out:
# {'NOUN': ['n-', 'Nb'],
#  'ADV': ['Dq', 'Df', 'Du', 'd-'],
#  'ADJ': ['Ps', 'S-', 'Px', 'A-', 'Pd', 'Mo', 'a-'],
#  'VERB': ['V-', 'v1', 'v2', 'v3', 'v-'],
#  'PRON': ['Pr', 'p3', 'Pc', 'Pp', 'p1', 'Pi', 'p2', 'p-', 'Pk'],
#  'SCONJ': ['G-', 'c-'],
#  'X': ['F-', '-3', 'x-', '--'],
#  'PUNCT': ['u-'],
#  'CCONJ': ['C-', 'c-'],
#  'NUM': ['Ma', 'm-'],
#  'ADP': ['R-', 'r-'],
#  'PROPN': ['Ne'],
#  'AUX': ['V-'],
#  'DET': ['l-', 'S-', 'Pd', 'Px'],
#  'INTJ': ['I-', 'i-'],
#  'PART': ['g-']}

# %%
upos_dict_reverse = {}
for key in upos_dict.keys():
    for el in upos_dict[key]:
        try:
            old_value = upos_dict_reverse[el] 
            # new_value = old_value.append(key)
            upos_dict_reverse[el] = old_value + [key]
        except:
            upos_dict_reverse[el] = [key]
upos_dict_reverse
# Out:
# {'n-': ['NOUN'],
#  'Nb': ['NOUN'],
#  'Dq': ['ADV'],
#  'Df': ['ADV'],
#  'Du': ['ADV'],
#  'd-': ['ADV'],
#  'Ps': ['ADJ'],
#  'S-': ['ADJ', 'DET'],
#  'Px': ['ADJ', 'DET'],
#  'A-': ['ADJ'],
#  'Pd': ['ADJ', 'DET'],
#  'Mo': ['ADJ'],
#  'a-': ['ADJ'],
#  'V-': ['VERB', 'AUX'],
#  'v1': ['VERB'],
#  'v2': ['VERB'],
#  'v3': ['VERB'],
#  'v-': ['VERB'],
#  'Pr': ['PRON'],
#  'p3': ['PRON'],
#  'Pc': ['PRON'],
#  'Pp': ['PRON'],
#  'p1': ['PRON'],
#  'Pi': ['PRON'],
#  'p2': ['PRON'],
#  'p-': ['PRON'],
#  'Pk': ['PRON'],
#  'G-': ['SCONJ'],
#  'c-': ['SCONJ', 'CCONJ'],
#  'F-': ['X'],
#  '-3': ['X'],
#  'x-': ['X'],
#  '--': ['X'],
#  'u-': ['PUNCT'],
#  'C-': ['CCONJ'],
#  'Ma': ['NUM'],
#  'm-': ['NUM'],
#  'R-': ['ADP'],
#  'r-': ['ADP'],
#  'Ne': ['PROPN'],
#  'l-': ['DET'],
#  'I-': ['INTJ'],
#  'i-': ['INTJ'],
#  'g-': ['PART']}

# %%
["NOUN", "ADV", "ADB", "VERB", "NUM"]
# Out:
# ['NOUN', 'ADV', 'ADB', 'VERB', 'NUM']

# %%
morph_list_dict = list(morpheus_dict.values())
morph_list_dict[0][:3]
# Out:
# [{'i': '1',
#   'f': 'ἀάατον',
#   'b': 'ααατον',
#   'l': 'ἀάατος',
#   'e': 'ααατος',
#   'p': 'a-s---fa-',
#   'd': '1',
#   's': 'not to be injured, inviolable',
#   'a': None},
#  {'i': '8',
#   'f': 'ἀάατον',
#   'b': 'ααατον',
#   'l': 'ἀάατος',
#   'e': 'ααατος',
#   'p': 'a-s---ma-',
#   'd': '1',
#   's': 'not to be injured, inviolable',
#   'a': None},
#  {'i': '15',
#   'f': 'ἀάατον',
#   'b': 'ααατον',
#   'l': 'ἀάατος',
#   'e': 'ααατος',
#   'p': 'a-s---na-',
#   'd': '1',
#   's': 'not to be injured, inviolable',
#   'a': None}]

# %%
# create empty dictionary to fill in by values
ag_lemma_lookup = {}
for upos in upos_unique: 
    ag_lemma_lookup[upos] = {}
ag_lemma_lookup
# Out:
# {'NOUN': {},
#  'ADV': {},
#  'ADJ': {},
#  'VERB': {},
#  'PRON': {},
#  'SCONJ': {},
#  'X': {},
#  'PUNCT': {},
#  'CCONJ': {},
#  'NUM': {},
#  'ADP': {},
#  'PROPN': {},
#  'AUX': {},
#  'DET': {},
#  'INTJ': {},
#  'PART': {}}

# %%
morheus_general = {}
for item in morph_list_dict:
    for el in item:
        if el["a"] == None: # ignore dialect specific words at this moment
            for key in upos_dict_reverse.keys(): # e.g. "V-" or "a-"...            
                if el["p"][:2] == key:
                    for tag in upos_dict_reverse[key]: # list of values of the individual key
                        ag_lemma_lookup[tag][el["f"]] = el["l"]

# %%
dict([it for it in ag_lemma_lookup["ADV"].items()][:20])
# Out:
# {'ἄτως': 'ἄατος',
#  'ἅτ’': 'ἅτε',
#  'κἄτ’': 'ἔτι',
#  'κᾆτ’': 'εἴτε',
#  'κἆτ’': 'ἔτι',
#  'κἆθ’': 'ἔτι',
#  'κᾆθ’': 'εἴτε',
#  'κάθ’': 'καθό',
#  'καθ’': 'καθό',
#  'κᾆτα': 'εἶτα',
#  'τώ': 'τῷ',
#  'τῴ': 'τῷ',
#  'τῶ': 'τῷ',
#  'τῷ': 'τῷ',
#  'τῳ': 'τῷ',
#  'ἁτός': 'ἐτός',
#  'ἅτε': 'ἅτε',
#  'ἇτε': 'ἅτε',
#  'ᾗ': 'ᾗ',
#  'ἤ': 'ἦ'}

# %% [markdown]
# # Update/extend Morpheus by word forms and lemmata from universal dependencies

# %%
len(ag_lemma_lookup["NOUN"])
# Out:
# 59014

# %%
corpus_perseus = pyconll.load.iter_from_url("https://raw.githubusercontent.com/UniversalDependencies/UD_Ancient_Greek-Perseus/master/grc_perseus-ud-train.conllu")
corpus_proiel = pyconll.load.iter_from_url("https://raw.githubusercontent.com/UniversalDependencies/UD_Ancient_Greek-PROIEL/master/grc_proiel-ud-train.conllu")

# %%
for sentence in corpus_perseus:
    for token in sentence:
        ag_lemma_lookup[token.upos][token.form] = token.lemma
for sentence in corpus_proiel:
    for token in sentence:
        ag_lemma_lookup[token.upos][token.form] = token.lemma

# %%
forms = []
for sentence in corpus_proiel:
    for token in sentence:
        forms.append(token.form)

# %%
forms = list(set(forms))

# %%
len(forms)
# Out:
# 0

# %%
for var in ['βιβλός', 'Βιβλός', 'βίβλος', 'Βίβλος']:
    print(var in forms)
# Out:
# False
# False
# False
# False

# %%
len(ag_lemma_lookup["NOUN"])
# Out:
# 67686

# %%
ag_lemma_lookup["NOUN"].update(ag_lemma_lookup["PROPN"])

# %%
ag_lemma_lookup["NOUN"]["Ἰησοῦ"]
# Out:
# 'Ἰησοῦς'

# %%
with open ("../data/ag_lemma_lookup.json", "w") as f:
    json.dump(ag_lemma_lookup, f)

# %%
ag_lemma_lookup["NOUN"]["τεχνών"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-29-5526d2f715d7> in <module>
# ----> 1 ag_lemma_lookup["NOUN"]["τεχνών"]
#
# KeyError: 'τεχνών'

# %% [markdown]
# # BACKUP.... (not used anymore)

# %%
# functions under development
# from anda import gr
# OR uncomment the following to read from github:
#script_url = "https://raw.githubusercontent.com/sdam-au/anda_py/master/anda/gr.py"
#exec(requests.get(script_url).content)

# %%
# to use the latest version (for development)
reload(gr)
# Out:
# <module 'anda.gr' from '/home/kasev/anda_py/anda/gr.py'>

# %%
conf = sddk.configure("SDAM_root", "648597@au.dk")
# Out:
# sciencedata.dk username (format '123456@au.dk'): 648597@au.dk
# sciencedata.dk password: ········
# connection with shared folder established with you as its owner
# endpoint variable has been configured to: https://sciencedata.dk/files/SDAM_root/

# %%
# to access gsheet, you need Google Service Account key json file
# I have mine located in my personal space on sciencedata.dk, so I read it from there:

# (1) read the file and parse its content
file_data = conf[0].get("https://sciencedata.dk/files/ServiceAccountsKey.json").json()
# (2) transform the content into crendentials object
credentials = service_account.Credentials.from_service_account_info(file_data)
# (3) specify your usage of the credentials
scoped_credentials = credentials.with_scopes(['https://spreadsheets.google.com/feeds', 'https://www.googleapis.com/auth/drive'])
# (4) use the constrained credentials for authentication of gspread package
gc = gspread.Client(auth=scoped_credentials)

AGT_overview = gc.open_by_url("https://docs.google.com/spreadsheets/d/1iVta_FuEDgUM_Lf_yByrdbbXNoVH_dnVZs6QRyYv1NM/edit?usp=sharing")

# AGT_metadata = gc.open_by_url("https://docs.google.com/spreadsheets/d/1hEUnL3E07F-EnE3wYnk1V91aXfPDrcnhFHKjD-04CM0/edit?usp=sharing")

# %% [markdown]
# # Extending Morpheus

# %%
def encoding(word):
    return unicodedata.normalize("NFC", word)

# %%
morpheus_dict = json.loads(requests.get("https://sciencedata.dk/public/" + publicfolder + "/morpheus_dict.json").content)

# %%
len(morpheus_dict)
# Out:
# 706506

# %%
"Ne".lower()
# Out:
# 'ne'

# %%
# enrich morpheus by additional data from universaldependencies
corpus_perseus = pyconll.load.iter_from_url("https://raw.githubusercontent.com/UniversalDependencies/UD_Ancient_Greek-Perseus/master/grc_perseus-ud-train.conllu")
forms_lemmas_dict = {}
for sentence in corpus_perseus:
    for token in sentence:
        forms_lemmas_dict[encoding(token.form)] = [{"l" : encoding(token.lemma), "p" : token.xpos.lower(), "s" : ""}]
        
for key in forms_lemmas_dict.keys():
    try:
        morpheus_dict[key]
    except:
        morpheus_dict[key] = forms_lemmas_dict[key]
len(morpheus_dict)
# Out:
# 714405

# %%
corpus_proiel = pyconll.load.iter_from_url("https://raw.githubusercontent.com/UniversalDependencies/UD_Ancient_Greek-PROIEL/master/grc_proiel-ud-train.conllu")
forms_lemmas_dict = {}
for sentence in corpus_proiel:
    for token in sentence:
        forms_lemmas_dict[encoding(token.form)] = [{"l" : encoding(token.lemma), "p" : token.xpos.lower(), "s" : ""}]
        
for key in forms_lemmas_dict.keys():
    try:
        morpheus_dict[key]
    except:
        morpheus_dict[key] = forms_lemmas_dict[key]
len(morpheus_dict)
# Out:
# 719663

# %%
morpheus_dict["Ἰησοῦ"]
# Out:
# [{'l': 'Ἰησοῦς', 'p': 'ne', 's': ''}]

# %% [markdown]
# # Load corpus

# %%
# import the data
AGT = sddk.read_file("SDAM_data/AGT/AGT_dated_20201027.json", "df", conf)

# %%
AGT_string = " ".join(AGT["string"].tolist())
len(AGT_string)
# Out:
# 219532769

# %% [markdown]
# # Testing cleaning

# %%
test_string = "ἀρχόμενος ³σέο, Φοῖβε, text in latin also CAPITAL ⁴παλαιγενέων 1234 κλέα 34056 φωτῶν μνήσομαι, οἳ Πόντοιο κατὰ στόμα καὶ διὰ πέτρας Κυανέας βασιλῆος ἐφημοσύνῃ Πελίαο χρύσειον μετὰ κῶας ἐύζυγον ἤλασαν Ἀργώ. τοίην γὰρ Πελίης φάτιν ἔκλυεν, ὥς μιν ὀπίσσω μοῖρα μένει στυγερή, τοῦδʼ ἀνέρος, ὅντινʼ ἴδοιτο δημόθεν οἰοπέδιλον, ὑπʼ ἐννεσίῃσι δαμῆναι."
test_string
# Out:
# 'ἀρχόμενος ³σέο, Φοῖβε, text in latin also CAPITAL ⁴παλαιγενέων 1234 κλέα 34056 φωτῶν μνήσομαι, οἳ Πόντοιο κατὰ στόμα καὶ διὰ πέτρας Κυανέας βασιλῆος ἐφημοσύνῃ Πελίαο χρύσειον μετὰ κῶας ἐύζυγον ἤλασαν Ἀργώ. τοίην γὰρ Πελίης φάτιν ἔκλυεν, ὥς μιν ὀπίσσω μοῖρα μένει στυγερή, τοῦδʼ ἀνέρος, ὅντινʼ ἴδοιτο δημόθεν οἰοπέδιλον, ὑπʼ ἐννεσίῃσι δαμῆναι.'

# %%
# remove numerical superscripts
sups = ["¹", "²", "³", "⁴","⁵", "⁶", "⁷", "⁰", "⁹"]
def remove_sups(string):
    for sup in sups:
        string = string.replace(sup, "")
    return string

def grave_to_acute(string):
    GRAVE = "\u0300"
    ACUTE = "\u0301"
    return unicodedata.normalize("NFC", "".join(unicodedata.normalize("NFD", string).replace(GRAVE, ACUTE)))

test_string_1 = re.sub("[a-zA-Z0-9]", "", test_string)
test_string_1
# Out:
# 'ἀρχόμενος ³σέο, Φοῖβε,      ⁴παλαιγενέων  κλέα  φωτῶν μνήσομαι, οἳ Πόντοιο κατὰ στόμα καὶ διὰ πέτρας Κυανέας βασιλῆος ἐφημοσύνῃ Πελίαο χρύσειον μετὰ κῶας ἐύζυγον ἤλασαν Ἀργώ. τοίην γὰρ Πελίης φάτιν ἔκλυεν, ὥς μιν ὀπίσσω μοῖρα μένει στυγερή, τοῦδʼ ἀνέρος, ὅντινʼ ἴδοιτο δημόθεν οἰοπέδιλον, ὑπʼ ἐννεσίῃσι δαμῆναι.'

# %%
test_string_2 = remove_sups(test_string_1)
test_string_3 = grave_to_acute(test_string_2)
print(test_string_3.split())
# Out:
# ['ἀρχόμενος', 'σέο,', 'Φοῖβε,', 'παλαιγενέων', 'κλέα', 'φωτῶν', 'μνήσομαι,', 'οἵ', 'Πόντοιο', 'κατά', 'στόμα', 'καί', 'διά', 'πέτρας', 'Κυανέας', 'βασιλῆος', 'ἐφημοσύνῃ', 'Πελίαο', 'χρύσειον', 'μετά', 'κῶας', 'ἐύζυγον', 'ἤλασαν', 'Ἀργώ.', 'τοίην', 'γάρ', 'Πελίης', 'φάτιν', 'ἔκλυεν,', 'ὥς', 'μιν', 'ὀπίσσω', 'μοῖρα', 'μένει', 'στυγερή,', 'τοῦδʼ', 'ἀνέρος,', 'ὅντινʼ', 'ἴδοιτο', 'δημόθεν', 'οἰοπέδιλον,', 'ὑπʼ', 'ἐννεσίῃσι', 'δαμῆναι.']

# %%
# add column with sentences

def get_sentences(string):
  sentences = [s.strip() for s in re.split("\·|\.|\:|\;", unicodedata.normalize("NFC", string))]
  return sentences

AGT["sentences"] = AGT["string"].apply(get_sentences)

# %%
AGT.head(5)
# Out:
#                           filename              author  \
# 0  tlg0001.tlg001.perseus-grc2.xml  Apollonius Rhodius
# 1  tlg0003.tlg001.perseus-grc2.xml          Thucydides
# 2  tlg0004.tlg001.perseus-grc1.xml   Diogenes Laertius
# 3  tlg0005.tlg001.perseus-grc1.xml          Theocritus
# 4  tlg0005.tlg002.perseus-grc1.xml          Theocritus
#
#                            title  \
# 0                    Argonautica
# 1          The Peloponnesian War
# 2  Lives of Eminent Philosophers
# 3                        Idylls
# 4                      Epigrams
#
#                                               string  wordcount author_id  \
# 0  ἀρχόμενος σέο, Φοῖβε, παλαιγενέων κλέα φωτῶν μ...      38822   tlg0001
# 1  \nΘουκυδίδης Ἀθηναῖος ξυνέγραψε τὸν πόλεμον τῶ...     150126   tlg0003
# 2  Τὸ τῆς φιλοσοφίας ἔργον ἔνιοί φασιν ἀπὸ βαρβάρ...     110773   tlg0004
# 3  \n̔Αδύ τι τὸ ψιθύρισμα καὶ ἁ πίτυς αἰπόλε τήνα...      19200   tlg0005
# 4  τὰ ῥόδα τὰ δροσόεντα καὶ ἁ κατάπυκνος ἐκείνα ἕ...       1734   tlg0005
#
#            doc_id  raw_date  date_avr                  date_probs  \
# 0  tlg0001.tlg001    3 B.C.      -2.5                 {'-2.5': 1}
# 1  tlg0003.tlg001    5 B.C.      -4.5                 {'-4.5': 1}
# 2  tlg0004.tlg001    A.D. 3       2.5                  {'2.5': 1}
# 3  tlg0005.tlg001  4-3 B.C.      -3.0  {'-3.5': 0.5, '-2.5': 0.5}
# 4  tlg0005.tlg002  4-3 B.C.      -3.0  {'-3.5': 0.5, '-2.5': 0.5}
#
#    date_manual provenience                                          sentences
# 0         -2.5       pagan  [ἀρχόμενος σέο, Φοῖβε, παλαιγενέων κλέα φωτῶν ...
# 1         -4.5       pagan  [Θουκυδίδης Ἀθηναῖος ξυνέγραψε τὸν πόλεμον τῶν...
# 2          NaN              [Τὸ τῆς φιλοσοφίας ἔργον ἔνιοί φασιν ἀπὸ βαρβά...
# 3          NaN              [̔Αδύ τι τὸ ψιθύρισμα καὶ ἁ πίτυς αἰπόλε τήνα,...
# 4          NaN              [τὰ ῥόδα τὰ δροσόεντα καὶ ἁ κατάπυκνος ἐκείνα ...

# %% [markdown]
# # Main Lemmatization

# %%
# %%time
AGT["lemmata"] = AGT.apply(lambda row: lemmatize_string(row["string"], all_lemmata=False, filter_by_postag=["n", "a", "v"], involve_unknown=True), axis=1)
# Out:
# CPU times: user 2min 26s, sys: 2.2 s, total: 2min 28s
# Wall time: 2min 29s

# %%
all_lemmata = []
for work in AGT["lemmata"].tolist():
    all_lemmata.extend(work)

# %%
AGT["lemmata_wordcount"] = AGT.apply(lambda row: len(row["lemmata"]), axis=1)
AGT["lemmata_wordcount"].sum() # previously we had 13925726, then 13713183
# Out:
# 13812934

# %%
# %%time
def lemmatize_sentences(sentences):
    lemmatized_sentences = []
    for sentence in sentences:
        lemmatized_sentence = lemmatize_string(sentence, all_lemmata=False, filter_by_postag=["n", "a", "v"], involve_unknown=True)
        lemmatized_sentences.append(lemmatized_sentence)
    return lemmatized_sentences

AGT["lemmatized_sentences"] = AGT["sentences"].apply(lemmatize_sentences)
# Out:
# CPU times: user 2min 46s, sys: 403 ms, total: 2min 47s
# Wall time: 2min 47s

# %%
AGT["n_sentences"] = AGT['lemmatized_sentences'].apply(lambda x: len(x))

# %% [markdown]
# # Test with GNT

# %% [markdown]
# we were very unhappy with the results obtained by Morpheus alone. So we extended it by means of additional morphems available in dependency tree data. Originally, the lemmatazed text looked like this:
#
# ```
# ['βιβλος', 'γένεσις', 'ἰησοῦ', 'χριστοῦ', 'υἱός', 'δαυείδ', 'υἱός', 'ἀβρααμ', 'ἀβραάμ', 'γεννάω', 'ἰσαάκ', 'ἰσαάκ', 'γεννάω', 'ἰακώβ', 'ἰακώβ', 'γεννάω', 'ἰούδαν', 'ἀδελφός', 'ἰούδας', 'γεννάω', 'φαρές', 'ζαρά', 'θάμαρ', 'φαρές', 'γεννάω', 'ἑσρώμ', 'ἑσρώμ', 'γεννάω', 'ἀράμ', 'ἀράμ', 'γεννάω', 'ἀμιναδάβ', 'ἀμιναδάβ', 'γεννάω', 'ναασσών', 'ναασσών', 'γεννάω', 'σαλμών', 'σαλμών', 'γεννάω', 'βοές', 'ῥαχάβ', 'βοές', 'γεννάω', 'ἰωβηδ', 'ῥούθ', 'ἰωβηδ', 'γεννάω', 'ἰεσσαί', 'ἰεσσαί', 'γεννάω', 'δαυείδ', 'βασιλεύς', 'δαυείδ', 'γεννάω', 'σολομῶνα', 'οὐρίου', 'σολομών', 'γεννάω', 'ῥοβοάμ', 'ῥοβοάμ', 'γεννάω', 'ἀβιά', 'ἀβιά', 'γεννάω', 'ἀσάφ', 'ἀσάφ', 'γεννάω', 'ἰωσαφάτ', 'ἰωσαφάτ', 'γεννάω', 'ἰωράμ', 'ἰωράμ', 'γεννάω', 'ὀζείαν', 'ὀζείας', 'γεννάω', 'ἰωαθάμ', 'ἰωαθάμ', 'γεννάω', 'ἄχας', 'ἄχας', 'γεννάω', 'ἑζεκίαν', 'ἑζεκίας', 'γεννάω', 'μανασσῆ', 'μανασσῆς', 'γεννάω', 'ἀμώς', 'ἀμώς', 'γεννάω', 'ἰωσείαν', 'ἰωσείας', 'γεννάω', 'ἰεχονίαν', 'ἀδελφός', 'μετοικεσία', 'Βαβυλών', 'μετοικεσία', 'Βαβυλών', 'ἰεχονίας', 'γεννάω', 'σαλαθιήλ', 'σαλαθιηλ', 'γεννάω', 'ζοροβάβελ', 'ζοροβάβελ', 'γεννάω', 'ἀβιούδ', 'ἀβιούδ', 'γεννάω', 'ἐλιακείμ', 'ἐλιακείμ', 'γεννάω', 'ἀζώρ', 'ἀζώρ', 'γεννάω', 'σαδώκ', 'σαδώκ', 'γεννάω', 'ἀχείμ', 'ἀχείμ', 'γεννάω', 'ἐλιούδ', 'ἐλιούδ', 'γεννάω', 'ἐλεάζαρ', 'ἐλεάζαρ', 'γεννάω', 'μαθθάν', 'μαθθάν', 'γεννάω', 'ἰακώβ', 'ἰακώβ', 'γεννάω', 'ἰωσηφ', 'ἀνήρ', 'μαρίας', 'γεννάω', 'ἰησοῦς', 'χριστός', 'πᾶσαι', 'γενεά', 'ἀβραάμ', 'ἑός', 'δαυείδ', 'γενεά', 'δεκατέσσαρες', 'δαυείδ', 'ἑός', 'μετοικεσία', 'Βαβυλών', 'γενεά', 'δεκατέσσαρες', 'μετοικεσία', 'Βαβυλών', 'ἑός', 'χριστός', 'γενεά', 'δεκατέσσαρες', 'του', 'δε', 'ιησου', 'χριστου', 'γένεσις', 'μνηστευθείσης', 'μήτηρ', 'μαρίας', 'ἰωσήφ', 'συνέρχομαι', 'εὑρίσκω', 'γαστήρ', 'πνεῦμα', 'ἅγιος', 'ἰωσηφ', 'ἀνηρ', 'δίκαιος', 'αὐτην', 'δειγματίζω', 'βούλομαι', 'ἀπολύω', 'ταῦτα', 'εἶδον', 'ἄγγελος', 'κυρίου', 'ἄατος', 'ὄναρ', 'φαίνω', 'ἰωσηφ', 'υἱός', 'δαυείδ', 'φοβέω', 'παραλαμβάνω', 'μαρίαν', 'γυνή', 'σεύω', 'γεννάω', 'πνεύματός', 'ἅγιος']```

# %%
def return_list_of_tokens(word, filter_by_postag=None, involve_unknown=False):
    word = unicodedata.normalize("NFC", word)
    try:
        list_of_tokens = morpheus_dict[word]
        if len(list_of_tokens) < 1:
            list_of_tokens = morpheus_dict[word.lower()]
            if len(list_of_tokens) < 1:
                list_of_tokens = [{"f":word, "i": "", "b":"", "l":word.lower(), "e":"", "p":"", "d":"", "s":"", "a":""}]
    except:
        list_of_tokens = [{"f":word, "i": "", "b":"", "l":word.lower(), "e":"", "p":"", "d":"", "s":"", "a":""}]

    if filter_by_postag != None:
        try:
            list_of_tokens_filtered = []
            for token in list_of_tokens:
                if token["p"][0] in filter_by_postag:
                    list_of_tokens_filtered.append(token)
            list_of_tokens = list_of_tokens_filtered
        except:
            if involve_unknown == False:
                list_of_tokens = []
    return list_of_tokens

# %%
return_first_lemma("του")
# Out:
# 'ἒ'

# %%
for word in AGT_GNT["lemmata"].tolist()[2][:100]:
    print(word, return_first_lemma(word))
# Out:
# επειδηπερ ἐπεί
# πολλοι πολύς
# ἐπιχειρέω ἐπιχειρέω
# ἀνατάσσομαι ἀνατάσσομαι
# διηγέομαι διηγέομαι
# πληροφορέω πληροφορέω
# πρᾶγμα πρᾶγμα
# καθώς καθώς
# παραδίδωμι παραδίδωμι
# ἀπ ἀπ
# ἀρχή ἀρχή
# αὐτόπτης αὐτόπτης
# ὑπηρέτης ὑπηρετέω
# γίγνομαι γίγνομαι
# λόγος λόγος
# δοκέω δοκέω
# ἁμός ἁμός
# παρακολουθέω παρακολουθέω
# ἄνωθεν ἄνωθεν
# πᾶς πᾶς
# ἀκριβής ἀκριβής
# κάθεξις κάθεξις
# γράφω γράφω
# κράτιστος κράτιστος
# Θεόφιλος θεόφιλος
# ἵνα ἵνα
# ἐπιγιγνώσκω ἐπιγιγνώσκω
# κατηχέω κατηχέω
# λόγος λόγος
# ἀσφάλεια ἀσφάλεια
# εγενετο γίγνομαι
# ἡμέρα ἡμέρα
# Ἡρῴδης Ἡρῴδης
# βασιλεύς βασιλεύς
# Ἰουδαία Ἰουδαῖος
# ἱερεύς ἱερεύς
# ὄνομα ὀνομάζω
# Ζαχαρίας Ζαχαρίας
# ἐφημερία ἐφημερία
# Ἀβιά Ἀβιά
# γυνή γυνή
# θυγάτηρ θυγάτηρ
# Ἀαρών Ἀαρών
# ὀνομάζω ὀνομάζω
# ἐλεισάβετ ἐλεισάβετ
# δίκαιος δίκαιος
# ἀμφότερος ἀμφότερος
# ἐναντίον ἐναντίον
# θεάομαι θεάομαι
# πορεύω πορεύω
# πᾶς πᾶς
# ἐντολή ἐντολή
# δικαίωμα δικαίωμα
# κύριος κύριος
# ἄμεμπτος ἄμεμπτος
# τέκνον τέκνον
# καθότι καθότι
# ἐλεισάβετ ἐλεισάβετ
# στεῖρα στεῖρα
# ἀμφότερος ἀμφότερος
# προβαίνω προβαίνω
# ἡμέρα ἡμέρα
# γίγνομαι γίγνομαι
# ἱερατεύω ἱερατεύω
# τάξις τάξις
# ἐφημερία ἐφημερία
# ἔναντι ἔναντι
# θεάομαι θεάομαι
# ἔθος ἔθος
# ἱερατίας ἱερατίας
# λαγχάνω λαγχάνω
# θυμιάω θυμιάω
# εἰσέρχομαι εἰσέρχομαι
# ναός ναός
# κύριος κύριος
# Πάν πάν
# πλῆθος πλῆθος
# λαός λᾶας
# προσεύχομαι προσεύχομαι
# ἔξεστι ἔξεστι
# ὥρα ὁράω
# θυμίαμα θυμίαμα
# ὁράω ὁράω
# ἄγγελος ἄγγελος
# κυρίου κύριος
# ἵστημι ἵστημι
# δείκνυμι δείκνυμι
# θυσιαστήριον θυσιαστήριον
# θυμίαμα θυμίαμα
# ταράσσω ταράσσω
# Ζαχαρίας Ζαχαρίας
# εἶδον εἶδον
# φόβος φόβος
# ἐπιπίπτω ἐπιπίπτω
# εἶπον εἶπον
# ἄγγελος ἄγγελος
# φοβέω φοβέω
# Ζαχαρίας Ζαχαρίας
# διότι διότι
# εἰσακούω εἰσακούω

# %%
AGT_GNT = AGT[AGT["author_id"].str.startswith("tlg0031")].copy()
#AGT_GNT["lemmata"] = AGT_GNT.apply(lambda row: lemmatize_string(row["string"], all_lemmata=False, filter_by_postag=["n", "a", "v"], involve_unknown=True), axis=1)
AGT_GNT["lemmata"] = AGT_GNT.apply(lambda row: lemmatize_string(row["string"]), axis=1)

# %%
print(AGT_GNT["lemmata"].tolist()[1][:300])
# Out:
# ['αρχη', 'εὐαγγέλιον', 'Ἰησοῦς', 'Χριστός', 'καθώς', 'γράφω', 'ἠσαίᾳ', 'προφήτης', 'ἰδού', 'ἀποστέλλω', 'ἄγγελος', 'ἁμός', 'πρό', 'πρόσωπον', 'σεύω', 'κατασκευάζω', 'ὁδός', 'σεύω', 'φωνη', 'βάζω', 'ἐρημάζω', 'ἑτοιμάσατε', 'ὁδός', 'κυρίου', 'εὐθεῖα', 'ποιέω', 'τρίβος', 'γίγνομαι', 'ἰωάνης', 'βαπτίζω', 'ἐρημάζω', 'κηρύσσω', 'βάπτισμα', 'μετάνοια', 'ἄφεσις', 'ἁμάρτημα', 'ἐκπορεύω', 'πᾶς', 'Ἰουδαῖος', 'χώρα', 'ἰεροσολυμεῖται', 'πᾶς', 'βαπτίζω', 'ὑπ', 'Ἰορδάνης', 'ποταμός', 'ἐξομολογέομαι', 'ἁμαρτία', 'ἰωάνης', 'ἐνδύω', 'θρίξ', 'κάμηλος', 'ζώνη', 'δερμάτινος', 'ὀσφύς', 'εἰσθέω', 'ἀκρίς', 'μέλι', 'ἀγρέω', 'κηρύσσω', 'λέγω', 'ἔρχεται', 'ἰσχυρός', 'ἁμός', 'ὀπίσω', 'ἁμός', 'ἕ', 'ἱκανός', 'κύπτω', 'λύω', 'ἱμάς', 'ὑπόδημα', 'βαπτίζω', 'ὕδωρ', 'βαπτίζω', 'πνεῦμα', 'ἅγιος', 'και', 'εγενετο', 'ἐκεῖνος', 'ἡμέρα', 'ἔρχομαι', 'Ἰησοῦς', 'Ναζαρά', 'Γαλιλαία', 'βαπτίζω', 'Ἰορδάνης', 'ἰωάνου', 'εὐθύς', 'ἀναβαίνω', 'ὕδωρ', 'εἶδον', 'σχίζω', 'οὐρανός', 'πνεῦμα', 'περιστερά', 'καταβαίνω', 'φωνέω', 'γίγνομαι', 'οὐρανός', 'εἶμι', 'υἱός', 'ἁμός', 'ἀγαπητός', 'εὐδοκέω', 'εὐθύς', 'πνεῦμα', 'ἐκβάλλω', 'ἐρῆμος', 'ἐρημάζω', 'τεσσαράκοντα', 'ἡμέρα', 'πειράζω', 'σατανᾶ', 'θηράω', 'ἀγγέλλω', 'διακονέω', 'παραδίδωμι', 'ἰωάνην', 'ἔρχομαι', 'Ἰησοῦς', 'Γαλιλαία', 'κηρύσσω', 'εὐαγγέλιον', 'θεάομαι', 'λέγω', 'πεπλήρωται', 'καῖρος', 'ἐγγίζω', 'βασίλεια', 'θεάομαι', 'μετανοέω', 'πιστεύω', 'εὐαγγέλιον', 'παράγω', 'θάλασσα', 'Γαλιλαία', 'εἶδον', 'Σίμων', 'Ἀνδρέας', 'ἀδελφός', 'Σίμων', 'ἀμφιβάλλω', 'θάλασσα', 'ἀλεής', 'εἶπον', 'Ἰησοῦς', 'δεῦτε', 'ὀπίσω', 'ἁμός', 'ποιέω', 'γίγνομαι', 'ἀλεής', 'ἄνθρωπος', 'εὐθύς', 'ἀφίημι', 'δίκτυον', 'ἀκολουθέω', 'προβαίνω', 'ὀλίγος', 'εἶδον', 'Ἰάκωβος', 'Ζεβεδαῖος', 'ἰωάνην', 'ἀδελφός', 'πλοῖον', 'καταρτίζω', 'δίκτυον', 'εὐθύς', 'καλέω', 'ἀφίημι', 'πατήρ', 'Ζεβεδαῖος', 'πλοῖον', 'μισθόω', 'ἀπέρχομαι', 'ὀπίσω', 'εἰσπορεύω', 'Καφαρναούμ', 'εὐθύς', 'σάββατον', 'εἰσέρχομαι', 'συναγωγή', 'διδάσκω', 'ἐκπλήσσω', 'διδαχή', 'διδάσκω', 'ἐξουσία', 'ἔχω', 'γραμματεύς', 'εὐθύς', 'συναγωγεύς', 'ἄνθρωπος', 'πνεῦμα', 'ἀκάθαρτος', 'ἀνακράζω', 'λέγω', 'Ἰησοῦς', 'Ναζαρηνός', 'ἔρχομαι', 'ἀπόλλυμι', 'οἶδα', 'εἶμι', 'ἅγιος', 'θεάομαι', 'ἐπιτιμάω', 'Ἰησοῦς', 'λέγω', 'φιμώθητι', 'ἐξέρχομαι', 'σπαράσσω', 'πνεῦμα', 'ἀκάθαρτος', 'φωνέω', 'φωνέω', 'μέγας', 'ἐξέρχομαι', 'θαμβέω', 'ἅπας', 'συζητέω', 'λέγω', 'διδαχη', 'καινός', 'ἄατος', 'ἐξουσία', 'πνεῦμα', 'ἀκάθαρτος', 'ἐπιτάσσω', 'ὑπακούω', 'ἐξέρχομαι', 'ἀκοη', 'εὐθύς', 'πανταχοῦ', 'ὁλάω', 'περίχωρος', 'Γαλιλαία', 'εὐθύς', 'συναγωγεύς', 'ἐξέρχομαι', 'ἔρχομαι', 'οἰκία', 'Σίμων', 'Ἀνδρέας', 'Ἰάκωβος', 'ἰωάνου', 'πενθερά', 'Σίμων', 'κατάκειμαι', 'πυρέσσω', 'εὐθύς', 'λέγω', 'προσέρχομαι', 'ἀγείρω', 'αὐτην', 'κρατέω', 'χείρ', 'ἀφήκω', 'αὐτην', 'πυρετός', 'διακονέω', 'ὄψιος', 'γίγνομαι', 'ὅστε', 'ἔδυσεν', 'ἥλιος', 'φέρω', 'πᾶς', 'κακός', 'ἔχω', 'δαιμονίζομαι', 'ὁλάω', 'πόλις', 'ἐπισυνάγω', 'θύρα', 'θεραπεύω', 'πολύς', 'κακός', 'ἔχω', 'ποικίλλω', 'νοσέω', 'δαιμόνιον', 'πολύς', 'ἐκβάλλω', 'ἀφίημι', 'λαλέω', 'δαιμόνιον', 'οἶδα', 'Χριστός', 'πρωί', 'ἔννυχος', 'λίαν', 'ἀνίστημι', 'ἐξέρχομαι', 'ἀπέρχομαι', 'ἐρῆμος', 'τόπος', 'ἀκέομαι', 'προσεύχομαι', 'καταδιώκω', 'Σίμων']

# %%
print(AGT_GNT["lemmata"].tolist()[0][:200])
# Out:
# ['βιβλος', 'γένεσις', 'ἰησοῦ', 'χριστοῦ', 'υἱός', 'δαυείδ', 'υἱός', 'ἀβρααμ', 'ἀβραάμ', 'γεννάω', 'ἰσαάκ', 'ἰσαάκ', 'γεννάω', 'ἰακώβ', 'ἰακώβ', 'γεννάω', 'ἰούδαν', 'ἀδελφός', 'ἰούδας', 'γεννάω', 'φαρές', 'ζαρά', 'θάμαρ', 'φαρές', 'γεννάω', 'ἑσρώμ', 'ἑσρώμ', 'γεννάω', 'ἀράμ', 'ἀράμ', 'γεννάω', 'ἀμιναδάβ', 'ἀμιναδάβ', 'γεννάω', 'ναασσών', 'ναασσών', 'γεννάω', 'σαλμών', 'σαλμών', 'γεννάω', 'βοές', 'ῥαχάβ', 'βοές', 'γεννάω', 'ἰωβηδ', 'ῥούθ', 'ἰωβηδ', 'γεννάω', 'ἰεσσαί', 'ἰεσσαί', 'γεννάω', 'δαυείδ', 'βασιλεύς', 'δαυείδ', 'γεννάω', 'σολομῶνα', 'οὐρίου', 'σολομών', 'γεννάω', 'ῥοβοάμ', 'ῥοβοάμ', 'γεννάω', 'ἀβιά', 'ἀβιά', 'γεννάω', 'ἀσάφ', 'ἀσάφ', 'γεννάω', 'ἰωσαφάτ', 'ἰωσαφάτ', 'γεννάω', 'ἰωράμ', 'ἰωράμ', 'γεννάω', 'ὀζείαν', 'ὀζείας', 'γεννάω', 'ἰωαθάμ', 'ἰωαθάμ', 'γεννάω', 'ἄχας', 'ἄχας', 'γεννάω', 'ἑζεκίαν', 'ἑζεκίας', 'γεννάω', 'μανασσῆ', 'μανασσῆς', 'γεννάω', 'ἀμώς', 'ἀμώς', 'γεννάω', 'ἰωσείαν', 'ἰωσείας', 'γεννάω', 'ἰεχονίαν', 'ἀδελφός', 'μετοικεσία', 'Βαβυλών', 'μετοικεσία', 'Βαβυλών', 'ἰεχονίας', 'γεννάω', 'σαλαθιήλ', 'σαλαθιηλ', 'γεννάω', 'ζοροβάβελ', 'ζοροβάβελ', 'γεννάω', 'ἀβιούδ', 'ἀβιούδ', 'γεννάω', 'ἐλιακείμ', 'ἐλιακείμ', 'γεννάω', 'ἀζώρ', 'ἀζώρ', 'γεννάω', 'σαδώκ', 'σαδώκ', 'γεννάω', 'ἀχείμ', 'ἀχείμ', 'γεννάω', 'ἐλιούδ', 'ἐλιούδ', 'γεννάω', 'ἐλεάζαρ', 'ἐλεάζαρ', 'γεννάω', 'μαθθάν', 'μαθθάν', 'γεννάω', 'ἰακώβ', 'ἰακώβ', 'γεννάω', 'ἰωσηφ', 'ἀνήρ', 'μαρίας', 'γεννάω', 'ἰησοῦς', 'χριστός', 'πᾶσαι', 'γενεά', 'ἀβραάμ', 'ἑός', 'δαυείδ', 'γενεά', 'δεκατέσσαρες', 'δαυείδ', 'ἑός', 'μετοικεσία', 'Βαβυλών', 'γενεά', 'δεκατέσσαρες', 'μετοικεσία', 'Βαβυλών', 'ἑός', 'χριστός', 'γενεά', 'δεκατέσσαρες', 'του', 'δε', 'ιησου', 'χριστου', 'γένεσις', 'μνηστευθείσης', 'μήτηρ', 'μαρίας', 'ἰωσήφ', 'συνέρχομαι', 'εὑρίσκω', 'γαστήρ', 'πνεῦμα', 'ἅγιος', 'ἰωσηφ', 'ἀνηρ', 'δίκαιος', 'αὐτην', 'δειγματίζω', 'βούλομαι', 'ἀπολύω', 'ταῦτα', 'εἶδον', 'ἄγγελος', 'κυρίου', 'ἄατος', 'ὄναρ', 'φαίνω', 'ἰωσηφ', 'υἱός', 'δαυείδ', 'φοβέω', 'παραλαμβάνω', 'μαρίαν', 'γυνή', 'σεύω', 'γεννάω', 'πνεύματός', 'ἅγιος']

# %%
NT_df.head(5)
# Out:
#                             filename                 author  \
# 385  tlg0031.tlg001.perseus-grc2.xml                   None
# 386  tlg0031.tlg002.perseus-grc2.xml                   None
# 387  tlg0031.tlg003.perseus-grc2.xml  Luke (the evangelist)
# 388  tlg0031.tlg004.perseus-grc2.xml  Johnannine literature
# 389  tlg0031.tlg005.perseus-grc2.xml  Luke (the evangelist)
#
#                        title  \
# 385  New Testament - Matthew
# 386     New Testament - Mark
# 387     New Testament - Luke
# 388     New Testament - John
# 389     New Testament - Acts
#
#                                                 string  wordcount  \
# 385    ΒΙΒΛΟΣ γενέσεως Ἰησοῦ Χριστοῦ υἱοῦ Δαυεὶδ υἱ...      18288
# 386  \n\n                    ΑΡΧΗ τοῦ εὐαγγελίου Ἰη...      11274
# 387  \n\n                    ΕΠΕΙΔΗΠΕΡ ΠΟΛΛΟΙ ἐπεχε...      19458
# 388  \n\n                    ΕΝ ΑΡΧΗ ἦν ὁ λόγος, κα...      15590
# 389  \n τὸν μὲν πρῶτον λόγον ἐποιησάμην περὶ πάντων...      18406
#
#        author_id          doc_id raw_date  date_avr  date_probs  date_manual  \
# 385     tlg0031a  tlg0031.tlg001   A.D. 1       0.5  {'0.5': 1}          0.5
# 386     tlg0031b  tlg0031.tlg002   A.D. 1       0.5  {'0.5': 1}          0.5
# 387  tlg0031luke  tlg0031.tlg003   A.D. 1       0.5  {'0.5': 1}          0.5
# 388  tlg0031john  tlg0031.tlg004   A.D. 1       0.5  {'0.5': 1}          0.5
# 389  tlg0031luke  tlg0031.tlg005   A.D. 1       0.5  {'0.5': 1}          0.5
#
#     provenience                                          sentences  \
# 385   christian  [ΒΙΒΛΟΣ γενέσεως Ἰησοῦ Χριστοῦ υἱοῦ Δαυεὶδ υἱο...
# 386   christian  [ΑΡΧΗ τοῦ εὐαγγελίου Ἰησοῦ Χριστοῦ, Καθὼς γέγρ...
# 387   christian  [ΕΠΕΙΔΗΠΕΡ ΠΟΛΛΟΙ ἐπεχείρησαν ἀνατάξασθαι\n\nδ...
# 388   christian  [ΕΝ ΑΡΧΗ ἦν ὁ λόγος, καὶ ὁ λόγος ἦν πρὸς τὸν θ...
# 389   christian  [τὸν μὲν πρῶτον λόγον ἐποιησάμην περὶ πάντων, ...
#
#                                                lemmata
# 385  [βιβλος, γένεσις, ἰησοῦ, χριστοῦ, υἱός, δαυείδ...
# 386  [αρχη, εὐαγγέλιον, ἰησοῦ, χριστοῦ, καθώς, γράφ...
# 387  [επειδηπερ, πολλοι, ἐπιχειρέω, ἀνατάξασθαι, δι...
# 388  [εν, αρχη, λόγος, λόγος, θεός, θεός, λόγος, ἀρ...
# 389  [πρότερος, λόγος, ποιέω, πᾶς, θεόφιλε, ἄρχω, ἰ...

# %%
for word in AGT_GNT.iloc[0]["string"].split()
# Out:
# ['ΒΙΒΛΟΣ',
#  'γενέσεως',
#  'Ἰησοῦ',
#  'Χριστοῦ',
#  'υἱοῦ',
#  'Δαυεὶδ',
#  'υἱοῦ',
#  'Ἀβρααμ.',
#  'Ἀβραὰμ',
#  'ἐγέννησεν',
#  'τὸν',
#  'Ἰσαάκ,',
#  'Ἰσαὰκ',
#  'δὲ',
#  'ἐγέννησεν',
#  'τὸν',
#  'Ἰακώβ,',
#  'Ἰακὼβ',
#  'δὲ',
#  'ἐγέννησεν',
#  'τὸν',
#  'Ἰούδαν',
#  'καὶ',
#  'τοὺς',
#  'ἀδελφοὺς',
#  'αὐτοῦ,',
#  'Ἰούδας',
#  'δὲ',
#  'ἐγέννησεν',
#  'τὸν',
#  'Φαρὲς',
#  'καὶ',
#  'τὸν',
#  'Ζαρὰ',
#  'ἐκ',
#  'τῆς',
#  'Θάμαρ,',
#  'Φαρὲς',
#  'δὲ',
#  'ἐγέννησεν',
#  'τὸν',
#  'Ἑσρώμ,',
#  'Ἑσρὼμ',
#  'δὲ',
#  'ἐγέννησεν',
#  'τὸν',
#  'Ἀράμ,',
#  'Ἀρὰμ',
#  'δὲ',
#  'ἐγέννησεν',
#  'τὸν',
#  'Ἀμιναδάβ,',
#  'Ἀμιναδὰβ',
#  'δὲ',
#  'ἐγέννησεν',
#  'τὸν',
#  'Ναασσών,',
#  'Ναασσὼν',
#  'δὲ',
#  'ἐγέννησεν',
#  'τὸν',
#  'Σαλμών,',
#  'Σαλμὼν',
#  'δὲ',
#  'ἐγέννησεν',
#  'τὸν',
#  'Βοὲς',
#  'ἐκ',
#  'τῆς',
#  'Ῥαχάβ,',
#  'Βοὲς',
#  'δὲ',
#  'ἐγέννησεν',
#  'τὸν',
#  'Ἰωβὴδ',
#  'ἐκ',
#  'τῆς',
#  'Ῥούθ,',
#  'Ἰωβὴδ',
#  'δὲ',
#  'ἐγέννησεν',
#  'τὸν',
#  'Ἰεσσαί,',
#  'Ἰεσσαὶ',
#  'δὲ',
#  'ἐγέννησεν',
#  'τὸν',
#  'Δαυεὶδ',
#  'τὸν',
#  'βασιλέα.',
#  'Δαυεὶδ',
#  'δὲ',
#  'ἐγέννησεν',
#  'τὸν',
#  'Σολομῶνα',
#  'ἐκ',
#  'τῆς',
#  'τοῦ',
#  'Οὐρίου,',
#  'Σολομὼν',
#  'δὲ',
#  'ἐγέννησεν',
#  'τὸν',
#  'Ῥοβοάμ,',
#  'Ῥοβοὰμ',
#  'δὲ',
#  'ἐγέννησεν',
#  'τὸν',
#  'Ἀβιά,',
#  'Ἀβιὰ',
#  'δὲ',
#  'ἐγέννησεν',
#  'τὸν',
#  'Ἀσάφ,',
#  'Ἀσὰφ',
#  'δὲ',
#  'ἐγέννησεν',
#  'τὸν',
#  'Ἰωσαφάτ,',
#  'Ἰωσαφὰτ',
#  'δὲ',
#  'ἐγέννησεν',
#  'τὸν',
#  'Ἰωράμ,',
#  'Ἰωρὰμ',
#  'δὲ',
#  'ἐγέννησεν',
#  'τὸν',
#  'Ὀζείαν,',
#  'Ὀζείας',
#  'δὲ',
#  'ἐγέννησεν',
#  'τὸν',
#  'Ἰωαθάμ,',
#  'Ἰωαθὰμ',
#  'δὲ',
#  'ἐγέννησεν',
#  'τὸν',
#  'Ἄχας,',
#  'Ἄχας',
#  'δὲ',
#  'ἐγέννησεν',
#  'τὸν',
#  'Ἑζεκίαν,',
#  'Ἑζεκίας',
#  'δὲ',
#  'ἐγέννησεν',
#  'τὸν',
#  'Μανασσῆ,',
#  'Μανασσῆς',
#  'δὲ',
#  'ἐγέννησεν',
#  'τὸν',
#  'Ἀμώς,',
#  'Ἀμὼς',
#  'δὲ',
#  'ἐγέννησεν',
#  'τὸν',
#  'Ἰωσείαν,',
#  'Ἰωσείας',
#  'δὲ',
#  'ἐγέννησεν',
#  'τὸν',
#  'Ἰεχονίαν',
#  'καὶ',
#  'τοὺς',
#  'ἀδελφοὺς',
#  'αὐτοῦ',
#  'ἐπὶ',
#  'τῆς',
#  'μετοικεσίας',
#  'Βαβυλῶνος.',
#  'Μετὰ',
#  'δὲ',
#  'τὴν',
#  'μετοικεσίαν',
#  'Βαβυλῶνος',
#  'Ἰεχονίας',
#  'ἐγέννησεν',
#  'τὸν',
#  'Σαλαθιήλ,',
#  'Σαλαθιὴλ',
#  'δὲ',
#  'ἐγέννησεν',
#  'τὸν',
#  'Ζοροβάβελ,',
#  'Ζοροβάβελ',
#  'δὲ',
#  'ἐγέννησεν',
#  'τὸν',
#  'Ἀβιούδ,',
#  'Ἀβιοὺδ',
#  'δὲ',
#  'ἐγέννησεν',
#  'τὸν',
#  'Ἐλιακείμ,',
#  'Ἐλιακεὶμ',
#  'δὲ',
#  'ἐγέννησεν',
#  'τὸν',
#  'Ἀζώρ,',
#  'Ἀζὼρ',
#  'δὲ',
#  'ἐγέννησεν',
#  'τὸν',
#  'Σαδώκ,',
#  'Σαδὼκ',
#  'δὲ',
#  'ἐγέννησεν',
#  'τὸν',
#  'Ἀχείμ,',
#  'Ἀχεὶμ',
#  'δὲ',
#  'ἐγέννησεν',
#  'τὸν',
#  'Ἐλιούδ,',
#  'Ἐλιοὺδ',
#  'δὲ',
#  'ἐγέννησεν',
#  'τὸν',
#  'Ἐλεάζαρ,',
#  'Ἐλεάζαρ',
#  'δὲ',
#  'ἐγέννησεν',
#  'τὸν',
#  'Μαθθάν,',
#  'Μαθθὰν',
#  'δὲ',
#  'ἐγέννησεν',
#  'τὸν',
#  'Ἰακώβ,',
#  'Ἰακὼβ',
#  'δὲ',
#  'ἐγέννησεν',
#  'τὸν',
#  'Ἰωσὴφ',
#  'τὸν',
#  'ἄνδρα',
#  'Μαρίας,',
#  'ἐξ',
#  'ἧς',
#  'ἐγεννήθη',
#  'Ἰησοῦς',
#  'ὁ',
#  'λεγόμενος',
#  'Χριστός.',
#  'Πᾶσαι',
#  'οὖν',
#  'αἱ',
#  'γενεαὶ',
#  'ἀπὸ',
#  'Ἀβραὰμ',
#  'ἕως',
#  'Δαυεὶδ',
#  'γενεαὶ',
#  'δεκατέσσαρες,',
#  'καὶ',
#  'ἀπὸ',
#  'Δαυεὶδ',
#  'ἕως',
#  'τῆς',
#  'μετοικεσίας',
#  'Βαβυλῶνος',
#  'γενεαὶ',
#  'δεκατέσσαρες,',
#  'καὶ',
#  'ἀπὸ',
#  'τῆς',
#  'μετοικεσίας',
#  'Βαβυλῶνος',
#  'ἕως',
#  'τοῦ',
#  'χριστοῦ',
#  'γενεαὶ',
#  'δεκατέσσαρες.',
#  'ΤΟΥ',
#  'ΔΕ',
#  '[ΙΗΣΟΥ]',
#  'ΧΡΙΣΤΟΥ',
#  'ἡ',
#  'γένεσις',
#  'οὕτως',
#  'ἦν.',
#  'Μνηστευθείσης',
#  'τῆς',
#  'μητρὸς',
#  'αὐτοῦ',
#  'Μαρίας',
#  'τῷ',
#  'Ἰωσήφ,',
#  'πρὶν',
#  'ἢ',
#  'συνελθεῖν',
#  'αὐτοὺς',
#  'εὑρέθη',
#  'ἐν',
#  'γαστρὶ',
#  'ἔχουσα',
#  'ἐκ',
#  'πνεύματος',
#  'ἁγίου.',
#  'Ἰωσὴφ',
#  'δὲ',
#  'ὁ',
#  'ἀνὴρ',
#  'αὐτῆς,',
#  'δίκαιος',
#  'ὢν',
#  'καὶ',
#  'μὴ',
#  'θέλων',
#  'αὐτὴν',
#  'δειγματίσαι,',
#  'ἐβουλήθη',
#  'λάθρᾳ',
#  'ἀπολῦσαι',
#  'αὐτήν.',
#  'Ταῦτα',
#  'δὲ',
#  'αὐτοῦ',
#  'ἐνθυμηθέντος',
#  'ἰδοὺ',
#  'ἄγγελος',
#  'Κυρίου',
#  'κατʼ',
#  'ὄναρ',
#  'ἐφάνη',
#  'αὐτῷ',
#  'λέγων',
#  'Ἰωσὴφ',
#  'υἱὸς',
#  'Δαυείδ,',
#  'μὴ',
#  'φοβηθῇς',
#  'παραλαβεῖν',
#  'Μαρίαν',
#  'τὴν',
#  'γυναῖκά',
#  'σου,',
#  'τὸ',
#  'γὰρ',
#  'ἐν',
#  'αὐτῇ',
#  'γεννηθὲν',
#  'ἐκ',
#  'πνεύματός',
#  'ἐστιν',
#  'ἁγίου·',
#  'τέξεται',
#  'δὲ',
#  'υἱὸν',
#  'καὶ',
#  'καλέσεις',
#  'τὸ',
#  'ὄνομα',
#  'αὐτοῦ',
#  'Ἰησοῦν,',
#  'αὐτὸς',
#  'γὰρ',
#  'σώσει',
#  'τὸν',
#  'λαὸν',
#  'αὐτοῦ',
#  'ἀπὸ',
#  'τῶν',
#  'ἁμαρτιῶν',
#  'αὐτῶν.',
#  'Τοῦτο',
#  'δὲ',
#  'ὅλον',
#  'γέγονεν',
#  'ἵνα',
#  'πληρωθῇ',
#  'τὸ',
#  'ῥηθὲν',
#  'ὑπὸ',
#  'Κυρίου',
#  'διὰ',
#  'τοῦ',
#  'προφήτου',
#  'λέγοντος',
#  'Ἰδοὺ',
#  'ἡ',
#  'παρθένος',
#  'ἐν',
#  'γαστρὶ',
#  'ἕξει',
#  'καὶ',
#  'τέξεται',
#  'υἱόν,',
#  'καὶ',
#  'καλέσουσιν',
#  'τὸ',
#  'ὄνομα',
#  'αὐτοῦ',
#  'Ἐμμανουήλ·',
#  'ὅ',
#  'ἐστιν',
#  'μεθερμηνευόμενον',
#  'Μεθʼ',
#  'ἡμῶν',
#  'ὁ',
#  'θεός.',
#  'Ἐγερθεὶς',
#  'δὲ',
#  '[ὁ]',
#  'Ἰωσὴφ',
#  'ἀπὸ',
#  'τοῦ',
#  'ὕπνου',
#  'ἐποίησεν',
#  'ὡς',
#  'προσέταξεν',
#  'αὐτῷ',
#  'ὁ',
#  'ἄγγελος',
#  'Κυρίου',
#  'καὶ',
#  'παρέλαβεν',
#  'τὴν',
#  'γυναῖκα',
#  'αὐτοῦ·',
#  'καὶ',
#  'οὐκ',
#  'ἐγίνωσκεν',
#  'αὐτὴν',
#  'ἕως',
#  '[οὗ]',
#  'ἔτεκεν',
#  'υἱόν·',
#  'καὶ',
#  'ἐκάλεσεν',
#  'τὸ',
#  'ὄνομα',
#  'αὐτοῦ',
#  'Ἰησοῦν.',
#  'Τοῦ',
#  'δὲ',
#  'Ἰησοῦ',
#  'γεννηθέντος',
#  'ἐν',
#  'Βηθλεὲμ',
#  'τῆς',
#  'Ἰουδαίας',
#  'ἐν',
#  'ἡμέραις',
#  'Ἡρῴδου',
#  'τοῦ',
#  'βασιλέως,',
#  'ἰδοὺ',
#  'μάγοι',
#  'ἀπὸ',
#  'ἀνατολῶν',
#  'παρεγένοντο',
#  'εἰς',
#  'Ἰεροσόλυμα',
#  'λέγοντες',
#  'Ποῦ',
#  'ἐστὶν',
#  'ὁ',
#  'τεχθεὶς',
#  'βασιλεὺς',
#  'τῶν',
#  'Ἰουδαίων;',
#  'εἴδομεν',
#  'γὰρ',
#  'αὐτοῦ',
#  'τὸν',
#  'ἀστέρα',
#  'ἐν',
#  'τῇ',
#  'ἀνατολῇ',
#  'καὶ',
#  'ἤλθομεν',
#  'προσκυνῆσαι',
#  'αὐτῷ.',
#  'Ἀκούσας',
#  'δὲ',
#  'ὁ',
#  'βασιλεὺς',
#  'Ἡρῴδης',
#  'ἐταράχθη',
#  'καὶ',
#  'πᾶσα',
#  'Ἰεροσόλυμα',
#  'μετʼ',
#  'αὐτοῦ,',
#  'καὶ',
#  'συναγαγὼν',
#  'πάντας',
#  'τοὺς',
#  'ἀρχιερεῖς',
#  'καὶ',
#  'γραμματεῖς',
#  'τοῦ',
#  'λαοῦ',
#  'ἐπυνθάνετο',
#  'παρʼ',
#  'αὐτῶν',
#  'ποῦ',
#  'ὁ',
#  'χριστὸς',
#  'γεννᾶται.',
#  'οἱ',
#  'δὲ',
#  'εἶπαν',
#  'αὐτῷ',
#  'Ἐν',
#  'Βηθλεὲμ',
#  'τῆς',
#  'Ἰουδαίας·',
#  'οὕτως',
#  'γὰρ',
#  'γέγραπται',
#  'διὰ',
#  'τοῦ',
#  'προφήτου',
#  'Καὶ',
#  'σύ,',
#  'Βηθλεὲμ',
#  'γῆ',
#  'Ἰούδα,',
#  'οὐδαμῶς',
#  'ἐλαχίστη',
#  'εἶ',
#  'ἐν',
#  'τοῖς',
#  'ἡγεμόσιν',
#  'Ἰούδα·',
#  'ἐκ',
#  'σοῦ',
#  'γὰρ',
#  'ἐξελεύσεται',
#  'ἡγούμενος,',
#  'ὅστις',
#  'ποιμανεῖ',
#  'τὸν',
#  'λαόν',
#  'μου',
#  'τὸν',
#  'Ἰσραήλ.',
#  'Τότε',
#  'Ἡρῴδης',
#  'λάθρᾳ',
#  'καλέσας',
#  'τοὺς',
#  'μάγους',
#  'ἠκρίβωσεν',
#  'παρʼ',
#  'αὐτῶν',
#  'τὸν',
#  'χρόνον',
#  'τοῦ',
#  'φαινομένου',
#  'ἀστέρος,',
#  'καὶ',
#  'πέμψας',
#  'αὐτοὺς',
#  'εἰς',
#  'Βηθλεὲμ',
#  'εἶπεν',
#  'Πορευθέντες',
#  'ἐξετάσατε',
#  'ἀκριβῶς',
#  'περὶ',
#  'τοῦ',
#  'παιδίου·',
#  'ἐπὰν',
#  'δὲ',
#  'εὕρητε',
#  'ἀπαγγείλατέ',
#  'μοι,',
#  'ὅπως',
#  'κἀγὼ',
#  'ἐλθὼν',
#  'προσκυνήσω',
#  'αὐτῷ.',
#  'οἱ',
#  'δὲ',
#  'ἀκούσαντες',
#  'τοῦ',
#  'βασιλέως',
#  'ἐπορεύθησαν,',
#  'καὶ',
#  'ἰδοὺ',
#  'ὁ',
#  'ἀστὴρ',
#  'ὃν',
#  'εἶδον',
#  'ἐν',
#  'τῇ',
#  'ἀνατολῇ',
#  'προῆγεν',
#  'αὐτούς,',
#  'ἕως',
#  'ἐλθὼν',
#  'ἐστάθη',
#  'ἐπάνω',
#  'οὗ',
#  'ἦν',
#  'τὸ',
#  'παιδίον.',
#  'ἰδόντες',
#  'δὲ',
#  'τὸν',
#  'ἀστέρα',
#  'ἐχάρησαν',
#  'χαρὰν',
#  'μεγάλην',
#  'σφόδρα.',
#  'καὶ',
#  'ἐλθόντες',
#  'εἰς',
#  'τὴν',
#  'οἰκίαν',
#  'εἶδον',
#  'τὸ',
#  'παιδίον',
#  'μετὰ',
#  'Μαρίας',
#  'τῆς',
#  'μητρὸς',
#  'αὐτοῦ,',
#  'καὶ',
#  'πεσόντες',
#  'προσεκύνησαν',
#  'αὐτῷ,',
#  'καὶ',
#  'ἀνοίξαντες',
#  'τοὺς',
#  'θησαυροὺς',
#  'αὐτῶν',
#  'προσήνεγκαν',
#  'αὐτῷ',
#  'δῶρα,',
#  'χρυσὸν',
#  'καὶ',
#  'λίβανον',
#  'καὶ',
#  'σμύρναν.',
#  'καὶ',
#  'χρηματισθέντες',
#  'κατʼ',
#  'ὄναρ',
#  'μὴ',
#  'ἀνακάμψαι',
#  'πρὸς',
#  'Ἡρῴδην',
#  'διʼ',
#  'ἄλλης',
#  'ὁδοῦ',
#  'ἀνεχώρησαν',
#  'εἰς',
#  'τὴν',
#  'χώραν',
#  'αὐτῶν.',
#  'Ἀναχωρησάντων',
#  'δὲ',
#  'αὐτῶν',
#  'ἰδοὺ',
#  'ἄγγελος',
#  'Κυρίου',
#  'φαίνεται',
#  'κατʼ',
#  'ὄναρ',
#  'τῷ',
#  'Ἰωσὴφ',
#  'λέγων',
#  'Ἐγερθεὶς',
#  'παράλαβε',
#  'τὸ',
#  'παιδίον',
#  'καὶ',
#  'τὴν',
#  'μητέρα',
#  'αὐτοῦ',
#  'καὶ',
#  'φεῦγε',
#  'εἰς',
#  'Αἴγυπτον,',
#  'καὶ',
#  'ἴσθι',
#  'ἐκεῖ',
#  'ἕως',
#  'ἂν',
#  'εἴπω',
#  'σοι·',
#  'μέλλει',
#  'γὰρ',
#  'Ἡρῴδης',
#  'ζητεῖν',
#  'τὸ',
#  'παιδίον',
#  'τοῦ',
#  'ἀπολέσαι',
#  'αὐτό.',
#  'ὁ',
#  'δὲ',
#  'ἐγερθεὶς',
#  'παρέλαβε',
#  'τὸ',
#  'παιδίον',
#  'καὶ',
#  'τὴν',
#  'μητέρα',
#  'αὐτοῦ',
#  'νυκτὸς',
#  'καὶ',
#  'ἀνεχώρησεν',
#  'εἰς',
#  'Αἴγυπτον,',
#  'καὶ',
#  'ἦν',
#  'ἐκεῖ',
#  'ἕως',
#  'τῆς',
#  'τελευτῆς',
#  'Ἡρῴδου·',
#  'ἵνα',
#  'πληρωθῇ',
#  'τὸ',
#  'ῥηθὲν',
#  'ὑπὸ',
#  'Κυρίου',
#  'διὰ',
#  'τοῦ',
#  'προφήτου',
#  'λέγοντος',
#  'Ἐξ',
#  'Αἰγύπτου',
#  'ἐκάλεσα',
#  'τὸν',
#  'υἱόν',
#  'μου.',
#  'Τότε',
#  'Ἡρῴδης',
#  'ἰδὼν',
#  'ὅτι',
#  'ἐνεπαίχθη',
#  'ὑπὸ',
#  'τῶν',
#  'μάγων',
#  'ἐθυμώθη',
#  'λίαν,',
#  'καὶ',
#  'ἀποστείλας',
#  'ἀνεῖλεν',
#  'πάντας',
#  'τοὺς',
#  'παῖδας',
#  'τοὺς',
#  'ἐν',
#  'Βηθλεὲμ',
#  'καὶ',
#  'ἐν',
#  'πᾶσι',
#  'τοῖς',
#  'ὁρίοις',
#  'αὐτῆς',
#  'ἀπὸ',
#  'διετοῦς',
#  'καὶ',
#  'κατωτέρω,',
#  'κατὰ',
#  'τὸν',
#  'χρόνον',
#  'ὃν',
#  'ἠκρίβωσεν',
#  'παρὰ',
#  'τῶν',
#  'μάγων.',
#  'Τότε',
#  'ἐπληρώθη',
#  'τὸ',
#  'ῥηθὲν',
#  'διὰ',
#  'Ἰερεμίου',
#  'τοῦ',
#  'προφήτου',
#  'λέγοντος',
#  'φωνὴ',
#  'ἐν',
#  'Ῥαμὰ',
#  'ἠκούσθη,',
#  'κλαυθμὸς',
#  'καὶ',
#  'ὀδυρμὸς',
#  'πολύς·',
#  'Ῥαχὴλ',
#  'κλαίουσα',
#  'τὰ',
#  'τέκνα',
#  'αὐτῆς,',
#  'καὶ',
#  'οὐκ',
#  'ἤθελεν',
#  'παρακληθῆναι',
#  'ὅτι',
#  'οὐκ',
#  'εἰσίν.',
#  'Τελευτήσαντος',
#  'δὲ',
#  'τοῦ',
#  'Ἡρῴδου',
#  'ἰδοὺ',
#  'ἄγγελος',
#  'Κυρίου',
#  'φαίνεται',
#  'κατʼ',
#  'ὄναρ',
#  'τῷ',
#  'Ἰωσὴφ',
#  'ἐν',
#  'Αἰγύπτῳ',
#  'λέγων',
#  'Ἐγερθεὶς',
#  'παράλαβε',
#  'τὸ',
#  'παιδίον',
#  'καὶ',
#  'τὴν',
#  'μητέρα',
#  'αὐτοῦ',
#  'καὶ',
#  'πορεύου',
#  'εἰς',
#  'γῆν',
#  'Ἰσραήλ,',
#  'τεθνήκασιν',
#  'γὰρ',
#  'οἱ',
#  'ζητοῦντες',
#  'τὴν',
#  'ψυχὴν',
#  'τοῦ',
#  'παιδίου.',
#  'ὁ',
#  'δὲ',
#  'ἐγερθεὶς',
#  'παρέλαβε',
#  'τὸ',
#  'παιδίον',
#  'καὶ',
#  'τὴν',
#  'μητέρα',
#  'αὐτοῦ',
#  'καὶ',
#  'εἰσῆλθεν',
#  'εἰς',
#  'γῆν',
#  'Ἰσραήλ.',
#  'ἀκούσας',
#  'δὲ',
#  'ὅτι',
#  'Ἀρχέλαος',
#  'βασιλεύει',
#  'τῆς',
#  'Ἰουδαίας',
#  'ἀντὶ',
#  'τοῦ',
#  'πατρὸς',
#  'αὐτοῦ',
#  'Ἡρῴδου',
#  'ἐφοβήθη',
#  'ἐκεῖ',
#  'ἀπελθεῖν·',
#  'χρηματισθεὶς',
#  'δὲ',
#  'κατʼ',
#  'ὄναρ',
#  'ἀνεχώρησεν',
#  'εἰς',
#  'τὰ',
#  'μέρη',
#  'τῆς',
#  'Γαλιλαίας,',
#  'καὶ',
#  'ἐλθὼν',
#  'κατῴκησεν',
#  'εἰς',
#  'πόλιν',
#  'λεγομένην',
#  'Ναζαρέτ,',
#  'ὅπως',
#  'πληρωθῇ',
#  'τὸ',
#  'ῥηθὲν',
#  'διὰ',
#  'τῶν',
#  'προφητῶν',
#  'ὅτι',
#  'Ναζωραῖος',
#  'κληθήσεται.',
#  'ΕΝ',
#  'ΔΕ',
#  'ΤΑΙΣ',
#  'ΗΜΕΡΑΙΣ',
#  'ἐκείναις',
#  'παραγίνεται',
#  'Ἰωάνης',
#  'ὁ',
#  'βαπτιστὴς',
#  'κηρύσσων',
#  'ἐν',
#  'τῇ',
#  'ἐρήμῳ',
#  'τῆς',
#  'Ἰουδαίας',
#  'λέγων',
#  'Μετανοεῖτε,',
#  'ἤγγικεν',
#  'γὰρ',
#  'ἡ',
#  'βασιλεία',
#  'τῶν',
#  'οὐρανῶν.',
#  'Οὗτος',
#  'γάρ',
#  'ἐστιν',
#  'ὁ',
#  'ῥηθεὶς',
#  'διὰ',
#  'Ἠσαίου',
#  'τοῦ',
#  'προφήτου',
#  'λέγοντος',
#  'φωνὴ',
#  'βοῶντος',
#  'ἐν',
#  'τῇ',
#  'ἐρήμῳ',
#  'Ἑτοιμάσατε',
#  'τὴν',
#  'ὁδὸν',
#  'Κυρίου,',
#  'εὐθείας',
#  'ποιεῖτε',
#  'τὰς',
#  'τρίβους',
#  'αὐτοῦ.',
#  'Αὐτὸς',
#  'δὲ',
#  'ὁ',
#  'Ἰωάνης',
#  'εἶχεν',
#  'τὸ',
#  'ἔνδυμα',
#  'αὐτοῦ',
#  'ἀπὸ',
#  'τριχῶν',
#  'καμήλου',
#  'καὶ',
#  'ζώνην',
#  'δερματίνην',
#  'περὶ',
#  'τὴν',
#  'ὀσφὺν',
#  'αὐτοῦ,',
#  'ἡ',
#  'δὲ',
#  'τροφὴ',
#  'ἦν',
#  'αὐτοῦ',
#  'ἀκρίδες',
#  'καὶ',
#  'μέλι',
#  'ἄγριον.',
#  'Τότε',
#  'ἐξεπορεύετο',
#  'πρὸς',
#  'αὐτὸν',
#  'Ἰεροσόλυμα',
#  'καὶ',
#  'πᾶσα',
#  'ἡ',
#  'Ἰουδαία',
#  'καὶ',
#  'πᾶσα',
#  'ἡ',
#  'περίχωρος',
#  'τοῦ',
#  'Ἰορδάνου,',
#  'καὶ',
#  'ἐβαπτίζοντο',
#  'ἐν',
#  'τῷ',
#  'Ἰορδάνῃ',
#  'ποταμῷ',
#  'ὑπʼ',
#  'αὐτοῦ',
#  'ἐξομολογούμενοι',
#  'τὰς',
#  'ἁμαρτίας',
#  'αὐτῶν.',
#  'Ἰδὼν',
#  'δὲ',
#  'πολλοὺς',
#  'τῶν',
#  'Φαρισαίων',
#  'καὶ',
#  ...]

# %%
GNT_df = pd.read_csv("https://raw.githubusercontent.com/biblicalhumanities/Nestle1904/master/morph/Nestle1904.csv", delim_whitespace=True, index_col=False, skiprows=1, names=("book", "ch_v", "func_morph", "pos1", "pos2", "strong", "lemma", "normalized"))
GNT_df.head(20)
# Out:
#     book ch_v func_morph      pos1      pos2     strong    lemma normalized
# 0   Matt  1:1     Βίβλος     N-NSF     N-NSF        976   βίβλος     Βίβλος
# 1   Matt  1:1   γενέσεως     N-GSF     N-GSF       1078  γένεσις   γενέσεως
# 2   Matt  1:1      Ἰησοῦ     N-GSM     N-GSM       2424   Ἰησοῦς      Ἰησοῦ
# 3   Matt  1:1    Χριστοῦ     N-GSM     N-GSM       5547  Χριστός    Χριστοῦ
# 4   Matt  1:1       υἱοῦ     N-GSM     N-GSM       5207     υἱός       υἱοῦ
# 5   Matt  1:1     Δαυεὶδ     N-PRI     N-PRI       1138    Δαυίδ     Δαυείδ
# 6   Matt  1:1       υἱοῦ     N-GSM     N-GSM       5207     υἱός       υἱοῦ
# 7   Matt  1:1    Ἀβραάμ.     N-PRI     N-PRI         11   Ἀβραάμ     Ἀβραάμ
# 8   Matt  1:2     Ἀβραὰμ     N-PRI     N-PRI         11   Ἀβραάμ     Ἀβραάμ
# 9   Matt  1:2  ἐγέννησεν  V-AAI-3S  V-AAI-3S  1080&5656   γεννάω  ἐγέννησεν
# 10  Matt  1:2        τὸν     T-ASM     T-ASM       3588        ὁ        τόν
# 11  Matt  1:2     Ἰσαάκ,     N-PRI     N-PRI       2464    Ἰσαάκ      Ἰσαάκ
# 12  Matt  1:2      Ἰσαὰκ     N-PRI     N-PRI       2464    Ἰσαάκ      Ἰσαάκ
# 13  Matt  1:2         δὲ      CONJ      CONJ       1161       δέ         δέ
# 14  Matt  1:2  ἐγέννησεν  V-AAI-3S  V-AAI-3S  1080&5656   γεννάω  ἐγέννησεν
# 15  Matt  1:2        τὸν     T-ASM     T-ASM       3588        ὁ        τόν
# 16  Matt  1:2     Ἰακώβ,     N-PRI     N-PRI       2384    Ἰακώβ      Ἰακώβ
# 17  Matt  1:2      Ἰακὼβ     N-PRI     N-PRI       2384    Ἰακώβ      Ἰακώβ
# 18  Matt  1:2         δὲ      CONJ      CONJ       1161       δέ         δέ
# 19  Matt  1:2  ἐγέννησεν  V-AAI-3S  V-AAI-3S  1080&5656   γεννάω  ἐγέννησεν

# %%
GNT_df.iloc[0]["string"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'string'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-47-ce3dbdb472a5> in <module>
# ----> 1 GNT_df.iloc[0]["string"]
#
# ~/.local/lib/python3.6/site-packages/pandas/core/series.py in __getitem__(self, key)
#     880
#     881         elif key_is_scalar:
# --> 882             return self._get_value(key)
#     883
#     884         if is_hashable(key):
#
# ~/.local/lib/python3.6/site-packages/pandas/core/series.py in _get_value(self, label, takeable)
#     987
#     988         # Similar to Index.get_value, but we do not fall back to positional
# --> 989         loc = self.index.get_loc(label)
#     990         return self.index._get_values_for_loc(self, loc, label)
#     991
#
# ~/.local/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'string'

# %%
len(GNT_morph_lemma_dict)

# %%
len(GNT_df["normalized"].tolist())
# Out:
# 137779

# %%
len(GNT_df["normalized"].unique().tolist())
# Out:
# 18444

# %%
len(GNT_df["func_morph"].unique().tolist())
# Out:
# 25215

# %%
GNT_morph_lemma =[(re.sub("\.|\,|\;", "", unicodedata.normalize("NFC", morph)), unicodedata.normalize("NFC", lemma), {"l" : lemma, "p": pos.lower(), "s" : ""}) for morph, lemma, pos in zip(GNT_df["func_morph"].tolist(), GNT_df["lemma"].tolist(), GNT_df["pos1"].tolist())]
GNT_morph_lemma[:10]
# Out:
# [('Βίβλος', 'βίβλος', {'l': 'βίβλος', 'p': 'n-nsf', 's': ''}),
#  ('γενέσεως', 'γένεσις', {'l': 'γένεσις', 'p': 'n-gsf', 's': ''}),
#  ('Ἰησοῦ', 'Ἰησοῦς', {'l': 'Ἰησοῦς', 'p': 'n-gsm', 's': ''}),
#  ('Χριστοῦ', 'Χριστός', {'l': 'Χριστός', 'p': 'n-gsm', 's': ''}),
#  ('υἱοῦ', 'υἱός', {'l': 'υἱός', 'p': 'n-gsm', 's': ''}),
#  ('Δαυεὶδ', 'Δαυίδ', {'l': 'Δαυίδ', 'p': 'n-pri', 's': ''}),
#  ('υἱοῦ', 'υἱός', {'l': 'υἱός', 'p': 'n-gsm', 's': ''}),
#  ('Ἀβραάμ', 'Ἀβραάμ', {'l': 'Ἀβραάμ', 'p': 'n-pri', 's': ''}),
#  ('Ἀβραὰμ', 'Ἀβραάμ', {'l': 'Ἀβραάμ', 'p': 'n-pri', 's': ''}),
#  ('ἐγέννησεν', 'γεννάω', {'l': 'γεννάω', 'p': 'v-aai-3s', 's': ''})]

# %%
len(GNT_morph_lemma)
# Out:
# 137779

# %%
GNT_morph_lemma_dict = {}
for tup in GNT_morph_lemma:
    if tup[0] not in GNT_morph_lemma_dict.keys():
        GNT_morph_lemma_dict[tup[0]] = tup[2]

# %%
GNT_morph_lemma_unique = list(set(GNT_morph_lemma))
len(GNT_morph_lemma_unique)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-17d1889a37b0> in <module>
# ----> 1 GNT_morph_lemma_unique = list(set(GNT_morph_lemma))
#       2 len(GNT_morph_lemma_unique)
#
# TypeError: unhashable type: 'dict'

# %%
GNT_morph_lemma_unique

# %%
NT_df = AGT[AGT["author_id"].str.startswith("tlg0031")]
NT_lemmata = []
for lemmata in NT_df["lemmata"].tolist():
    NT_lemmata.extend(lemmata)

# %%
NT_freqdist = nltk.FreqDist(NT_lemmata).most_common()
NT_freqdist
# Out:
# [('πᾶς', 1086),
#  ('ἁμός', 1078),
#  ('εἶπον', 828),
#  ('λέγω', 786),
#  ('θεάομαι', 701),
#  ('θεός', 620),
#  ('ἡμός', 564),
#  ('ἄνθρωπος', 522),
#  ('ποιέω', 487),
#  ('γίγνομαι', 482),
#  ('σεύω', 476),
#  ('ἔχω', 465),
#  ('ἰησοῦς', 454),
#  ('ἔρχομαι', 421),
#  ('πατήρ', 397),
#  ('εἶμι', 388),
#  ('ἡμέρα', 380),
#  ('υἱός', 371),
#  ('κύριος', 371),
#  ('εἶδον', 367),
#  ('πνεῦμα', 357),
#  ('πολύς', 341),
#  ('λόγος', 329),
#  ('ἰησοῦ', 325),
#  ('δίδωμι', 312),
#  ('ἀδελφός', 311),
#  ('οὐρανός', 273),
#  ('μαθητής', 262),
#  ('ἐκεῖνος', 253),
#  ('οἶδα', 249),
#  ('ἀκούω', 247),
#  ('γῆ', 246),
#  ('μέγας', 239),
#  ('λαλέω', 231),
#  ('πίστις', 226),
#  ('ἐμέω', 219),
#  ('δοκέω', 217),
#  ('χριστός', 214),
#  ('ἀλλ', 214),
#  ('ἅγιος', 203),
#  ('ἵημι', 202),
#  ('νόμος', 194),
#  ('γυνή', 192),
#  ('γιγνώσκω', 190),
#  ('χριστοῦ', 182),
#  ('δύναμαι', 176),
#  ('πιστεύω', 174),
#  ('ἐθέλω', 170),
#  ('φωνέω', 165),
#  ('βασίλεια', 162),
#  ('ἔθνος', 162),
#  ('ἔργον', 162),
#  ('πρότερος', 161),
#  ('χάρις', 158),
#  ('ὁράω', 157),
#  ('καρδία', 156),
#  ('ζωή', 151),
#  ('ἀνήρ', 146),
#  ('ἄατος', 146),
#  ('ἐπ', 145),
#  ('λαμβάνω', 144),
#  ('ἑός', 143),
#  ('εὑρίσκω', 142),
#  ('προφήτης', 142),
#  ('γράφω', 140),
#  ('ἄγγελος', 139),
#  ('εἰσέρχομαι', 136),
#  ('χείρ', 135),
#  ('ἐσθίω', 135),
#  ('ἔμετος', 132),
#  ('ἀγαπάω', 131),
#  ('νεκρός', 130),
#  ('πόλις', 128),
#  ('ἐξέρχομαι', 127),
#  ('ἰησοῦν', 125),
#  ('ἀπ', 124),
#  ('δοῦλος', 124),
#  ('ἀποκρίνω', 124),
#  ('ἀρχιερεύς', 123),
#  ('σῶμα', 122),
#  ('αἰών', 120),
#  ('λαός', 116),
#  ('δύναμις', 116),
#  ('κόσμος', 114),
#  ('ἁμαρτία', 112),
#  ('ὄχλος', 111),
#  ('βασιλεύς', 109),
#  ('μόνος', 109),
#  ('ἐκκλησιάζω', 107),
#  ('ἀλήθεια', 107),
#  ('ἀποστέλλω', 105),
#  ('βάλλω', 104),
#  ('ἀγαπάζω', 104),
#  ('ὅσος', 104),
#  ('ψυχή', 102),
#  ('ἐξουσία', 102),
#  ('σάρξ', 102),
#  ('καλέω', 101),
#  ('ζάω', 101),
#  ('δεῖ', 101),
#  ('ἀποθνήσκω', 100),
#  ('ἀλλήλων', 100),
#  ('ἀμην', 99),
#  ('ὀφθαλμός', 99),
#  ('ἕτερος', 99),
#  ('ὄνομα', 99),
#  ('κυριάζω', 98),
#  ('ἴδιος', 98),
#  ('πέτρος', 98),
#  ('τέκνον', 97),
#  ('παραδίδωμι', 97),
#  ('ἀγαθός', 95),
#  ('αἷμα', 95),
#  ('οἰκία', 93),
#  ('σώζω', 91),
#  ('ὀνομάζω', 90),
#  ('χριστῷ', 90),
#  ('δικαιοσύνη', 89),
#  ('θάλασσα', 89),
#  ('εἰρήνη', 89),
#  ('πούς', 88),
#  ('ἐνώπιος', 87),
#  ('δίκαιος', 86),
#  ('χόω', 86),
#  ('καῖρος', 84),
#  ('ζητέω', 83),
#  ('οἶκος', 83),
#  ('ἀνίστημι', 83),
#  ('μήτηρ', 82),
#  ('φοβέω', 82),
#  ('παρακαλέω', 82),
#  ('ἔξεστι', 82),
#  ('εἷς', 82),
#  ('μηδείς', 82),
#  ('ἐφ', 81),
#  ('ἕκαστος', 81),
#  ('μαλλός', 80),
#  ('τίνω', 80),
#  ('ἵστημι', 79),
#  ('ἄρχω', 79),
#  ('κοσμέω', 78),
#  ('ἔλεγος', 78),
#  ('τόπος', 78),
#  ('ἀπέρχομαι', 77),
#  ('πονηρός', 77),
#  ('κύριε', 77),
#  ('γεννάω', 76),
#  ('ἕνος', 76),
#  ('σημεῖον', 76),
#  ('κεφαλή', 75),
#  ('ἄρτος', 75),
#  ('ἀπόλλυμι', 74),
#  ('δωδεκάς', 74),
#  ('εὐαγγέλιον', 73),
#  ('πρόσωπον', 73),
#  ('μαρτυρέω', 73),
#  ('Πάν', 72),
#  ('φάος', 72),
#  ('αἴρω', 72),
#  ('ἀβραάμ', 71),
#  ('ἄγαμαι', 71),
#  ('ἀφίημι', 71),
#  ('κυρίου', 70),
#  ('ἐγείρω', 70),
#  ('θανατάω', 70),
#  ('βλέπω', 70),
#  ('περιπατέω', 70),
#  ('αἰώνιος', 70),
#  ('πληρόω', 69),
#  ('στόμα', 69),
#  ('πλοῖον', 68),
#  ('ἀποκτείνω', 68),
#  ('αὐτην', 67),
#  ('κᾶλον', 67),
#  ('κυρέω', 67),
#  ('ἐκβάλλω', 67),
#  ('καρπός', 66),
#  ('παῦλος', 66),
#  ('μέλλω', 65),
#  ('ὕδωρ', 65),
#  ('ἀναβαίνω', 65),
#  ('ὁλάω', 65),
#  ('μένω', 65),
#  ('πιστός', 65),
#  ('ἰουδαίων', 64),
#  ('ὁδός', 64),
#  ('φημί', 64),
#  ('ἀκολουθέω', 64),
#  ('τίθημι', 64),
#  ('ἁμάρτημα', 63),
#  ('γραμματεύς', 63),
#  ('πορεύω', 63),
#  ('ὀχλέω', 63),
#  ('ῥῆμα', 62),
#  ('πρέσβυς', 62),
#  ('νύξ', 61),
#  ('ἦδος', 61),
#  ('Πάρος', 60),
#  ('ποτός', 60),
#  ('αἰτέω', 60),
#  ('δαυείδ', 59),
#  ('χαρά', 59),
#  ('βαπτίζω', 59),
#  ('διδάσκω', 59),
#  ('πάομαι', 59),
#  ('ὑπάγω', 58),
#  ('μέσος', 58),
#  ('ἀπόστολος', 58),
#  ('ἀνοίγνυμι', 57),
#  ('κρίνω', 57),
#  ('τιμάω', 57),
#  ('ἰδού', 56),
#  ('δείκνυμι', 56),
#  ('Μῆδος', 56),
#  ('ἰουδαῖοι', 56),
#  ('χαίρω', 55),
#  ('πλείων', 55),
#  ('ἱμάτιον', 55),
#  ('προσεύχομαι', 55),
#  ('πόα', 55),
#  ('θέλημα', 55),
#  ('τηρέω', 55),
#  ('χρόνος', 54),
#  ('ἐρωτάω', 54),
#  ('τρίτος', 54),
#  ('πέμπω', 53),
#  ('εὐθύς', 53),
#  ('κακός', 53),
#  ('ἱερός', 53),
#  ('λοιπός', 53),
#  ('ἀέκων', 52),
#  ('ἐπαγγελία', 52),
#  ('ἐλπίς', 52),
#  ('προσκυνέω', 51),
#  ('δαιμόνιον', 51),
#  ('θάνατος', 51),
#  ('ὅμοιος', 51),
#  ('Ἴδη', 50),
#  ('φαρισαῖοι', 50),
#  ('πίνω', 50),
#  ('λαβή', 50),
#  ('φυλάζω', 50),
#  ('θρόνον', 50),
#  ('γλῶσσα', 50),
#  ('ἰωάνης', 49),
#  ('φέρω', 49),
#  ('ἀρχή', 49),
#  ('τυφλός', 49),
#  ('σοφία', 49),
#  ('ἐπερωτάω', 49),
#  ('παραβολή', 49),
#  ('ἀπολύω', 48),
#  ('καταβαίνω', 48),
#  ('δοξάζω', 48),
#  ('φυλακή', 48),
#  ('δεξιά', 48),
#  ('χρεία', 47),
#  ('κρίσις', 47),
#  ('σωτηρία', 46),
#  ('ὅλοξ', 45),
#  ('ναός', 45),
#  ('ἐπιγιγνώσκω', 44),
#  ('ἔπειμι', 44),
#  ('ἔτης', 44),
#  ('μέθη', 44),
#  ('πλανάω', 44),
#  ('σαρκάζω', 44),
#  ('γενεά', 43),
#  ('πῦρ', 43),
#  ('κηρύσσω', 43),
#  ('μωυσῆς', 43),
#  ('ἄγω', 43),
#  ('μικρός', 43),
#  ('δεύτερος', 43),
#  ('ἀφ', 43),
#  ('τότε', 42),
#  ('μέρος', 42),
#  ('ὄρος', 42),
#  ('ὀλίγος', 42),
#  ('θαυμάζω', 42),
#  ('τρέω', 42),
#  ('ἀνάστασις', 42),
#  ('χριστόν', 42),
#  ('ἀγαπητός', 41),
#  ('καλός', 41),
#  ('ἀγείρω', 41),
#  ('σπέρμα', 41),
#  ('φανερόω', 41),
#  ('ἐντολή', 40),
#  ('ἀποδίδωμι', 40),
#  ('τέσσαρες', 40),
#  ('ἀνηρ', 39),
#  ('σπειράομαι', 39),
#  ('μνημεῖον', 39),
#  ('ἰωάνου', 39),
#  ('τέλος', 39),
#  ('καθίζω', 39),
#  ('ἰερουσαλημ', 39),
#  ('πειλᾶτος', 39),
#  ('ἐρῶ', 38),
#  ('ἰεροσόλυμα', 38),
#  ('ἰσραήλ', 38),
#  ('προσφέρω', 38),
#  ('ἱκανός', 38),
#  ('θύρα', 38),
#  ('ἐσχατάω', 38),
#  ('γαλιλαίας', 37),
#  ('θεραπεύω', 37),
#  ('προσευχή', 37),
#  ('ἀπαγγέλλω', 37),
#  ('ἰερουσαλήμ', 37),
#  ('ἐπιθυμιάω', 37),
#  ('φόβος', 37),
#  ('μαρτυρία', 37),
#  ('μένος', 37),
#  ('ἰωάνην', 36),
#  ('διάβολος', 36),
#  ('λίθος', 36),
#  ('ἐρέω', 36),
#  ('κρατέω', 36),
#  ('σίμων', 36),
#  ('γραφεύς', 36),
#  ('περιτομή', 36),
#  ('παιδίον', 35),
#  ('ὁδάω', 35),
#  ('ἄξιος', 35),
#  ('διώκω', 35),
#  ('οἰκοδομέω', 35),
#  ('δέω', 35),
#  ('ἀγοράζω', 35),
#  ('θεωρέω', 35),
#  ('διακονέω', 34),
#  ('ἅπτω', 34),
#  ('ἁμαρτωλός', 34),
#  ('ἐπιστρέφω', 34),
#  ('ἀδελφή', 34),
#  ('λυπέω', 34),
#  ('ἁμαρτάνω', 34),
#  ('βιβλίον', 34),
#  ('εἰκών', 34),
#  ('χρύσεος', 34),
#  ('διακονία', 34),
#  ('λογίζομαι', 34),
#  ('πτωχός', 33),
#  ('περισσεύω', 33),
#  ('οἶνος', 33),
#  ('πολέω', 33),
#  ('ὀφείλω', 33),
#  ('διαθήκη', 33),
#  ('χιλιάς', 33),
#  ('ταῦτα', 32),
#  ('μέλος', 32),
#  ('ἅπας', 32),
#  ('ἐργάζομαι', 32),
#  ('σταυρόω', 32),
#  ('ἀσθενέω', 32),
#  ('ἐγένετο', 32),
#  ('καυχάομαι', 32),
#  ('παραλαμβάνω', 31),
#  ('ἀγγέλλω', 31),
#  ('κρίνον', 31),
#  ('ἄνεμος', 31),
#  ('ἐπιέννυμι', 31),
#  ('δικαιόω', 31),
#  ('πλέω', 31),
#  ('πάσχω', 31),
#  ('πλούσιος', 31),
#  ('φεύγω', 30),
#  ('ἐχθρός', 30),
#  ('ἀσπάζομαι', 30),
#  ('σκότος', 30),
#  ('ἀκοή', 30),
#  ('ἰσραηλ', 30),
#  ('καινός', 30),
#  ('ἀκάθαρτος', 30),
#  ('ἀποκαλύπτω', 30),
#  ('οὖς', 30),
#  ('ποτήριον', 30),
#  ('μετανοέω', 30),
#  ('Σάββατον', 30),
#  ('συνάγω', 30),
#  ('παρίστημι', 30),
#  ('πείθω', 30),
#  ('πλῆθος', 30),
#  ('ἀρνίον', 30),
#  ('παῦλον', 30),
#  ('παύλου', 30),
#  ('ἐφορεύω', 29),
#  ('φαρισαίων', 29),
#  ('μισθός', 29),
#  ('σκανδαλίζω', 29),
#  ('διδάσκαλε', 29),
#  ('ἐπιτιμάω', 29),
#  ('ἐκραίνω', 29),
#  ('διδάσκαλος', 29),
#  ('περισσός', 29),
#  ('ἑτοιμάζω', 29),
#  ('πράσσω', 29),
#  ('συνείδησις', 29),
#  ('λᾶας', 28),
#  ('συναγωγή', 28),
#  ('τελέω', 28),
#  ('ὥρα', 28),
#  ('μάχαιρα', 28),
#  ('σταυρός', 28),
#  ('μυστήριον', 28),
#  ('συναγωγεύς', 28),
#  ('δυνατός', 28),
#  ('δεκάζω', 28),
#  ('πνευματικός', 28),
#  ('ἰακώβ', 27),
#  ('φαίνω', 27),
#  ('ἰουδαίας', 27),
#  ('χώρα', 27),
#  ('προσέρχομαι', 27),
#  ('πυρός', 27),
#  ('γαμέω', 27),
#  ('μισέω', 27),
#  ('φιλέω', 27),
#  ('ὄντα', 27),
#  ('κρῖμα', 27),
#  ('καθαρίζω', 27),
#  ('θυγάτηρ', 27),
#  ('ἄρχων', 27),
#  ('ὑπάρχω', 27),
#  ('παράκλησις', 27),
#  ('νικάω', 27),
#  ('ἀληθινός', 27),
#  ('ἰωσηφ', 26),
#  ('κατοικέω', 26),
#  ('ἰσχύω', 26),
#  ('στρατιώτης', 26),
#  ('βλασφημέω', 26),
#  ('παραγγέλλω', 26),
#  ('ἀγρός', 26),
#  ('μαριάμ', 26),
#  ('εὐλογέω', 26),
#  ('εὐχαριστέω', 26),
#  ('κλαίω', 26),
#  ('ἰουδαίοις', 26),
#  ('θηρίον', 26),
#  ('ἁγίζω', 26),
#  ('ἡρῴδης', 25),
#  ('ὑπ', 25),
#  ('δένδρον', 25),
#  ('πέτρον', 25),
#  ('πορνεία', 25),
#  ('ὄμνυμι', 25),
#  ('πρόβατον', 25),
#  ('ἀναγιγνώσκω', 25),
#  ('ἱερεύς', 25),
#  ('ἐλπίζω', 25),
#  ('ἰσχυρός', 25),
#  ('λύω', 25),
#  ('νεφέλη', 25),
#  ('εἶπεν', 25),
#  ('χήρα', 25),
#  ('ὑποστρέφω', 25),
#  ('ὑποτάσσω', 25),
#  ('ἀδικία', 25),
#  ('παῖς', 24),
#  ('ἐρημάζω', 24),
#  ('πειράζω', 24),
#  ('πέρα', 24),
#  ('κληρονομέω', 24),
#  ('παρέρχομαι', 24),
#  ('πιέζω', 24),
#  ('ἀσθένεια', 24),
#  ('εἰδοί', 24),
#  ('θυσιάζω', 24),
#  ('εὐαγγελίζομαι', 24),
#  ('διέρχομαι', 24),
#  ('παρουσία', 24),
#  ('δίδημι', 24),
#  ('βούλομαι', 23),
#  ('τοῦτο', 23),
#  ('Αἴγυπτος', 23),
#  ('ἀναιρέω', 23),
#  ('τρέφω', 23),
#  ('ὄνομά', 23),
#  ('ὁμολογέω', 23),
#  ('ἰάομαι', 23),
#  ('πίπτω', 23),
#  ('ἀρνέομαι', 23),
#  ('φίλος', 23),
#  ('φρονέω', 23),
#  ('πίμπλημι', 23),
#  ('μωυσέως', 23),
#  ('δεσμεύω', 23),
#  ('ἐλεός', 23),
#  ('σωτήρ', 23),
#  ('γνωρίζω', 23),
#  ('ἄνδρες', 23),
#  ('ἱεράομαι', 22),
#  ('θυσιαστήριον', 22),
#  ('βλέπος', 22),
#  ('ἦλθαν', 22),
#  ('ἥκω', 22),
#  ('ἀποστολή', 22),
#  ('κοιλία', 22),
#  ('κοινός', 22),
#  ('ἀμπελών', 22),
#  ('ἑνί', 22),
#  ('ἀδικέω', 22),
#  ('ἐκλεκτός', 22),
#  ('ὑπομονή', 22),
#  ('πληγή', 22),
#  ('δοκιμάζω', 22),
#  ('καταργέω', 22),
#  ('μάρτυς', 22),
#  ('ἰούδας', 21),
#  ('ἀστήρ', 21),
#  ('βασιλεύω', 21),
#  ('μετάνοια', 21),
#  ('ἐρῆμος', 21),
#  ('ὑμεῖς', 21),
#  ('μιμνήσκω', 21),
#  ('πειρασμός', 21),
#  ('ποσός', 21),
#  ('κελεύω', 21),
#  ('ὑπακούω', 21),
#  ('ἐκχέω', 21),
#  ('φανερός', 21),
#  ('διδασκαλία', 21),
#  ('σκηνάω', 21),
#  ('ὀρεύς', 21),
#  ('ὀνόματί', 21),
#  ('διάκονος', 21),
#  ('καθαρός', 21),
#  ('ἐλεύθερος', 21),
#  ('βάπτισμα', 20),
#  ('χειρίς', 20),
#  ('εὐδοκέω', 20),
#  ('συνέδριον', 20),
#  ('παράπτωμα', 20),
#  ('δουλεύω', 20),
#  ('αὐξάνω', 20),
#  ('ἀφήκω', 20),
#  ('δωρεά', 20),
#  ('γονεύς', 20),
#  ('ἀναβλέπω', 20),
#  ('σοφός', 20),
#  ('γένος', 20),
#  ('αἰτία', 20),
#  ('κωλύω', 20),
#  ('ἐάω', 20),
#  ('ξύλον', 20),
#  ('ἀκροβυστία', 20),
#  ('διό', 20),
#  ('ἀμάω', 20),
#  ('ἰσαάκ', 19),
#  ('ἐπανίημι', 19),
#  ('βαστάζω', 19),
#  ('ἀρτάω', 19),
#  ('χειρόω', 19),
#  ('κριτής', 19),
#  ('ναῦς', 19),
#  ('τέλειος', 19),
#  ('μανθάνω', 19),
#  ('παλαιός', 19),
#  ('ἐπιτίθημι', 19),
#  ('ναί', 19),
#  ('κατηγορέω', 19),
#  ('προφητεία', 19),
#  ('πῶς', 19),
#  ('ἀργύριον', 19),
#  ('παρρησιάζομαι', 19),
#  ('κενός', 19),
#  ('μαίνομαι', 19),
#  ('ἐπουράνιος', 19),
#  ('κοινωνία', 19),
#  ('θηράω', 19),
#  ('ἡγεμών', 18),
#  ('ἥλιος', 18),
#  ('κρυπτός', 18),
#  ('ἀπώλεια', 18),
#  ('τοσοῦτος', 18),
#  ('οὐαί', 18),
#  ('βλασφημία', 18),
#  ('κάθημαι', 18),
#  ('ἐντολην', 18),
#  ('μαρία', 18),
#  ('ἐκλέγω', 18),
#  ('πλοῦτος', 18),
#  ('τελειόω', 18),
#  ('ζῆλος', 18),
#  ('πίστει', 18),
#  ('συνέρχομαι', 17),
#  ('θησαυρός', 17),
#  ('ἐκπορεύω', 17),
#  ('ποταμός', 17),
#  ('ὀργάζω', 17),
#  ('ῥίζα', 17),
#  ('οὗτός', 17),
#  ('γαλιλαίαν', 17),
#  ('σκοτία', 17),
#  ('χορτάζω', 17),
#  ('ἐλεέω', 17),
#  ('πλησίος', 17),
#  ('κλέπτης', 17),
#  ('πλήρωμα', 17),
#  ('σατανᾶς', 17),
#  ('κατακρίνω', 17),
#  ('μνημονεύω', 17),
#  ('μακάριος', 17),
#  ('κερδαίνω', 17),
#  ('πόλεμος', 17),
#  ('γρηγορέω', 17),
#  ('ἄφεσις', 17),
#  ('στέφανος', 17),
#  ('τοῦτ', 17),
#  ('ἐπαυρέω', 17),
#  ('λιθάζω', 17),
#  ('νέω', 17),
#  ('ἀλάομαι', 17),
#  ('ἰουδαίους', 17),
#  ('χιλίαρχος', 17),
#  ('Ἀσία', 17),
#  ('παρρησία', 17),
#  ('παύλῳ', 17),
#  ('χάρισμα', 17),
#  ('κρείσσων', 17),
#  ('ἵππος', 17),
#  ('ἕξις', 16),
#  ('παραγίγνομαι', 16),
#  ('ποῦ', 16),
#  ('ἀνάγω', 16),
#  ('καφαρναούμ', 16),
#  ('ἰάκωβον', 16),
#  ('μακαρίζω', 16),
#  ('ὑποκριτής', 16),
#  ('ἀπέχω', 16),
#  ('θερίζω', 16),
#  ('προστίθημι', 16),
#  ('νυμφίος', 16),
#  ('ἐπικαλέω', 16),
#  ('ἠλείας', 16),
#  ('ἐξίστημι', 16),
#  ('πλήρης', 16),
#  ('ἐναντίος', 16),
#  ('δηνάριον', 16),
#  ('γραφή', 16),
#  ('τέρας', 16),
#  ('σίμωνος', 16),
#  ('ὑπηρέτης', 16),
#  ('πυλών', 16),
#  ('δέησις', 16),
#  ('θύμον', 16),
#  ('λάλος', 16),
#  ('θεμέλιος', 16),
#  ('χαρίζομαι', 16),
#  ('ἀριθμός', 16),
#  ('καταγγέλλω', 16),
#  ('ἡγέομαι', 16),
#  ('σφραγίς', 16),
#  ('κατεργάζομαι', 16),
#  ('πάθημα', 16),
#  ('εὐλογία', 16),
#  ('τίκτω', 15),
#  ('παρθένος', 15),
#  ('δῶρον', 15),
#  ('θρίξ', 15),
#  ('νηστεύω', 15),
#  ('λατρεύω', 15),
#  ('κρύπτω', 15),
#  ('ἔσχατος', 15),
#  ('ἐπιθυμέω', 15),
#  ('τελώνης', 15),
#  ('ἐνδύω', 15),
#  ('κοπιάω', 15),
#  ('ἀνομία', 15),
#  ('φρόνιμος', 15),
#  ('πέτρα', 15),
#  ('ἑκατοντάρχης', 15),
#  ('ἦν', 15),
#  ('ἐπιβάλλω', 15),
#  ('προσέχω', 15),
#  ('ὁμοιάζω', 15),
#  ('ἕκατος', 15),
#  ('σκάνδαλον', 15),
#  ('ἀρέσκω', 15),
#  ('παιδιή', 15),
#  ('κράζω', 15),
#  ('τράπεζα', 15),
#  ('πέτρῳ', 15),
#  ('ἄπιστος', 15),
#  ('ῥαββεί', 15),
#  ('ὑψόω', 15),
#  ('οἰκουμένη', 15),
#  ('τοπάζω', 15),
#  ('καθίστημι', 15),
#  ('ἴδε', 15),
#  ('ἀγνοέω', 15),
#  ('κτίσις', 15),
#  ('ἀπιστέω', 15),
#  ('ὑπαρχή', 15),
#  ('εἶπέν', 15),
#  ('γνῶσις', 15),
#  ('ἐπιμένω', 15),
#  ('τύπος', 15),
#  ('εὐσέβεια', 15),
#  ('εὐχαριστία', 15),
#  ('ἤγγικεν', 14),
#  ('πεινάω', 14),
#  ('καθίημι', 14),
#  ('σίμωνα', 14),
#  ('λύχνος', 14),
#  ('καταλύω', 14),
#  ('συμφέρω', 14),
#  ('σῶμά', 14),
#  ('κριθάω', 14),
#  ('πετεινός', 14),
#  ('χόρτος', 14),
#  ('κατανοέω', 14),
#  ('ὄφις', 14),
#  ('ἄκανθα', 14),
#  ('ἐκτείνω', 14),
#  ('σεισμός', 14),
#  ('μακρός', 14),
#  ('ἀμφότερος', 14),
#  ('στράπτω', 14),
#  ('κωφός', 14),
#  ('κωμάζω', 14),
#  ('φίλιππος', 14),
#  ('ἀνίημι', 14),
#  ('δέχομαι', 14),
#  ('χωλός', 14),
#  ('κραυγάζω', 14),
#  ('σπείρω', 14),
#  ('ἰχθυάω', 14),
#  ('ἀναγκάζω', 14),
#  ('ὠφελέω', 14),
#  ('διαλογισμός', 14),
#  ('ἐκλανθάνω', 14),
#  ('διαλογίζομαι', 14),
#  ('εἴ', 14),
#  ('ἀλλότριος', 14),
#  ('ἕκτος', 14),
#  ('κληρονομία', 14),
#  ('οἷος', 14),
#  ('γυμνός', 14),
#  ('και', 14),
#  ('μύρον', 14),
#  ('κόπος', 14),
#  ('θλίβω', 14),
#  ('ἐξαποστέλλω', 14),
#  ('ἐπαίρω', 14),
#  ('ἰδιόομαι', 14),
#  ('γράμμα', 14),
#  ('ἰεροσολύμοις', 14),
#  ('ἀσθενής', 14),
#  ('Ἕλλην', 14),
#  ('ἡρῴδου', 13),
#  ('ταράσσω', 13),
#  ('ἰούδα', 13),
#  ('ἐλάχιστος', 13),
#  ('κεῖμαι', 13),
#  ('ἐντέλλω', 13),
#  ('πέσος', 13),
#  ('σατανᾶ', 13),
#  ('προβαίνω', 13),
#  ('ταχύς', 13),
#  ('μοιχεύω', 13),
#  ('ἀνθίστημι', 13),
#  ('ἄδικος', 13),
#  ('ἐλεημοσύνη', 13),
#  ('πάτερ', 13),
#  ('μέριμνα', 13),
#  ('διδαχῇ', 13),
#  ('ὑπαντάω', 13),
#  ('θερισμός', 13),
#  ('κώμη', 13),
#  ('ὑπομένω', 13),
#  ('οἰκοδεσποτέω', 13),
#  ('μέλλησις', 13),
#  ('καθάπτω', 13),
#  ('νήπιος', 13),
#  ('σάββασιν', 13),
#  ('σαββάτου', 13),
#  ('πνεῦμά', 13),
#  ('σύνειμι', 13),
#  ('πλουτέω', 13),
#  ('παρατίθημι', 13),
#  ('ζύμη', 13),
#  ('χωρέω', 13),
#  ('ταπεινόω', 13),
#  ('μάρτυρος', 13),
#  ('ὑστερέω', 13),
#  ('γάμος', 13),
#  ('τρόπος', 13),
#  ('ἑτοῖμος', 13),
#  ('παιδίσκη', 13),
#  ('ἰακώβου', 13),
#  ('σπουδάζω', 13),
#  ('ἀθετέω', 13),
#  ('σκεῦος', 13),
#  ('περιτέμνω', 13),
#  ('ἐφίστημι', 13),
#  ('γνωστός', 13),
#  ('ἐνιαυτός', 13),
#  ('κατέχω', 13),
#  ('καταισχύνω', 13),
#  ('ὅτε', 13),
#  ('παυλος', 13),
#  ('δράκων', 13),
#  ('σφοδρός', 12),
#  ('βαπτιστής', 12),
#  ('δίκτυον', 12),
#  ('νομίζω', 12),
#  ('κέρας', 12),
#  ('φονεύω', 12),
#  ('γέεννα', 12),
#  ('θρόνος', 12),
#  ('ὀδούς', 12),
#  ('σαλπίζω', 12),
#  ('ὁμοιόω', 12),
#  ('σής', 12),
#  ('μεριμνάω', 12),
#  ('μέτρον', 12),
#  ('μετρέω', 12),
#  ('χοῖρος', 12),
#  ('ἐκπλήσσω', 12),
#  ('πέτρου', 12),
#  ('θάπτω', 12),
#  ('καθεύδω', 12),
#  ('ἐμβαίνω', 12),
#  ('ἁμαρτωλή', 12),
#  ('ἐργάτης', 12),
#  ('οἰκέω', 12),
#  ('ῥάβδος', 12),
#  ('κάλαμος', 12),
#  ('ἁρπάζω', 12),
#  ('πίνος', 12),
#  ('πρόθεσις', 12),
#  ('μερίζω', 12),
#  ('ἡλιόομαι', 12),
#  ('ξηραίνω', 12),
#  ('ἄναξ', 12),
#  ('ἐνεργέω', 12),
#  ('βρῶμα', 12),
#  ('παράδοσις', 12),
#  ('νοέω', 12),
#  ('ὅραμα', 12),
#  ('δαιμονάω', 12),
#  ('ἀνάγκη', 12),
#  ('ἐπιθέω', 12),
#  ('πῶλος', 12),
#  ('ληιστής', 12),
#  ('γεωργέω', 12),
#  ('διάνοια', 12),
#  ('κοινωνέω', 12),
#  ('λιμός', 12),
#  ('ξένος', 12),
#  ('ἑορτάζω', 12),
#  ('παρέχω', 12),
#  ('πάρειμι', 12),
#  ('βῆμα', 12),
#  ('βοάω', 12),
#  ('τρέχω', 12),
#  ('κύριός', 12),
#  ('καταλαμβάνω', 12),
#  ('τολμάω', 12),
#  ('ἐπίσταμαι', 12),
#  ('ἔθος', 12),
#  ('ἀπειθέω', 12),
#  ('βουλή', 12),
#  ('στηρίζω', 12),
#  ('κάκη', 12),
#  ('ζῇν', 12),
#  ('τίμιος', 12),
#  ('κλῆσις', 12),
#  ('ὑδατόω', 12),
#  ('φιάλη', 12),
#  ('ἀναχωρέω', 11),
#  ('ἐμπαίζω', 11),
#  ('ἰορδάνου', 11),
#  ('λιθάω', 11),
#  ('κατακαίω', 11),
#  ('ὕστερος', 11),
#  ('ὑψηλός', 11),
#  ('ζεβεδαίου', 11),
#  ('ἰεροσολύμων', 11),
#  ('ἀρχαῖος', 11),
#  ('ῥύομαι', 11),
#  ('νίζω', 11),
#  ('κλέπτω', 11),
#  ('ἐπιζητέω', 11),
#  ('κακία', 11),
#  ('μωρός', 11),
#  ('κλίνη', 11),
#  ('οἶκόν', 11),
#  ('ποτίζω', 11),
#  ('προσδοκάω', 11),
#  ('γυναικωνῖτις', 11),
#  ('ἔσθος', 11),
#  ('ταπεινός', 11),
#  ('κατεσθίω', 11),
#  ('εἶδαν', 11),
#  ('κλάδος', 11),
#  ('καταβολή', 11),
#  ('ἀπιστία', 11),
#  ('συνίημι', 11),
#  ('διακρίνω', 11),
#  ('ἀπαρνέομαι', 11),
#  ('ἀνέχω', 11),
#  ('πρᾶγμα', 11),
#  ('τάλαντον', 11),
#  ('χωρίζω', 11),
#  ('ἐλαιῶν', 11),
#  ('πόρνη', 11),
#  ('καίσαρος', 11),
#  ('δειπνέω', 11),
#  ('βλέπετε', 11),
#  ('πληθύνω', 11),
#  ('σάλπιγξ', 11),
#  ('ἔλαιον', 11),
#  ('δόλος', 11),
#  ('ἀλέκτωρ', 11),
#  ('ἔθω', 11),
#  ('κλῆρος', 11),
#  ('σαββάτων', 11),
#  ('ἐπιτάσσω', 11),
#  ('πηγάζω', 11),
#  ('μενετός', 11),
#  ('ἐπαισχύνομαι', 11),
#  ('αὐτη', 11),
#  ('στήκω', 11),
#  ('θύω', 11),
#  ('ἡμεῖς', 11),
#  ('γόνυ', 11),
#  ('σπλάγχνον', 11),
#  ('εἰσάγω', 11),
#  ('ἀποκάλυψις', 11),
#  ('ἔλεγεν', 11),
#  ('λίμνη', 11),
#  ('ἐμην', 11),
#  ('φωνή', 11),
#  ('ἐμη', 11),
#  ('ζωοποιέω', 11),
#  ('βροντάω', 11),
#  ('ἀντιόχειαν', 11),
#  ('μακεδονίαν', 11),
#  ('ζηλόω', 11),
#  ('ἔπαινος', 11),
#  ('ἐλευθερία', 11),
#  ('ἀνατολή', 10),
#  ('τελευτάω', 10),
#  ('ἐκκόπτω', 10),
#  ('ὑπόδημα', 10),
#  ('περιστερά', 10),
#  ('κύριον', 10),
#  ('ὕπαγε', 10),
#  ('ποικίλλω', 10),
#  ('παραλυτικός', 10),
#  ('ἀγαλλιάω', 10),
#  ('ὅρκος', 10),
#  ('κλείω', 10),
#  ('δύσις', 10),
#  ('ἐμβλέπω', 10),
#  ('διαφέρω', 10),
#  ('μεταβαίνω', 10),
#  ('ὅριον', 10),
#  ('ἰάκωβος', 10),
#  ('χιτών', 10),
#  ('ἀναπαύω', 10),
#  ('βάθος', 10),
#  ('διωγμός', 10),
#  ('ἀπατάω', 10),
#  ('ἠσαίας', 10),
#  ('φονάω', 10),
#  ('γεύω', 10),
#  ('ἀναφέρω', 10),
#  ('ἐπιτρέπω', 10),
#  ('ἔνατος', 10),
#  ('συκῆ', 10),
#  ('ἐπιμελέομαι', 10),
#  ('ἄγνυμι', 10),
#  ('κλητός', 10),
#  ('ἐντολη', 10),
#  ('ἀσπασμός', 10),
#  ('ἀκαθαρσία', 10),
#  ('θλίψιν', 10),
#  ('ἰουδαίᾳ', 10),
#  ('Καινόν', 10),
#  ('ἀφαιρέω', 10),
#  ('ἀπάγω', 10),
#  ('σχίζω', 10),
#  ('ἅλυσις', 10),
#  ('πλεονεξία', 10),
#  ('ἀσέλγεια', 10),
#  ('ἰσχύς', 10),
#  ('κράς', 10),
#  ('οὐχί', 10),
#  ('ἐπιφαίνω', 10),
#  ('ὑμέτερος', 10),
#  ('δάκρυον', 10),
#  ('μάρθα', 10),
#  ('νέος', 10),
#  ('λαμπρός', 10),
#  ('ἐκδικέω', 10),
#  ...]

# %%
# Out:
# [{'i': '432951',
#   'f': 'ἰησοῦς',
#   'b': 'ιησους',
#   'l': 'Ἰησοῦς',
#   'e': 'ιησους',
#   'p': 'n-p---ma-',
#   'd': '15766',
#   's': 'Joshua',
#   'a': 'attic'},
#  {'i': '432956',
#   'f': 'ἰησοῦς',
#   'b': 'ιησους',
#   'l': 'Ἰησοῦς',
#   'e': 'ιησους',
#   'p': 'n-s---mn-',
#   'd': '15766',
#   's': 'Joshua',
#   'a': 'attic epic'}]

# %%
"ἰησοῦ" : "ἰησοῦς",
"ἰησοῦν" : "ἰησοῦς",
"χριστοῦ" : "χριστός",
"χριστῷ" : "χριστός",
"κύριε" : "κύριος",
"κυρίου" : "κύριος",
"ἀβρααμ" : "ἀβραάμ"

# %%
[(tup[0], lemma_translator(tup[0]), tup[1]) for tup in NT_freqdist[:500]]
# Out:
# [('πᾶς', 'all, the whole', 1086),
#  ('ἁμός', 'as, when / our, ours', 1078),
#  ('εἶπον', 'to speak, say', 828),
#  ('λέγω',
#   'to gather, pick up / to say, speak / to lay asleep, lull to sleep',
#   786),
#  ('θεάομαι', 'to look on, gaze at, view, behold', 701),
#  ('θεός', 'God', 620),
#  ('ἡμός', '', 564),
#  ('ἄνθρωπος', 'manfaced', 522),
#  ('ποιέω', 'to make', 487),
#  ('γίγνομαι', 'gi-geno', 482),
#  ('σεύω', 'to put in quick motion: to drive, hunt, chase away', 476),
#  ('ἔχω', 'to have', 465),
#  ('ἰησοῦς', '', 454),
#  ('ἔρχομαι', 'to come', 421),
#  ('πατήρ', 'a father', 397),
#  ('εἶμι', 'to go', 388),
#  ('ἡμέρα', 'day', 380),
#  ('υἱός', 'A son', 371),
#  ('κύριος', 'having power / a lord, master', 371),
#  ('εἶδον', 'to see', 367),
#  ('πνεῦμα', 'a blowing', 357),
#  ('πολύς', 'many', 341),
#  ('λόγος', 'the word', 329),
#  ('ἰησοῦ', '', 325),
#  ('δίδωμι', 'to give', 312),
#  ('ἀδελφός', 'sons of the same mother', 311),
#  ('οὐρανός', 'heaven', 273),
#  ('μαθητής', 'a learner, pupil', 262),
#  ('ἐκεῖνος', 'the person there, that person', 253),
#  ('οἶδα', 'to know', 249),
#  ('ἀκούω', 'to hear', 247),
#  ('γῆ', 'earth', 246),
#  ('μέγας', 'big, great', 239),
#  ('λαλέω', 'to talk, chat, prattle, babble', 231),
#  ('πίστις', 'trust', 226),
#  ('ἐμέω', 'to vomit, throw up', 219),
#  ('δοκέω', 'videor mihi, to think, suppose, imagine, expect', 217),
#  ('χριστός', 'to be rubbed on', 214),
#  ('ἀλλ', '', 214),
#  ('ἅγιος', 'devoted to the gods, sacred, holy', 203),
#  ('ἵημι', 'to set a going, put in motion', 202),
#  ('νόμος', 'anything assigned, a usage, custom, law, ordinance', 194),
#  ('γυνή', 'a woman', 192),
#  ('γιγνώσκω', 'to learn to know, to perceive, mark, learn', 190),
#  ('χριστοῦ', '', 182),
#  ('δύναμαι', 'to be able, capable, strong enough', 176),
#  ('πιστεύω', 'to trust, trust to', 174),
#  ('ἐθέλω', 'to will, wish, purpose', 170),
#  ('φωνέω', 'to produce a sound', 165),
#  ('βασίλεια', 'a queen, princess', 162),
#  ('ἔθνος',
#   'a number of people accustomed to live together, a company, body of men',
#   162),
#  ('ἔργον', 'work', 162),
#  ('πρότερος', 'prae.', 161),
#  ('χάρις', 'Grace', 158),
#  ('ὁράω', 'To see', 157),
#  ('καρδία', 'the heart', 156),
#  ('ζωή', 'a living', 151),
#  ('ἀνήρ', 'a man', 146),
#  ('ἄατος', 'insatiate', 146),
#  ('ἐπ', '', 145),
#  ('λαμβάνω', 'to take', 144),
#  ('ἑός', 'his, her own', 143),
#  ('εὑρίσκω', 'to find', 142),
#  ('προφήτης', 'one who speaks for a God and interprets his will', 142),
#  ('γράφω', 'to scratch, scrape, graze', 140),
#  ('ἄγγελος', 'a messenger, envoy', 139),
#  ('εἰσέρχομαι', 'to go in', 136),
#  ('χείρ', 'the hand', 135),
#  ('ἐσθίω', 'to eat', 135),
#  ('ἔμετος', 'vomiting', 132),
#  ('ἀγαπάω', 'to treat with affection, to caress, love, be fond of', 131),
#  ('νεκρός', 'a dead body, corpse', 130),
#  ('πόλις', 'a city', 128),
#  ('ἐξέρχομαι', 'to go', 127),
#  ('ἰησοῦν', '', 125),
#  ('ἀπ', '', 124),
#  ('δοῦλος', 'a born bondman', 124),
#  ('ἀποκρίνω', 'to separate, set apart', 124),
#  ('ἀρχιερεύς', 'an arch-priest, chief-priest', 123),
#  ('σῶμα', 'the body', 122),
#  ('αἰών', 'aevum', 120),
#  ('λαός', 'the people', 116),
#  ('δύναμις', 'power, might, strength', 116),
#  ('κόσμος', 'order', 114),
#  ('ἁμαρτία', 'a failure, fault, sin', 112),
#  ('ὄχλος', 'a moving crowd, a throng, mob', 111),
#  ('βασιλεύς', 'a king, chief', 109),
#  ('μόνος', 'alone, left alone, forsaken solitary', 109),
#  ('ἐκκλησιάζω', 'to hold an assembly, debate therein', 107),
#  ('ἀλήθεια', 'truth', 107),
#  ('ἀποστέλλω', 'to send off', 105),
#  ('βάλλω', 'to throw', 104),
#  ('ἀγαπάζω', 'to treat with affection, shew affection to', 104),
#  ('ὅσος', 'quantus', 104),
#  ('ψυχή', 'breath', 102),
#  ('ἐξουσία', 'power', 102),
#  ('σάρξ', 'flesh', 102),
#  ('καλέω', 'to call, summon', 101),
#  ('ζάω', 'to live', 101),
#  ('δεῖ', 'to bind', 101),
#  ('ἀποθνήσκω', 'to die off, die', 100),
#  ('ἀλλήλων', 'of one another, to one another, one another', 100),
#  ('ἀμην', '', 99),
#  ('ὀφθαλμός', 'the eye', 99),
#  ('ἕτερος', 'one of the', 99),
#  ('ὄνομα', 'by name', 99),
#  ('κυριάζω', '', 98),
#  ('ἴδιος', "one's own, pertaining to oneself", 98),
#  ('πέτρος', 'a stone', 98),
#  ('τέκνον', 'that which is borne', 97),
#  ('παραδίδωμι', 'to give', 97),
#  ('ἀγαθός', 'good', 95),
#  ('αἷμα', 'blood', 95),
#  ('οἰκία', 'a building, house, dwelling', 93),
#  ('σώζω', 'to save, keep', 91),
#  ('ὀνομάζω', 'to name', 90),
#  ('χριστῷ', '', 90),
#  ('δικαιοσύνη', 'righteousness, justice', 89),
#  ('θάλασσα', 'the sea', 89),
#  ('εἰρήνη', 'peace, time of peace', 89),
#  ('πούς', 'a foot', 88),
#  ('ἐνώπιος', 'face to face', 87),
#  ('δίκαιος',
#   'observant of custom and social rule, well-ordered, civilised',
#   86),
#  ('χόω', 'to throw', 86),
#  ('καῖρος', 'the row of thrums', 84),
#  ('ζητέω', 'to seek, seek for', 83),
#  ('οἶκος', 'a house, abode, dwelling', 83),
#  ('ἀνίστημι', 'to make to stand up, raise up', 83),
#  ('μήτηρ', 'a mother', 82),
#  ('φοβέω', 'to put to flight', 82),
#  ('παρακαλέω', 'to call to', 82),
#  ('ἔξεστι', "it is allowed, it is in one's power, is possible", 82),
#  ('εἷς', '', 82),
#  ('μηδείς', 'and not one', 82),
#  ('ἐφ', '', 81),
#  ('ἕκαστος', 'every, every one, each, each one', 81),
#  ('μαλλός', 'a lock of wool, wool', 80),
#  ('τίνω', 'to pay a price', 80),
#  ('ἵστημι', 'to make to stand', 79),
#  ('ἄρχω', 'to be first', 79),
#  ('κοσμέω', 'to order, arrange', 78),
#  ('ἔλεγος', 'a song of mourning, a lament', 78),
#  ('τόπος', 'a place', 78),
#  ('ἀπέρχομαι', 'to go away, depart from', 77),
#  ('πονηρός', 'toilsome, painful, grievous', 77),
#  ('κύριε', '', 77),
#  ('γεννάω', 'to beget, engender', 76),
#  ('ἕνος',
#   "belonging to the former of two periods, last year's / the day after to-morrow",
#   76),
#  ('σημεῖον', 'a sign, a mark, token', 76),
#  ('κεφαλή', 'the head', 75),
#  ('ἄρτος', 'a cake', 75),
#  ('ἀπόλλυμι', 'to destroy utterly, kill, slay', 74),
#  ('δωδεκάς', 'the number twelve', 74),
#  ('εὐαγγέλιον', 'the reward of good tidings', 73),
#  ('πρόσωπον', 'the face, visage, countenance', 73),
#  ('μαρτυρέω',
#   'to be a witness, to bear witness, give evidence, bear testimony',
#   73),
#  ('Πάν', 'Pan', 72),
#  ('φάος', 'light, daylight', 72),
#  ('αἴρω', 'to take up, raise, lift up', 72),
#  ('ἀβραάμ', '', 71),
#  ('ἄγαμαι', 'to wonder, be astonished', 71),
#  ('ἀφίημι', 'to send forth, discharge', 71),
#  ('κυρίου', '', 70),
#  ('ἐγείρω', 'to awaken, wake up, rouse', 70),
#  ('θανατάω', 'to desire to die', 70),
#  ('βλέπω', 'to see, have the power of sight', 70),
#  ('περιπατέω', 'to walk up and down, to walk about', 70),
#  ('αἰώνιος', 'lasting for an age', 70),
#  ('πληρόω', 'to make full', 69),
#  ('στόμα', 'the mouth', 69),
#  ('πλοῖον', 'a floating vessel, a ship, vessel', 68),
#  ('ἀποκτείνω', 'to kill, slay', 68),
#  ('αὐτην', '', 67),
#  ('κᾶλον', 'wood', 67),
#  ('κυρέω', 'to hit, light upon', 67),
#  ('ἐκβάλλω', 'to throw', 67),
#  ('καρπός', 'the wrist / fruit', 66),
#  ('παῦλος', '', 66),
#  ('μέλλω', 'to think of doing, intend to do, to be about to do', 65),
#  ('ὕδωρ', 'water', 65),
#  ('ἀναβαίνω', 'to go up, mount, to go up to', 65),
#  ('ὁλάω', '', 65),
#  ('μένω', 'to stay at home, stay where one is, not stir', 65),
#  ('πιστός', 'liquid medicines / to be trusted', 65),
#  ('ἰουδαίων', '', 64),
#  ('ὁδός', 'a way, path, track, road, highway / a threshold', 64),
#  ('φημί', 'to declare, make known', 64),
#  ('ἀκολουθέω', 'to follow', 64),
#  ('τίθημι', 'to set, put, place', 64),
#  ('ἁμάρτημα', 'a failure, fault, sin', 63),
#  ('γραμματεύς', 'a secretary, clerk', 63),
#  ('πορεύω', 'to make to go, carry, convey', 63),
#  ('ὀχλέω', 'to move, disturb', 63),
#  ('ῥῆμα', 'that which is said', 62),
#  ('πρέσβυς', 'an old man', 62),
#  ('νύξ', 'the night-season', 61),
#  ('ἦδος', 'delight, enjoyment, pleasure', 61),
#  ('Πάρος', 'Paros', 60),
#  ('ποτός', 'drunk, fit for drinking', 60),
#  ('αἰτέω', 'to ask, beg', 60),
#  ('δαυείδ', '', 59),
#  ('χαρά', 'joy, delight', 59),
#  ('βαπτίζω', 'to dip in', 59),
#  ('διδάσκω', 'to teach', 59),
#  ('πάομαι', 'to eat', 59),
#  ('ὑπάγω', 'to lead', 58),
#  ('μέσος', 'middle, in the middle', 58),
#  ('ἀπόστολος', 'a messenger, ambassador, envoy', 58),
#  ('ἀνοίγνυμι', 'to open', 57),
#  ('κρίνω', 'to pick out, choose', 57),
#  ('τιμάω',
#   'to pay honour to, hold in honour, to honour, revere, reverence',
#   57),
#  ('ἰδού', 'lo! behold! see there!', 56),
#  ('δείκνυμι', 'to bring to light, display, exhibit', 56),
#  ('Μῆδος', 'a Mede, Median', 56),
#  ('ἰουδαῖοι', '', 56),
#  ('χαίρω', 'to rejoice, be glad, be delighted', 55),
#  ('πλείων', 'more, larger', 55),
#  ('ἱμάτιον', 'an outer garment, a cloak', 55),
#  ('προσεύχομαι', 'to offer prayers', 55),
#  ('πόα', 'grass, herb', 55),
#  ('θέλημα', 'will', 55),
#  ('τηρέω', 'to watch over, protect, guard', 55),
#  ('χρόνος', 'time', 54),
#  ('ἐρωτάω', 'to ask', 54),
#  ('τρίτος', 'the third', 54),
#  ('πέμπω', 'to send, despatch', 53),
#  ('εὐθύς', 'straight, direct / straight', 53),
#  ('κακός', 'bad', 53),
#  ('ἱερός', 'super-human, mighty, divine, wonderful', 53),
#  ('λοιπός', 'remaining, the rest', 53),
#  ('ἀέκων', "against one's will, unwilling", 52),
#  ('ἐπαγγελία', 'a public denunciation', 52),
#  ('ἐλπίς', 'hope, expectation', 52),
#  ('προσκυνέω', 'to make obeisance', 51),
#  ('δαιμόνιον', 'the Deity', 51),
#  ('θάνατος', 'death', 51),
#  ('ὅμοιος', 'like, resembling', 51),
#  ('Ἴδη', 'Ida', 50),
#  ('φαρισαῖοι', '', 50),
#  ('πίνω', 'to drink', 50),
#  ('λαβή', 'the part intended for grasping, a handle, haft', 50),
#  ('φυλάζω', 'to divide into tribes', 50),
#  ('θρόνον', 'flowers embroidered on cloth, patterns', 50),
#  ('γλῶσσα', 'the tongue', 50),
#  ('ἰωάνης', '', 49),
#  ('φέρω', 'to bear', 49),
#  ('ἀρχή', 'a beginning, origin, first cause', 49),
#  ('τυφλός', 'blind', 49),
#  ('σοφία', 'skill', 49),
#  ('ἐπερωτάω', 'to inquire of, question, consult', 49),
#  ('παραβολή', 'juxta-position, comparison', 49),
#  ('ἀπολύω', 'to loose from', 48),
#  ('καταβαίνω', 'to step down, go', 48),
#  ('δοξάζω', 'to think, imagine, suppose, fancy, conjecture', 48),
#  ('φυλακή', 'a watching', 48),
#  ('δεξιά', 'the right hand', 48),
#  ('χρεία', 'use, advantage, service', 47),
#  ('κρίσις', 'a separating, power of distinguishing', 47),
#  ('σωτηρία', 'a saving, deliverance, preservation, safety', 46),
#  ('ὅλοξ', 'whole, entire, complete', 45),
#  ('ναός', 'the dwelling of a god, a temple', 45),
#  ('ἐπιγιγνώσκω', 'to look upon, witness, observe', 44),
#  ('ἔπειμι', 'sum', 44),
#  ('ἔτης', 'clansmen', 44),
#  ('μέθη', 'strong drink', 44),
#  ('πλανάω', 'to make to wander, lead wandering about', 44),
#  ('σαρκάζω', 'to tear flesh like dogs', 44),
#  ('γενεά', 'race, stock, family', 43),
#  ('πῦρ', 'fire', 43),
#  ('κηρύσσω', 'to be a herald, officiate as herald', 43),
#  ('μωυσῆς', '', 43),
#  ('ἄγω', 'to lead', 43),
#  ('μικρός', 'small, little', 43),
#  ('δεύτερος', 'second', 43),
#  ('ἀφ', '', 43),
#  ('τότε', 'at that time, then', 42),
#  ('μέρος', 'a part, share', 42),
#  ('ὄρος', 'a mountain, hill', 42),
#  ('ὀλίγος', 'few, little, scanty, small', 42),
#  ('θαυμάζω', 'to wonder, marvel, be astonied', 42),
#  ('τρέω', 'to flee from fear, flee away', 42),
#  ('ἀνάστασις', 'a raising up', 42),
#  ('χριστόν', '', 42),
#  ('ἀγαπητός', 'beloved', 41),
#  ('καλός', 'beautiful, beauteous, fair', 41),
#  ('ἀγείρω', 'to bring together, gather together', 41),
#  ('σπέρμα', 'that which is sown', 41),
#  ('φανερόω', 'to make manifest', 41),
#  ('ἐντολή', 'an injunction, order, command, behest', 40),
#  ('ἀποδίδωμι', 'to give up', 40),
#  ('τέσσαρες', 'four', 40),
#  ('ἀνηρ', '', 39),
#  ('σπειράομαι', 'to be coiled', 39),
#  ('μνημεῖον', 'a monument', 39),
#  ('ἰωάνου', '', 39),
#  ('τέλος', 'the fulfilment', 39),
#  ('καθίζω', 'to make to sit down, seat', 39),
#  ('ἰερουσαλημ', '', 39),
#  ('πειλᾶτος', '', 39),
#  ('ἐρῶ', 'I will say', 38),
#  ('ἰεροσόλυμα', '', 38),
#  ('ἰσραήλ', '', 38),
#  ('προσφέρω', 'to bring to', 38),
#  ('ἱκανός', 'becoming, befitting, sufficing', 38),
#  ('θύρα', 'a door', 38),
#  ('ἐσχατάω', 'to be at the edge, on the border', 38),
#  ('γαλιλαίας', '', 37),
#  ('θεραπεύω', 'to be an attendant, do service', 37),
#  ('προσευχή', 'prayer', 37),
#  ('ἀπαγγέλλω', 'to bring tidings, report, announce', 37),
#  ('ἰερουσαλήμ', '', 37),
#  ('ἐπιθυμιάω', 'to offer incense', 37),
#  ('φόβος', 'flight', 37),
#  ('μαρτυρία', 'witness, testimony, evidence', 37),
#  ('μένος', 'might, force, strength, prowess, courage', 37),
#  ('ἰωάνην', '', 36),
#  ('διάβολος', 'slanderous, backbiting', 36),
#  ('λίθος', 'a stone', 36),
#  ('ἐρέω', 'to ask, enquire', 36),
#  ('κρατέω', 'to be strong, mighty, powerful', 36),
#  ('σίμων', '', 36),
#  ('γραφεύς', 'a painter', 36),
#  ('περιτομή', 'circumcision', 36),
#  ('παιδίον', 'a little', 35),
#  ('ὁδάω', 'to export and sell;', 35),
#  ('ἄξιος', 'weighing as much', 35),
#  ('διώκω', 'to pursue', 35),
#  ('οἰκοδομέω', 'to build a house', 35),
#  ('δέω', 'to lack, miss, stand in need of / to bind, tie, fetter', 35),
#  ('ἀγοράζω', 'to be in the a)gora/', 35),
#  ('θεωρέω', 'to look at, view, behold', 35),
#  ('διακονέω', 'to minister, serve, do service', 34),
#  ('ἅπτω', 'to fasten, bind fast', 34),
#  ('ἁμαρτωλός', 'sinful', 34),
#  ('ἐπιστρέφω', 'to turn about, turn round', 34),
#  ('ἀδελφή', 'a sister', 34),
#  ('λυπέω', 'to give pain to, to pain, distress, grieve, vex, annoy', 34),
#  ('ἁμαρτάνω', 'to miss, miss the mark', 34),
#  ('βιβλίον', 'a paper, scroll, letter', 34),
#  ('εἰκών', 'a likeness, image, portrait', 34),
#  ('χρύσεος', 'golden, of gold, decked', 34),
#  ('διακονία', 'the office of a', 34),
#  ('λογίζομαι', 'to count, reckon, calculate, compute', 34),
#  ('πτωχός', 'one who crouches', 33),
#  ('περισσεύω', 'to be over and above', 33),
#  ('οἶνος', 'wine', 33),
#  ('πολέω', 'to go about, range over', 33),
#  ('ὀφείλω', 'to owe, have to pay', 33),
#  ('διαθήκη', 'a disposition', 33),
#  ('χιλιάς', 'the number one thousand, a thousand', 33),
#  ('ταῦτα', '', 32),
#  ('μέλος', 'a limb', 32),
#  ('ἅπας', 'quite all, the whole', 32),
#  ('ἐργάζομαι', 'to work, labour', 32),
#  ('σταυρόω', 'to fence with pales, impalisade', 32),
#  ('ἀσθενέω', 'to be weak, feeble, sickly', 32),
#  ('ἐγένετο', '', 32),
#  ('καυχάομαι', 'to speak loud, be loud-tongued', 32),
#  ('παραλαμβάνω', 'to receive from', 31),
#  ('ἀγγέλλω', 'to bear a message', 31),
#  ('κρίνον', 'a lily', 31),
#  ('ἄνεμος', 'wind', 31),
#  ('ἐπιέννυμι', 'to put on besides', 31),
#  ('δικαιόω', 'to set right', 31),
#  ('πλέω', 'to sail, go by sea', 31),
#  ('πάσχω', 'to receive an impression from without, to suffer', 31),
#  ('πλούσιος', 'rich, wealthy, opulent', 31),
#  ('φεύγω', 'to flee, take flight, run away', 30),
#  ('ἐχθρός', 'hated, hateful', 30),
#  ('ἀσπάζομαι', 'to welcome kindly, bid welcome, greet', 30),
#  ('σκότος', 'darkness, gloom', 30),
#  ('ἀκοή', 'a hearing, the sound heard', 30),
#  ('ἰσραηλ', '', 30),
#  ('καινός', 'new, fresh', 30),
#  ('ἀκάθαρτος', 'uncleansed, unclean, impure', 30),
#  ('ἀποκαλύπτω', 'to uncover', 30),
#  ('οὖς', 'auris, the ear', 30),
#  ('ποτήριον', 'a drinking-cup, wine-cup', 30),
#  ('μετανοέω', "to change one's mind", 30),
#  ('Σάββατον', 'sabbath', 30),
#  ('συνάγω', 'to bring together, gather together, collect, convene', 30),
#  ('παρίστημι', 'to make to stand', 30),
#  ('πείθω', 'to prevail upon, win over, persuade', 30),
#  ('πλῆθος', 'a great number, a throng, crowd, multitude', 30),
#  ('ἀρνίον', 'a sheep-skin', 30),
#  ('παῦλον', '', 30),
#  ('παύλου', '', 30),
#  ('ἐφορεύω', 'to be ephor', 29),
#  ('φαρισαίων', '', 29),
#  ('μισθός', 'wages, pay, hire', 29),
#  ('σκανδαλίζω', 'to make to stumble, give offence to', 29),
#  ('διδάσκαλε', '', 29),
#  ('ἐπιτιμάω', 'to lay a value upon', 29),
#  ('ἐκραίνω', 'to scatter out of, make to fall in drops from', 29),
#  ('διδάσκαλος', 'a teacher, master', 29),
#  ('περισσός', 'beyond the regular number', 29),
#  ('ἑτοιμάζω', 'to make', 29),
#  ('πράσσω', 'to pass over', 29),
#  ('συνείδησις', 'self-consciousness: conscience', 29),
#  ('λᾶας', '', 28),
#  ('συναγωγή', 'a bringing together, uniting', 28),
#  ('τελέω', 'to complete, fulfil, accomplish', 28),
#  ('ὥρα', 'period', 28),
#  ('μάχαιρα', 'a large knife', 28),
#  ('σταυρός', 'an upright pale', 28),
#  ('μυστήριον', 'a mystery', 28),
#  ('συναγωγεύς', 'one who brings together, a convener', 28),
#  ('δυνατός', 'strong, mighty, able', 28),
#  ('δεκάζω', 'to bribe', 28),
#  ('πνευματικός', 'of spirit, spiritual', 28),
#  ('ἰακώβ', '', 27),
#  ('φαίνω', 'to bring to light, make to appear', 27),
#  ('ἰουδαίας', '', 27),
#  ('χώρα', 'the space in which a thing is', 27),
#  ('προσέρχομαι', 'to come', 27),
#  ('πυρός', 'wheat', 27),
#  ('γαμέω', 'to marry', 27),
#  ('μισέω', 'to hate', 27),
#  ('φιλέω', 'to love, regard with affection', 27),
#  ('ὄντα', '(sum)', 27),
#  ('κρῖμα', 'a decision, judgment', 27),
#  ('καθαρίζω', 'to make clean, to cleanse', 27),
#  ('θυγάτηρ', 'a daughter', 27),
#  ('ἄρχων', 'a ruler, commander, chief, captain', 27),
#  ('ὑπάρχω', 'to begin, make a beginning', 27),
#  ('παράκλησις', "a calling to one's aid, summons", 27),
#  ('νικάω', 'to conquer, prevail, vanquish', 27),
#  ('ἀληθινός', 'agreeable to truth', 27),
#  ('ἰωσηφ', '', 26),
#  ('κατοικέω', 'to dwell in as a', 26),
#  ('ἰσχύω', 'to be strong', 26),
#  ('στρατιώτης', 'a citizen bound to military service;', 26),
#  ('βλασφημέω', 'to drop evil', 26),
#  ('παραγγέλλω', 'to transmit as a message', 26),
#  ('ἀγρός', 'fields, lands', 26),
#  ('μαριάμ', '', 26),
#  ('εὐλογέω', 'to speak well of, praise, honour', 26),
#  ('εὐχαριστέω', 'to be thankful, return thanks', 26),
#  ('κλαίω', 'to weep, lament, wail', 26),
#  ('ἰουδαίοις', '', 26),
#  ('θηρίον', 'a wild animal, beast', 26),
#  ('ἁγίζω', 'to hallow, dedicate', 26),
#  ('ἡρῴδης', '', 25),
#  ('ὑπ', '', 25),
#  ('δένδρον', 'a tree', 25),
#  ('πέτρον', '', 25),
#  ('πορνεία', 'fornication, prostitution', 25),
#  ('ὄμνυμι', 'to swear', 25),
#  ('πρόβατον', 'anything that walks forward;', 25),
#  ('ἀναγιγνώσκω', 'to know well, know certainly', 25),
#  ('ἱερεύς', 'a priest, sacrificer', 25),
#  ('ἐλπίζω', 'to hope for, look for, expect', 25),
#  ('ἰσχυρός', 'strong, mighty', 25),
#  ('λύω', 'to loose', 25),
#  ('νεφέλη', 'a cloud', 25),
#  ('εἶπεν', '', 25),
#  ('χήρα', 'bereft of a husband, a widow', 25),
#  ('ὑποστρέφω', 'to turn round about, turn back', 25),
#  ('ὑποτάσσω', 'to place', 25),
#  ('ἀδικία', 'wrong-doing, injustice', 25),
#  ('παῖς', 'a child', 24),
#  ('ἐρημάζω', 'to be left lonely, go alone', 24),
#  ('πειράζω', 'to make proof', 24),
#  ('πέρα', '', 24),
#  ('κληρονομέω',
#   'to receive a share of an inheritance, to inherit a portion',
#   24),
#  ('παρέρχομαι', 'to go by, beside', 24),
#  ('πιέζω', 'to press, squeeze, press tight', 24),
#  ('ἀσθένεια', 'want of strength, weakness, feebleness, sickliness', 24),
#  ('εἰδοί', 'Idus', 24),
#  ('θυσιάζω', 'to sacrifice', 24),
#  ('εὐαγγελίζομαι', 'to bring good news, announce them', 24),
#  ('διέρχομαι', 'to go through, pass through', 24),
#  ('παρουσία', 'a being present, presence', 24),
#  ('δίδημι', 'to bind, fetter', 24),
#  ('βούλομαι', 'to will, wish, be willing', 23),
#  ('τοῦτο', '', 23),
#  ('Αἴγυπτος', 'the river Nile', 23),
#  ('ἀναιρέω', 'to take up, raise', 23),
#  ('τρέφω', 'to thicken', 23),
#  ('ὄνομά', '', 23),
#  ('ὁμολογέω', 'to speak together', 23),
#  ('ἰάομαι', 'to heal, cure', 23),
#  ('πίπτω', 'to fall, fall down', 23),
#  ('ἀρνέομαι', 'to deny, disown', 23),
#  ('φίλος', 'loved, beloved, dear', 23),
#  ('φρονέω', 'to think, to have understanding, to be sage, wise, prudent', 23),
#  ('πίμπλημι', 'to fill full of', 23),
#  ('μωυσέως', '', 23),
#  ('δεσμεύω', 'to fetter, put in chains', 23),
#  ('ἐλεός', 'a kitchen-table, a board on which meat was cut up, a dresser', 23),
#  ('σωτήρ', 'a saviour, deliverer, preserver', 23),
#  ('γνωρίζω', 'to make known, point out, explain', 23),
#  ('ἄνδρες', '', 23),
#  ('ἱεράομαι', 'to be a priest', 22),
#  ('θυσιαστήριον', 'an altar', 22),
#  ('βλέπος', 'a look', 22),
#  ('ἦλθαν', '', 22),
#  ('ἥκω', 'to have come, be present, be here', 22),
#  ('ἀποστολή', 'a sending off', 22),
#  ('κοιλία', 'the large cavity of the body, the belly', 22)]

# %%
# straightforward corrections might be added here

corrections = {
    "ἔχις" : "ἔχω"
}

for key in corrections.keys():
    AGT["lemmata"] = AGT["lemmata"].apply(lambda word_list: [corrections[key] if x == key else x for x in word_list])
    AGT["lemmatized_sentences"] = AGT["lemmatized_sentences"].apply(lambda sentences_list: [[corrections[key] if x == key else x for x in sentence] for sentence in sentences_list])

# %%
https://raw.githubusercontent.com/UniversalDependencies/UD_Ancient_Greek-PROIEL/master/grc_proiel-ud-train.conllu

# %%
# enrich morpheus by additional data from universaldependencies
corpus_perseus = pyconll.load.iter_from_url("https://raw.githubusercontent.com/UniversalDependencies/UD_Ancient_Greek-Perseus/master/grc_perseus-ud-train.conllu")
forms_lemmas_dict = {}
for sentence in corpus_perseus:
    for token in sentence:
        forms_lemmas_dict[token.form] = [{"l" : token.lemma, "p" : token.xpos, "s" : ""}]
        
for key in forms_lemmas_dict.keys():
    try:
        morpheus_dict[key]
    except:
        morpheus_dict[key] = forms_lemmas_dict[key]

# %%
sddk.write_file("SDAM_data/AGT/AGT_20201110.json", AGT, conf)
# Out:
# Your <class 'pandas.core.frame.DataFrame'> object has been succefully written as "https://sciencedata.dk/files/SDAM_root/SDAM_data/AGT/AGT_20201110.json"
