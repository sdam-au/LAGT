# %%
import pandas as pd
import os
from bs4 import BeautifulSoup

# %%
glaux_metadata = pd.read_csv("/srv/data/greek/glaux/metadata.txt", sep="\t")
glaux_metadata.head(30)
# Out:
#     GLAUX_TEXT_ID       TLG  STARTDATE  ENDDATE AUTHOR_STANDARD  \
# 0               1  0012-001       -800     -701         Homerus
# 1               2  0012-002       -800     -701         Homerus
# 2               3  0012-003       -800     -701         Homerus
# 3               4  1351-001       -800     -701         Epigoni
# 4               5  1547-001       -800     -701       Oedipodea
# 5               6  1712-001       -800     -701         Thebaïs
# 6               7  0298-001       -800     -601         Eumelus
# 7               9  0020-001       -800     -601        Hesiodus
# 8              10  0020-002       -800     -601        Hesiodus
# 9              11  0020-003       -800     -601        Hesiodus
# 10             12  0020-004       -800     -601        Hesiodus
# 11             13  0020-006       -800     -601        Hesiodus
# 12             14  0020-007       -800     -601        Hesiodus
# 13             15  0020-008       -800     -601        Hesiodus
# 14             18  0232-002       -700     -601     Archilochus
# 15             19  0232-003       -700     -601     Archilochus
# 16             22  1296-001       -700     -601          Cypria
# 17             23  1444-001       -700     -601     Ilias Parva
# 18             24  1445-001       -700     -601     Iliu Persis
# 19             25  0013-001       -700     -601  Hymni Homerici
# 20             26  0013-005       -700     -601  Hymni Homerici
# 21             27  0013-009       -700     -601  Hymni Homerici
# 22             29  0255-002       -700     -601       Mimnermus
# 23             32  0299-001       -700     -601       Terpander
# 24             33  1737-001       -700     -601    Titanomachia
# 25             37  0696-002       -700     -501      Alcmaeonis
# 26             38  1182-004       -700     -501        Aristeas
# 27             39  0241-003       -700     -501     Aristoxenus
# 28             41  0242-003       -700     -501           Asius
# 29             43  1274-002       -700     -501       Cleobulus
#
#                 TITLE_STANDARD     GENRE_STANDARD     DIALECT  \
# 0                        Ilias        Epic poetry  Ionic/Epic
# 1                      Odyssea        Epic poetry  Ionic/Epic
# 2                  Epigrammata       Lyric poetry  Ionic/Epic
# 3                      Epigoni        Epic poetry  Ionic/Epic
# 4                    Oedipodea        Epic poetry  Ionic/Epic
# 5                      Thebaïs        Epic poetry  Ionic/Epic
# 6                   Fragmentum       Lyric poetry  Ionic/Epic
# 7                    Theogonia        Epic poetry  Ionic/Epic
# 8                Opera et dies        Epic poetry  Ionic/Epic
# 9                       Scutum        Epic poetry  Ionic/Epic
# 10                   Fragmenta        Epic poetry  Ionic/Epic
# 11       Fragmenta astronomica  Scientific Poetry  Ionic/Epic
# 12                   Fragmenta        Epic poetry  Ionic/Epic
# 13                  Fragmentum       Lyric poetry  Ionic/Epic
# 14            Fragmenta lyrica       Lyric poetry  Ionic/Epic
# 15                 Epigrammata       Lyric poetry  Ionic/Epic
# 16                      Cypria        Epic poetry  Ionic/Epic
# 17                 Ilias parva        Epic poetry  Ionic/Epic
# 18                 Iliu persis        Epic poetry  Ionic/Epic
# 19  Fragmenta hymni in Bacchum       Lyric poetry  Ionic/Epic
# 20                  In Venerem       Lyric poetry  Ionic/Epic
# 21                   In Dianam       Lyric poetry  Ionic/Epic
# 22                   Epigramma       Lyric poetry  Ionic/Epic
# 23                   Fragmenta       Lyric poetry       Doric
# 24                Titanomachia        Epic poetry  Ionic/Epic
# 25                  Alcmaeonis        Epic poetry  Ionic/Epic
# 26             Fragmenta epica        Epic poetry  Ionic/Epic
# 27                  Fragmentum             Comedy       Doric
# 28             Fragmenta epica       Lyric poetry  Ionic/Epic
# 29                 Epigrammata       Lyric poetry  Ionic/Epic
#
#                                                SOURCE SOURCE_LICENSE  \
# 0                                             Perseus   CC BY-SA 4.0
# 1                                             Perseus   CC BY-SA 4.0
# 2                                             Perseus   CC BY-SA 4.0
# 3                      https://sententiaeantiquae.com            NaN
# 4                      https://sententiaeantiquae.com            NaN
# 5                      https://sententiaeantiquae.com            NaN
# 6                                  http://remacle.org            NaN
# 7                                             Perseus   CC BY-SA 4.0
# 8                                             Perseus   CC BY-SA 4.0
# 9                                             Perseus   CC BY-SA 4.0
# 10  https://www.hs-augsburg.de/~harsch/augustana.html            NaN
# 11                          https://en.wikisource.org   CC-BY-SA 3.0
# 12  https://www.hs-augsburg.de/~harsch/augustana.html            NaN
# 13                                            Perseus   CC BY-SA 4.0
# 14                                  http://aoidoi.org            NaN
# 15                                            Perseus   CC BY-SA 4.0
# 16                                            First1K   CC BY-SA 4.0
# 17                   https://zenodo.org/record/437896      CC BY 4.0
# 18                   https://zenodo.org/record/437896      CC BY 4.0
# 19                                            Perseus   CC BY-SA 4.0
# 20                                            Perseus   CC BY-SA 4.0
# 21                                            Perseus   CC BY-SA 4.0
# 22                                            Perseus   CC BY-SA 4.0
# 23  https://archive.org/details/greekmelicpoets00s...            NaN
# 24                   https://zenodo.org/record/437896      CC BY 4.0
# 25                     https://sententiaeantiquae.com            NaN
# 26                     https://sententiaeantiquae.com            NaN
# 27  https://archive.org/details/comicorumgraecor11...            NaN
# 28                   https://zenodo.org/record/437896      CC BY 4.0
# 29                                            Perseus   CC BY-SA 4.0
#
#    SOURCE_FORMAT  TOKENS           TM_TEXT
# 0            XML  129604               511
# 1            XML  104364               512
# 2            XML      26             12612
# 3            TXT      60     13805 / 15768
# 4            TXT      15             12913
# 5            TXT     157             13811
# 6            TXT      14              2272
# 7            XML    8101               513
# 8            XML    6954               796
# 9            XML    3834              1341
# 10           TXT    9107  794 / 795 / 1915
# 11           TXT      38             15962
# 12           TXT     513              1915
# 13           TXT       7              1915
# 14           TXT     319              2188
# 15           XML      26             12604
# 16           XML     412      2817 / 14457
# 17           TXT     390              1407
# 18           TXT      96             13807
# 19           XML     180              2304
# 20           XML    2393             11435
# 21           XML      67             11438
# 22           XML      17             12614
# 23           TXT      70             10428
# 24           TXT     125             13812
# 25           TXT      51             13797
# 26           TXT      91             14049
# 27           TXT      10             10263
# 28           TXT      98             12820
# 29           XML      72             12606

# %%
# load the following file with beautiful soup
filepath = "/srv/data/greek/opera_graeca_adnotata_v0.2.0/work_chronology/texts/chronology_greek_works_plus_date_label.xml"
with open(filepath, 'r', encoding='utf-8') as file:
    soup = BeautifulSoup(file, 'xml')

# %%
# Extract records
records = []
for record in soup.find_all("record"):
    record_data = {}
    for field in record.find_all():
        record_data[field.name] = field.text.strip()  # Use tag name as key, text content as value
    records.append(record_data)

# Convert to DataFrame
oga_metadata = pd.DataFrame(records)

# %%
oga_metadata.head(5)
# Out:
#   id            urn_cts                     title_labels  \
# 0  1     ogl0001.ogl001  De Epistola Pinyti ad Dionysium
# 1  2   stoa0033a.tlg028                         De mundo
# 2  3   stoa0033a.tlg043                       De spiritu
# 3  4   stoa0121.stoa001     Breviarium historiae romanae
# 4  5  stoa0146d.stoa001                    Acta Archelai
#
#           title_from_print_edition  \
# 0  De Epistola Pinyti ad Dionysium
# 1                         De mundo
# 2                       De spiritu
# 3     Breviarium historiae romanae
# 4                    Acta Archelai
#
#                                        print_edition  \
# 0  Pinytus, Saint, Bishop of Knossos. Reliquiae S...
# 1  pseudo-Aristotle, De mundo, Aristotelis Opera,...
# 2  pseudo-Aristotle, De spiritu, Aristotelis Oper...
# 3  Eutropius. Breviarium historiae romanae. Droys...
# 4  Hegemonius. Acta Archelai. Beeson, Charles Hen...
#
#                               author       estimated_work_date  \
# 0  Pinytus, Saint, Bishop of Knossos  2nd Century AD (101-200)
# 1                   Pseudo-Aristotle               250 BC-50BC
# 2                   Pseudo-Aristotle             275 BC-250 BC
# 3                          Eutropius             364 AD-378 AD
# 4                         Hegemonius           280 AD - 350 AD
#
#   is_temporary_work_date                                        date_source  \
# 0                     No     Kritiko Agiologio, Holy Archibisophry of Crete
# 1                     No  Pseudo-Aristotle: De Mundo (On the Cosmos). Ca...
# 2                     No  Pseud-Aristotelian De Spiritu: A New Case agai...
# 3                     No                        Eutropius, Livius.org, 2020
# 4                     No                              Archelaos, Wikisource
#
#                                     date_source_link  \
# 0  http://www.iak.gr/gr/ekklisia-kritis/kritiko_a...
# 1  https://www.cambridge.org/core/books/pseudoari...
# 2
# 3  https://www.livius.org/articles/person/eutropius/
# 4     https://de.wikisource.org/wiki/RE:Archelaos_40
#
#                                comment_on_chronology formatted_work_date  \
# 0  Church of Crete Saints' Days Catalogue. The da...   +0101-01/+0200-12
# 1  Written between the middle of the 3rd and the ...   —0249-01/—0049-12
# 2              Follows Jaeger's proposed chronology.   —0274-01/—0249-12
# 3                  Proposes an exact date of 369 AD.   +0364-01/+0378-12
# 4  Based on the fact that he was bishop around 28...   +0280-01/+0350-12
#
#             date_label
# 0                 p2_2
# 1  m3_2/m2_1/m2_2/m1_1
# 2                 m3_1
# 3                 p4_2
# 4                 p4_1
