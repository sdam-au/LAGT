# %%
import pandas as pd
import os
from bs4 import BeautifulSoup
import json
import pickle
import re
from nltk.tokenize import word_tokenize
import gspread
from gspread_dataframe import get_as_dataframe, set_with_dataframe
from google.oauth2 import service_account # based on google-auth library

# %%
file_data = json.load(open(os.path.expanduser("../../../ServiceAccountsKey.json")))
# (2) transform the content into crendentials object
credentials = service_account.Credentials.from_service_account_info(file_data)
# (3) specify your usage of the credentials
scoped_credentials = credentials.with_scopes(
    ['https://spreadsheets.google.com/feeds', 'https://www.googleapis.com/auth/drive'])
# (4) use the constrained credentials for authentication of gspread package
gc = gspread.Client(auth=scoped_credentials)

lagt_metadata_gs = gc.open_by_url(
    "https://docs.google.com/spreadsheets/d/10pGulpiwzjUozVEVstKBwtftyDisSY9h7-kl82TVs0A/edit?usp=sharing")

# %% [markdown]
# ## LAGT v3.0

# %%
LAGT = pd.read_parquet("https://zenodo.org/records/10684841/files/LAGT_v3-0.parquet?download=1")

# %%
LAGT.head(5)
# Out:
#    author_id          doc_id                       filename      author  \
# 2    ogl0001  ogl0001.ogl001  ogl0001.ogl001.1st1K-grc1.xml     Pinytus
# 8    tlg0005  tlg0005.tlg003  tlg0005.tlg003.1st1K-grc1.xml  Theocritus
# 9    tlg0006  tlg0006.tlg020  tlg0006.tlg020.1st1K-grc1.xml   Euripides
# 10   tlg0007  tlg0007.tlg146  tlg0007.tlg146.1st1K-grc1.xml    Plutarch
# 11   tlg0007  tlg0007.tlg147  tlg0007.tlg147.1st1K-grc1.xml    Plutarch
#
#                                 title  \
# 2     De Epistola Pinyti ad Dionysium
# 8                              Syrinx
# 9                           Fragmenta
# 10  Παροιμίαι αἷς Ἀλεξανδρεῖς ἐχρῶντο
# 11           Ἐκλογὴ περὶ τῶν ἀδυνάτων
#
#                                                string  wordcount source  \
# 2   FRAGMENTUM BEATI PINYTI, CNOSSI IN CRETA EPISC...        180   1Kgr
# 8   Οὐδενὸς εὐνάτειρα Μακροπτολέμοιο δὲ μάτηρ  μαί...         77   1Kgr
# 9   ποίαν σε φῶμεν γαῖαν ἐκλελοιπότα πόλει ξενοῦσθ...      17708   1Kgr
# 10  Οἴκοι τὰ Μιλήσια: ἐπὶ τῶν ὅποι μὴ προςήκει τὴν...       2685   1Kgr
# 11  Κατὰ πετρῶν σπείρεις. Πλίνθον πλύνεις. Δικτύῳ ...        143   1Kgr
#
#                                  lemmatized_sentences lemmata_source  \
# 2   [[Πινυτός, ἀντιγράφω, θαυμάζω, ἀποδέχω, Διονύσ...          grecy
# 8   [[οὐδενός, εὐνητήρ], [μακροπτολέμοιο, μήτηρ, μ...          grecy
# 9   [[φημί, γῆ, ἐκλείπω, πόλις, ξενοῦσθαι], [πάτρα...          grecy
# 10  [[Μιλήσιος], [προςήκω, τρυφή, ἐπιδείκνυμι], [Ἀ...          grecy
# 11  [[πέτρα, σπείρω], [Πλίνθος, πλύνω, Δίκτυον, ἄν...          grecy
#
#     tlg_date  not_before  not_after date_uncertain  \
# 2       None       101.0      200.0           None
# 8   4-3 B.C.      -400.0     -201.0          False
# 9     5 B.C.      -500.0     -401.0          False
# 10  A.D. 1-2         1.0      200.0          False
# 11  A.D. 1-2         1.0      200.0          False
#
#                       tlg_epithet provenience  lemmatacount
# 2                              []   christian            34
# 8                      [Bucolici]       pagan            61
# 9                       [Tragici]       pagan         10277
# 10  [Biographi, Philosophici/-ae]       pagan          1488
# 11  [Biographi, Philosophici/-ae]       pagan           125

# %%
LAGT.groupby("source").size()
# Out:
# source
# 1Kgr       949
# perseus    761
# dtype: int64

# %%
LAGT.groupby("lemmata_source").size()
# Out:
# lemmata_source
# agdt         25
# glaux       835
# gorman        2
# grecy       762
# lxxmorph     55
# morphgnt     27
# pedalion      4
# dtype: int64

# %%
LAGT["tokencount"] = LAGT["string"].apply(lambda x: len(word_tokenize(x)))

# %%
LAGT3_metadata = LAGT[['doc_id', 'lemmata_source', 'tokencount']].copy()
for col in LAGT3_metadata.columns:
    if col !="doc_id":
        LAGT3_metadata.rename(columns={col : "lagt3_" + col}, inplace=True)

# %% [markdown]
# ## LAGT v4.1

# %%
LAGT = pd.read_parquet("../data/large_files/LAGT_v4-1.parquet")

# %%
LAGT.columns
# Out:
# Index(['author_id', 'doc_id', 'filename', 'author', 'title', 'sentences',
#        'lemmatized_sentences', 'source', 'lemmata_source', 'not_before',
#        'not_after', 'tlg_epithet', 'genre', 'provenience', 'wordcount',
#        'lemmatacount'],
#       dtype='object')

# %%
LAGT["string"] = LAGT["sentences"].apply(lambda x: " ".join(x))

# %%
LAGT["string"].tolist()[:3]
# Out:
# [', , . . . . . . — πρός ἥν ( , ) ὁ Πινυτός ἀντιγράφων, θαυμάζει μέν καί ἀποδέχεται τόν Διονύσιον· ἀντιπαρακαλεῖ δέ στεῤῥοτέρας ἤδη ποτέ μεταδιδόναι τροφῆς, τελειοτέροις γράμμασιν εἰσαῦθις τόν παῤ αὐτῷ λαόν ὑποθρέψαντα, ὡς μή διατέλους τοῖς γαλακτώδεσιν ἐνδιατρίβοντες λόγοις, τῇ νηπιώδει ἀγωγῇ λάθοιεν καταγηράσαντες. δι᾿ ἧς ἐπιστολῆς καί ἡ τοῦ Πινυτοῦ περί τήν πίστιν ὀρθοδοξία τε καί φροντίς τῆς τῶν ὑπηκόων ὡφελείας, τό, τε λόγιον καί ἡ περί τά θεῖα σύνεσις , ὡς δι᾿ ἀκριβεστάτης ἀναδείκνυται εἰκόνος. , : , . : , . . , , , . . . , , .',
#  'Οὐδενός εὐνάτειρα Μακροπτολέμοιο δέ μάτηρ μαίας ἀντιπέτροιο θοόν τέκεν ἰθυντῆρα, οὐχί Κεράσταν ὅν ποτε θρέψατο ταυροπάτωρ, ἀλλ᾽ ου πειλιπές αἶθε πάρος φρένα τέρμα σάκους, οὔνομ᾽ Ὅλον, δίζων, ὅς τᾶς μέροπος πόθον κούρας γηρυγόνας ἔχε τᾶς ἀνεμώδεος, ὅς Μοίσᾳ λιγύ πᾶξεν ἰοστεφάνῳ ἕλκος, ἄγαλμα πόθοιο πυρισμαράγου, ὅς σβέσεν ἀνορέαν ἰσαυδέα παππο
# 3  [Οἴκοι τά Μιλήσια: ἐπί τῶν ὅποι μή προςήκει τή...
# 4  [Κατά πετρῶν σπείρεις., Πλίνθον πλύνεις., Δικτ...
#
#                                 lemmatized_sentences  source lemmata_source  \
# 0  [[], [], [], [], [πινυτός, ἀντιγράφω], [θαυμάζ...  glaux1         glaux1
# 1  [[εὐνητήρ, μακροπτολέμον, μήτηρ, μαῖα, ἀντιπέτ...  glaux1         glaux1
# 2  [[φημί, γῆ, ἐκλείπω, πόλις, ξενοῦσθαι], [πάτρα...  glaux1         glaux1
# 3  [[μιλήσιος, πργοςήκω, τρυφή, ἐπιδείκνυμι], [ἀρ...  glaux1         glaux1
# 4  [[πέτρα, σπείρω], [πλίνθος, πλύνω], [δίκτυον, ...  glaux1         glaux1
#
#    not_before  not_after                    tlg_epithet genre provenience  \
# 0       101.0      200.0                             []    []   christian
# 1      -400.0     -201.0                     [Bucolici]    []       pagan
# 2      -500.0     -401.0                      [Tragici]    []       pagan
# 3         1.0      200.0  [Biographi, Philosophici/-ae]    []       pagan
# 4         1.0      200.0  [Biographi, Philosophici/-ae]    []       pagan
#
#    wordcount  lemmatacount                                             string  \
# 0        109            34  , , . . . . . . — πρός ἥν ( , ) ὁ Πινυτός ἀντι...
# 1         95            59  Οὐδενός εὐνάτειρα Μακροπτολέμοιο δέ μάτηρ μαία...
# 2      21516         10315  ποίαν σε φῶμεν γαῖαν ἐκλελοιπότα πόλει ξενοῦσθ...
# 3       3206          1496  Οἴκοι τά Μιλήσια: ἐπί τῶν ὅποι μή προςήκει τήν...
# 4        195           125  Κατά πετρῶν σπείρεις. Πλίνθον πλύνεις. Δικτύῳ ...
#
#    tokencount
# 0         108
# 1          94
# 2       21729
# 3        3178
# 4         194

# %%
LAGT41_metadata = LAGT[['doc_id', 'author', 'title', 'not_before',
       'not_after', 'tlg_epithet', 'genre', 'provenience', "tokencount"]].copy()
for col in LAGT41_metadata.columns:
    if col !="doc_id":
        LAGT41_metadata.rename(columns={col : "lagt4-1_" + col}, inplace=True)
LAGT41_metadata.head(5)
# Out:
#    lagt4-1_doc_id lagt4-1_author                      lagt4-1_title  \
# 0  ogl0001.ogl001        Pinytus    De Epistola Pinyti ad Dionysium
# 1  tlg0005.tlg003     Theocritus                             Syrinx
# 2  tlg0006.tlg020      Euripides                          Fragmenta
# 3  tlg0007.tlg146       Plutarch  Παροιμίαι αἷς Ἀλεξανδρεῖς ἐχρῶντο
# 4  tlg0007.tlg147       Plutarch           Ἐκλογὴ περὶ τῶν ἀδυνάτων
#
#    lagt4-1_not_before  lagt4-1_not_after            lagt4-1_tlg_epithet  \
# 0               101.0              200.0                             []
# 1              -400.0             -201.0                     [Bucolici]
# 2              -500.0             -401.0                      [Tragici]
# 3                 1.0              200.0  [Biographi, Philosophici/-ae]
# 4                 1.0              200.0  [Biographi, Philosophici/-ae]
#
#   lagt4-1_genre lagt4-1_provenience  lagt4-1_tokencount
# 0            []           christian                 108
# 1            []               pagan                  94
# 2            []               pagan               21729
# 3            []               pagan                3178
# 4            []               pagan                 194

# %% [markdown]
# ## Glaux metadata

# %%
glaux_metadata = pd.read_csv("/srv/data/greek/glaux/metadata.txt", sep="\t")
glaux_metadata.head(5)
# Out:
#    GLAUX_TEXT_ID       TLG  STARTDATE  ENDDATE AUTHOR_STANDARD TITLE_STANDARD  \
# 0              1  0012-001       -800     -701         Homerus          Ilias
# 1              2  0012-002       -800     -701         Homerus        Odyssea
# 2              3  0012-003       -800     -701         Homerus    Epigrammata
# 3              4  1351-001       -800     -701         Epigoni        Epigoni
# 4              5  1547-001       -800     -701       Oedipodea      Oedipodea
#
#   GENRE_STANDARD     DIALECT                          SOURCE SOURCE_LICENSE  \
# 0    Epic poetry  Ionic/Epic                         Perseus   CC BY-SA 4.0
# 1    Epic poetry  Ionic/Epic                         Perseus   CC BY-SA 4.0
# 2   Lyric poetry  Ionic/Epic                         Perseus   CC BY-SA 4.0
# 3    Epic poetry  Ionic/Epic  https://sententiaeantiquae.com            NaN
# 4    Epic poetry  Ionic/Epic  https://sententiaeantiquae.com            NaN
#
#   SOURCE_FORMAT  TOKENS        TM_TEXT
# 0           XML  129604            511
# 1           XML  104364            512
# 2           XML      26          12612
# 3           TXT      60  13805 / 15768
# 4           TXT      15          12913

# %%
glaux_tlg = "0012-001"
groups = re.search(r"(\d{4})\-(\d{3})", glaux_tlg).groups()
# Out:
# ('0012', '001')

# %%
def tlg_parsing(glaux_tlg):
    groups = re.search(r"(\d{4})\-(\d{3})", glaux_tlg).groups()
    tlg_id = "tlg"+ groups[0] + ".tlg" + groups[1]
    return tlg_id
glaux_metadata["tlg_id"] = glaux_metadata["TLG"].apply(lambda x: tlg_parsing(x))

# %%
for col in glaux_metadata.columns:
    glaux_metadata.rename(columns={col : "glaux_" + col}, inplace=True)
glaux_metadata.head(5)
# Out:
#    glaux_GLAUX_TEXT_ID glaux_TLG  glaux_STARTDATE  glaux_ENDDATE  \
# 0                    1  0012-001             -800           -701
# 1                    2  0012-002             -800           -701
# 2                    3  0012-003             -800           -701
# 3                    4  1351-001             -800           -701
# 4                    5  1547-001             -800           -701
#
#   glaux_AUTHOR_STANDARD glaux_TITLE_STANDARD glaux_GENRE_STANDARD  \
# 0               Homerus                Ilias          Epic poetry
# 1               Homerus              Odyssea          Epic poetry
# 2               Homerus          Epigrammata         Lyric poetry
# 3               Epigoni              Epigoni          Epic poetry
# 4             Oedipodea            Oedipodea          Epic poetry
#
#   glaux_DIALECT                    glaux_SOURCE glaux_SOURCE_LICENSE  \
# 0    Ionic/Epic                         Perseus         CC BY-SA 4.0
# 1    Ionic/Epic                         Perseus         CC BY-SA 4.0
# 2    Ionic/Epic                         Perseus         CC BY-SA 4.0
# 3    Ionic/Epic  https://sententiaeantiquae.com                  NaN
# 4    Ionic/Epic  https://sententiaeantiquae.com                  NaN
#
#   glaux_SOURCE_FORMAT  glaux_TOKENS  glaux_TM_TEXT    glaux_tlg_id
# 0                 XML        129604            511  tlg0012.tlg001
# 1                 XML        104364            512  tlg0012.tlg002
# 2                 XML            26          12612  tlg0012.tlg003
# 3                 TXT            60  13805 / 15768  tlg1351.tlg001
# 4                 TXT            15          12913  tlg1547.tlg001

# %%
glaux_metadata["doc_id"] = glaux_metadata["glaux_tlg_id"]

# %% [markdown]
# ## OGA metadata

# %%
# load the following file with beautiful soup
filepath = "/srv/data/greek/opera_graeca_adnotata_v0.2.0/work_chronology/texts/chronology_greek_works_plus_date_label.xml"
with open(filepath, 'r', encoding='utf-8') as file:
    soup = BeautifulSoup(file, 'xml')

# %%
# Extract records
records = []
for record in soup.find_all("record"):
    record_data = {}
    for field in record.find_all():
        record_data[field.name] = field.text.strip()  # Use tag name as key, text content as value
    records.append(record_data)

# Convert to DataFrame
oga_metadata = pd.DataFrame(records)

# %%
oga_metadata.head(5)
# Out:
#   id            urn_cts                     title_labels  \
# 0  1     ogl0001.ogl001  De Epistola Pinyti ad Dionysium
# 1  2   stoa0033a.tlg028                         De mundo
# 2  3   stoa0033a.tlg043                       De spiritu
# 3  4   stoa0121.stoa001     Breviarium historiae romanae
# 4  5  stoa0146d.stoa001                    Acta Archelai
#
#           title_from_print_edition  \
# 0  De Epistola Pinyti ad Dionysium
# 1                         De mundo
# 2                       De spiritu
# 3     Breviarium historiae romanae
# 4                    Acta Archelai
#
#                                        print_edition  \
# 0  Pinytus, Saint, Bishop of Knossos. Reliquiae S...
# 1  pseudo-Aristotle, De mundo, Aristotelis Opera,...
# 2  pseudo-Aristotle, De spiritu, Aristotelis Oper...
# 3  Eutropius. Breviarium historiae romanae. Droys...
# 4  Hegemonius. Acta Archelai. Beeson, Charles Hen...
#
#                               author       estimated_work_date  \
# 0  Pinytus, Saint, Bishop of Knossos  2nd Century AD (101-200)
# 1                   Pseudo-Aristotle               250 BC-50BC
# 2                   Pseudo-Aristotle             275 BC-250 BC
# 3                          Eutropius             364 AD-378 AD
# 4                         Hegemonius           280 AD - 350 AD
#
#   is_temporary_work_date                                        date_source  \
# 0                     No     Kritiko Agiologio, Holy Archibisophry of Crete
# 1                     No  Pseudo-Aristotle: De Mundo (On the Cosmos). Ca...
# 2                     No  Pseud-Aristotelian De Spiritu: A New Case agai...
# 3                     No                        Eutropius, Livius.org, 2020
# 4                     No                              Archelaos, Wikisource
#
#                                     date_source_link  \
# 0  http://www.iak.gr/gr/ekklisia-kritis/kritiko_a...
# 1  https://www.cambridge.org/core/books/pseudoari...
# 2
# 3  https://www.livius.org/articles/person/eutropius/
# 4     https://de.wikisource.org/wiki/RE:Archelaos_40
#
#                                comment_on_chronology formatted_work_date  \
# 0  Church of Crete Saints' Days Catalogue. The da...   +0101-01/+0200-12
# 1  Written between the middle of the 3rd and the ...   —0249-01/—0049-12
# 2              Follows Jaeger's proposed chronology.   —0274-01/—0249-12
# 3                  Proposes an exact date of 369 AD.   +0364-01/+0378-12
# 4  Based on the fact that he was bishop around 28...   +0280-01/+0350-12
#
#             date_label
# 0                 p2_2
# 1  m3_2/m2_1/m2_2/m1_1
# 2                 m3_1
# 3                 p4_2
# 4                 p4_1

# %%
oga_metadata["formatted_work_date"].tolist()[:10]
# Out:
# ['+0101-01/+0200-12',
#  '—0249-01/—0049-12',
#  '—0274-01/—0249-12',
#  '+0364-01/+0378-12',
#  '+0280-01/+0350-12',
#  '—0299-01/—0200-12',
#  '—0430-01/—0410-12',
#  '+0222-01/+0235-12',
#  '—0299-01/—0259-12',
#  '—0299-01/—0259-12']

# %%
def parse_dates(formatted_date):
    # Split the string into not_before and not_after parts
    not_before, not_after = formatted_date.split("/")

    # Convert not_before and not_after consistently
    not_before = not_before.replace("+", "").replace("—", "-")
    if not_before[0]=="-":
        not_before = int(not_before[:5])
    else:
        not_before = int(not_before[:4])

    # Replace em dash and +, handle full string
    not_after = not_after.replace("+", "").replace("—", "-")
    if not_after[0]=="-":
        not_after = int(not_after[:5])
    else:
        not_after = int(not_after[:4])# Replace em dash and +, handle full string
    return not_before, not_after

# %%
parse_dates("—0299-01/—0200-12")
# Out:
# (-299, -200)

# %%
oga_metadata["not_before"], oga_metadata["not_after"] = zip(*oga_metadata["formatted_work_date"].apply(parse_dates))

# %%
oga_metadata.head(5)
# Out:
#   id            urn_cts                     title_labels  \
# 0  1     ogl0001.ogl001  De Epistola Pinyti ad Dionysium
# 1  2   stoa0033a.tlg028                         De mundo
# 2  3   stoa0033a.tlg043                       De spiritu
# 3  4   stoa0121.stoa001     Breviarium historiae romanae
# 4  5  stoa0146d.stoa001                    Acta Archelai
#
#           title_from_print_edition  \
# 0  De Epistola Pinyti ad Dionysium
# 1                         De mundo
# 2                       De spiritu
# 3     Breviarium historiae romanae
# 4                    Acta Archelai
#
#                                        print_edition  \
# 0  Pinytus, Saint, Bishop of Knossos. Reliquiae S...
# 1  pseudo-Aristotle, De mundo, Aristotelis Opera,...
# 2  pseudo-Aristotle, De spiritu, Aristotelis Oper...
# 3  Eutropius. Breviarium historiae romanae. Droys...
# 4  Hegemonius. Acta Archelai. Beeson, Charles Hen...
#
#                               author       estimated_work_date  \
# 0  Pinytus, Saint, Bishop of Knossos  2nd Century AD (101-200)
# 1                   Pseudo-Aristotle               250 BC-50BC
# 2                   Pseudo-Aristotle             275 BC-250 BC
# 3                          Eutropius             364 AD-378 AD
# 4                         Hegemonius           280 AD - 350 AD
#
#   is_temporary_work_date                                        date_source  \
# 0                     No     Kritiko Agiologio, Holy Archibisophry of Crete
# 1                     No  Pseudo-Aristotle: De Mundo (On the Cosmos). Ca...
# 2                     No  Pseud-Aristotelian De Spiritu: A New Case agai...
# 3                     No                        Eutropius, Livius.org, 2020
# 4                     No                              Archelaos, Wikisource
#
#                                     date_source_link  \
# 0  http://www.iak.gr/gr/ekklisia-kritis/kritiko_a...
# 1  https://www.cambridge.org/core/books/pseudoari...
# 2
# 3  https://www.livius.org/articles/person/eutropius/
# 4     https://de.wikisource.org/wiki/RE:Archelaos_40
#
#                                comment_on_chronology formatted_work_date  \
# 0  Church of Crete Saints' Days Catalogue. The da...   +0101-01/+0200-12
# 1  Written between the middle of the 3rd and the ...   —0249-01/—0049-12
# 2              Follows Jaeger's proposed chronology.   —0274-01/—0249-12
# 3                  Proposes an exact date of 369 AD.   +0364-01/+0378-12
# 4  Based on the fact that he was bishop around 28...   +0280-01/+0350-12
#
#             date_label  not_before  not_after
# 0                 p2_2         101        200
# 1  m3_2/m2_1/m2_2/m1_1        -249        -49
# 2                 m3_1        -274       -249
# 3                 p4_2         364        378
# 4                 p4_1         280        350

# %%
for col in oga_metadata.columns:
    oga_metadata.rename(columns={col : "oga_" + col}, inplace=True)
oga_metadata.head(5)
# Out:
#   oga_id        oga_urn_cts                 oga_title_labels  \
# 0      1     ogl0001.ogl001  De Epistola Pinyti ad Dionysium
# 1      2   stoa0033a.tlg028                         De mundo
# 2      3   stoa0033a.tlg043                       De spiritu
# 3      4   stoa0121.stoa001     Breviarium historiae romanae
# 4      5  stoa0146d.stoa001                    Acta Archelai
#
#       oga_title_from_print_edition  \
# 0  De Epistola Pinyti ad Dionysium
# 1                         De mundo
# 2                       De spiritu
# 3     Breviarium historiae romanae
# 4                    Acta Archelai
#
#                                    oga_print_edition  \
# 0  Pinytus, Saint, Bishop of Knossos. Reliquiae S...
# 1  pseudo-Aristotle, De mundo, Aristotelis Opera,...
# 2  pseudo-Aristotle, De spiritu, Aristotelis Oper...
# 3  Eutropius. Breviarium historiae romanae. Droys...
# 4  Hegemonius. Acta Archelai. Beeson, Charles Hen...
#
#                           oga_author   oga_estimated_work_date  \
# 0  Pinytus, Saint, Bishop of Knossos  2nd Century AD (101-200)
# 1                   Pseudo-Aristotle               250 BC-50BC
# 2                   Pseudo-Aristotle             275 BC-250 BC
# 3                          Eutropius             364 AD-378 AD
# 4                         Hegemonius           280 AD - 350 AD
#
#   oga_is_temporary_work_date  \
# 0                         No
# 1                         No
# 2                         No
# 3                         No
# 4                         No
#
#                                      oga_date_source  \
# 0     Kritiko Agiologio, Holy Archibisophry of Crete
# 1  Pseudo-Aristotle: De Mundo (On the Cosmos). Ca...
# 2  Pseud-Aristotelian De Spiritu: A New Case agai...
# 3                        Eutropius, Livius.org, 2020
# 4                              Archelaos, Wikisource
#
#                                 oga_date_source_link  \
# 0  http://www.iak.gr/gr/ekklisia-kritis/kritiko_a...
# 1  https://www.cambridge.org/core/books/pseudoari...
# 2
# 3  https://www.livius.org/articles/person/eutropius/
# 4     https://de.wikisource.org/wiki/RE:Archelaos_40
#
#                            oga_comment_on_chronology oga_formatted_work_date  \
# 0  Church of Crete Saints' Days Catalogue. The da...       +0101-01/+0200-12
# 1  Written between the middle of the 3rd and the ...       —0249-01/—0049-12
# 2              Follows Jaeger's proposed chronology.       —0274-01/—0249-12
# 3                  Proposes an exact date of 369 AD.       +0364-01/+0378-12
# 4  Based on the fact that he was bishop around 28...       +0280-01/+0350-12
#
#         oga_date_label  oga_not_before  oga_not_after
# 0                 p2_2             101            200
# 1  m3_2/m2_1/m2_2/m1_1            -249            -49
# 2                 m3_1            -274           -249
# 3                 p4_2             364            378
# 4                 p4_1             280            350

# %%
oga_metadata["doc_id"] = oga_metadata["oga_urn_cts"]

# %%
sentences_path = "/srv/data/greek/oga_sentences/"
os.listdir(sentences_path)[:10]
# Out:
# ['tlg1264.tlg001.pickle',
#  'tlg0007.tlg121.pickle',
#  'pta0100.pta008.pickle',
#  'tlg0527.tlg020.pickle',
#  'tlg0540.tlg019.pickle',
#  'tlg0026.tlg004.pickle',
#  'tlg0018.tlg020.pickle',
#  'tlg0540.tlg015.pickle',
#  'tlg2042.tlg086.pickle',
#  'pta0001.pta005.pickle']

# %%
doc_id = oga_metadata["doc_id"][0]
with open(os.path.join(sentences_path, doc_id + ".pickle"), "rb") as f:
    sentences_data = pickle.load(f)

# %%
sum([len(sent[3]) for sent in sentences_data])
# Out:
# 109

# %%
def count_oga_tokens(doc_id):
    try:
        with open(os.path.join(sentences_path, doc_id + ".pickle"), "rb") as f:
            sentences_data = pickle.load(f)
        return sum([len(sent[3]) for sent in sentences_data])
    except:
        return None

# %%
oga_metadata["oga_tokencount"] = oga_metadata["doc_id"].apply(count_oga_tokens)

# %%
oga_metadata.columns
# Out:
# Index(['oga_id', 'oga_urn_cts', 'oga_title_labels',
#        'oga_title_from_print_edition', 'oga_print_edition', 'oga_author',
#        'oga_estimated_work_date', 'oga_is_temporary_work_date',
#        'oga_date_source', 'oga_date_source_link', 'oga_comment_on_chronology',
#        'oga_formatted_work_date', 'oga_date_label', 'oga_not_before',
#        'oga_not_after', 'doc_id'],
#       dtype='object')

# %%
oga_metadata = oga_metadata[['oga_id', 'oga_title_labels', 'oga_title_from_print_edition', 'oga_print_edition', 'oga_author', 'oga_date_source', 'oga_date_source_link', 'oga_comment_on_chronology', 'oga_formatted_work_date', 'oga_not_before', 'oga_not_after', 'doc_id', 'oga_tokencount']]

# %% [markdown]
# ## Merge metadata

# %%
from functools import reduce

# %%
dataframes = [LAGT3_metadata, LAGT41_metadata, glaux_metadata, oga_metadata]

# %%
gr_metadata_merged = reduce(lambda left, right: pd.merge(left, right, on="doc_id", how="outer"), dataframes)

# %%
gr_metadata_merged.columns
# Out:
# Index(['doc_id', 'lagt3_lemmata_source', 'lagt3_tokencount', 'lagt4-1_author',
#        'lagt4-1_title', 'lagt4-1_not_before', 'lagt4-1_not_after',
#        'lagt4-1_tlg_epithet', 'lagt4-1_genre', 'lagt4-1_provenience',
#        'lagt4-1_tokencount', 'glaux_GLAUX_TEXT_ID', 'glaux_TLG',
#        'glaux_STARTDATE', 'glaux_ENDDATE', 'glaux_AUTHOR_STANDARD',
#        'glaux_TITLE_STANDARD', 'glaux_GENRE_STANDARD', 'glaux_DIALECT',
#        'glaux_SOURCE', 'glaux_SOURCE_LICENSE', 'glaux_SOURCE_FORMAT',
#        'glaux_TOKENS', 'glaux_TM_TEXT', 'glaux_tlg_id', 'oga_id',
#        'oga_title_labels', 'oga_title_from_print_edition', 'oga_print_edition',
#        'oga_author', 'oga_date_source', 'oga_date_source_link',
#        'oga_comment_on_chronology', 'oga_formatted_work_date',
#        'oga_not_before', 'oga_not_after', 'oga_tokencount'],
#       dtype='object')

# %%
gr_metadata_merged = gr_metadata_merged[[
    'doc_id',
    'lagt4-1_author',
    'glaux_AUTHOR_STANDARD',
    'oga_author',
    'lagt4-1_title',
    'glaux_TITLE_STANDARD',
    'oga_title_labels',
    'oga_title_from_print_edition',
    'lagt4-1_not_before',
    'lagt4-1_not_after',
    'glaux_STARTDATE',
    'glaux_ENDDATE',
    'oga_not_before',
    'oga_not_after',
    'oga_date_source',
    'oga_date_source_link',
    'oga_comment_on_chronology',
    'oga_formatted_work_date',
    'lagt3_tokencount',
    'lagt4-1_tokencount',
    'glaux_TOKENS',
    'oga_tokencount',
    'lagt4-1_tlg_epithet',
    'lagt4-1_genre',
    'glaux_GENRE_STANDARD',
    'glaux_DIALECT',
    'lagt4-1_provenience',
    'glaux_GLAUX_TEXT_ID',
    'glaux_TLG',
    'glaux_SOURCE',
    'glaux_SOURCE_FORMAT',
    'glaux_TM_TEXT',
    'oga_id',
    'oga_print_edition',
]]

# %%
gr_metadata_merged.sample(10)
# Out:
#               doc_id       lagt4-1_author glaux_AUTHOR_STANDARD  \
# 150   tlg0007.tlg022             Plutarch            Plutarchus
# 590   tlg0057.tlg016                Galen               Galenus
# 1683  tlg1799.tlg007               Euclid                   NaN
# 1085  tlg0365.tlg001  Apollodorus Lyricus           Apollodorus
# 1716  tlg2001.tlg040           Themistius                   NaN
# 1256  tlg0552.tlg004            Archimède            Archimedes
# 1186  tlg0537.tlg012             Epicurus                   NaN
# 2034  tlg3129.ogl001                  NaN                   NaN
# 899   tlg0087.tlg007           Herodianus                   NaN
# 561   tlg0035.tlg005              Moschus               Moschus
#
#              oga_author                               lagt4-1_title  \
# 150            Plutarch                                   Μάρκελλος
# 590               Galen                        De uteri dissectione
# 1683             Euclid                                        Data
# 1085                NaN                                   Fragmenta
# 1716         Themistius  In libros Aristotelis de Anima paraphrasis
# 1256         Archimedes                        De lineis spiralibus
# 1186           Epicurus                Epistula Tertia ad Menoeceum
# 2034      Theophylactus                                         NaN
# 899   Aelius Herodianus                      Περὶ Ἰλιακῆς προσῳδίας
# 561             Moschus                                   Fragmenta
#
#       glaux_TITLE_STANDARD                            oga_title_labels  \
# 150              Marcellus                                   Marcellus
# 590   De uteri dissectione                        De uteri dissectione
# 1683                   NaN                                        Data
# 1085            Fragmentum                                         NaN
# 1716                   NaN  In Aristotelis Libros De Anima Paraphrasis
# 1256  De lineis spiralibus                        De lineis spiralibus
# 1186                   NaN                       Epistula ad Menoeceum
# 2034                   NaN    Commentary on St. Cyril In XII Prophetas
# 899                    NaN                      Περὶ Ἰλιακῆς προσῳδίας
# 561              Fragmenta                                   Fragmenta
#
#                            oga_title_from_print_edition  lagt4-1_not_before  \
# 150                                           Marcellus                 1.0
# 590                                De uteri dissectione               101.0
# 1683                                               Data              -300.0
# 1085                                                NaN              -600.0
# 1716         In Aristotelis Libros De Anima Paraphrasis               301.0
# 1256                               De lineis spiralibus              -300.0
# 1186                       Epistula Tertia ad Menoeceum              -400.0
# 2034  Quae Theopylacti, Pro D. Cyrilli Commentariis ...                 NaN
# 899                              Περὶ Ἰλιακῆς προσῳδίας               101.0
# 561                                           Fragmenta              -200.0
#
#       lagt4-1_not_after  ...  glaux_GENRE_STANDARD  glaux_DIALECT  \
# 150               200.0  ...             Biography    Attic/Koine
# 590               200.0  ...              Medicine    Attic/Koine
# 1683             -201.0  ...                   NaN            NaN
# 1085             -501.0  ...          Lyric poetry     Ionic/Epic
# 1716              400.0  ...                   NaN            NaN
# 1256             -201.0  ...           Mathematics          Doric
# 1186             -201.0  ...                   NaN            NaN
# 2034                NaN  ...                   NaN            NaN
# 899               200.0  ...                   NaN            NaN
# 561              -101.0  ...          Lyric poetry          Doric
#
#       lagt4-1_provenience  glaux_GLAUX_TEXT_ID glaux_TLG  \
# 150                 pagan               1075.0  0007-022
# 590                 pagan               1379.0  0057-016
# 1683                pagan                  NaN       NaN
# 1085                pagan                 88.0  0365-001
# 1716                pagan                  NaN       NaN
# 1256                pagan                666.0  0552-004
# 1186                pagan                  NaN       NaN
# 2034                  NaN                  NaN       NaN
# 899                 pagan                  NaN       NaN
# 561                 pagan                762.0  0035-005
#
#               glaux_SOURCE glaux_SOURCE_FORMAT glaux_TM_TEXT  oga_id  \
# 150                Perseus                 XML          5775      52
# 590                First1K                 XML         12536    1101
# 1683                   NaN                 NaN           NaN     898
# 1085  Loeb (public domain)                 TXT         10797     NaN
# 1716                   NaN                 NaN           NaN     924
# 1256               First1K                 XML          5366     680
# 1186                   NaN                 NaN           NaN    1295
# 2034                   NaN                 NaN           NaN    1521
# 899                    NaN                 NaN           NaN     534
# 561                Perseus                 XML         12732    1083
#
#                                       oga_print_edition
# 150   Plutarch. Plutarch's Lives, Vol. V. Perrin, Be...
# 590   Galen, De uteri dissectione, Claudii Galeni Op...
# 1683  Euclid. Euclidis Opera Omnia, Volume 6. Menge,...
# 1085                                                NaN
# 1716  Themistius. Themistii in libros Aristotelis de...
# 1256  Archimedes. Archimède, Volume 2. Mugler, Charl...
# 1186  Epicurus. Epicuri epistulae tres et ratae sent...
# 2034  Quae Theopylacti, Pro D. Cyrilli Commentariis ...
# 899   Aelius Herodianus, Περὶ Ἰλιακῆς προσῳδίας, Gra...
# 561   Moschus. The Greek Bucolic Poets. Edmonds, J. ...
#
# [10 rows x 34 columns]

# %%
set_with_dataframe(lagt_metadata_gs.add_worksheet("gr_metadata_merged", 1, 1), gr_metadata_merged)

# %%
gr_metadata_merged.to_csv("../data/gr_metadata_merged.csv", index=False)
