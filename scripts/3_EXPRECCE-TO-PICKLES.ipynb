# %% [markdown]
# CHANGES:
# - NEW TEXT FILES:
#     * renamed for easier reference; renaming removed the need for a test looking a way to find the doc_id from the filename
#     * added to a project-internal folder, which is more end-user-friendly and allows for checking and troubleshooting this code
# - UPDATED METADATA FILE:
#     * All the relevant metadata now comes directly from the file, no need to reintroduce static data with code on each run.
# - MERGED SCRIPTS:
#     * New approach to LAGT makes a lot of previous code obsolete / unnecessary. Preprocessing was reformulated into a test of text / metadata correspondence and merged into the same file for an easier total run
#     * Combined cells that can run at once to reduce manual running
# - ENHANCED HUMAN-READABILITY:
#     * Re.search made "unsafe" to act as a notification if some filenames are not properly formatted. Renaming made use of rex unnecessary and left the code cleaner.
#     * Removed testing / legacy code; if needed, they can be accessed from earlier versions, being unnecessary in final code.
#     * New markdown cells and comments
# - FUTURE-PROOFING:
#     * More prints to control the workflow in case any changes to the manually added texts or metadata happen
#
# TO BE ADDED:
# - total token counts; the earlier approach based on raw text won't work as the new texts contain section tags

# %%
import os
import re
import shutil
import pickle
import unicodedata
import pandas as pd
from datetime import datetime
import spacy
from spacy.language import Language

# %%
# pip install ipywidgets

#!sudo pip install https://huggingface.co/Jacobo/grc_proiel_trf/resolve/main/grc_proiel_trf-3.7.5-py3-none-any.whl
# pip install https://huggingface.co/Jacobo/grc_proiel_trf/resolve/main/grc_proiel_trf-3.7.5-py3-none-any.whl # If you haven't enabled sudo for the IDE, this seems to work for .venv install

#If it still doesn't work (there were issues in the huggingface release), use GitHub instructions instead: https://github.com/jmyerston/greCy

# %% [markdown]
# # Tokenize & lemmatize EXPRECCE texts

# %% [markdown]
# ## Test that the text files and metadata match (optional; also creates a dataframe with the full texts)

# %%
def load_metadata(path):
    metadata = pd.read_csv(path, sep=",")
    if not metadata.empty:
        print("Metadata dataframe created")
    else:
        print("Metadata dataframe is empty")
    return metadata


def load_texts(path):
    exprecce_texts = []
    succeeded = []
    failed = []

    for fn in os.listdir(path):
        if fn.endswith(".txt"):
            try:
                doc_id = re.search(r"(tlg\d{4}\.tlg\d{3})", fn).group(1)
                file_path = os.path.join(path, fn)  # join dir + filename
                with open(file_path, encoding="utf-8") as f:
                    string = f.read()
                exprecce_texts.append({"doc_id": doc_id, "string": string})
                succeeded.append(doc_id)
            except Exception as e:
                print(f"!!!!!! Error processing {fn}: {e}!!!!!!")

    print(f"\nText dataframe created.\nSuccessfully processed {succeeded}.\n")
    if len(failed) == 0:
        print("All texts processed successfully.")
    else:
        print(f"Failed: {failed}")
    exprecce_texts_df = pd.DataFrame(exprecce_texts)
    return exprecce_texts_df


def merge_data(metadata_df, texts_df):
    """Merge metadata and texts, keep everything, create author_id only if missing"""
    # Outer merge to keep everything
    merged = pd.merge(metadata_df, texts_df, on="doc_id", how="outer")
    merged.sort_values("doc_id", inplace=True)

    # Notify missing text
    missing_texts = merged[merged['string'].isna()]['doc_id'].tolist()
    if missing_texts:
        print(
            f"Warning: {len(missing_texts)} metadata rows have no text: {missing_texts}. Add the missing text file to th folder")
    else:
        print("All the metadata rows have a corresponding text")

    # Notify missing metadata
    missing_metadata = \
    merged[merged['doc_id'].isin(texts_df['doc_id']) & merged['string'].notna() & merged['author_id'].isna()][
        'doc_id'].tolist()
    if missing_metadata:
        print(
            f"Warning: {len(missing_metadata)} text files have no metadata: {missing_metadata}. Add metadata to the medatadata file an run again.")
    else:
        print("All the texts have corresponding metadata rows.")

    # Fill author_id for rows with no metadata using doc_id
    merged['author_id'] = merged['author_id'].fillna(merged['doc_id'].str.split(".").str[0])

    print(f"Merged dataframe has {len(merged)} rows.")
    return merged

### MAIN EXECUTION FOR CHECKIN

# Read EXPRECCE metadata from a manually created .csv file into a dataframe and raw text files into another dataframe
metadata_df = load_metadata("../data/sources/exprecce/exprecce_metadata_v2.csv")
texts_df = load_texts("../data/sources/exprecce/exprecce_raw_data_v2/")

# Merge the dataframes based on doc_id
exprecce_df = merge_data(metadata_df, texts_df)
# Show the result
exprecce_df
# Out:
# Metadata dataframe created
#
# Text dataframe created.
# Successfully processed ['tlg2062.tlg041', 'tlg0304.tlg001', 'tlg3150.tlg002', 'tlg2005.tlg001', 'tlg2062.tlg511', 'tlg2062.tlg043', 'tlg2015.tlg001', 'tlg2062.tlg050', 'tlg0390.tlg001', 'tlg2017.tlg065', 'tlg2012.tlg001', 'tlg0388.tlg004', 'tlg0391.tlg001', 'tlg0389.tlg001', 'tlg2040.tlg035', 'tlg0388.tlg002', 'tlg2011.tlg001', 'tlg2040.tlg034', 'tlg2010.tlg001', 'tlg2798.tlg005', 'tlg5451.tlg001', 'tlg2008.tlg001', 'tlg2007.tlg001', 'tlg0384.tlg002'].
#
# All texts processed successfully.
# All the metadata rows have a corresponding text
# All the texts have corresponding metadata rows.
# Merged dataframe has 24 rows.
#    author_id          doc_id             grela_id  \
# 0    tlg0304  tlg0304.tlg001  lagt_tlg0304.tlg001
# 1    tlg0384  tlg0384.tlg002  lagt_tlg0384.tlg002
# 2    tlg0388  tlg0388.tlg002  lagt_tlg0388.tlg002
# 3    tlg0388  tlg0388.tlg004  lagt_tlg0388.tlg004
# 4    tlg0389  tlg0389.tlg001  lagt_tlg0389.tlg001
# 5    tlg0390  tlg0390.tlg001  lagt_tlg0390.tlg001
# 6    tlg0391  tlg0391.tlg001  lagt_tlg0391.tlg001
# 7    tlg2005  tlg2005.tlg001  lagt_tlg2005.tlg001
# 8    tlg2007  tlg2007.tlg001  lagt_tlg2007.tlg001
# 9    tlg2008  tlg2008.tlg001  lagt_tlg2008.tlg001
# 10   tlg2010  tlg2010.tlg001  lagt_tlg2010.tlg001
# 11   tlg2011  tlg2011.tlg001  lagt_tlg2011.tlg001
# 12   tlg2012  tlg2012.tlg001  lagt_tlg2012.tlg001
# 13   tlg2015  tlg2015.tlg001  lagt_tlg2015.tlg001
# 14   tlg2017  tlg2017.tlg065  lagt_tlg2017.tlg065
# 15   tlg2040  tlg2040.tlg034  lagt_tlg2040.tlg034
# 16   tlg2040  tlg2040.tlg035  lagt_tlg2040.tlg035
# 17   tlg2062  tlg2062.tlg041  lagt_tlg2062.tlg041
# 18   tlg2062  tlg2062.tlg043  lagt_tlg2062.tlg043
# 19   tlg2062  tlg2062.tlg050  lagt_tlg2062.tlg050
# 20   tlg2062  tlg2062.tlg511  lagt_tlg2062.tlg511
# 21   tlg2798  tlg2798.tlg005  lagt_tlg2798.tlg005
# 22   tlg3150  tlg3150.tlg002  lagt_tlg3150.tlg002
# 23   tlg5451  tlg5451.tlg001  lagt_tlg5451.tlg001
#
#                          author  \
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# 5                           NaN
# 6                           NaN
# 7                           NaN
# 8                           NaN
# 9                           NaN
# 10                          NaN
# 11                          NaN
# 12                          NaN
# 13                          NaN
# 14           Gregorius Nyssenus
# 15        Basilius Caesariensis
# 16        Basilius Caesariensis
# 17         Joannes Chrysostomus
# 18         Joannes Chrysostomus
# 19         Joannes Chrysostomus
# 20         Joannes Chrysostomus
# 21  Pseudo-Dionysius Areopagita
# 22                          NaN
# 23                          NaN
#
#                                                 title     raw_date  \
# 0                         Acta et martyrium Apollonii     A.D. 2/4
# 1        Acta Justini et septem sodalium (recensio B)     A.D. 2/3
# 2                                     Martyrium Pauli       A.D. 2
# 3                               Acta Pauli et Theclae       A.D. 2
# 4                                     Martyrium Petri       A.D. 2
# 5    Martyrium sanctorum Carpi, Papyli et Agathonicae       A.D. 2
# 6   Acta Scillitanorum martyrum sive passio Sperat...     A.D. 2-3
# 7             Martyrium Pionii presbyteri et sodalium       A.D. 4
# 8                  Martyrium Potamiaenae et Basilidis  post A.D. 3
# 9                                   Martyrium Cononis  post A.D. 4
# 10                                    Martyrium Dasii  post A.D. 4
# 11      Martyrium Agapae, Irenae, Chionae et sodalium       A.D. 4
# 12                                         Acta Eupli  post A.D. 4
# 13                            Testamentum xl martyrum  post A.D. 4
# 14                                 De sancto Theodoro       A.D. 4
# 15                                In Gordium martyrem       A.D. 4
# 16                In quadraginta martyres Sebastenses       A.D. 4
# 17                      De sancto hieromartyre Babyla     A.D. 4-5
# 18               De sancta Pelagia virgine et martyre     A.D. 4-5
# 19                              De sanctis martyribus     A.D. 4-5
# 20                       In sanctum Julianum martyrem     A.D. 4-5
# 21                               De mystica theologia     A.D. 5-6
# 22                            Martyrium prius Andreae       A.D. 2
# 23  Passio sancti Sabae Gothi (sub auctore Athanar...       A.D. 4
#
#     not_before  not_after                  lagt_genre  \
# 0          101      400.0                    Hagiogr.
# 1          101      300.0                    Hagiogr.
# 2          101      200.0         Apocryph., Hagiogr.
# 3          101      200.0         Apocryph., Hagiogr.
# 4          101      200.0         Apocryph., Hagiogr.
# 5          101      200.0                    Hagiogr.
# 6          101      300.0                    Hagiogr.
# 7          301      400.0                    Hagiogr.
# 8          301        NaN                    Hagiogr.
# 9          401        NaN                    Hagiogr.
# 10         401        NaN                    Hagiogr.
# 11         301      400.0                    Hagiogr.
# 12         401        NaN                    Hagiogr.
# 13         401        NaN                    Hagiogr.
# 14         301      400.0            Encom., Hagiogr.
# 15         301      400.0  Encom., Hagiogr., Homilet.
# 16         301      400.0  Encom., Hagiogr., Homilet.
# 17         301      500.0  Encom., Hagiogr., Homilet.
# 18         301      500.0  Encom., Hagiogr., Homilet.
# 19         301      500.0  Encom., Hagiogr., Homilet.
# 20         301      500.0            Encom., Hagiogr.
# 21         401      600.0                      Theol.
# 22         101      200.0              Acta, Hagiogr.
# 23         301      400.0                    Hagiogr.
#
#                                               edition  \
# 0   Rudolf Knopf, Ausgewählte Märtyrerakten, 3. ne...
# 1   Rudolf Knopf, Ausgewählte Märtyrerakten, 3. ne...
# 2   R.A. Lipsius & Bonnet, M., Acta apostolorum ap...
# 3   R.A. Lipsius & Bonnet, M., Acta apostolorum ap...
# 4   R.A. Lipsius & Bonnet, M., Acta apostolorum ap...
# 5   Rudolf Knopf, Ausgewählte Märtyrerakten, 3. ne...
# 6   J. Armitage Robinson, The Passion of S. Perpet...
# 7   Rudolf Knopf, Ausgewählte Märtyrerakten, 3. ne...
# 8   Rudolf Knopf, Ausgewählte Märtyrerakten, 3. ne...
# 9   Rudolf Knopf, Ausgewählte Märtyrerakten, 3. ne...
# 10  Rudolf Knopf, Ausgewählte Märtyrerakten, 3. ne...
# 11  Rudolf Knopf, Ausgewählte Märtyrerakten, 3. ne...
# 12  Rudolf Knopf, Ausgewählte Märtyrerakten, 3. ne...
# 13  Rudolf Knopf, Ausgewählte Märtyrerakten, 3. ne...
# 14  J.-P. Migne, Patrologiæ cursus completus: Patr...
# 15  J.-P. Migne, Patrologiæ cursus completus: Patr...
# 16  J.-P. Migne, Patrologiæ cursus completus: Patr...
# 17  J.-P. Migne, Patrologiæ cursus completus: Patr...
# 18  J.-P. Migne, Patrologiæ cursus completus: Patr...
# 19  J.-P. Migne, Patrologiæ cursus completus: Patr...
# 20  J.-P. Migne, Patrologiæ cursus completus: Patr...
# 21  J.-P. Migne, Patrologiæ cursus completus: Patr...
# 22  Tischendorf, C., Acta apostolorvm apocrypha, e...
# 23  Rudolf Knopf, Ausgewählte Märtyrerakten, 3. ne...
#
#                                          edition_link lagt_provenience  \
# 0   https://archive.org/details/ausgewahltemarty00...        christian
# 1   https://archive.org/details/ausgewahltemarty00...        christian
# 2   https://archive.org/details/ntapoc-acta-aposto...        christian
# 3   https://archive.org/details/ntapoc-acta-aposto...        christian
# 4   https://archive.org/details/ntapoc-acta-aposto...        christian
# 5   https://archive.org/details/ausgewahltemarty00...        christian
# 6   https://archive.org/details/MN5140ucmf_2/page/...        christian
# 7   https://archive.org/details/ausgewahltemarty00...        christian
# 8   https://archive.org/details/ausgewahltemarty00...        christian
# 9   https://archive.org/details/ausgewahltemarty00...        christian
# 10  https://archive.org/details/ausgewahltemarty00...        christian
# 11  https://archive.org/details/ausgewahltemarty00...        christian
# 12  https://archive.org/details/ausgewahltemarty00...        christian
# 13  https://archive.org/details/ausgewahltemarty00...        christian
# 14  https://archive.org/details/patrologia-volumes...        christian
# 15  https://archive.org/details/patrologia-volumes...        christian
# 16  https://archive.org/details/patrologia-volumes...        christian
# 17  https://archive.org/details/patrologia-volumes...        christian
# 18  https://archive.org/details/patrologia-volumes...        christian
# 19  https://archive.org/details/patrologia-volumes...        christian
# 20  https://archive.org/details/patrologia-volumes...        christian
# 21  https://archive.org/details/patrologia-volumes...        christian
# 22  https://archive.org/details/actaapostolorvm02t...        christian
# 23  https://archive.org/details/ausgewahltemarty00...        christian
#
#    textsource grela_source                                             string
# 0    exprecce         lagt  Μαρτύριον τοῦ ἁγίου καὶ πανευφήμου ἀποστόλου Ἀ...
# 1    exprecce         lagt  Μαρτύριον τῶν ἁγίων μαρτύρων Ἰουστίνου, Χαρίτω...
# 2    exprecce         lagt  Μαρτύριον τοῦ ἁγίου ἀποστόλου Παύλου. <1>  Ἦσα...
# 3    exprecce         lagt  Πράξεις Παύλου καὶ Θέκλης. <1> Ἀναβαίνοντος Πα...
# 4    exprecce         lagt  Μαρτύριον τοῦ ἁγίου ἀποστόλου Πέτρου. <1> Κυρι...
# 5    exprecce         lagt  Μαρτύριον τῶν ἁγίων Κάρπου Παπύλου καὶ Ἀγαθονί...
# 6    exprecce         lagt  ΜΑΡΤΥΡΙΟΝ ΤΟΥ ΑΓΙΟΥ ΚΑΙ ΚΑΛΛΙΝΙΚΟΥ ΜΑΡΤΥΡΟΣ ΣΠ...
# 7    exprecce         lagt  Μαρτύριον τοῦ ἁγίου Πιονίου τοῦ πρεσβυτέρου κα...
# 8    exprecce         lagt  Ἕβδομος ἐν τούτοις ἀριθμείσθω Βασιλείδης, τὴν ...
# 9    exprecce         lagt  <1.1> Πάλιν ὦ τῆς δυσσεβοῦς κρίσεως. Μετὰ τὸ τ...
# 10   exprecce         lagt  Μαρτύριον τοῦ ἁγίου Δασίου. Κύριε εὐλόγησον. <...
# 11   exprecce         lagt  Μαρτύριον τῶν ἁγίων Ἀγάπης, Εἰρήνης καὶ Χιόνης...
# 12   exprecce         lagt  <1.1> Τοῖς κυρίοις ἡμῶν Διοκλιτιανῷ τὸ ἔννατον...
# 13   exprecce         lagt  ΔΙΑΘΗΚΗ τῶν ἁγίων καὶ ἐνδόξων τοῦ Χριστοῦ τεσσ...
# 14   exprecce         lagt  Ὑμεῖς ὁ τοῦ Χριστοῦ λαὸς, ἡ ἁγία ποίμνη, τὸ βα...
# 15   exprecce         lagt  Εἰς Γόρδιον τὸν μάρτυρα. <1> Νόμος ἐστὶ φύσεως...
# 16   exprecce         lagt  Εἰς τοὺς ἀγίους τεσσαράκοντα μαρτυρας. <1> Μαρ...
# 17   exprecce         lagt  ΕΙΣ ΤΟΝ ΑΓΙΟΝ ΙΕΡΟΜΑΤΥΡΑ ΒΑΒΥΛΑΝ. <1> Ἐγὼ μὲν ...
# 18   exprecce         lagt  ΟΜΙΛΛΙΑ ΕΓΚΩΜΙΑΣΤΙΚΕ Εἰς τὴν ἁγίαν μάρτυρα Πελ...
# 19   exprecce         lagt  Άπελθόντος τοῦ έπισκόπου μαρτύρων ἡμέρα ἐν τῇ ...
# 20   exprecce         lagt  ΕΓΚΟΜΙΟΝ ΕΙΣ ΤΟΝ ΑΓΙΟΝ ΜΑΡΤΥΡΑ ΙΟΥΛΙΑΝΟΝ. <1> ...
# 21   exprecce         lagt  <1.0> Τίς ὁ θεῖος γνόφος. <1.1> Τριὰς ὑπερούσι...
# 22   exprecce         lagt  Μαρτύριον τοῦ ἁγίου Ἀνδρέου τοῦ ἀποστόλου. <1>...
# 23   exprecce         lagt  Μαρτύριον τοῦ ἁγίου Σάβα τοῦ Γότθου. Ἡ ἐκκλησί...

# %% [markdown]
# ## Process the text files into .pickles

# %%
### LOAD NLP MODEL AND DEFINE A CUSTOM SENTENCIZER
nlp = spacy.load('grc_proiel_trf')
nlp.disable_pipe("parser")

@Language.component("custom_sentencizer")
def custom_sentencizer(doc, max_words=11):
    strong_punct = {".", "!", "?", ";", "·"}
    for token in doc:
        token.is_sent_start = False
    start = 0
    for i, token in enumerate(doc):
        if token.text in strong_punct:
            if i + 1 < len(doc):
                doc[i + 1].is_sent_start = True
            start = i + 1
        elif token.text == "," and i + 1 < len(doc):
            nxt1 = doc[i + 1]
            nxt2 = doc[i + 2] if i + 2 < len(doc) else None
            trigger1 = nxt1.pos_ in {"CCONJ", "SCONJ", "ADP"}
            trigger2 = nxt2.pos_ in {"CCONJ"} if nxt2 else False
            if trigger1 or trigger2:
                current_len = i - start + 1
                if current_len >= max_words:
                    doc[i + 1].is_sent_start = True
                    start = i + 1
                    continue
                j = i + 1
                while j < len(doc) and not (
                        doc[j].text in strong_punct or
                        (doc[j].text == "," and j + 1 < len(doc) and doc[j + 1].pos_ in {"CCONJ", "SCONJ"})
                ):
                    j += 1
                if j - start >= max_words:
                    doc[i + 1].is_sent_start = True
                    start = i + 1
    return doc

nlp.add_pipe("custom_sentencizer", after="tagger")
print("NLP model loaded and custom sentencizer added")
spacy.__version__
# Out:
# NLP model loaded and custom sentencizer added
# '3.8.7'

# %%
### DEFINITIONS & FUNCTIONS

_PUNCT = ".,;:!?··’'" # Punctuation to preserve
_ALLOWED_BLOCKS = r"\u0370-\u03FF\u1F00-\u1FFF\u0300-\u036F" # Greek & Coptic + Greek Extended + Combining Diacritics
_EXTRA_GREEK = r"\u1FBD\u0374\u0375" # Optional extra Greek marks (safe to keep)
_CTRL_FMT = re.compile(r"[\u0000-\u001F\u007F-\u009F\u200B\u200C\u200D\u2060\uFEFF]") # Remove controls/format chars (keeps normal space)
_REMOVE_DISALLOWED = re.compile(rf"[^{_ALLOWED_BLOCKS}{_EXTRA_GREEK} {re.escape(_PUNCT)}]") # Allow-list removal: keep Greek blocks + extra marks + ASCII space + chosen punctuation
_COLLAPSE_SPACES = re.compile(r" +") # Collapse runs of spaces
_WORDCHAR = r"A-Za-z0-9\u0370-\u03FF\u1F00-\u1FFF" # Treat "word char" here as: ASCII letters/digits + Greek ranges
_FINAL_POS = re.compile(rf"ϲ(?=[^{_WORDCHAR}]|$)") # Use the word-final class for deciding final sigma after lunate sigma


def grave_to_acute(string: str) -> str:
    grave = "\u0300"
    acute = "\u0301"
    nfd = unicodedata.normalize("NFD", string or "")
    return unicodedata.normalize("NFC", nfd.replace(grave, acute))


def clean_string(string: str) -> str:
    s = unicodedata.normalize("NFC", string) # Normalize to NFC
    s = grave_to_acute(s) # Map grave → acute (polytonic consistency)
    s = _FINAL_POS.sub("ς", s)  # Normalize lunate sigma ϲ: final ϲ → ς
    s = s.replace("ϲ", "σ") # Remaining ϲ → σ
    s = s.replace(", —", ", ").replace(", –", ", ").replace(". —", ". ").replace(". –", "-, ") # Replace dashes with space (we don't keep dashes in punctuation allow-list)
    s = s.replace("—", " ").replace("–", " ") # Replace remaining dashes with comma, as they ase used as such in some texts
    s = s.replace("...", ".") # Make starts of lacunae etc. into sentence ends
    s = s.replace(".,", ",") # Correct artefacts from the previous step
    s = _CTRL_FMT.sub("", s)  # Drop control/format codepoints, keep ordinary space
    s = _REMOVE_DISALLOWED.sub(" ", s)# Allow-list: keep only Greek blocks + combining + extra marks + chosen punctuation + space
    s = _COLLAPSE_SPACES.sub(" ", s).strip() # Collapse multiple spaces
    s = re.sub(r"\s+([.,;:!?··])", r"\1", s) # Remove possible spaces before punctuation
    s = s.replace("·", ".").replace("·", ".") # Normalize Greek middle dot / ano teleia to period
    return s


def split_text_by_divisions(raw_text):
    matches = list(re.finditer(r"<([^>]+)>", raw_text))
    chunks = []
    last_pos = 0
    last_div = 0  # text before first tag
    for m in matches:
        text_chunk = raw_text[last_pos:m.start()]
        chunks.append((last_div, text_chunk))
        last_div = m.group(1)
        last_pos = m.end()

    # remaining text after last tag
    chunks.append((last_div, raw_text[last_pos:]))
    return chunks


# Function to process a single text and write pickle
def data_to_pickles(doc_id, raw_text, target_path):
    all_sentences = []
    sent_counter = 0  # global sentence index

    # Split into division chunks
    chunks = split_text_by_divisions(raw_text)
    for division_number, chunk_text in chunks:
        cleaned_chunk = clean_string(chunk_text)
        if not cleaned_chunk.strip():
            continue
        doc = nlp(cleaned_chunk)
        for sent in doc.sents:
            token_data = [
                (t.text, t.lemma_.lower(), t.pos_, {"div": division_number}, t.idx - sent[0].idx, t.idx - sent[0].idx + len(t))
                for t in sent
            ]
            all_sentences.append((doc_id, sent_counter, sent.text, token_data))
            sent_counter += 1

    # Save pickle
    with open(os.path.join(target_path, doc_id + ".pickle"), "wb") as f:
        pickle.dump(all_sentences, f)

def process_txt_files(target_path):
    # Process files directly from .txt
    raw_path = "../data/sources/exprecce/exprecce_raw_data_v2/"
    os.makedirs(target_path, exist_ok=True)

    succeeded = []
    failed = []

    for fn in os.listdir(raw_path):
        if not fn.endswith(".txt"):
            continue
        try:
            doc_id = re.search(r"(tlg\d{4}\.tlg\d{3})", fn).group(1)
            with open(os.path.join(raw_path, fn), encoding="utf-8") as f:
                raw_text = f.read()
            data_to_pickles(doc_id, raw_text, target_path)
            succeeded.append(doc_id)
        except Exception as e:
            print(f"Error processing {fn}: {e}")
            failed.append(fn)

    print(f"Processed successfully into pickles: {succeeded}")
    if failed:
        print(f"Failed: {failed}")

# %%
### MAIN EXECUTION
target_path = "../data/output/exprecce/pickles"
process_txt_files(target_path)
# Out:
# Processed successfully into pickles: ['tlg2062.tlg041', 'tlg0304.tlg001', 'tlg3150.tlg002', 'tlg2005.tlg001', 'tlg2062.tlg511', 'tlg2062.tlg043', 'tlg2015.tlg001', 'tlg2062.tlg050', 'tlg0390.tlg001', 'tlg2017.tlg065', 'tlg2012.tlg001', 'tlg0388.tlg004', 'tlg0391.tlg001', 'tlg0389.tlg001', 'tlg2040.tlg035', 'tlg0388.tlg002', 'tlg2011.tlg001', 'tlg2040.tlg034', 'tlg2010.tlg001', 'tlg2798.tlg005', 'tlg5451.tlg001', 'tlg2008.tlg001', 'tlg2007.tlg001', 'tlg0384.tlg002']

# %%
# Source and destination directories
src_dir = "../data/output/exprecce/pickles/"
dst_dir = "/srv/data/greek/exprecce_sentences_2025-10/"

# Create destination directory if it doesn't exist
os.makedirs(dst_dir, exist_ok=True)

# Copy all contents (files + subfolders)
for item in os.listdir(src_dir):
    s = os.path.join(src_dir, item)
    d = os.path.join(dst_dir, item)
    if os.path.isdir(s):
        shutil.copytree(s, d, dirs_exist_ok=True)
    else:
        shutil.copy2(s, d)

print(os.listdir(dst_dir))
print("✅ All files copied successfully!")
# Out:
# ['tlg0389.tlg001.pickle', 'tlg2062.tlg050.pickle', 'tlg2017.tlg065.pickle', 'tlg2012.tlg001.pickle', 'tlg0304.tlg001.pickle', 'tlg2798.tlg005.pickle', 'tlg0388.tlg002.pickle', 'tlg2062.tlg043.pickle', 'tlg2010.tlg001.pickle', 'tlg2008.tlg001.pickle', 'tlg2062.tlg041.pickle', 'tlg0391.tlg001.pickle', 'tlg2007.tlg001.pickle', 'tlg0384.tlg002.pickle', 'tlg2011.tlg001.pickle', 'tlg2005.tlg001.pickle', 'tlg2062.tlg511.pickle', 'tlg2040.tlg035.pickle', 'tlg2040.tlg034.pickle', 'tlg5451.tlg001.pickle', 'tlg3150.tlg002.pickle', 'tlg2015.tlg001.pickle', 'tlg0388.tlg004.pickle', 'tlg0390.tlg001.pickle']
# ✅ All files copied successfully!

# %%
with open(os.path.join(dst_dir + "tlg0389.tlg001.pickle"), "rb") as f:
    sent_data = pickle.load(f)
sent_data[:10]
# Out:
# [('tlg0389.tlg001',
#   0,
#   'Μαρτύριον τοῦ ἁγίου ἀποστόλου Πέτρου.',
#   [('Μαρτύριον', 'μαρτύριος', 'NOUN', {'div': 0}, 0, 9),
#    ('τοῦ', 'ὁ', 'DET', {'div': 0}, 10, 13),
#    ('ἁγίου', 'ἅγιος', 'ADJ', {'div': 0}, 14, 19),
#    ('ἀποστόλου', 'ἀποστόλου', 'NOUN', {'div': 0}, 20, 29),
#    ('Πέτρου', 'πέτρος', 'PROPN', {'div': 0}, 30, 36),
#    ('.', '.', 'PUNCT', {'div': 0}, 36, 37)]),
#  ('tlg0389.tlg001',
#   1,
#   'Κυριακῆς οὔσης, ὁμιλοῦντος τοῦ Πέτρου τοῖς ἀδελφοῖς,',
#   [('Κυριακῆς', 'κυριακός', 'ADJ', {'div': '1'}, 0, 8),
#    ('οὔσης', 'εἰμί', 'AUX', {'div': '1'}, 9, 14),
#    (',', ',', 'PUNCT', {'div': '1'}, 14, 15),
#    ('ὁμιλοῦντος', 'ὁμιλοῦντος', 'VERB', {'div': '1'}, 16, 26),
#    ('τοῦ', 'ὁ', 'DET', {'div': '1'}, 27, 30),
#    ('Πέτρου', 'πέτρος', 'PROPN', {'div': '1'}, 31, 37),
#    ('τοῖς', 'ὁ', 'DET', {'div': '1'}, 38, 42),
#    ('ἀδελφοῖς', 'ἀδελφός', 'NOUN', {'div': '1'}, 43, 51),
#    (',', ',', 'PUNCT', {'div': '1'}, 51, 52)]),
#  ('tlg0389.tlg001',
#   2,
#   'καί προτρέποντος εἰς τήν τοῦ Χριστοῦ πίστιν, παρόντων πολλῶν συγκλητικῶν καί ἱππικῶν πλειόνων καί γυναικῶν πλουσίων καί ματρωνῶν καί στηριζομένων τῇ πίστει, μία τις ἔνθα οὖσα γυνή πάνυ πλουσία, ἥτις τήν ἐπίκλησιν τοὔνομα Χρυσή εἶχεν,',
#   [('καί', 'καί', 'CCONJ', {'div': '1'}, 0, 3),
#    ('προτρέποντος', 'προτρέπω', 'VERB', {'div': '1'}, 4, 16),
#    ('εἰς', 'εἰς', 'ADP', {'div': '1'}, 17, 20),
#    ('τήν', 'ὁ', 'DET', {'div': '1'}, 21, 24),
#    ('τοῦ', 'ὁ', 'DET', {'div': '1'}, 25, 28),
#    ('Χριστοῦ', 'χριστός', 'PROPN', {'div': '1'}, 29, 36),
#    ('πίστιν', 'πίστις', 'NOUN', {'div': '1'}, 37, 43),
#    (',', ',', 'PUNCT', {'div': '1'}, 43, 44),
#    ('παρόντων', 'πάρειμι', 'VERB', {'div': '1'}, 45, 53),
#    ('πολλῶν', 'πολύς', 'ADJ', {'div': '1'}, 54, 60),
#    ('συγκλητικῶν', 'συγκλητικός', 'ADJ', {'div': '1'}, 61, 72),
#    ('καί', 'καί', 'CCONJ', {'div': '1'}, 73, 76),
#    ('ἱππικῶν', 'ἱππικός', 'ADJ', {'div': '1'}, 77, 84),
#    ('πλειόνων', 'πολύς', 'ADJ', {'div': '1'}, 85, 93),
#    ('καί', 'καί', 'CCONJ', {'div': '1'}, 94, 97),
#    ('γυναικῶν', 'γυνή', 'NOUN', {'div': '1'}, 98, 106),
#    ('πλουσίων', 'πλούσιος', 'ADJ', {'div': '1'}, 107, 115),
#    ('καί', 'καί', 'CCONJ', {'div': '1'}, 116, 119),
#    ('ματρωνῶν', 'ματρωνός', 'NOUN', {'div': '1'}, 120, 128),
#    ('καί', 'καί', 'CCONJ', {'div': '1'}, 129, 132),
#    ('στηριζομένων', 'στηριζομένω', 'VERB', {'div': '1'}, 133, 145),
#    ('τῇ', 'ὁ', 'DET', {'div': '1'}, 146, 148),
#    ('πίστει', 'πίστις', 'NOUN', {'div': '1'}, 149, 155),
#    (',', ',', 'PUNCT', {'div': '1'}, 155, 156),
#    ('μία', 'εἷς', 'NUM', {'div': '1'}, 157, 160),
#    ('τις', 'τίς', 'DET', {'div': '1'}, 161, 164),
#    ('ἔνθα', 'ἔνθα', 'ADV', {'div': '1'}, 165, 169),
#    ('οὖσα', 'εἰμί', 'AUX', {'div': '1'}, 170, 174),
#    ('γυνή', 'γυνή', 'NOUN', {'div': '1'}, 175, 179),
#    ('πάνυ', 'πάνυ', 'ADV', {'div': '1'}, 180, 184),
#    ('πλουσία', 'πλούσιος', 'ADJ', {'div': '1'}, 185, 192),
#    (',', ',', 'PUNCT', {'div': '1'}, 192, 193),
#    ('ἥτις', 'ὅστις', 'PRON', {'div': '1'}, 194, 198),
#    ('τήν', 'ὁ', 'DET', {'div': '1'}, 199, 202),
#    ('ἐπίκλησιν', 'ἐπίκλησις', 'NOUN', {'div': '1'}, 203, 212),
#    ('τοὔ', 'τοὔ', 'NOUN', {'div': '1'}, 213, 216),
#    ('νομα', 'νομα', 'NOUN', {'div': '1'}, 216, 220),
#    ('Χρυσή', 'χρυσή', 'ADJ', {'div': '1'}, 221, 226),
#    ('εἶχεν', 'ἔχω', 'VERB', {'div': '1'}, 227, 232),
#    (',', ',', 'PUNCT', {'div': '1'}, 232, 233)]),
#  ('tlg0389.tlg001',
#   3,
#   'διά τό πᾶν αὐτῆς σκεῦος χρύσεον ὑπάρχειν ἥτις γεννηθεῖσα οὔτε ἀργυρέῳ ποτέ σκεύει ἐχρήσατο οὔτε ὑελῷ, εἰ μή μόνοις χρυσέοις εἶπεν τῷ Πέτρῳ.',
#   [('διά', 'διά', 'ADP', {'div': '1'}, 0, 3),
#    ('τό', 'ὁ', 'DET', {'div': '1'}, 4, 6),
#    ('πᾶν', 'πᾶς', 'DET', {'div': '1'}, 7, 10),
#    ('αὐτῆς', 'αὐτός', 'PRON', {'div': '1'}, 11, 16),
#    ('σκεῦος', 'σκεῦος', 'NOUN', {'div': '1'}, 17, 23),
#    ('χρύσεον', 'χρύσεος', 'ADJ', {'div': '1'}, 24, 31),
#    ('ὑπάρχειν', 'ὑπάρχω', 'VERB', {'div': '1'}, 32, 40),
#    ('ἥτις', 'ὅστις', 'PRON', {'div': '1'}, 41, 45),
#    ('γεννηθεῖσα', 'γεννάω', 'VERB', {'div': '1'}, 46, 56),
#    ('οὔτε', 'οὔτε', 'CCONJ', {'div': '1'}, 57, 61),
#    ('ἀργυρέῳ', 'ἀργύρεος', 'ADJ', {'div': '1'}, 62, 69),
#    ('ποτέ', 'ποτε', 'ADV', {'div': '1'}, 70, 74),
#    ('σκεύει', 'σκεῦος', 'NOUN', {'div': '1'}, 75, 81),
#    ('ἐχρήσατο', 'χράω', 'VERB', {'div': '1'}, 82, 90),
#    ('οὔτε', 'οὔτε', 'CCONJ', {'div': '1'}, 91, 95),
#    ('ὑελῷ', 'ὑελῷς', 'NOUN', {'div': '1'}, 96, 100),
#    (',', ',', 'PUNCT', {'div': '1'}, 100, 101),
#    ('εἰ', 'εἰ', 'ADV', {'div': '1'}, 102, 104),
#    ('μή', 'μή', 'ADV', {'div': '1'}, 105, 107),
#    ('μόνοις', 'μόνος', 'ADJ', {'div': '1'}, 108, 114),
#    ('χρυσέοις', 'χρύσεος', 'ADJ', {'div': '1'}, 115, 123),
#    ('εἶπεν', 'λέγω', 'VERB', {'div': '1'}, 124, 129),
#    ('τῷ', 'ὁ', 'DET', {'div': '1'}, 130, 132),
#    ('Πέτρῳ', 'πέτρος', 'PROPN', {'div': '1'}, 133, 138),
#    ('.', '.', 'PUNCT', {'div': '1'}, 138, 139)]),
#  ('tlg0389.tlg001',
#   4,
#   'Πέτρε, θεοῦ δοῦλε.',
#   [('Πέτρε', 'πέτρος', 'PROPN', {'div': '1'}, 0, 5),
#    (',', ',', 'PUNCT', {'div': '1'}, 5, 6),
#    ('θεοῦ', 'θεός', 'NOUN', {'div': '1'}, 7, 11),
#    ('δοῦλε', 'δοῦλος', 'NOUN', {'div': '1'}, 12, 17),
#    ('.', '.', 'PUNCT', {'div': '1'}, 17, 18)]),
#  ('tlg0389.tlg001',
#   5,
#   'εἰς ὄναρ ἐμοί παραστάς ὅν λέγεις θεόν εἶπεν.',
#   [('εἰς', 'εἰς', 'ADP', {'div': '1'}, 0, 3),
#    ('ὄναρ', 'ὄναρ', 'NOUN', {'div': '1'}, 4, 8),
#    ('ἐμοί', 'ἐγώ', 'PRON', {'div': '1'}, 9, 13),
#    ('παραστάς', 'παρίστημι', 'VERB', {'div': '1'}, 14, 22),
#    ('ὅν', 'ὅς', 'PRON', {'div': '1'}, 23, 25),
#    ('λέγεις', 'λέγω', 'VERB', {'div': '1'}, 26, 32),
#    ('θεόν', 'θεός', 'NOUN', {'div': '1'}, 33, 37),
#    ('εἶπεν', 'λέγω', 'VERB', {'div': '1'}, 38, 43),
#    ('.', '.', 'PUNCT', {'div': '1'}, 43, 44)]),
#  ('tlg0389.tlg001',
#   6,
#   'Χρυσή, Πέτρῳ τῷ διακόνῳ μου ἀποκόμισον μυρίους χρυσίνους.',
#   [('Χρυσή', 'χρυσή', 'ADJ', {'div': '1'}, 0, 5),
#    (',', ',', 'PUNCT', {'div': '1'}, 5, 6),
#    ('Πέτρῳ', 'πέτρος', 'PROPN', {'div': '1'}, 7, 12),
#    ('τῷ', 'ὁ', 'DET', {'div': '1'}, 13, 15),
#    ('διακόνῳ', 'διακόνος', 'NOUN', {'div': '1'}, 16, 23),
#    ('μου', 'ἐγώ', 'PRON', {'div': '1'}, 24, 27),
#    ('ἀποκόμισον', 'ἀποκόμισος', 'VERB', {'div': '1'}, 28, 38),
#    ('μυρίους', 'μυρίος', 'NUM', {'div': '1'}, 39, 46),
#    ('χρυσίνους', 'χρυσίνος', 'NOUN', {'div': '1'}, 47, 56),
#    ('.', '.', 'PUNCT', {'div': '1'}, 56, 57)]),
#  ('tlg0389.tlg001',
#   7,
#   'ὀφείλεις γάρ αὐτῷ.',
#   [('ὀφείλεις', 'ὀφείλω', 'VERB', {'div': '1'}, 0, 8),
#    ('γάρ', 'γάρ', 'ADV', {'div': '1'}, 9, 12),
#    ('αὐτῷ', 'αὐτός', 'PRON', {'div': '1'}, 13, 17),
#    ('.', '.', 'PUNCT', {'div': '1'}, 17, 18)]),
#  ('tlg0389.tlg001',
#   8,
#   'ἐκόμισα οὖν φοβουμένη,',
#   [('ἐκόμισα', 'κομίζω', 'VERB', {'div': '1'}, 0, 7),
#    ('οὖν', 'οὖν', 'ADV', {'div': '1'}, 8, 11),
#    ('φοβουμένη', 'φοβέω', 'VERB', {'div': '1'}, 12, 21),
#    (',', ',', 'PUNCT', {'div': '1'}, 21, 22)]),
#  ('tlg0389.tlg001',
#   9,
#   'μήτε κακόν πάθω ὑπό τοῦ ὀφθέντος μοι,',
#   [('μήτε', 'μήτε', 'CCONJ', {'div': '1'}, 0, 4),
#    ('κακόν', 'κακός', 'ADJ', {'div': '1'}, 5, 10),
#    ('πάθω', 'πάσχω', 'VERB', {'div': '1'}, 11, 15),
#    ('ὑπό', 'ὑπό', 'ADP', {'div': '1'}, 16, 19),
#    ('τοῦ', 'ὁ', 'DET', {'div': '1'}, 20, 23),
#    ('ὀφθέντος', 'ὀφθέντος', 'VERB', {'div': '1'}, 24, 32),
#    ('μοι', 'ἐγώ', 'PRON', {'div': '1'}, 33, 36),
#    (',', ',', 'PUNCT', {'div': '1'}, 36, 37)])]

# %% [markdown]
# ### EXTRA: Dataframe with metadata from the pickles

# %%
# Build final sentence dataframe from pickles & merge metadata
def build_df_from_pickles(source_path, target_path):
    records = []
    for fname in sorted(os.listdir(source_path)):
        if not fname.endswith(".pickle"):
            continue
        with open(os.path.join(source_path, fname), "rb") as f:
            sent_data = pickle.load(f)
        for doc_id, sent_id, sent_text, token_data in sent_data:
            records.append({
                "doc_id": doc_id,
                "sentence_id": f"lagt_{doc_id}_{sent_id}",
                "position": sent_id,
                "text": sent_text,
                "tokens": token_data,
                "sentence_token_count": len(token_data),
            })

    # Load metadata and make a dataframe from the pickle info
    metadata_df = pd.read_csv("../data/sources/exprecce/exprecce_metadata_v2.csv", sep=",")
    if metadata_df.empty:
        raise ValueError("Metadata dataframe is empty")
    print(f"Metadata loaded: {len(metadata_df)} rows")
    df_sentences = pd.DataFrame(records)

    # Merge and reorder
    metadata_cols = [c for c in metadata_df.columns if c != "string"]
    df_merged = df_sentences.merge(metadata_df[metadata_cols], on="doc_id", how="left")
    newcolumns = ["author_id", "doc_id", "grela_id", "sentence_id", "position", "text", "tokens", "sentence_token_count", "author", "title", "raw_date", "not_before", "not_after", "lagt_genre", "lagt_provenience", "grela_source", "textsource", "edition", "edition_link"]
    df_merged = df_merged[newcolumns]

    # Save final CSV
    date = datetime.now().strftime("%Y%m%d_%H%M")
    df_sentences.to_csv(os.path.join(target_path, f"exprecce_sentences_{date}.csv"), index=True)
    df_merged.to_csv(os.path.join(target_path, f"exprecce_complete_{date}.csv"), index=True)
    return df_merged

# %%
################
# MAIN EXECUTION
################
source_path = "../data/output/exprecce/pickles"
target_path = "../data/output/exprecce/"
os.makedirs(target_path, exist_ok=True)
df_merged = build_df_from_pickles(source_path, target_path)

# Preview
print(f"Total sentences processed: {len(df_merged)}")
df_merged
# Out:
# Metadata loaded: 24 rows
# Total sentences processed: 5002
#      author_id          doc_id             grela_id              sentence_id  \
# 0      tlg0304  tlg0304.tlg001  lagt_tlg0304.tlg001    lagt_tlg0304.tlg001_0
# 1      tlg0304  tlg0304.tlg001  lagt_tlg0304.tlg001    lagt_tlg0304.tlg001_1
# 2      tlg0304  tlg0304.tlg001  lagt_tlg0304.tlg001    lagt_tlg0304.tlg001_2
# 3      tlg0304  tlg0304.tlg001  lagt_tlg0304.tlg001    lagt_tlg0304.tlg001_3
# 4      tlg0304  tlg0304.tlg001  lagt_tlg0304.tlg001    lagt_tlg0304.tlg001_4
# ...        ...             ...                  ...                      ...
# 4997   tlg5451  tlg5451.tlg001  lagt_tlg5451.tlg001  lagt_tlg5451.tlg001_133
# 4998   tlg5451  tlg5451.tlg001  lagt_tlg5451.tlg001  lagt_tlg5451.tlg001_134
# 4999   tlg5451  tlg5451.tlg001  lagt_tlg5451.tlg001  lagt_tlg5451.tlg001_135
# 5000   tlg5451  tlg5451.tlg001  lagt_tlg5451.tlg001  lagt_tlg5451.tlg001_136
# 5001   tlg5451  tlg5451.tlg001  lagt_tlg5451.tlg001  lagt_tlg5451.tlg001_137
#
#       position                                               text  \
# 0            0  Μαρτύριον τοῦ ἁγίου καί πανευφήμου ἀποστόλου Ἀ...
# 1            1  Ἐπί Κομόδου βασιλέως γεναμένου διωγμοῦ κατά τῶ...
# 2            2  Ἀπολλώς δέ ὁ ἀπόστολος, ἀνήρ ὤν εὐλαβής, Ἀλεξα...
# 3            3      Οὗ προσαχθέντος, Περέννιος ὁ ἀνθύπατος εἶπεν.
# 4            4                             Ἀπολλώ, Χριστιανός εἶ;
# ...        ...                                                ...
# 4997       133  τῷ δέ δυναμένῳ πάντας ἡμᾶς εἰσαγαγεῖν τῇ ἑαυτο...
# 4998       134                                              δόξα,
# 4999       135                                              τιμή,
# 5000       136                                κράτος, μεγαλωσύνη,
# 5001       137  σύν παιδί μονογενεῖ καί ἁγίῳ πνεύματι εἰς τούς...
#
#                                                  tokens  sentence_token_count  \
# 0     [(Μαρτύριον, μαρτύριος, NOUN, {'div': 0}, 0, 9...                    12
# 1     [(Ἐπί, ἐπί, ADP, {'div': 0}, 0, 3), (Κομόδου, ...                    16
# 2     [(Ἀπολλώς, ἀπολλώς, PROPN, {'div': 0}, 0, 7), ...                    20
# 3     [(Οὗ, ὅς, PRON, {'div': '1'}, 0, 2), (προσαχθέ...                     8
# 4     [(Ἀπολλώ, ἀπολλώ, PROPN, {'div': '1'}, 0, 6), ...                     5
# ...                                                 ...                   ...
# 4997  [(τῷ, ὁ, DET, {'div': '8.4'}, 0, 2), (δέ, δέ, ...                    16
# 4998  [(δόξα, δόξα, NOUN, {'div': '8.4'}, 0, 4), (,,...                     2
# 4999  [(τιμή, τιμή, NOUN, {'div': '8.4'}, 0, 4), (,,...                     2
# 5000  [(κράτος, κράτος, NOUN, {'div': '8.4'}, 0, 6),...                     4
# 5001  [(σύν, σύν, ADP, {'div': '8.4'}, 0, 3), (παιδί...                    14
#
#      author                                              title  raw_date  \
# 0       NaN                        Acta et martyrium Apollonii  A.D. 2/4
# 1       NaN                        Acta et martyrium Apollonii  A.D. 2/4
# 2       NaN                        Acta et martyrium Apollonii  A.D. 2/4
# 3       NaN                        Acta et martyrium Apollonii  A.D. 2/4
# 4       NaN                        Acta et martyrium Apollonii  A.D. 2/4
# ...     ...                                                ...       ...
# 4997    NaN  Passio sancti Sabae Gothi (sub auctore Athanar...    A.D. 4
# 4998    NaN  Passio sancti Sabae Gothi (sub auctore Athanar...    A.D. 4
# 4999    NaN  Passio sancti Sabae Gothi (sub auctore Athanar...    A.D. 4
# 5000    NaN  Passio sancti Sabae Gothi (sub auctore Athanar...    A.D. 4
# 5001    NaN  Passio sancti Sabae Gothi (sub auctore Athanar...    A.D. 4
#
#       not_before  not_after lagt_genre lagt_provenience grela_source  \
# 0            101      400.0   Hagiogr.        christian         lagt
# 1            101      400.0   Hagiogr.        christian         lagt
# 2            101      400.0   Hagiogr.        christian         lagt
# 3            101      400.0   Hagiogr.        christian         lagt
# 4            101      400.0   Hagiogr.        christian         lagt
# ...          ...        ...        ...              ...          ...
# 4997         301      400.0   Hagiogr.        christian         lagt
# 4998         301      400.0   Hagiogr.        christian         lagt
# 4999         301      400.0   Hagiogr.        christian         lagt
# 5000         301      400.0   Hagiogr.        christian         lagt
# 5001         301      400.0   Hagiogr.        christian         lagt
#
#      textsource                                            edition  \
# 0      exprecce  Rudolf Knopf, Ausgewählte Märtyrerakten, 3. ne...
# 1      exprecce  Rudolf Knopf, Ausgewählte Märtyrerakten, 3. ne...
# 2      exprecce  Rudolf Knopf, Ausgewählte Märtyrerakten, 3. ne...
# 3      exprecce  Rudolf Knopf, Ausgewählte Märtyrerakten, 3. ne...
# 4      exprecce  Rudolf Knopf, Ausgewählte Märtyrerakten, 3. ne...
# ...         ...                                                ...
# 4997   exprecce  Rudolf Knopf, Ausgewählte Märtyrerakten, 3. ne...
# 4998   exprecce  Rudolf Knopf, Ausgewählte Märtyrerakten, 3. ne...
# 4999   exprecce  Rudolf Knopf, Ausgewählte Märtyrerakten, 3. ne...
# 5000   exprecce  Rudolf Knopf, Ausgewählte Märtyrerakten, 3. ne...
# 5001   exprecce  Rudolf Knopf, Ausgewählte Märtyrerakten, 3. ne...
#
#                                            edition_link
# 0     https://archive.org/details/ausgewahltemarty00...
# 1     https://archive.org/details/ausgewahltemarty00...
# 2     https://archive.org/details/ausgewahltemarty00...
# 3     https://archive.org/details/ausgewahltemarty00...
# 4     https://archive.org/details/ausgewahltemarty00...
# ...                                                 ...
# 4997  https://archive.org/details/ausgewahltemarty00...
# 4998  https://archive.org/details/ausgewahltemarty00...
# 4999  https://archive.org/details/ausgewahltemarty00...
# 5000  https://archive.org/details/ausgewahltemarty00...
# 5001  https://archive.org/details/ausgewahltemarty00...
#
# [5002 rows x 19 columns]
