# %%
import pandas as pd

# %%
exprecce = pd.read_csv("../data/exprecce_v1.csv", sep=",")
exprecce
# Out:
#                                                 title          doc_id  \
# 0      The Letter of the Churches of Vienne and Lyons  tlg1352.tlg001
# 1             Martyrium Pionii presbyteri et sodalium  tlg2005.tlg001
# 2       Martyrium Agapae, Irenae, Chionae et sodalium  tlg2011.tlg001
# 3                             Testamentum xl martyrum  tlg2015.tlg001
# 4   Passio sancti Sabae Gothi (sub auctore Athanar...  tlg5451.tlg001
# 5                  Martyrium Potamiaenae et Basilidis  tlg2007.tlg001
# 6                                     Martyrium Dasii  tlg2010.tlg001
# 7                                   Martyrium Cononis  tlg2008.tlg001
# 8        Acta Justini et septem sodalium (recensio B)  tlg0384.tlg002
# 9                        Acta Eupli - RECENSIO GRAECA  tlg2012.tlg001
# 10   Martyrium sanctorum Carpi, Papyli et Agathonicae  tlg0390.tlg001
# 11                        Acta et martyrium Apollonii  tlg0304.tlg001
# ...
